# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_16HT_65102b_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 01:54:56 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454505    77.7 1437489  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65102
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L),   # filas
  makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Wed Nov 19 02:10:53 PM 2025 AUC 0.911842884934528
#
# [mbo] 49: num_leaves=3686; max_depth=21; min_child_weight=2.22; min_data_in_leaf=1363; min_gain_to_split=0.0288; lambda_l1=87.6; lambda_l2=207; scale_pos_weight=4.2; learning_rate=0.0821; num_iterations=2053; early_stopping_rounds=144; feature_fraction=0.235; bagging_fraction=0.957; bagging_freq=2; max_delta_step=6.4; path_smooth=4.46 : y = 0.912 : 54.9 secs : infill_ei
#
# Saved the current state after iteration 50 in the file HT.RDATA.
#
# Wed Nov 19 02:18:58 PM 2025 AUC 0.925603740246912
#
# [mbo] 50: num_leaves=4772; max_depth=11; min_child_weight=3.93; min_data_in_leaf=3356; min_gain_to_split=0.0816; lambda_l1=0.0974; lambda_l2=317; scale_pos_weight=3.63; learning_rate=0.0746; num_iterations=2490; early_stopping_rounds=339; feature_fraction=0.526; bagging_fraction=0.957; bagging_freq=1; max_delta_step=8.68; path_smooth=2.38 : y = 0.926 : 482.8 secs : infill_ei
#
# Wed Nov 19 02:22:28 PM 2025 AUC 0.923426134888056
#
# [mbo] 51: num_leaves=2661; max_depth=10; min_child_weight=3.11; min_data_in_leaf=1939; min_gain_to_split=0.0617; lambda_l1=3.03; lambda_l2=163; scale_pos_weight=3.14; learning_rate=0.0767; num_iterations=3832; early_stopping_rounds=204; feature_fraction=0.334; bagging_fraction=0.832; bagging_freq=1; max_delta_step=8.93; path_smooth=3.59 : y = 0.923 : 207.4 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Wed Nov 19 02:26:13 PM 2025 AUC 0.917780802043258
#
# [mbo] 52: num_leaves=5615; max_depth=16; min_child_weight=4.6; min_data_in_leaf=7058; min_gain_to_split=0.00921; lambda_l1=1.75; lambda_l2=275; scale_pos_weight=3.67; learning_rate=0.0634; num_iterations=3612; early_stopping_rounds=377; feature_fraction=0.814; bagging_fraction=0.886; bagging_freq=2; max_delta_step=7.42; path_smooth=4.99 : y = 0.918 : 220.8 secs : infill_ei
#
# Wed Nov 19 02:31:11 PM 2025 AUC 0.92212158486722
#
# [mbo] 53: num_leaves=6184; max_depth=10; min_child_weight=8.13; min_data_in_leaf=838; min_gain_to_split=0.0137; lambda_l1=28.6; lambda_l2=359; scale_pos_weight=3.52; learning_rate=0.0517; num_iterations=4246; early_stopping_rounds=214; feature_fraction=0.15; bagging_fraction=0.72; bagging_freq=2; max_delta_step=8.6; path_smooth=2.1 : y = 0.922 : 296.2 secs : infill_ei
#
# Wed Nov 19 02:36:11 PM 2025 AUC 0.922154802576084
#
# [mbo] 54: num_leaves=7454; max_depth=16; min_child_weight=3.35; min_data_in_leaf=1549; min_gain_to_split=0.0534; lambda_l1=21.7; lambda_l2=296; scale_pos_weight=3.59; learning_rate=0.0762; num_iterations=3905; early_stopping_rounds=375; feature_fraction=0.131; bagging_fraction=0.969; bagging_freq=3; max_delta_step=8.58; path_smooth=5.93 : y = 0.922 : 297.0 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Wed Nov 19 02:38:15 PM 2025 AUC 0.914264422357464
#
# [mbo] 55: num_leaves=7123; max_depth=9; min_child_weight=5.07; min_data_in_leaf=3945; min_gain_to_split=0.0267; lambda_l1=36.2; lambda_l2=257; scale_pos_weight=3.62; learning_rate=0.0756; num_iterations=2956; early_stopping_rounds=263; feature_fraction=0.272; bagging_fraction=0.782; bagging_freq=0; max_delta_step=8.05; path_smooth=5.26 : y = 0.914 : 121.5 secs : infill_ei
#
# Wed Nov 19 02:41:59 PM 2025 AUC 0.926692878458752
#
# [mbo] 56: num_leaves=1581; max_depth=10; min_child_weight=7.29; min_data_in_leaf=801; min_gain_to_split=0.0119; lambda_l1=0.0153; lambda_l2=158; scale_pos_weight=2.64; learning_rate=0.0417; num_iterations=3194; early_stopping_rounds=270; feature_fraction=0.674; bagging_fraction=0.943; bagging_freq=2; max_delta_step=9.43; path_smooth=9.84 : y = 0.927 : 219.2 secs : infill_ei
#
# Wed Nov 19 02:50:34 PM 2025 AUC 0.925226266282549
#
# [mbo] 57: num_leaves=1754; max_depth=24; min_child_weight=4.22; min_data_in_leaf=587; min_gain_to_split=0.0232; lambda_l1=0.874; lambda_l2=692; scale_pos_weight=2.73; learning_rate=0.0706; num_iterations=2701; early_stopping_rounds=357; feature_fraction=0.439; bagging_fraction=0.984; bagging_freq=4; max_delta_step=9.58; path_smooth=5.01 : y = 0.925 : 512.0 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Wed Nov 19 02:57:43 PM 2025 AUC 0.922061524565335
#
# [mbo] 58: num_leaves=1468; max_depth=28; min_child_weight=8.01; min_data_in_leaf=294; min_gain_to_split=0.0183; lambda_l1=6.9; lambda_l2=847; scale_pos_weight=3.07; learning_rate=0.0428; num_iterations=4569; early_stopping_rounds=146; feature_fraction=0.563; bagging_fraction=0.833; bagging_freq=2; max_delta_step=9.06; path_smooth=6.92 : y = 0.922 : 427.5 secs : infill_ei
#
# Wed Nov 19 03:01:57 PM 2025 AUC 0.926390228222437
#
# [mbo] 59: num_leaves=3379; max_depth=15; min_child_weight=7.71; min_data_in_leaf=110; min_gain_to_split=0.0317; lambda_l1=0.553; lambda_l2=60.1; scale_pos_weight=3.33; learning_rate=0.0678; num_iterations=2663; early_stopping_rounds=384; feature_fraction=0.556; bagging_fraction=0.976; bagging_freq=1; max_delta_step=5.99; path_smooth=3.57 : y = 0.926 : 249.7 secs : infill_ei
#
# Saved the current state after iteration 60 in the file HT.RDATA.
#
# Wed Nov 19 03:12:20 PM 2025 AUC 0.925224253088073
#
# [mbo] 60: num_leaves=3794; max_depth=19; min_child_weight=4.21; min_data_in_leaf=350; min_gain_to_split=0.0705; lambda_l1=1.27; lambda_l2=578; scale_pos_weight=3.7; learning_rate=0.0457; num_iterations=4113; early_stopping_rounds=363; feature_fraction=0.436; bagging_fraction=0.886; bagging_freq=2; max_delta_step=3.26; path_smooth=2.07 : y = 0.925 : 619.9 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Wed Nov 19 03:13:11 PM 2025 AUC 0.911177524160011
#
# [mbo] 61: num_leaves=4336; max_depth=10; min_child_weight=9.77; min_data_in_leaf=7612; min_gain_to_split=0.0313; lambda_l1=28.2; lambda_l2=41.3; scale_pos_weight=1.79; learning_rate=0.0375; num_iterations=446; early_stopping_rounds=451; feature_fraction=0.828; bagging_fraction=0.905; bagging_freq=3; max_delta_step=0.964; path_smooth=3.69 : y = 0.911 : 48.5 secs : infill_ei
#
# Wed Nov 19 03:19:02 PM 2025 AUC 0.927173025341421
#
# [mbo] 62: num_leaves=3995; max_depth=16; min_child_weight=8.11; min_data_in_leaf=68; min_gain_to_split=0.0708; lambda_l1=0.612; lambda_l2=315; scale_pos_weight=3.06; learning_rate=0.0372; num_iterations=1915; early_stopping_rounds=270; feature_fraction=0.755; bagging_fraction=0.97; bagging_freq=3; max_delta_step=9.84; path_smooth=6.42 : y = 0.927 : 347.9 secs : infill_ei
#
# Wed Nov 19 03:24:21 PM 2025 AUC 0.928683256731283
#
# [mbo] 63: num_leaves=1767; max_depth=10; min_child_weight=4.62; min_data_in_leaf=329; min_gain_to_split=0.064; lambda_l1=1.99; lambda_l2=104; scale_pos_weight=3.5; learning_rate=0.0496; num_iterations=1450; early_stopping_rounds=328; feature_fraction=0.547; bagging_fraction=0.921; bagging_freq=4; max_delta_step=7.92; path_smooth=2.76 : y = 0.929 : 315.8 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Wed Nov 19 03:28:16 PM 2025 AUC 0.920305347916914
#
# [mbo] 64: num_leaves=2792; max_depth=8; min_child_weight=7.6; min_data_in_leaf=323; min_gain_to_split=0.0306; lambda_l1=5.6; lambda_l2=428; scale_pos_weight=2.8; learning_rate=0.0392; num_iterations=1721; early_stopping_rounds=210; feature_fraction=0.268; bagging_fraction=0.72; bagging_freq=3; max_delta_step=6.67; path_smooth=5.54 : y = 0.92 : 229.9 secs : infill_ei
#
# Wed Nov 19 03:35:07 PM 2025 AUC 0.927062635177621
#
# [mbo] 65: num_leaves=1439; max_depth=16; min_child_weight=6.94; min_data_in_leaf=335; min_gain_to_split=0.0349; lambda_l1=0.336; lambda_l2=90.8; scale_pos_weight=2.97; learning_rate=0.0304; num_iterations=4343; early_stopping_rounds=332; feature_fraction=0.775; bagging_fraction=0.927; bagging_freq=4; max_delta_step=9.97; path_smooth=1.18 : y = 0.927 : 407.1 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Wed Nov 19 03:41:05 PM 2025 AUC 0.932839496728223
#
# [mbo] 66: num_leaves=6162; max_depth=23; min_child_weight=3.8; min_data_in_leaf=391; min_gain_to_split=0.0524; lambda_l1=1.11; lambda_l2=27.1; scale_pos_weight=3.14; learning_rate=0.0374; num_iterations=3417; early_stopping_rounds=446; feature_fraction=0.489; bagging_fraction=0.987; bagging_freq=4; max_delta_step=7.34; path_smooth=0.823 : y = 0.933 : 355.0 secs : infill_ei
#
# Wed Nov 19 03:49:45 PM 2025 AUC 0.925027295561779
#
# [mbo] 67: num_leaves=3642; max_depth=20; min_child_weight=5.95; min_data_in_leaf=885; min_gain_to_split=0.0537; lambda_l1=0.719; lambda_l2=199; scale_pos_weight=3.01; learning_rate=0.0184; num_iterations=2636; early_stopping_rounds=471; feature_fraction=0.459; bagging_fraction=0.891; bagging_freq=3; max_delta_step=8.33; path_smooth=2.63 : y = 0.925 : 516.6 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Wed Nov 19 03:51:22 PM 2025 AUC 0.92465519011602
#
# [mbo] 68: num_leaves=6517; max_depth=15; min_child_weight=7.71; min_data_in_leaf=1416; min_gain_to_split=0.0867; lambda_l1=1.73; lambda_l2=40.6; scale_pos_weight=3.6; learning_rate=0.0703; num_iterations=633; early_stopping_rounds=332; feature_fraction=0.665; bagging_fraction=0.679; bagging_freq=4; max_delta_step=3.5; path_smooth=5.79 : y = 0.925 : 93.3 secs : infill_ei
#
# Wed Nov 19 03:54:03 PM 2025 AUC 0.923772739870444
#
# [mbo] 69: num_leaves=5379; max_depth=20; min_child_weight=5.01; min_data_in_leaf=85; min_gain_to_split=0.0841; lambda_l1=2.73; lambda_l2=62.5; scale_pos_weight=3.36; learning_rate=0.0461; num_iterations=4136; early_stopping_rounds=343; feature_fraction=0.518; bagging_fraction=0.751; bagging_freq=5; max_delta_step=9.4; path_smooth=1.75 : y = 0.924 : 157.6 secs : infill_ei
#
# Wed Nov 19 03:57:02 PM 2025 AUC 0.924918583060042
#
# [mbo] 70: num_leaves=7117; max_depth=10; min_child_weight=8.63; min_data_in_leaf=216; min_gain_to_split=0.0639; lambda_l1=27.3; lambda_l2=177; scale_pos_weight=4.24; learning_rate=0.0485; num_iterations=1730; early_stopping_rounds=386; feature_fraction=0.708; bagging_fraction=0.966; bagging_freq=4; max_delta_step=7.83; path_smooth=2.75 : y = 0.925 : 175.2 secs : infill_ei
#
# Wed Nov 19 04:01:18 PM 2025 AUC 0.924605866851344
#
# [mbo] 71: num_leaves=5681; max_depth=28; min_child_weight=8.56; min_data_in_leaf=478; min_gain_to_split=0.0392; lambda_l1=2.98; lambda_l2=331; scale_pos_weight=3.76; learning_rate=0.0408; num_iterations=1612; early_stopping_rounds=174; feature_fraction=0.867; bagging_fraction=0.839; bagging_freq=4; max_delta_step=8.98; path_smooth=5.02 : y = 0.925 : 253.3 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Wed Nov 19 04:02:17 PM 2025 AUC 0.922140374682335
#
# [mbo] 72: num_leaves=6450; max_depth=13; min_child_weight=7.77; min_data_in_leaf=617; min_gain_to_split=0.0699; lambda_l1=2.51; lambda_l2=78.1; scale_pos_weight=3.4; learning_rate=0.0568; num_iterations=351; early_stopping_rounds=159; feature_fraction=0.246; bagging_fraction=0.909; bagging_freq=3; max_delta_step=7.44; path_smooth=0.161 : y = 0.922 : 54.9 secs : infill_ei
#
# Wed Nov 19 04:14:16 PM 2025 AUC 0.927000897213672
#
# [mbo] 73: num_leaves=6191; max_depth=14; min_child_weight=8.94; min_data_in_leaf=686; min_gain_to_split=0.0172; lambda_l1=0.139; lambda_l2=453; scale_pos_weight=3.17; learning_rate=0.0413; num_iterations=4259; early_stopping_rounds=362; feature_fraction=0.592; bagging_fraction=0.997; bagging_freq=5; max_delta_step=8.83; path_smooth=2.46 : y = 0.927 : 715.3 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Wed Nov 19 04:17:11 PM 2025 AUC 0.921323017724835
#
# [mbo] 74: num_leaves=4265; max_depth=22; min_child_weight=3.97; min_data_in_leaf=402; min_gain_to_split=0.0338; lambda_l1=15.7; lambda_l2=152; scale_pos_weight=3.01; learning_rate=0.0438; num_iterations=3947; early_stopping_rounds=170; feature_fraction=0.944; bagging_fraction=0.997; bagging_freq=4; max_delta_step=4.11; path_smooth=4.73 : y = 0.921 : 171.7 secs : infill_ei
#
# Wed Nov 19 04:19:12 PM 2025 AUC 0.92096097825146
#
# [mbo] 75: num_leaves=4678; max_depth=11; min_child_weight=8.45; min_data_in_leaf=221; min_gain_to_split=0.0577; lambda_l1=0.411; lambda_l2=656; scale_pos_weight=3.8; learning_rate=0.0813; num_iterations=905; early_stopping_rounds=391; feature_fraction=0.856; bagging_fraction=0.635; bagging_freq=2; max_delta_step=9.8; path_smooth=1.19 : y = 0.921 : 116.9 secs : infill_ei
#
# Wed Nov 19 04:20:16 PM 2025 AUC 0.915855852591216
#
# [mbo] 76: num_leaves=6341; max_depth=7; min_child_weight=6.58; min_data_in_leaf=6070; min_gain_to_split=0.0782; lambda_l1=2.05; lambda_l2=61.7; scale_pos_weight=3.72; learning_rate=0.04; num_iterations=593; early_stopping_rounds=424; feature_fraction=0.708; bagging_fraction=0.797; bagging_freq=4; max_delta_step=6.37; path_smooth=2.2 : y = 0.916 : 59.2 secs : infill_ei
#
# Wed Nov 19 04:23:09 PM 2025 AUC 0.926802262025314
#
# [mbo] 77: num_leaves=6421; max_depth=10; min_child_weight=3.27; min_data_in_leaf=294; min_gain_to_split=0.043; lambda_l1=5.78; lambda_l2=94.2; scale_pos_weight=3.47; learning_rate=0.0509; num_iterations=1720; early_stopping_rounds=406; feature_fraction=0.691; bagging_fraction=0.989; bagging_freq=3; max_delta_step=0.586; path_smooth=3.44 : y = 0.927 : 171.8 secs : infill_ei
#
# Wed Nov 19 04:28:20 PM 2025 AUC 0.926512697553096
#
# [mbo] 78: num_leaves=8048; max_depth=25; min_child_weight=8.54; min_data_in_leaf=412; min_gain_to_split=0.00688; lambda_l1=1.32; lambda_l2=46.7; scale_pos_weight=3.89; learning_rate=0.0357; num_iterations=2374; early_stopping_rounds=435; feature_fraction=0.538; bagging_fraction=0.658; bagging_freq=3; max_delta_step=2.12; path_smooth=3.01 : y = 0.927 : 306.8 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Wed Nov 19 04:33:13 PM 2025 AUC 0.922369878852667
#
# [mbo] 79: num_leaves=6536; max_depth=18; min_child_weight=5.29; min_data_in_leaf=88; min_gain_to_split=0.0451; lambda_l1=27.8; lambda_l2=54.8; scale_pos_weight=3.68; learning_rate=0.0214; num_iterations=3518; early_stopping_rounds=284; feature_fraction=0.125; bagging_fraction=0.967; bagging_freq=4; max_delta_step=5.68; path_smooth=4.14 : y = 0.922 : 289.5 secs : infill_ei
#
# Wed Nov 19 04:35:04 PM 2025 AUC 0.921294833002163
#
# [mbo] 80: num_leaves=6679; max_depth=19; min_child_weight=6.87; min_data_in_leaf=1212; min_gain_to_split=0.0636; lambda_l1=4.76; lambda_l2=19; scale_pos_weight=4.66; learning_rate=0.0634; num_iterations=1821; early_stopping_rounds=274; feature_fraction=0.938; bagging_fraction=0.615; bagging_freq=1; max_delta_step=2.86; path_smooth=6.2 : y = 0.921 : 108.5 secs : infill_ei
#
# Wed Nov 19 04:39:13 PM 2025 AUC 0.923500958616103
#
# [mbo] 81: num_leaves=7259; max_depth=30; min_child_weight=2.93; min_data_in_leaf=2573; min_gain_to_split=0.0499; lambda_l1=0.718; lambda_l2=201; scale_pos_weight=3.29; learning_rate=0.0679; num_iterations=1255; early_stopping_rounds=398; feature_fraction=0.536; bagging_fraction=0.854; bagging_freq=4; max_delta_step=9.27; path_smooth=0.525 : y = 0.924 : 245.1 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Wed Nov 19 04:43:49 PM 2025 AUC 0.923809648435849
#
# [mbo] 82: num_leaves=5579; max_depth=14; min_child_weight=7.06; min_data_in_leaf=112; min_gain_to_split=0.0103; lambda_l1=7.05; lambda_l2=89; scale_pos_weight=4.42; learning_rate=0.0498; num_iterations=4229; early_stopping_rounds=397; feature_fraction=0.608; bagging_fraction=0.568; bagging_freq=3; max_delta_step=9.72; path_smooth=7.06 : y = 0.924 : 272.2 secs : infill_ei
#
# Wed Nov 19 04:48:11 PM 2025 AUC 0.930802143917905
#
# [mbo] 83: num_leaves=6424; max_depth=27; min_child_weight=9.1; min_data_in_leaf=384; min_gain_to_split=0.0127; lambda_l1=0.942; lambda_l2=34.6; scale_pos_weight=2.34; learning_rate=0.036; num_iterations=2143; early_stopping_rounds=420; feature_fraction=0.321; bagging_fraction=0.931; bagging_freq=4; max_delta_step=3.96; path_smooth=1.74 : y = 0.931 : 257.8 secs : infill_ei
#
# Wed Nov 19 04:52:41 PM 2025 AUC 0.932944853905832
#
# [mbo] 84: num_leaves=5814; max_depth=30; min_child_weight=6.73; min_data_in_leaf=552; min_gain_to_split=0.0506; lambda_l1=0.417; lambda_l2=10.1; scale_pos_weight=2.23; learning_rate=0.0324; num_iterations=3501; early_stopping_rounds=343; feature_fraction=0.456; bagging_fraction=0.916; bagging_freq=2; max_delta_step=9.1; path_smooth=6.39 : y = 0.933 : 266.4 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Wed Nov 19 05:00:04 PM 2025 AUC 0.920721072576332
#
# [mbo] 85: num_leaves=5233; max_depth=27; min_child_weight=8.01; min_data_in_leaf=2905; min_gain_to_split=0.0226; lambda_l1=3.19; lambda_l2=295; scale_pos_weight=2.5; learning_rate=0.0279; num_iterations=3599; early_stopping_rounds=331; feature_fraction=0.219; bagging_fraction=0.858; bagging_freq=3; max_delta_step=9.61; path_smooth=5.31 : y = 0.921 : 438.4 secs : infill_ei
#
# Wed Nov 19 05:03:23 PM 2025 AUC 0.924045192189611
#
# [mbo] 86: num_leaves=6223; max_depth=26; min_child_weight=3.57; min_data_in_leaf=3; min_gain_to_split=0.0422; lambda_l1=0.0152; lambda_l2=306; scale_pos_weight=2.35; learning_rate=0.0905; num_iterations=2548; early_stopping_rounds=246; feature_fraction=0.772; bagging_fraction=0.766; bagging_freq=2; max_delta_step=3.33; path_smooth=0.204 : y = 0.924 : 195.3 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Wed Nov 19 05:05:08 PM 2025 AUC 0.929685492048217
#
# [mbo] 87: num_leaves=6767; max_depth=16; min_child_weight=6.04; min_data_in_leaf=269; min_gain_to_split=0.0765; lambda_l1=2.37; lambda_l2=34; scale_pos_weight=2.27; learning_rate=0.0782; num_iterations=545; early_stopping_rounds=227; feature_fraction=0.361; bagging_fraction=0.911; bagging_freq=2; max_delta_step=6.62; path_smooth=6.28 : y = 0.93 : 101.3 secs : infill_ei
#
# Wed Nov 19 05:08:31 PM 2025 AUC 0.9283893303377
#
# [mbo] 88: num_leaves=7290; max_depth=26; min_child_weight=4.15; min_data_in_leaf=211; min_gain_to_split=0.0197; lambda_l1=0.571; lambda_l2=40.3; scale_pos_weight=2.4; learning_rate=0.0433; num_iterations=1005; early_stopping_rounds=381; feature_fraction=0.805; bagging_fraction=0.929; bagging_freq=1; max_delta_step=1.76; path_smooth=4.57 : y = 0.928 : 199.0 secs : infill_ei
#
# Wed Nov 19 05:15:29 PM 2025 AUC 0.926971034828936
#
# [mbo] 89: num_leaves=5699; max_depth=26; min_child_weight=8.93; min_data_in_leaf=2; min_gain_to_split=0.0263; lambda_l1=1.04; lambda_l2=165; scale_pos_weight=2.04; learning_rate=0.0663; num_iterations=4542; early_stopping_rounds=421; feature_fraction=0.484; bagging_fraction=0.896; bagging_freq=1; max_delta_step=5.26; path_smooth=9.38 : y = 0.927 : 414.3 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Wed Nov 19 05:19:38 PM 2025 AUC 0.925313169177456
#
# [mbo] 90: num_leaves=6879; max_depth=23; min_child_weight=6.44; min_data_in_leaf=33; min_gain_to_split=0.0369; lambda_l1=0.097; lambda_l2=74.1; scale_pos_weight=2.64; learning_rate=0.0507; num_iterations=3306; early_stopping_rounds=444; feature_fraction=0.562; bagging_fraction=0.578; bagging_freq=2; max_delta_step=3.04; path_smooth=4.43 : y = 0.925 : 246.5 secs : infill_ei
#
# Wed Nov 19 05:21:52 PM 2025 AUC 0.931868465925677
#
# [mbo] 91: num_leaves=5545; max_depth=22; min_child_weight=2.12; min_data_in_leaf=828; min_gain_to_split=0.0531; lambda_l1=1.52; lambda_l2=50.4; scale_pos_weight=2.15; learning_rate=0.062; num_iterations=1887; early_stopping_rounds=442; feature_fraction=0.242; bagging_fraction=0.953; bagging_freq=2; max_delta_step=2.88; path_smooth=5.27 : y = 0.932 : 129.9 secs : infill_ei
#
# Wed Nov 19 05:24:48 PM 2025 AUC 0.926536520354403
#
# [mbo] 92: num_leaves=6196; max_depth=26; min_child_weight=6.01; min_data_in_leaf=320; min_gain_to_split=0.0904; lambda_l1=0.0341; lambda_l2=87.4; scale_pos_weight=2.02; learning_rate=0.0439; num_iterations=1053; early_stopping_rounds=451; feature_fraction=0.741; bagging_fraction=0.956; bagging_freq=2; max_delta_step=5.91; path_smooth=3.23 : y = 0.927 : 172.8 secs : infill_ei
#
# Wed Nov 19 05:27:20 PM 2025 AUC 0.929382506279489
#
# [mbo] 93: num_leaves=5733; max_depth=18; min_child_weight=5.99; min_data_in_leaf=106; min_gain_to_split=0.0236; lambda_l1=0.74; lambda_l2=9.38; scale_pos_weight=2.38; learning_rate=0.0792; num_iterations=2106; early_stopping_rounds=292; feature_fraction=0.412; bagging_fraction=0.998; bagging_freq=3; max_delta_step=3.2; path_smooth=8.73 : y = 0.929 : 147.4 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Wed Nov 19 05:33:03 PM 2025 AUC 0.925876863630904
#
# [mbo] 94: num_leaves=8074; max_depth=9; min_child_weight=2.49; min_data_in_leaf=3094; min_gain_to_split=0.00953; lambda_l1=1.26; lambda_l2=38.2; scale_pos_weight=2.24; learning_rate=0.0503; num_iterations=3348; early_stopping_rounds=471; feature_fraction=0.832; bagging_fraction=0.908; bagging_freq=3; max_delta_step=6.19; path_smooth=0.183 : y = 0.926 : 337.6 secs : infill_ei
#
# Wed Nov 19 05:35:32 PM 2025 AUC 0.930943738596092
#
# [mbo] 95: num_leaves=7198; max_depth=11; min_child_weight=1.07; min_data_in_leaf=126; min_gain_to_split=0.049; lambda_l1=1.78; lambda_l2=19.2; scale_pos_weight=2.3; learning_rate=0.0534; num_iterations=3217; early_stopping_rounds=264; feature_fraction=0.558; bagging_fraction=0.978; bagging_freq=2; max_delta_step=7.68; path_smooth=5.55 : y = 0.931 : 145.8 secs : infill_ei
#
# Wed Nov 19 05:40:16 PM 2025 AUC 0.923371107572363
#
# [mbo] 96: num_leaves=7892; max_depth=23; min_child_weight=4.91; min_data_in_leaf=87; min_gain_to_split=0.0429; lambda_l1=1.7; lambda_l2=414; scale_pos_weight=2.25; learning_rate=0.0424; num_iterations=1399; early_stopping_rounds=496; feature_fraction=0.488; bagging_fraction=0.987; bagging_freq=4; max_delta_step=3.99; path_smooth=9.43 : y = 0.923 : 280.1 secs : infill_ei
#
# Saved the current state after iteration 97 in the file HT.RDATA.
#
# Wed Nov 19 05:47:27 PM 2025 AUC 0.927501176041107
#
# [mbo] 97: num_leaves=6255; max_depth=12; min_child_weight=8.29; min_data_in_leaf=1056; min_gain_to_split=0.086; lambda_l1=0.576; lambda_l2=134; scale_pos_weight=2.42; learning_rate=0.052; num_iterations=2535; early_stopping_rounds=388; feature_fraction=0.529; bagging_fraction=0.965; bagging_freq=1; max_delta_step=6.89; path_smooth=5.29 : y = 0.928 : 426.0 secs : infill_ei
#
# Wed Nov 19 05:52:56 PM 2025 AUC 0.923167439397813
#
# [mbo] 98: num_leaves=6463; max_depth=29; min_child_weight=4.62; min_data_in_leaf=4758; min_gain_to_split=0.0154; lambda_l1=0.785; lambda_l2=166; scale_pos_weight=1.93; learning_rate=0.0674; num_iterations=2976; early_stopping_rounds=270; feature_fraction=0.759; bagging_fraction=0.969; bagging_freq=2; max_delta_step=7.42; path_smooth=4.94 : y = 0.923 : 324.8 secs : infill_ei
#
# Saved the current state after iteration 99 in the file HT.RDATA.
#
# Wed Nov 19 06:01:22 PM 2025 AUC 0.924149207237568
#
# [mbo] 99: num_leaves=1186; max_depth=13; min_child_weight=3.9; min_data_in_leaf=301; min_gain_to_split=0.0576; lambda_l1=0.249; lambda_l2=450; scale_pos_weight=1.9; learning_rate=0.0321; num_iterations=4596; early_stopping_rounds=369; feature_fraction=0.71; bagging_fraction=0.952; bagging_freq=2; max_delta_step=9.97; path_smooth=8.78 : y = 0.924 : 500.4 secs : infill_ei
#
# Wed Nov 19 06:12:38 PM 2025 AUC 0.923913999016219
#
# [mbo] 100: num_leaves=1847; max_depth=30; min_child_weight=1.93; min_data_in_leaf=15; min_gain_to_split=0.0689; lambda_l1=0.21; lambda_l2=360; scale_pos_weight=1.96; learning_rate=0.018; num_iterations=4110; early_stopping_rounds=127; feature_fraction=0.767; bagging_fraction=0.726; bagging_freq=0; max_delta_step=3.49; path_smooth=6.32 : y = 0.924 : 671.2 secs : infill_ei
#
# Saved the current state after iteration 101 in the file HT.RDATA.
#
# Wed Nov 19 06:13:07 PM 2025 AUC 0.885169064716821
#
# [mbo] 101: num_leaves=385; max_depth=24; min_child_weight=1.6; min_data_in_leaf=6846; min_gain_to_split=0.0325; lambda_l1=982; lambda_l2=699; scale_pos_weight=3.2; learning_rate=0.0691; num_iterations=4187; early_stopping_rounds=254; feature_fraction=0.129; bagging_fraction=0.821; bagging_freq=0; max_delta_step=8.93; path_smooth=9.87 : y = 0.885 : 26.0 secs : infill_ei
#
# Wed Nov 19 06:19:04 PM 2025 AUC 0.926936474990421
#
# [mbo] 102: num_leaves=4882; max_depth=30; min_child_weight=4.43; min_data_in_leaf=93; min_gain_to_split=0.063; lambda_l1=0.24; lambda_l2=392; scale_pos_weight=4.14; learning_rate=0.0394; num_iterations=3826; early_stopping_rounds=303; feature_fraction=0.67; bagging_fraction=0.745; bagging_freq=0; max_delta_step=9.8; path_smooth=8.26 : y = 0.927 : 353.0 secs : infill_ei
#
# Wed Nov 19 06:24:11 PM 2025 AUC 0.929384183941553
#
# [mbo] 103: num_leaves=2646; max_depth=29; min_child_weight=5.84; min_data_in_leaf=321; min_gain_to_split=0.00939; lambda_l1=0.292; lambda_l2=56.8; scale_pos_weight=2.11; learning_rate=0.0494; num_iterations=4198; early_stopping_rounds=452; feature_fraction=0.478; bagging_fraction=0.984; bagging_freq=2; max_delta_step=1.98; path_smooth=3.19 : y = 0.929 : 302.2 secs : infill_ei
#
# Saved the current state after iteration 104 in the file HT.RDATA.
#
# Wed Nov 19 06:27:38 PM 2025 AUC 0.935570395035731
#
# [mbo] 104: num_leaves=7499; max_depth=28; min_child_weight=2.23; min_data_in_leaf=539; min_gain_to_split=0.0555; lambda_l1=0.719; lambda_l2=8.1; scale_pos_weight=2.43; learning_rate=0.0405; num_iterations=3594; early_stopping_rounds=383; feature_fraction=0.748; bagging_fraction=0.969; bagging_freq=2; max_delta_step=3.97; path_smooth=0.168 : y = 0.936 : 202.3 secs : infill_ei
#
# Wed Nov 19 06:31:31 PM 2025 AUC 0.930848782923279
#
# [mbo] 105: num_leaves=6943; max_depth=18; min_child_weight=5.78; min_data_in_leaf=260; min_gain_to_split=0.0834; lambda_l1=0.429; lambda_l2=46.5; scale_pos_weight=3.9; learning_rate=0.0488; num_iterations=2125; early_stopping_rounds=473; feature_fraction=0.741; bagging_fraction=0.862; bagging_freq=1; max_delta_step=7.26; path_smooth=9.74 : y = 0.931 : 227.9 secs : infill_ei
#
# Wed Nov 19 06:34:11 PM 2025 AUC 0.931102780959744
#
# [mbo] 106: num_leaves=3355; max_depth=29; min_child_weight=2.79; min_data_in_leaf=323; min_gain_to_split=0.0599; lambda_l1=1.29; lambda_l2=28; scale_pos_weight=2.44; learning_rate=0.0644; num_iterations=4878; early_stopping_rounds=378; feature_fraction=0.659; bagging_fraction=0.983; bagging_freq=1; max_delta_step=8.13; path_smooth=6.15 : y = 0.931 : 155.1 secs : infill_ei
#
# Saved the current state after iteration 107 in the file HT.RDATA.
#
# Wed Nov 19 06:42:32 PM 2025 AUC 0.929687505242694
#
# [mbo] 107: num_leaves=6812; max_depth=23; min_child_weight=2.5; min_data_in_leaf=546; min_gain_to_split=0.012; lambda_l1=0.529; lambda_l2=37.9; scale_pos_weight=2.18; learning_rate=0.024; num_iterations=4975; early_stopping_rounds=307; feature_fraction=0.37; bagging_fraction=0.897; bagging_freq=2; max_delta_step=3.32; path_smooth=5.63 : y = 0.93 : 496.9 secs : infill_ei
#
# Wed Nov 19 06:50:13 PM 2025 AUC 0.924569964883178
#
# [mbo] 108: num_leaves=6596; max_depth=23; min_child_weight=9.34; min_data_in_leaf=740; min_gain_to_split=0.0927; lambda_l1=0.437; lambda_l2=646; scale_pos_weight=4.41; learning_rate=0.0768; num_iterations=3659; early_stopping_rounds=423; feature_fraction=0.685; bagging_fraction=0.832; bagging_freq=2; max_delta_step=9.4; path_smooth=9.38 : y = 0.925 : 456.3 secs : infill_ei
#
# Saved the current state after iteration 109 in the file HT.RDATA.
#
# Wed Nov 19 06:55:05 PM 2025 AUC 0.923066779673983
#
# [mbo] 109: num_leaves=7028; max_depth=29; min_child_weight=1.89; min_data_in_leaf=120; min_gain_to_split=0.0875; lambda_l1=0.00872; lambda_l2=629; scale_pos_weight=2.26; learning_rate=0.0538; num_iterations=4549; early_stopping_rounds=82; feature_fraction=0.791; bagging_fraction=0.919; bagging_freq=1; max_delta_step=9.02; path_smooth=9.12 : y = 0.923 : 288.1 secs : infill_ei
#
# Wed Nov 19 06:57:43 PM 2025 AUC 0.92368617250795
#
# [mbo] 110: num_leaves=7337; max_depth=25; min_child_weight=5.73; min_data_in_leaf=33; min_gain_to_split=0.0133; lambda_l1=0.57; lambda_l2=791; scale_pos_weight=4.32; learning_rate=0.0605; num_iterations=994; early_stopping_rounds=390; feature_fraction=0.679; bagging_fraction=0.836; bagging_freq=2; max_delta_step=4.63; path_smooth=7.79 : y = 0.924 : 152.9 secs : infill_ei
#
# Wed Nov 19 06:59:31 PM 2025 AUC 0.928037356836708
#
# [mbo] 111: num_leaves=258; max_depth=27; min_child_weight=1.17; min_data_in_leaf=213; min_gain_to_split=0.0714; lambda_l1=1.03; lambda_l2=80.2; scale_pos_weight=2.21; learning_rate=0.0557; num_iterations=688; early_stopping_rounds=115; feature_fraction=0.885; bagging_fraction=0.94; bagging_freq=2; max_delta_step=9.6; path_smooth=3.36 : y = 0.928 : 103.2 secs : infill_ei
#
# Wed Nov 19 07:03:10 PM 2025 AUC 0.923754956652568
#
# [mbo] 112: num_leaves=6579; max_depth=16; min_child_weight=9.98; min_data_in_leaf=846; min_gain_to_split=0.000575; lambda_l1=1.18; lambda_l2=476; scale_pos_weight=4.1; learning_rate=0.0478; num_iterations=2046; early_stopping_rounds=296; feature_fraction=0.745; bagging_fraction=0.626; bagging_freq=1; max_delta_step=8.92; path_smooth=8.68 : y = 0.924 : 213.8 secs : infill_ei
#
# Saved the current state after iteration 113 in the file HT.RDATA.
#
# Wed Nov 19 07:06:15 PM 2025 AUC 0.9250383681314
#
# [mbo] 113: num_leaves=700; max_depth=12; min_child_weight=9.53; min_data_in_leaf=23; min_gain_to_split=0.0948; lambda_l1=0.336; lambda_l2=356; scale_pos_weight=3.86; learning_rate=0.0623; num_iterations=4901; early_stopping_rounds=437; feature_fraction=0.792; bagging_fraction=0.96; bagging_freq=1; max_delta_step=9.89; path_smooth=9.13 : y = 0.925 : 179.5 secs : infill_ei
#
# Wed Nov 19 07:07:11 PM 2025 AUC 0.933186772775437
#
# [mbo] 114: num_leaves=6936; max_depth=16; min_child_weight=3.05; min_data_in_leaf=4; min_gain_to_split=0.0266; lambda_l1=1.92; lambda_l2=2.82; scale_pos_weight=2.4; learning_rate=0.0907; num_iterations=229; early_stopping_rounds=474; feature_fraction=0.496; bagging_fraction=0.998; bagging_freq=2; max_delta_step=8.63; path_smooth=0.541 : y = 0.933 : 51.9 secs : infill_ei
#
# Wed Nov 19 07:10:27 PM 2025 AUC 0.928016553827116
#
# [mbo] 115: num_leaves=3300; max_depth=25; min_child_weight=0.512; min_data_in_leaf=100; min_gain_to_split=0.0424; lambda_l1=1.45; lambda_l2=3.81; scale_pos_weight=1.68; learning_rate=0.0302; num_iterations=2510; early_stopping_rounds=457; feature_fraction=0.612; bagging_fraction=0.782; bagging_freq=2; max_delta_step=7.78; path_smooth=2.31 : y = 0.928 : 192.0 secs : infill_ei
#
# Wed Nov 19 07:13:38 PM 2025 AUC 0.92151762652424
#
# [mbo] 116: num_leaves=7455; max_depth=30; min_child_weight=1.29; min_data_in_leaf=394; min_gain_to_split=0.0933; lambda_l1=0.391; lambda_l2=709; scale_pos_weight=3.92; learning_rate=0.0689; num_iterations=1733; early_stopping_rounds=481; feature_fraction=0.859; bagging_fraction=0.562; bagging_freq=1; max_delta_step=0.846; path_smooth=5.56 : y = 0.922 : 186.7 secs : infill_ei
#
# Saved the current state after iteration 117 in the file HT.RDATA.
#
# Wed Nov 19 07:17:02 PM 2025 AUC 0.920205023725497
#
# [mbo] 117: num_leaves=5578; max_depth=18; min_child_weight=1.31; min_data_in_leaf=4139; min_gain_to_split=0.0629; lambda_l1=1.07; lambda_l2=186; scale_pos_weight=2.43; learning_rate=0.052; num_iterations=1157; early_stopping_rounds=277; feature_fraction=0.505; bagging_fraction=0.956; bagging_freq=3; max_delta_step=5.78; path_smooth=0.527 : y = 0.92 : 199.3 secs : infill_ei
#
# Wed Nov 19 07:19:30 PM 2025 AUC 0.914033576057481
#
# [mbo] 118: num_leaves=6778; max_depth=27; min_child_weight=6.76; min_data_in_leaf=796; min_gain_to_split=0.0334; lambda_l1=43; lambda_l2=336; scale_pos_weight=4.25; learning_rate=0.041; num_iterations=4838; early_stopping_rounds=486; feature_fraction=0.923; bagging_fraction=0.726; bagging_freq=0; max_delta_step=0.742; path_smooth=1.25 : y = 0.914 : 142.3 secs : infill_ei
#
# Wed Nov 19 07:23:38 PM 2025 AUC 0.925446040012911
#
# [mbo] 119: num_leaves=364; max_depth=25; min_child_weight=3.89; min_data_in_leaf=533; min_gain_to_split=0.0918; lambda_l1=0.957; lambda_l2=655; scale_pos_weight=4.18; learning_rate=0.0576; num_iterations=1757; early_stopping_rounds=336; feature_fraction=0.771; bagging_fraction=0.885; bagging_freq=1; max_delta_step=2.55; path_smooth=9.32 : y = 0.925 : 243.7 secs : infill_ei
#
# Wed Nov 19 07:25:17 PM 2025 AUC 0.926443577876066
#
# [mbo] 120: num_leaves=1509; max_depth=29; min_child_weight=2.81; min_data_in_leaf=55; min_gain_to_split=0.0631; lambda_l1=0.183; lambda_l2=48.2; scale_pos_weight=3.7; learning_rate=0.0669; num_iterations=3932; early_stopping_rounds=274; feature_fraction=0.92; bagging_fraction=0.597; bagging_freq=1; max_delta_step=6.73; path_smooth=9.35 : y = 0.926 : 93.5 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:       7499        28         2.225627              539        0.05553158
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.7188949  8.101833          2.42853    0.04050197           3594
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   383         0.747837        0.9688092            2
#    max_delta_step path_smooth
#             <num>       <num>
# 1:        3.97094   0.1675568

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5988600
#
# $envios
# [1] 1856

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_2020668061
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Wed Nov 19 07:31:23 PM 2025"
# Inicio: Wed Nov 19 01:54:56 PM 2025
# Fin:    Wed Nov 19 07:31:23 PM 2025
# Duración (hh:mm:ss): 05:36:27
