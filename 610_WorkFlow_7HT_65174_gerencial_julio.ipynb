# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_7HT_65174_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Nov 22 02:45:53 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454505    77.7 1437487  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65174 # 7HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 70

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  #makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L)   # columnas
  #makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Nov 22 03:00:47 AM 2025 AUC 0.909596159898642
#
# Sat Nov 22 03:04:47 AM 2025 AUC 0.9154270421677
#
# Sat Nov 22 03:09:37 AM 2025 AUC 0.914388233817775
#
# Sat Nov 22 03:16:07 AM 2025 AUC 0.919159504727316
#
# Sat Nov 22 03:20:15 AM 2025 AUC 0.916585300056571
#
# Sat Nov 22 03:25:51 AM 2025 AUC 0.922013878962722
#
# Sat Nov 22 03:30:00 AM 2025 AUC 0.926843532512084
#
# Sat Nov 22 03:33:38 AM 2025 AUC 0.920858640865566
#
# Sat Nov 22 03:34:46 AM 2025 AUC 0.91166001976957
#
# Sat Nov 22 03:38:04 AM 2025 AUC 0.919478596051857
#
# Sat Nov 22 03:49:49 AM 2025 AUC 0.915846457683659
#
# Sat Nov 22 03:50:26 AM 2025 AUC 0.904031019300495
#
# Sat Nov 22 03:53:31 AM 2025 AUC 0.914106386591051
#
# Sat Nov 22 03:55:05 AM 2025 AUC 0.923042956872677
#
# Sat Nov 22 03:57:50 AM 2025 AUC 0.913366873153313
#
# Sat Nov 22 03:58:17 AM 2025 AUC 0.895778431842294
#
# Sat Nov 22 04:00:41 AM 2025 AUC 0.900585436953795
#
# Sat Nov 22 04:04:14 AM 2025 AUC 0.916352776094523
#
# Sat Nov 22 04:10:13 AM 2025 AUC 0.92260911346297
#
# Sat Nov 22 04:18:38 AM 2025 AUC 0.919757087954453
#
# Sat Nov 22 04:19:31 AM 2025 AUC 0.91109364105682
#
# Sat Nov 22 04:23:37 AM 2025 AUC 0.92532457727949
#
# Sat Nov 22 04:30:55 AM 2025 AUC 0.926284199980002
#
# Sat Nov 22 04:39:13 AM 2025 AUC 0.918613929024158
#
# Sat Nov 22 04:48:29 AM 2025 AUC 0.921943752688453
#
# Sat Nov 22 04:51:56 AM 2025 AUC 0.914999573873836
#
# Sat Nov 22 04:59:40 AM 2025 AUC 0.918012990472893
#
# Sat Nov 22 05:01:33 AM 2025 AUC 0.911995216649924
#
# [mbo] 0: num_leaves=2166; min_data_in_leaf=6686; lambda_l2=638; learning_rate=0.0181; num_iterations=1632; early_stopping_rounds=265; feature_fraction=0.771 : y = 0.91 : 147.3 secs : initdesign
#
# [mbo] 0: num_leaves=3613; min_data_in_leaf=4390; lambda_l2=957; learning_rate=0.0753; num_iterations=2246; early_stopping_rounds=299; feature_fraction=0.706 : y = 0.915 : 240.0 secs : initdesign
#
# [mbo] 0: num_leaves=4159; min_data_in_leaf=6090; lambda_l2=438; learning_rate=0.0508; num_iterations=1872; early_stopping_rounds=120; feature_fraction=0.477 : y = 0.914 : 289.6 secs : initdesign
#
# [mbo] 0: num_leaves=4992; min_data_in_leaf=1897; lambda_l2=428; learning_rate=0.0392; num_iterations=3093; early_stopping_rounds=343; feature_fraction=0.819 : y = 0.919 : 390.0 secs : initdesign
#
# [mbo] 0: num_leaves=3857; min_data_in_leaf=6202; lambda_l2=304; learning_rate=0.0648; num_iterations=3533; early_stopping_rounds=314; feature_fraction=0.344 : y = 0.917 : 247.9 secs : initdesign
#
# [mbo] 0: num_leaves=6402; min_data_in_leaf=1534; lambda_l2=534; learning_rate=0.054; num_iterations=2744; early_stopping_rounds=291; feature_fraction=0.271 : y = 0.922 : 336.4 secs : initdesign
#
# [mbo] 0: num_leaves=706; min_data_in_leaf=4368; lambda_l2=25.3; learning_rate=0.0328; num_iterations=3396; early_stopping_rounds=333; feature_fraction=0.631 : y = 0.927 : 248.9 secs : initdesign
#
# [mbo] 0: num_leaves=2819; min_data_in_leaf=3093; lambda_l2=382; learning_rate=0.0848; num_iterations=3633; early_stopping_rounds=162; feature_fraction=0.152 : y = 0.921 : 217.6 secs : initdesign
#
# [mbo] 0: num_leaves=3268; min_data_in_leaf=7782; lambda_l2=822; learning_rate=0.0882; num_iterations=746; early_stopping_rounds=211; feature_fraction=0.924 : y = 0.912 : 68.6 secs : initdesign
#
# [mbo] 0: num_leaves=3101; min_data_in_leaf=5019; lambda_l2=720; learning_rate=0.0695; num_iterations=2697; early_stopping_rounds=415; feature_fraction=0.0723 : y = 0.919 : 197.4 secs : initdesign
#
# [mbo] 0: num_leaves=6643; min_data_in_leaf=3248; lambda_l2=283; learning_rate=0.0138; num_iterations=4169; early_stopping_rounds=467; feature_fraction=0.538 : y = 0.916 : 705.0 secs : initdesign
#
# [mbo] 0: num_leaves=5660; min_data_in_leaf=445; lambda_l2=673; learning_rate=0.0277; num_iterations=338; early_stopping_rounds=395; feature_fraction=0.748 : y = 0.904 : 37.2 secs : initdesign
#
# [mbo] 0: num_leaves=1075; min_data_in_leaf=5602; lambda_l2=492; learning_rate=0.0618; num_iterations=2042; early_stopping_rounds=362; feature_fraction=0.853 : y = 0.914 : 185.5 secs : initdesign
#
# [mbo] 0: num_leaves=7158; min_data_in_leaf=3758; lambda_l2=66.2; learning_rate=0.0924; num_iterations=1121; early_stopping_rounds=70; feature_fraction=0.681 : y = 0.923 : 93.5 secs : initdesign
#
# [mbo] 0: num_leaves=1210; min_data_in_leaf=6967; lambda_l2=968; learning_rate=0.0444; num_iterations=2426; early_stopping_rounds=112; feature_fraction=0.142 : y = 0.913 : 165.3 secs : initdesign
#
# [mbo] 0: num_leaves=210; min_data_in_leaf=3925; lambda_l2=554; learning_rate=0.0241; num_iterations=214; early_stopping_rounds=258; feature_fraction=0.41 : y = 0.896 : 27.2 secs : initdesign
#
# [mbo] 0: num_leaves=4871; min_data_in_leaf=4973; lambda_l2=689; learning_rate=0.00504; num_iterations=1805; early_stopping_rounds=180; feature_fraction=0.963 : y = 0.901 : 143.2 secs : initdesign
#
# [mbo] 0: num_leaves=8040; min_data_in_leaf=2600; lambda_l2=907; learning_rate=0.0793; num_iterations=1398; early_stopping_rounds=434; feature_fraction=0.436 : y = 0.916 : 213.6 secs : initdesign
#
# [mbo] 0: num_leaves=5991; min_data_in_leaf=5273; lambda_l2=94.5; learning_rate=0.0564; num_iterations=4446; early_stopping_rounds=172; feature_fraction=0.866 : y = 0.923 : 358.6 secs : initdesign
#
# [mbo] 0: num_leaves=7507; min_data_in_leaf=7064; lambda_l2=769; learning_rate=0.0703; num_iterations=4663; early_stopping_rounds=234; feature_fraction=0.237 : y = 0.92 : 505.1 secs : initdesign
#
# [mbo] 0: num_leaves=6897; min_data_in_leaf=1351; lambda_l2=201; learning_rate=0.0218; num_iterations=624; early_stopping_rounds=91; feature_fraction=0.0982 : y = 0.911 : 53.5 secs : initdesign
#
# [mbo] 0: num_leaves=521; min_data_in_leaf=160; lambda_l2=335; learning_rate=0.0937; num_iterations=1217; early_stopping_rounds=441; feature_fraction=0.587 : y = 0.925 : 245.5 secs : initdesign
#
# [mbo] 0: num_leaves=7896; min_data_in_leaf=2794; lambda_l2=165; learning_rate=0.0981; num_iterations=4036; early_stopping_rounds=469; feature_fraction=0.619 : y = 0.926 : 438.6 secs : initdesign
#
# [mbo] 0: num_leaves=2486; min_data_in_leaf=2289; lambda_l2=878; learning_rate=0.0804; num_iterations=2962; early_stopping_rounds=132; feature_fraction=0.524 : y = 0.919 : 497.3 secs : initdesign
#
# [mbo] 0: num_leaves=5384; min_data_in_leaf=1107; lambda_l2=821; learning_rate=0.0369; num_iterations=4891; early_stopping_rounds=490; feature_fraction=0.207 : y = 0.922 : 555.8 secs : initdesign
#
# [mbo] 0: num_leaves=1472; min_data_in_leaf=7600; lambda_l2=122; learning_rate=0.0294; num_iterations=3783; early_stopping_rounds=57; feature_fraction=0.317 : y = 0.915 : 207.7 secs : initdesign
#
# [mbo] 0: num_leaves=1765; min_data_in_leaf=680; lambda_l2=225; learning_rate=0.00992; num_iterations=4542; early_stopping_rounds=201; feature_fraction=0.994 : y = 0.918 : 463.6 secs : initdesign
#
# [mbo] 0: num_leaves=4628; min_data_in_leaf=8042; lambda_l2=574; learning_rate=0.0469; num_iterations=911; early_stopping_rounds=376; feature_fraction=0.358 : y = 0.912 : 112.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Sat Nov 22 05:05:03 AM 2025 AUC 0.928651045619658
#
# [mbo] 1: num_leaves=867; min_data_in_leaf=1447; lambda_l2=0.269; learning_rate=0.0482; num_iterations=3429; early_stopping_rounds=427; feature_fraction=0.706 : y = 0.929 : 209.3 secs : infill_ei
#
# Sat Nov 22 05:08:07 AM 2025 AUC 0.92848025962156
#
# [mbo] 2: num_leaves=2504; min_data_in_leaf=651; lambda_l2=75.7; learning_rate=0.0916; num_iterations=2828; early_stopping_rounds=377; feature_fraction=0.656 : y = 0.928 : 183.1 secs : infill_ei
#
# Sat Nov 22 05:11:20 AM 2025 AUC 0.927252210990834
#
# [mbo] 3: num_leaves=652; min_data_in_leaf=1526; lambda_l2=1.21; learning_rate=0.0826; num_iterations=2714; early_stopping_rounds=500; feature_fraction=0.46 : y = 0.927 : 193.1 secs : infill_ei
#
# Sat Nov 22 05:13:51 AM 2025 AUC 0.929185213220782
#
# [mbo] 4: num_leaves=5201; min_data_in_leaf=9; lambda_l2=6.34; learning_rate=0.0998; num_iterations=1927; early_stopping_rounds=368; feature_fraction=0.495 : y = 0.929 : 149.9 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Sat Nov 22 05:16:16 AM 2025 AUC 0.927966223965201
#
# [mbo] 5: num_leaves=3878; min_data_in_leaf=136; lambda_l2=32.1; learning_rate=0.096; num_iterations=2355; early_stopping_rounds=285; feature_fraction=0.425 : y = 0.928 : 144.9 secs : infill_ei
#
# Sat Nov 22 05:17:57 AM 2025 AUC 0.928163517023908
#
# [mbo] 6: num_leaves=7928; min_data_in_leaf=318; lambda_l2=4; learning_rate=0.096; num_iterations=2890; early_stopping_rounds=450; feature_fraction=0.365 : y = 0.928 : 99.9 secs : infill_ei
#
# Sat Nov 22 05:22:28 AM 2025 AUC 0.929776085799664
#
# [mbo] 7: num_leaves=4103; min_data_in_leaf=1608; lambda_l2=0.072; learning_rate=0.0434; num_iterations=4996; early_stopping_rounds=466; feature_fraction=0.701 : y = 0.93 : 270.8 secs : infill_ei
#
# Sat Nov 22 05:27:28 AM 2025 AUC 0.92855307015513
#
# [mbo] 8: num_leaves=5473; min_data_in_leaf=5; lambda_l2=56; learning_rate=0.0727; num_iterations=3915; early_stopping_rounds=490; feature_fraction=0.658 : y = 0.929 : 299.7 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Sat Nov 22 05:30:56 AM 2025 AUC 0.927493794328026
#
# [mbo] 9: num_leaves=1644; min_data_in_leaf=2376; lambda_l2=0.24; learning_rate=0.0391; num_iterations=4993; early_stopping_rounds=351; feature_fraction=0.727 : y = 0.927 : 206.7 secs : infill_ei
#
# Sat Nov 22 05:33:41 AM 2025 AUC 0.928151102324636
#
# [mbo] 10: num_leaves=5499; min_data_in_leaf=1677; lambda_l2=27.3; learning_rate=0.0667; num_iterations=4268; early_stopping_rounds=419; feature_fraction=0.611 : y = 0.928 : 164.7 secs : infill_ei
#
# Sat Nov 22 05:36:19 AM 2025 AUC 0.928759758121394
#
# [mbo] 11: num_leaves=6059; min_data_in_leaf=80; lambda_l2=0.175; learning_rate=0.0541; num_iterations=4966; early_stopping_rounds=453; feature_fraction=0.685 : y = 0.929 : 157.5 secs : infill_ei
#
# Sat Nov 22 05:39:10 AM 2025 AUC 0.930748458731862
#
# [mbo] 12: num_leaves=4198; min_data_in_leaf=8; lambda_l2=0.154; learning_rate=0.0984; num_iterations=3914; early_stopping_rounds=486; feature_fraction=0.568 : y = 0.931 : 170.1 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Sat Nov 22 05:42:14 AM 2025 AUC 0.930234758607916
#
# [mbo] 13: num_leaves=3279; min_data_in_leaf=722; lambda_l2=0.00598; learning_rate=0.0896; num_iterations=4897; early_stopping_rounds=486; feature_fraction=0.716 : y = 0.93 : 183.2 secs : infill_ei
#
# Sat Nov 22 05:57:10 AM 2025 AUC 0.925921489441802
#
# [mbo] 14: num_leaves=4798; min_data_in_leaf=17; lambda_l2=429; learning_rate=0.0998; num_iterations=4758; early_stopping_rounds=497; feature_fraction=0.588 : y = 0.926 : 896.2 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Sat Nov 22 06:00:49 AM 2025 AUC 0.924807186299004
#
# [mbo] 15: num_leaves=5138; min_data_in_leaf=799; lambda_l2=1.8; learning_rate=0.0996; num_iterations=3640; early_stopping_rounds=473; feature_fraction=0.944 : y = 0.925 : 217.7 secs : infill_ei
#
# Sat Nov 22 06:03:50 AM 2025 AUC 0.930174698306031
#
# [mbo] 16: num_leaves=4762; min_data_in_leaf=12; lambda_l2=17.8; learning_rate=0.0999; num_iterations=2409; early_stopping_rounds=483; feature_fraction=0.0612 : y = 0.93 : 181.3 secs : infill_ei
#
# Sat Nov 22 06:06:50 AM 2025 AUC 0.933012631453211
#
# [mbo] 17: num_leaves=4003; min_data_in_leaf=367; lambda_l2=1.02; learning_rate=0.054; num_iterations=4327; early_stopping_rounds=500; feature_fraction=0.0761 : y = 0.933 : 179.2 secs : infill_ei
#
# Sat Nov 22 06:09:43 AM 2025 AUC 0.932726086772708
#
# [mbo] 18: num_leaves=3099; min_data_in_leaf=21; lambda_l2=25.1; learning_rate=0.0702; num_iterations=4980; early_stopping_rounds=481; feature_fraction=0.0515 : y = 0.933 : 171.9 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Sat Nov 22 06:11:57 AM 2025 AUC 0.933381381574842
#
# [mbo] 19: num_leaves=2302; min_data_in_leaf=2; lambda_l2=7.19; learning_rate=0.092; num_iterations=4502; early_stopping_rounds=429; feature_fraction=0.117 : y = 0.933 : 133.4 secs : infill_ei
#
# Sat Nov 22 06:14:29 AM 2025 AUC 0.936123687984383
#
# [mbo] 20: num_leaves=1100; min_data_in_leaf=2; lambda_l2=0.198; learning_rate=0.0514; num_iterations=4787; early_stopping_rounds=496; feature_fraction=0.184 : y = 0.936 : 150.9 secs : infill_ei
#
# Sat Nov 22 06:17:37 AM 2025 AUC 0.934668819442627
#
# [mbo] 21: num_leaves=213; min_data_in_leaf=65; lambda_l2=7.25; learning_rate=0.0578; num_iterations=4480; early_stopping_rounds=477; feature_fraction=0.375 : y = 0.935 : 187.3 secs : infill_ei
#
# Sat Nov 22 06:22:39 AM 2025 AUC 0.926176829607917
#
# [mbo] 22: num_leaves=19; min_data_in_leaf=7; lambda_l2=137; learning_rate=0.0502; num_iterations=4695; early_stopping_rounds=409; feature_fraction=0.0514 : y = 0.926 : 302.0 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Sat Nov 22 06:28:27 AM 2025 AUC 0.937930530027131
#
# [mbo] 23: num_leaves=1033; min_data_in_leaf=7; lambda_l2=0.535; learning_rate=0.016; num_iterations=4769; early_stopping_rounds=494; feature_fraction=0.36 : y = 0.938 : 346.8 secs : infill_ei
#
# Sat Nov 22 06:32:43 AM 2025 AUC 0.934424887378546
#
# [mbo] 24: num_leaves=1688; min_data_in_leaf=17; lambda_l2=0.289; learning_rate=0.0259; num_iterations=4772; early_stopping_rounds=500; feature_fraction=0.409 : y = 0.934 : 255.4 secs : infill_ei
#
# Saved the current state after iteration 25 in the file HT.RDATA.
#
# Sat Nov 22 06:44:50 AM 2025 AUC 0.934062512372758
#
# [mbo] 25: num_leaves=633; min_data_in_leaf=1080; lambda_l2=0.536; learning_rate=0.00527; num_iterations=4989; early_stopping_rounds=453; feature_fraction=0.276 : y = 0.934 : 726.1 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Sat Nov 22 06:49:31 AM 2025 AUC 0.928974163333152
#
# [mbo] 26: num_leaves=887; min_data_in_leaf=73; lambda_l2=111; learning_rate=0.0996; num_iterations=4820; early_stopping_rounds=493; feature_fraction=0.264 : y = 0.929 : 280.7 secs : infill_ei
#
# Sat Nov 22 06:51:57 AM 2025 AUC 0.92522156882877
#
# [mbo] 27: num_leaves=7901; min_data_in_leaf=4342; lambda_l2=0.412; learning_rate=0.049; num_iterations=3271; early_stopping_rounds=486; feature_fraction=0.118 : y = 0.925 : 145.0 secs : infill_ei
#
# Sat Nov 22 06:56:11 AM 2025 AUC 0.935949211129744
#
# [mbo] 28: num_leaves=681; min_data_in_leaf=35; lambda_l2=0.239; learning_rate=0.0175; num_iterations=4456; early_stopping_rounds=433; feature_fraction=0.291 : y = 0.936 : 253.4 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Sat Nov 22 07:01:17 AM 2025 AUC 0.919103470814384
#
# [mbo] 29: num_leaves=322; min_data_in_leaf=8089; lambda_l2=0.459; learning_rate=0.0147; num_iterations=3347; early_stopping_rounds=480; feature_fraction=0.829 : y = 0.919 : 305.1 secs : infill_ei
#
# Sat Nov 22 07:03:07 AM 2025 AUC 0.924939386069634
#
# [mbo] 30: num_leaves=2858; min_data_in_leaf=4793; lambda_l2=0.26; learning_rate=0.0996; num_iterations=4997; early_stopping_rounds=477; feature_fraction=0.064 : y = 0.925 : 108.6 secs : infill_ei
#
# Sat Nov 22 07:05:06 AM 2025 AUC 0.926121802292223
#
# [mbo] 31: num_leaves=7999; min_data_in_leaf=5; lambda_l2=102; learning_rate=0.0992; num_iterations=4694; early_stopping_rounds=53; feature_fraction=0.296 : y = 0.926 : 118.4 secs : infill_ei
#
# Sat Nov 22 07:08:38 AM 2025 AUC 0.928041047693248
#
# [mbo] 32: num_leaves=7261; min_data_in_leaf=29; lambda_l2=370; learning_rate=0.1; num_iterations=1834; early_stopping_rounds=486; feature_fraction=0.114 : y = 0.928 : 211.1 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Sat Nov 22 07:18:02 AM 2025 AUC 0.93691889980264
#
# [mbo] 33: num_leaves=157; min_data_in_leaf=26; lambda_l2=0.944; learning_rate=0.00754; num_iterations=4200; early_stopping_rounds=492; feature_fraction=0.533 : y = 0.937 : 563.8 secs : infill_ei
#
# Sat Nov 22 07:20:02 AM 2025 AUC 0.93541873438516
#
# [mbo] 34: num_leaves=6565; min_data_in_leaf=5; lambda_l2=0.838; learning_rate=0.0767; num_iterations=4959; early_stopping_rounds=360; feature_fraction=0.155 : y = 0.935 : 119.0 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Sat Nov 22 07:20:55 AM 2025 AUC 0.919642335869287
#
# [mbo] 35: num_leaves=5987; min_data_in_leaf=131; lambda_l2=132; learning_rate=0.0999; num_iterations=254; early_stopping_rounds=500; feature_fraction=0.457 : y = 0.92 : 52.8 secs : infill_ei
#
# Sat Nov 22 07:21:41 AM 2025 AUC 0.930448157222436
#
# [mbo] 36: num_leaves=4074; min_data_in_leaf=20; lambda_l2=0.476; learning_rate=0.0589; num_iterations=4972; early_stopping_rounds=111; feature_fraction=0.189 : y = 0.93 : 45.3 secs : infill_ei
#
# Sat Nov 22 07:27:14 AM 2025 AUC 0.926543566535071
#
# [mbo] 37: num_leaves=8172; min_data_in_leaf=32; lambda_l2=811; learning_rate=0.1; num_iterations=3786; early_stopping_rounds=383; feature_fraction=0.0506 : y = 0.927 : 331.6 secs : infill_ei
#
# Sat Nov 22 07:29:46 AM 2025 AUC 0.927956493525231
#
# [mbo] 38: num_leaves=5116; min_data_in_leaf=8180; lambda_l2=0.575; learning_rate=0.0989; num_iterations=2642; early_stopping_rounds=290; feature_fraction=0.624 : y = 0.928 : 151.0 secs : infill_ei
#
# Sat Nov 22 07:40:47 AM 2025 AUC 0.929331505352749
#
# [mbo] 39: num_leaves=28; min_data_in_leaf=55; lambda_l2=1.45; learning_rate=0.00858; num_iterations=4904; early_stopping_rounds=495; feature_fraction=0.586 : y = 0.929 : 661.0 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Sat Nov 22 07:43:01 AM 2025 AUC 0.933144831223841
#
# [mbo] 40: num_leaves=5077; min_data_in_leaf=7; lambda_l2=0.684; learning_rate=0.0541; num_iterations=4905; early_stopping_rounds=499; feature_fraction=0.191 : y = 0.933 : 133.2 secs : infill_ei
#
# Sat Nov 22 07:44:52 AM 2025 AUC 0.932929419414845
#
# [mbo] 41: num_leaves=8153; min_data_in_leaf=55; lambda_l2=0.239; learning_rate=0.098; num_iterations=4683; early_stopping_rounds=225; feature_fraction=0.0594 : y = 0.933 : 110.2 secs : infill_ei
#
# Sat Nov 22 07:46:28 AM 2025 AUC 0.936025712519855
#
# [mbo] 42: num_leaves=7507; min_data_in_leaf=1129; lambda_l2=0.0182; learning_rate=0.0897; num_iterations=4800; early_stopping_rounds=499; feature_fraction=0.114 : y = 0.936 : 95.2 secs : infill_ei
#
# Sat Nov 22 07:54:14 AM 2025 AUC 0.937181621681836
#
# [mbo] 43: num_leaves=458; min_data_in_leaf=4; lambda_l2=2.96; learning_rate=0.00607; num_iterations=3735; early_stopping_rounds=476; feature_fraction=0.365 : y = 0.937 : 465.0 secs : infill_ei
#
# Saved the current state after iteration 44 in the file HT.RDATA.
#
# Sat Nov 22 07:55:08 AM 2025 AUC 0.919806075686717
#
# [mbo] 44: num_leaves=4643; min_data_in_leaf=8047; lambda_l2=17.1; learning_rate=0.0968; num_iterations=4898; early_stopping_rounds=72; feature_fraction=0.682 : y = 0.92 : 53.4 secs : infill_ei
#
# Sat Nov 22 08:00:49 AM 2025 AUC 0.930922935586501
#
# [mbo] 45: num_leaves=7039; min_data_in_leaf=14; lambda_l2=126; learning_rate=0.0992; num_iterations=4973; early_stopping_rounds=495; feature_fraction=0.0994 : y = 0.931 : 341.0 secs : infill_ei
#
# Sat Nov 22 08:02:26 AM 2025 AUC 0.929317077459
#
# [mbo] 46: num_leaves=6735; min_data_in_leaf=663; lambda_l2=0.792; learning_rate=0.0882; num_iterations=4139; early_stopping_rounds=444; feature_fraction=0.125 : y = 0.929 : 95.9 secs : infill_ei
#
# Sat Nov 22 08:07:50 AM 2025 AUC 0.929461691928902
#
# [mbo] 47: num_leaves=8124; min_data_in_leaf=2734; lambda_l2=110; learning_rate=0.0628; num_iterations=4996; early_stopping_rounds=337; feature_fraction=0.0936 : y = 0.929 : 323.4 secs : infill_ei
#
# Saved the current state after iteration 48 in the file HT.RDATA.
#
# Sat Nov 22 08:11:09 AM 2025 AUC 0.927120011220204
#
# [mbo] 48: num_leaves=8106; min_data_in_leaf=7231; lambda_l2=5.27; learning_rate=0.0997; num_iterations=1913; early_stopping_rounds=499; feature_fraction=0.521 : y = 0.927 : 198.0 secs : infill_ei
#
# Sat Nov 22 08:23:45 AM 2025 AUC 0.923655303525976
#
# [mbo] 49: num_leaves=484; min_data_in_leaf=471; lambda_l2=725; learning_rate=0.0501; num_iterations=4135; early_stopping_rounds=500; feature_fraction=0.507 : y = 0.924 : 754.8 secs : infill_ei
#
# Saved the current state after iteration 50 in the file HT.RDATA.
#
# Sat Nov 22 08:25:29 AM 2025 AUC 0.932447259337699
#
# [mbo] 50: num_leaves=5653; min_data_in_leaf=63; lambda_l2=2.28; learning_rate=0.0879; num_iterations=4980; early_stopping_rounds=227; feature_fraction=0.321 : y = 0.932 : 102.9 secs : infill_ei
#
# Sat Nov 22 08:32:59 AM 2025 AUC 0.928394027791479
#
# [mbo] 51: num_leaves=998; min_data_in_leaf=3493; lambda_l2=2.84; learning_rate=0.0215; num_iterations=4251; early_stopping_rounds=500; feature_fraction=0.197 : y = 0.928 : 449.1 secs : infill_ei
#
# Sat Nov 22 08:44:12 AM 2025 AUC 0.922870493212515
#
# [mbo] 52: num_leaves=8186; min_data_in_leaf=392; lambda_l2=779; learning_rate=0.0998; num_iterations=4984; early_stopping_rounds=478; feature_fraction=0.817 : y = 0.923 : 672.5 secs : infill_ei
#
# Saved the current state after iteration 53 in the file HT.RDATA.
#
# Sat Nov 22 08:48:15 AM 2025 AUC 0.924829666970659
#
# [mbo] 53: num_leaves=8186; min_data_in_leaf=1063; lambda_l2=638; learning_rate=0.1; num_iterations=4999; early_stopping_rounds=116; feature_fraction=0.0963 : y = 0.925 : 241.6 secs : infill_ei
#
# Sat Nov 22 08:52:44 AM 2025 AUC 0.935992830343404
#
# [mbo] 54: num_leaves=3229; min_data_in_leaf=10; lambda_l2=0.206; learning_rate=0.0198; num_iterations=2290; early_stopping_rounds=424; feature_fraction=0.586 : y = 0.936 : 268.7 secs : infill_ei
#
# Sat Nov 22 09:04:04 AM 2025 AUC 0.935830768188038
#
# [mbo] 55: num_leaves=667; min_data_in_leaf=2; lambda_l2=2.45; learning_rate=0.00504; num_iterations=3046; early_stopping_rounds=466; feature_fraction=0.526 : y = 0.936 : 679.3 secs : infill_ei
#
# Saved the current state after iteration 56 in the file HT.RDATA.
#
# Sat Nov 22 09:16:28 AM 2025 AUC 0.926610673017624
#
# [mbo] 56: num_leaves=106; min_data_in_leaf=23; lambda_l2=998; learning_rate=0.0997; num_iterations=4983; early_stopping_rounds=233; feature_fraction=0.352 : y = 0.927 : 742.9 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Sat Nov 22 09:18:43 AM 2025 AUC 0.935719706959412
#
# [mbo] 57: num_leaves=2493; min_data_in_leaf=1594; lambda_l2=0.424; learning_rate=0.0532; num_iterations=4985; early_stopping_rounds=498; feature_fraction=0.145 : y = 0.936 : 133.7 secs : infill_ei
#
# Sat Nov 22 09:20:17 AM 2025 AUC 0.9350912547503
#
# [mbo] 58: num_leaves=459; min_data_in_leaf=23; lambda_l2=0.0103; learning_rate=0.0814; num_iterations=1630; early_stopping_rounds=486; feature_fraction=0.112 : y = 0.935 : 93.4 secs : infill_ei
#
# Sat Nov 22 09:22:44 AM 2025 AUC 0.940235302170425
#
# [mbo] 59: num_leaves=2290; min_data_in_leaf=52; lambda_l2=1.03; learning_rate=0.0353; num_iterations=2134; early_stopping_rounds=466; feature_fraction=0.144 : y = 0.94 : 145.7 secs : infill_ei
#
# Sat Nov 22 09:26:16 AM 2025 AUC 0.929694215890949
#
# [mbo] 60: num_leaves=2651; min_data_in_leaf=2011; lambda_l2=2.47; learning_rate=0.00977; num_iterations=1907; early_stopping_rounds=498; feature_fraction=0.175 : y = 0.93 : 210.8 secs : infill_ei
#
# Sat Nov 22 09:30:04 AM 2025 AUC 0.932736152745091
#
# [mbo] 61: num_leaves=2426; min_data_in_leaf=19; lambda_l2=6.32; learning_rate=0.0558; num_iterations=2194; early_stopping_rounds=477; feature_fraction=0.21 : y = 0.933 : 227.8 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Sat Nov 22 09:35:13 AM 2025 AUC 0.939208572987359
#
# [mbo] 62: num_leaves=1124; min_data_in_leaf=7; lambda_l2=0.418; learning_rate=0.0175; num_iterations=2327; early_stopping_rounds=447; feature_fraction=0.108 : y = 0.939 : 307.9 secs : infill_ei
#
# Sat Nov 22 09:38:39 AM 2025 AUC 0.935614349781803
#
# [mbo] 63: num_leaves=700; min_data_in_leaf=24; lambda_l2=41.1; learning_rate=0.0463; num_iterations=2070; early_stopping_rounds=167; feature_fraction=0.0702 : y = 0.936 : 205.4 secs : infill_ei
#
# Sat Nov 22 09:42:50 AM 2025 AUC 0.935513354525561
#
# [mbo] 64: num_leaves=1808; min_data_in_leaf=17; lambda_l2=5.36; learning_rate=0.0305; num_iterations=2110; early_stopping_rounds=403; feature_fraction=0.0943 : y = 0.936 : 250.1 secs : infill_ei
#
# Saved the current state after iteration 65 in the file HT.RDATA.
#
# Sat Nov 22 09:46:35 AM 2025 AUC 0.934510112611388
#
# [mbo] 65: num_leaves=2593; min_data_in_leaf=59; lambda_l2=11.2; learning_rate=0.0382; num_iterations=2519; early_stopping_rounds=461; feature_fraction=0.213 : y = 0.935 : 223.7 secs : infill_ei
#
# Sat Nov 22 09:47:58 AM 2025 AUC 0.935408332880365
#
# [mbo] 66: num_leaves=474; min_data_in_leaf=10; lambda_l2=5.65; learning_rate=0.0472; num_iterations=2717; early_stopping_rounds=223; feature_fraction=0.145 : y = 0.935 : 82.3 secs : infill_ei
#
# Sat Nov 22 09:49:52 AM 2025 AUC 0.931578230388634
#
# [mbo] 67: num_leaves=171; min_data_in_leaf=26; lambda_l2=1.62; learning_rate=0.0509; num_iterations=2324; early_stopping_rounds=82; feature_fraction=0.574 : y = 0.932 : 112.1 secs : infill_ei
#
# Sat Nov 22 09:52:16 AM 2025 AUC 0.935481478946348
#
# [mbo] 68: num_leaves=8044; min_data_in_leaf=21; lambda_l2=2.48; learning_rate=0.0688; num_iterations=5000; early_stopping_rounds=460; feature_fraction=0.163 : y = 0.935 : 143.0 secs : infill_ei
#
# Sat Nov 22 09:57:50 AM 2025 AUC 0.932242920098324
#
# [mbo] 69: num_leaves=2174; min_data_in_leaf=17; lambda_l2=30.6; learning_rate=0.0369; num_iterations=2538; early_stopping_rounds=497; feature_fraction=0.141 : y = 0.932 : 333.9 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Sat Nov 22 10:01:48 AM 2025 AUC 0.93341996780231
#
# [mbo] 70: num_leaves=1736; min_data_in_leaf=20; lambda_l2=0.0774; learning_rate=0.0361; num_iterations=1599; early_stopping_rounds=455; feature_fraction=0.306 : y = 0.933 : 237.1 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf lambda_l2 learning_rate num_iterations
#         <int>            <int>     <num>         <num>          <int>
# 1:       2290               52  1.026555    0.03534722           2134
#    early_stopping_rounds feature_fraction
#                    <int>            <num>
# 1:                   466        0.1436913

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6264000
#
# $envios
# [1] 1394

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_111531493
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Sat Nov 22 10:11:00 AM 2025"
# Inicio: Sat Nov 22 02:45:53 AM 2025
# Fin:    Sat Nov 22 10:11:00 AM 2025
# Duración (hh:mm:ss): 07:25:07
