# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_7HT_65175_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Nov 22 02:48:19 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454491    77.7 1437483  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 999983 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65175 # 7HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 70

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  #makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L)   # columnas
  #makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Nov 22 03:07:28 AM 2025 AUC 0.917838849150667
#
# Sat Nov 22 03:11:31 AM 2025 AUC 0.911673776598493
#
# Sat Nov 22 03:16:31 AM 2025 AUC 0.912041520122885
#
# Sat Nov 22 03:21:36 AM 2025 AUC 0.923685165910712
#
# Sat Nov 22 03:30:00 AM 2025 AUC 0.914633508011507
#
# Sat Nov 22 03:34:17 AM 2025 AUC 0.914074175479425
#
# Sat Nov 22 03:38:31 AM 2025 AUC 0.921595134511589
#
# Sat Nov 22 03:41:25 AM 2025 AUC 0.914865360908729
#
# Sat Nov 22 03:44:13 AM 2025 AUC 0.915033127115112
#
# Sat Nov 22 03:52:26 AM 2025 AUC 0.924437765112548
#
# Sat Nov 22 03:52:57 AM 2025 AUC 0.906593144804381
#
# Sat Nov 22 03:55:38 AM 2025 AUC 0.913682273621314
#
# Sat Nov 22 04:01:09 AM 2025 AUC 0.92035332905194
#
# Sat Nov 22 04:02:48 AM 2025 AUC 0.909280759430642
#
# Sat Nov 22 04:13:25 AM 2025 AUC 0.924371665227233
#
# Sat Nov 22 04:14:58 AM 2025 AUC 0.924108607815624
#
# Sat Nov 22 04:23:36 AM 2025 AUC 0.915233104433121
#
# Sat Nov 22 04:26:48 AM 2025 AUC 0.904748052066578
#
# Sat Nov 22 04:29:45 AM 2025 AUC 0.919657770360275
#
# Sat Nov 22 04:38:15 AM 2025 AUC 0.919326264336461
#
# Sat Nov 22 04:40:20 AM 2025 AUC 0.914681489146533
#
# Sat Nov 22 04:42:25 AM 2025 AUC 0.907312526297353
#
# Sat Nov 22 04:46:49 AM 2025 AUC 0.920421777664144
#
# Sat Nov 22 04:48:24 AM 2025 AUC 0.911692566413608
#
# Sat Nov 22 05:00:25 AM 2025 AUC 0.929435855933119
#
# Sat Nov 22 05:03:26 AM 2025 AUC 0.925334978784286
#
# Sat Nov 22 05:05:32 AM 2025 AUC 0.916236346347293
#
# Sat Nov 22 05:05:52 AM 2025 AUC 0.893839557795123
#
# [mbo] 0: num_leaves=5125; min_data_in_leaf=3562; lambda_l2=337; learning_rate=0.0311; num_iterations=3373; early_stopping_rounds=412; feature_fraction=0.709 : y = 0.918 : 390.5 secs : initdesign
#
# [mbo] 0: num_leaves=5327; min_data_in_leaf=7462; lambda_l2=359; learning_rate=0.0168; num_iterations=2586; early_stopping_rounds=337; feature_fraction=0.667 : y = 0.912 : 242.9 secs : initdesign
#
# [mbo] 0: num_leaves=4387; min_data_in_leaf=4258; lambda_l2=710; learning_rate=0.0204; num_iterations=2202; early_stopping_rounds=425; feature_fraction=0.389 : y = 0.912 : 300.5 secs : initdesign
#
# [mbo] 0: num_leaves=3646; min_data_in_leaf=1533; lambda_l2=307; learning_rate=0.0552; num_iterations=2440; early_stopping_rounds=292; feature_fraction=0.259 : y = 0.924 : 305.1 secs : initdesign
#
# [mbo] 0: num_leaves=6641; min_data_in_leaf=4744; lambda_l2=860; learning_rate=0.0277; num_iterations=3719; early_stopping_rounds=254; feature_fraction=0.376 : y = 0.915 : 503.8 secs : initdesign
#
# [mbo] 0: num_leaves=1578; min_data_in_leaf=4559; lambda_l2=662; learning_rate=0.0444; num_iterations=3169; early_stopping_rounds=70; feature_fraction=0.506 : y = 0.914 : 257.6 secs : initdesign
#
# [mbo] 0: num_leaves=7637; min_data_in_leaf=4052; lambda_l2=210; learning_rate=0.071; num_iterations=2760; early_stopping_rounds=100; feature_fraction=0.807 : y = 0.922 : 253.8 secs : initdesign
#
# [mbo] 0: num_leaves=2285; min_data_in_leaf=5120; lambda_l2=506; learning_rate=0.0975; num_iterations=1360; early_stopping_rounds=230; feature_fraction=0.548 : y = 0.915 : 174.0 secs : initdesign
#
# [mbo] 0: num_leaves=3926; min_data_in_leaf=2769; lambda_l2=592; learning_rate=0.047; num_iterations=2094; early_stopping_rounds=97; feature_fraction=0.772 : y = 0.915 : 167.8 secs : initdesign
#
# [mbo] 0: num_leaves=6747; min_data_in_leaf=3105; lambda_l2=220; learning_rate=0.0799; num_iterations=3937; early_stopping_rounds=357; feature_fraction=0.758 : y = 0.924 : 493.4 secs : initdesign
#
# [mbo] 0: num_leaves=3125; min_data_in_leaf=6954; lambda_l2=913; learning_rate=0.0494; num_iterations=379; early_stopping_rounds=165; feature_fraction=0.643 : y = 0.907 : 30.3 secs : initdesign
#
# [mbo] 0: num_leaves=1776; min_data_in_leaf=2015; lambda_l2=618; learning_rate=0.0364; num_iterations=1253; early_stopping_rounds=402; feature_fraction=0.332 : y = 0.914 : 161.1 secs : initdesign
#
# [mbo] 0: num_leaves=3225; min_data_in_leaf=7879; lambda_l2=254; learning_rate=0.0612; num_iterations=4776; early_stopping_rounds=285; feature_fraction=0.12 : y = 0.92 : 330.7 secs : initdesign
#
# [mbo] 0: num_leaves=7509; min_data_in_leaf=1164; lambda_l2=569; learning_rate=0.0251; num_iterations=653; early_stopping_rounds=354; feature_fraction=0.432 : y = 0.909 : 99.1 secs : initdesign
#
# [mbo] 0: num_leaves=404; min_data_in_leaf=601; lambda_l2=715; learning_rate=0.0573; num_iterations=4548; early_stopping_rounds=206; feature_fraction=0.295 : y = 0.924 : 637.6 secs : initdesign
#
# [mbo] 0: num_leaves=1205; min_data_in_leaf=427; lambda_l2=157; learning_rate=0.0916; num_iterations=548; early_stopping_rounds=384; feature_fraction=0.869 : y = 0.924 : 92.9 secs : initdesign
#
# [mbo] 0: num_leaves=4426; min_data_in_leaf=5683; lambda_l2=464; learning_rate=0.0352; num_iterations=3063; early_stopping_rounds=313; feature_fraction=0.564 : y = 0.915 : 518.3 secs : initdesign
#
# [mbo] 0: num_leaves=2680; min_data_in_leaf=2397; lambda_l2=788; learning_rate=0.00731; num_iterations=2020; early_stopping_rounds=467; feature_fraction=0.945 : y = 0.905 : 191.1 secs : initdesign
#
# [mbo] 0: num_leaves=6138; min_data_in_leaf=6115; lambda_l2=136; learning_rate=0.0957; num_iterations=1754; early_stopping_rounds=225; feature_fraction=0.171 : y = 0.92 : 177.6 secs : initdesign
#
# [mbo] 0: num_leaves=4899; min_data_in_leaf=7080; lambda_l2=977; learning_rate=0.0794; num_iterations=4916; early_stopping_rounds=274; feature_fraction=0.211 : y = 0.919 : 510.2 secs : initdesign
#
# [mbo] 0: num_leaves=2430; min_data_in_leaf=2167; lambda_l2=828; learning_rate=0.0864; num_iterations=805; early_stopping_rounds=120; feature_fraction=0.46 : y = 0.915 : 124.2 secs : initdesign
#
# [mbo] 0: num_leaves=7287; min_data_in_leaf=5344; lambda_l2=437; learning_rate=0.0101; num_iterations=1508; early_stopping_rounds=143; feature_fraction=0.106 : y = 0.907 : 125.4 secs : initdesign
#
# [mbo] 0: num_leaves=982; min_data_in_leaf=6234; lambda_l2=94.4; learning_rate=0.0866; num_iterations=4434; early_stopping_rounds=451; feature_fraction=0.846 : y = 0.92 : 263.6 secs : initdesign
#
# [mbo] 0: num_leaves=7964; min_data_in_leaf=7950; lambda_l2=423; learning_rate=0.0677; num_iterations=1069; early_stopping_rounds=157; feature_fraction=0.983 : y = 0.912 : 95.6 secs : initdesign
#
# [mbo] 0: num_leaves=241; min_data_in_leaf=20; lambda_l2=66.1; learning_rate=0.0132; num_iterations=4096; early_stopping_rounds=184; feature_fraction=0.599 : y = 0.929 : 721.1 secs : initdesign
#
# [mbo] 0: num_leaves=5749; min_data_in_leaf=3314; lambda_l2=21.1; learning_rate=0.0633; num_iterations=3489; early_stopping_rounds=490; feature_fraction=0.0508 : y = 0.925 : 180.9 secs : initdesign
#
# [mbo] 0: num_leaves=6184; min_data_in_leaf=1325; lambda_l2=777; learning_rate=0.075; num_iterations=4149; early_stopping_rounds=59; feature_fraction=0.913 : y = 0.916 : 126.3 secs : initdesign
#
# [mbo] 0: num_leaves=844; min_data_in_leaf=6439; lambda_l2=943; learning_rate=0.0408; num_iterations=192; early_stopping_rounds=472; feature_fraction=0.234 : y = 0.894 : 19.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Sat Nov 22 05:07:29 AM 2025 AUC 0.935325456374411
#
# [mbo] 1: num_leaves=525; min_data_in_leaf=2; lambda_l2=0.323; learning_rate=0.0779; num_iterations=4851; early_stopping_rounds=243; feature_fraction=0.375 : y = 0.935 : 95.7 secs : infill_ei
#
# Sat Nov 22 05:09:02 AM 2025 AUC 0.935719371426999
#
# [mbo] 2: num_leaves=3135; min_data_in_leaf=152; lambda_l2=3.06; learning_rate=0.0998; num_iterations=4993; early_stopping_rounds=176; feature_fraction=0.413 : y = 0.936 : 92.3 secs : infill_ei
#
# Sat Nov 22 05:11:54 AM 2025 AUC 0.93066692435556
#
# [mbo] 3: num_leaves=2325; min_data_in_leaf=13; lambda_l2=0.13; learning_rate=0.0996; num_iterations=4873; early_stopping_rounds=370; feature_fraction=0.382 : y = 0.931 : 171.8 secs : infill_ei
#
# Sat Nov 22 05:12:58 AM 2025 AUC 0.930393800971568
#
# [mbo] 4: num_leaves=211; min_data_in_leaf=19; lambda_l2=0.601; learning_rate=0.0997; num_iterations=4763; early_stopping_rounds=116; feature_fraction=0.35 : y = 0.93 : 63.6 secs : infill_ei
#
# Sat Nov 22 05:15:27 AM 2025 AUC 0.929345597714085
#
# [mbo] 5: num_leaves=2494; min_data_in_leaf=921; lambda_l2=1.18; learning_rate=0.0834; num_iterations=4999; early_stopping_rounds=223; feature_fraction=0.444 : y = 0.929 : 148.7 secs : infill_ei
#
# Sat Nov 22 05:18:05 AM 2025 AUC 0.931622520667119
#
# [mbo] 6: num_leaves=5000; min_data_in_leaf=64; lambda_l2=33.1; learning_rate=0.0705; num_iterations=4579; early_stopping_rounds=136; feature_fraction=0.594 : y = 0.932 : 156.3 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Sat Nov 22 05:20:15 AM 2025 AUC 0.924989715931549
#
# [mbo] 7: num_leaves=4732; min_data_in_leaf=3; lambda_l2=37.5; learning_rate=0.0997; num_iterations=4090; early_stopping_rounds=222; feature_fraction=0.23 : y = 0.925 : 130.0 secs : infill_ei
#
# Sat Nov 22 05:20:50 AM 2025 AUC 0.913300437735586
#
# [mbo] 8: num_leaves=7; min_data_in_leaf=66; lambda_l2=3.51; learning_rate=0.0882; num_iterations=4523; early_stopping_rounds=280; feature_fraction=0.697 : y = 0.913 : 34.3 secs : infill_ei
#
# Sat Nov 22 05:22:48 AM 2025 AUC 0.929647241353162
#
# [mbo] 9: num_leaves=4310; min_data_in_leaf=3; lambda_l2=12.7; learning_rate=0.0666; num_iterations=4830; early_stopping_rounds=65; feature_fraction=0.403 : y = 0.93 : 117.2 secs : infill_ei
#
# Sat Nov 22 05:26:40 AM 2025 AUC 0.933855153341668
#
# [mbo] 10: num_leaves=3652; min_data_in_leaf=39; lambda_l2=50; learning_rate=0.0592; num_iterations=4702; early_stopping_rounds=186; feature_fraction=0.38 : y = 0.934 : 231.2 secs : infill_ei
#
# Sat Nov 22 05:34:31 AM 2025 AUC 0.930486743449904
#
# [mbo] 11: num_leaves=652; min_data_in_leaf=3; lambda_l2=86.9; learning_rate=0.0441; num_iterations=4225; early_stopping_rounds=204; feature_fraction=0.364 : y = 0.93 : 470.8 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Sat Nov 22 05:37:08 AM 2025 AUC 0.926649259245092
#
# [mbo] 12: num_leaves=3532; min_data_in_leaf=1163; lambda_l2=33.2; learning_rate=0.09; num_iterations=4990; early_stopping_rounds=376; feature_fraction=0.435 : y = 0.927 : 156.4 secs : infill_ei
#
# Sat Nov 22 05:42:36 AM 2025 AUC 0.925671182261878
#
# [mbo] 13: num_leaves=3640; min_data_in_leaf=5; lambda_l2=76.6; learning_rate=0.0883; num_iterations=4948; early_stopping_rounds=205; feature_fraction=0.374 : y = 0.926 : 327.0 secs : infill_ei
#
# Sat Nov 22 05:44:24 AM 2025 AUC 0.928862095507288
#
# [mbo] 14: num_leaves=2639; min_data_in_leaf=543; lambda_l2=0.845; learning_rate=0.0489; num_iterations=4331; early_stopping_rounds=169; feature_fraction=0.387 : y = 0.929 : 107.1 secs : infill_ei
#
# Sat Nov 22 05:46:37 AM 2025 AUC 0.931928190695149
#
# [mbo] 15: num_leaves=1085; min_data_in_leaf=506; lambda_l2=5.6; learning_rate=0.0676; num_iterations=4762; early_stopping_rounds=259; feature_fraction=0.388 : y = 0.932 : 132.9 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Sat Nov 22 05:57:20 AM 2025 AUC 0.925739630874082
#
# [mbo] 16: num_leaves=3152; min_data_in_leaf=9; lambda_l2=627; learning_rate=0.0855; num_iterations=4839; early_stopping_rounds=163; feature_fraction=0.468 : y = 0.926 : 642.2 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Sat Nov 22 06:02:23 AM 2025 AUC 0.931243704573105
#
# [mbo] 17: num_leaves=3586; min_data_in_leaf=2; lambda_l2=25.2; learning_rate=0.0341; num_iterations=4950; early_stopping_rounds=198; feature_fraction=0.407 : y = 0.931 : 301.8 secs : infill_ei
#
# Sat Nov 22 06:08:52 AM 2025 AUC 0.930022702123048
#
# [mbo] 18: num_leaves=3495; min_data_in_leaf=502; lambda_l2=59.4; learning_rate=0.0755; num_iterations=4922; early_stopping_rounds=470; feature_fraction=0.439 : y = 0.93 : 387.8 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Sat Nov 22 06:10:51 AM 2025 AUC 0.93618274168903
#
# [mbo] 19: num_leaves=631; min_data_in_leaf=219; lambda_l2=1.8; learning_rate=0.0791; num_iterations=4986; early_stopping_rounds=110; feature_fraction=0.279 : y = 0.936 : 118.4 secs : infill_ei
#
# Sat Nov 22 06:13:24 AM 2025 AUC 0.930431380601798
#
# [mbo] 20: num_leaves=1616; min_data_in_leaf=365; lambda_l2=22.2; learning_rate=0.0762; num_iterations=4959; early_stopping_rounds=159; feature_fraction=0.351 : y = 0.93 : 152.7 secs : infill_ei
#
# Sat Nov 22 06:17:22 AM 2025 AUC 0.932694882258321
#
# [mbo] 21: num_leaves=398; min_data_in_leaf=23; lambda_l2=40.3; learning_rate=0.0758; num_iterations=4233; early_stopping_rounds=212; feature_fraction=0.226 : y = 0.933 : 237.8 secs : infill_ei
#
# Sat Nov 22 06:18:16 AM 2025 AUC 0.934920133219789
#
# [mbo] 22: num_leaves=810; min_data_in_leaf=6; lambda_l2=0.923; learning_rate=0.0938; num_iterations=3125; early_stopping_rounds=127; feature_fraction=0.34 : y = 0.935 : 53.0 secs : infill_ei
#
# Sat Nov 22 06:19:43 AM 2025 AUC 0.929491889846051
#
# [mbo] 23: num_leaves=3229; min_data_in_leaf=9; lambda_l2=11.2; learning_rate=0.0675; num_iterations=2554; early_stopping_rounds=74; feature_fraction=0.43 : y = 0.929 : 86.4 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Sat Nov 22 06:21:30 AM 2025 AUC 0.928754725135203
#
# [mbo] 24: num_leaves=779; min_data_in_leaf=988; lambda_l2=15; learning_rate=0.094; num_iterations=4593; early_stopping_rounds=190; feature_fraction=0.328 : y = 0.929 : 105.5 secs : infill_ei
#
# Sat Nov 22 06:23:14 AM 2025 AUC 0.931686607357957
#
# [mbo] 25: num_leaves=2535; min_data_in_leaf=156; lambda_l2=11; learning_rate=0.061; num_iterations=4551; early_stopping_rounds=258; feature_fraction=0.44 : y = 0.932 : 103.2 secs : infill_ei
#
# Sat Nov 22 06:26:26 AM 2025 AUC 0.92965797839037
#
# [mbo] 26: num_leaves=5218; min_data_in_leaf=9; lambda_l2=10.2; learning_rate=0.0575; num_iterations=4928; early_stopping_rounds=274; feature_fraction=0.475 : y = 0.93 : 192.3 secs : infill_ei
#
# Sat Nov 22 06:28:01 AM 2025 AUC 0.931125597163812
#
# [mbo] 27: num_leaves=532; min_data_in_leaf=276; lambda_l2=40; learning_rate=0.0772; num_iterations=2980; early_stopping_rounds=78; feature_fraction=0.34 : y = 0.931 : 93.9 secs : infill_ei
#
# Sat Nov 22 06:30:31 AM 2025 AUC 0.925198752624702
#
# [mbo] 28: num_leaves=3512; min_data_in_leaf=1546; lambda_l2=8.95; learning_rate=0.0997; num_iterations=2874; early_stopping_rounds=164; feature_fraction=0.42 : y = 0.925 : 148.9 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Sat Nov 22 06:32:14 AM 2025 AUC 0.935695548625693
#
# [mbo] 29: num_leaves=136; min_data_in_leaf=19; lambda_l2=0.201; learning_rate=0.0668; num_iterations=2931; early_stopping_rounds=424; feature_fraction=0.245 : y = 0.936 : 102.4 secs : infill_ei
#
# Sat Nov 22 06:33:35 AM 2025 AUC 0.924893418129085
#
# [mbo] 30: num_leaves=41; min_data_in_leaf=346; lambda_l2=1; learning_rate=0.0798; num_iterations=4024; early_stopping_rounds=414; feature_fraction=0.284 : y = 0.925 : 80.1 secs : infill_ei
#
# Sat Nov 22 06:35:31 AM 2025 AUC 0.931174584896076
#
# [mbo] 31: num_leaves=801; min_data_in_leaf=8; lambda_l2=21; learning_rate=0.0639; num_iterations=2633; early_stopping_rounds=81; feature_fraction=0.259 : y = 0.931 : 115.5 secs : infill_ei
#
# Sat Nov 22 06:39:40 AM 2025 AUC 0.929824402467103
#
# [mbo] 32: num_leaves=280; min_data_in_leaf=28; lambda_l2=46.9; learning_rate=0.0538; num_iterations=3412; early_stopping_rounds=233; feature_fraction=0.38 : y = 0.93 : 248.4 secs : infill_ei
#
# Sat Nov 22 06:41:30 AM 2025 AUC 0.932846878441304
#
# [mbo] 33: num_leaves=425; min_data_in_leaf=6; lambda_l2=0.337; learning_rate=0.0658; num_iterations=961; early_stopping_rounds=473; feature_fraction=0.252 : y = 0.933 : 109.2 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Sat Nov 22 06:44:14 AM 2025 AUC 0.931358456658272
#
# [mbo] 34: num_leaves=3303; min_data_in_leaf=5; lambda_l2=36.2; learning_rate=0.069; num_iterations=4616; early_stopping_rounds=168; feature_fraction=0.547 : y = 0.931 : 163.1 secs : infill_ei
#
# Sat Nov 22 06:48:13 AM 2025 AUC 0.931843972059545
#
# [mbo] 35: num_leaves=2905; min_data_in_leaf=11; lambda_l2=14; learning_rate=0.061; num_iterations=3947; early_stopping_rounds=456; feature_fraction=0.243 : y = 0.932 : 238.7 secs : infill_ei
#
# Sat Nov 22 06:52:33 AM 2025 AUC 0.929836481633962
#
# [mbo] 36: num_leaves=2430; min_data_in_leaf=6; lambda_l2=116; learning_rate=0.0976; num_iterations=4949; early_stopping_rounds=203; feature_fraction=0.46 : y = 0.93 : 258.6 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Sat Nov 22 06:54:56 AM 2025 AUC 0.935770036821327
#
# [mbo] 37: num_leaves=194; min_data_in_leaf=9; lambda_l2=4.99; learning_rate=0.0269; num_iterations=4510; early_stopping_rounds=477; feature_fraction=0.183 : y = 0.936 : 142.2 secs : infill_ei
#
# Sat Nov 22 06:57:37 AM 2025 AUC 0.932321434682912
#
# [mbo] 38: num_leaves=593; min_data_in_leaf=4; lambda_l2=9.18; learning_rate=0.0671; num_iterations=3859; early_stopping_rounds=460; feature_fraction=0.129 : y = 0.932 : 160.1 secs : infill_ei
#
# Sat Nov 22 06:59:12 AM 2025 AUC 0.936592091232605
#
# [mbo] 39: num_leaves=358; min_data_in_leaf=3; lambda_l2=0.49; learning_rate=0.0292; num_iterations=5000; early_stopping_rounds=271; feature_fraction=0.245 : y = 0.937 : 94.5 secs : infill_ei
#
# Sat Nov 22 07:01:55 AM 2025 AUC 0.936386745395992
#
# [mbo] 40: num_leaves=273; min_data_in_leaf=2; lambda_l2=13.2; learning_rate=0.051; num_iterations=4845; early_stopping_rounds=468; feature_fraction=0.156 : y = 0.936 : 162.5 secs : infill_ei
#
# Sat Nov 22 07:06:51 AM 2025 AUC 0.931414490571204
#
# [mbo] 41: num_leaves=150; min_data_in_leaf=18; lambda_l2=35.5; learning_rate=0.0336; num_iterations=4760; early_stopping_rounds=417; feature_fraction=0.176 : y = 0.931 : 295.4 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Sat Nov 22 07:10:20 AM 2025 AUC 0.934376235178695
#
# [mbo] 42: num_leaves=924; min_data_in_leaf=24; lambda_l2=0.0453; learning_rate=0.0486; num_iterations=3154; early_stopping_rounds=403; feature_fraction=0.154 : y = 0.934 : 207.8 secs : infill_ei
#
# Sat Nov 22 07:15:07 AM 2025 AUC 0.936319974445851
#
# [mbo] 43: num_leaves=327; min_data_in_leaf=94; lambda_l2=3.99; learning_rate=0.016; num_iterations=2598; early_stopping_rounds=478; feature_fraction=0.227 : y = 0.936 : 286.5 secs : infill_ei
#
# Sat Nov 22 07:20:14 AM 2025 AUC 0.933216970692586
#
# [mbo] 44: num_leaves=637; min_data_in_leaf=115; lambda_l2=14.4; learning_rate=0.0204; num_iterations=4288; early_stopping_rounds=337; feature_fraction=0.271 : y = 0.933 : 306.6 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Sat Nov 22 07:22:31 AM 2025 AUC 0.935998869926834
#
# [mbo] 45: num_leaves=465; min_data_in_leaf=48; lambda_l2=0.0698; learning_rate=0.0212; num_iterations=3399; early_stopping_rounds=167; feature_fraction=0.205 : y = 0.936 : 135.6 secs : infill_ei
#
# Sat Nov 22 07:24:23 AM 2025 AUC 0.932663677743934
#
# [mbo] 46: num_leaves=3030; min_data_in_leaf=195; lambda_l2=0.494; learning_rate=0.0794; num_iterations=4093; early_stopping_rounds=116; feature_fraction=0.328 : y = 0.933 : 111.6 secs : infill_ei
#
# Sat Nov 22 07:28:06 AM 2025 AUC 0.935740174436591
#
# [mbo] 47: num_leaves=278; min_data_in_leaf=372; lambda_l2=0.337; learning_rate=0.0185; num_iterations=4906; early_stopping_rounds=225; feature_fraction=0.132 : y = 0.936 : 222.7 secs : infill_ei
#
# Sat Nov 22 07:32:14 AM 2025 AUC 0.933882666999515
#
# [mbo] 48: num_leaves=284; min_data_in_leaf=3; lambda_l2=47; learning_rate=0.0337; num_iterations=3462; early_stopping_rounds=132; feature_fraction=0.147 : y = 0.934 : 246.8 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Sat Nov 22 07:39:32 AM 2025 AUC 0.928120568875074
#
# [mbo] 49: num_leaves=4058; min_data_in_leaf=147; lambda_l2=117; learning_rate=0.0498; num_iterations=3902; early_stopping_rounds=388; feature_fraction=0.588 : y = 0.928 : 437.1 secs : infill_ei
#
# Sat Nov 22 07:46:18 AM 2025 AUC 0.929136896553344
#
# [mbo] 50: num_leaves=502; min_data_in_leaf=14; lambda_l2=58.1; learning_rate=0.0537; num_iterations=2694; early_stopping_rounds=486; feature_fraction=0.223 : y = 0.929 : 405.2 secs : infill_ei
#
# Saved the current state after iteration 51 in the file HT.RDATA.
#
# Sat Nov 22 07:50:42 AM 2025 AUC 0.939858834803301
#
# [mbo] 51: num_leaves=919; min_data_in_leaf=519; lambda_l2=0.556; learning_rate=0.0259; num_iterations=2486; early_stopping_rounds=297; feature_fraction=0.0932 : y = 0.94 : 263.1 secs : infill_ei
#
# Sat Nov 22 07:53:00 AM 2025 AUC 0.932245939890039
#
# [mbo] 52: num_leaves=34; min_data_in_leaf=224; lambda_l2=2.89; learning_rate=0.0263; num_iterations=1588; early_stopping_rounds=143; feature_fraction=0.108 : y = 0.932 : 137.9 secs : infill_ei
#
# Sat Nov 22 07:56:35 AM 2025 AUC 0.932246946487278
#
# [mbo] 53: num_leaves=629; min_data_in_leaf=2602; lambda_l2=0.148; learning_rate=0.0273; num_iterations=2621; early_stopping_rounds=308; feature_fraction=0.0549 : y = 0.932 : 213.4 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Sat Nov 22 08:00:42 AM 2025 AUC 0.933403526714084
#
# [mbo] 54: num_leaves=1304; min_data_in_leaf=59; lambda_l2=0.326; learning_rate=0.0147; num_iterations=2334; early_stopping_rounds=293; feature_fraction=0.0535 : y = 0.933 : 245.7 secs : infill_ei
#
# Sat Nov 22 08:03:42 AM 2025 AUC 0.936779653851342
#
# [mbo] 55: num_leaves=1102; min_data_in_leaf=53; lambda_l2=0.0263; learning_rate=0.0259; num_iterations=2739; early_stopping_rounds=285; feature_fraction=0.136 : y = 0.937 : 179.3 secs : infill_ei
#
# Sat Nov 22 08:07:38 AM 2025 AUC 0.932202991741205
#
# [mbo] 56: num_leaves=30; min_data_in_leaf=718; lambda_l2=0.234; learning_rate=0.0283; num_iterations=3171; early_stopping_rounds=249; feature_fraction=0.0854 : y = 0.932 : 235.4 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Sat Nov 22 08:10:57 AM 2025 AUC 0.935624415754186
#
# [mbo] 57: num_leaves=900; min_data_in_leaf=873; lambda_l2=0.52; learning_rate=0.0247; num_iterations=1730; early_stopping_rounds=236; feature_fraction=0.136 : y = 0.936 : 197.8 secs : infill_ei
#
# Sat Nov 22 08:12:33 AM 2025 AUC 0.933505193035152
#
# [mbo] 58: num_leaves=688; min_data_in_leaf=63; lambda_l2=0.679; learning_rate=0.0992; num_iterations=1904; early_stopping_rounds=166; feature_fraction=0.0542 : y = 0.934 : 95.6 secs : infill_ei
#
# Sat Nov 22 08:16:23 AM 2025 AUC 0.935736148047637
#
# [mbo] 59: num_leaves=782; min_data_in_leaf=8; lambda_l2=1.8; learning_rate=0.0719; num_iterations=2248; early_stopping_rounds=340; feature_fraction=0.0598 : y = 0.936 : 228.9 secs : infill_ei
#
# Sat Nov 22 08:17:38 AM 2025 AUC 0.934888257640576
#
# [mbo] 60: num_leaves=148; min_data_in_leaf=147; lambda_l2=2.4; learning_rate=0.0987; num_iterations=1021; early_stopping_rounds=254; feature_fraction=0.21 : y = 0.935 : 74.1 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Sat Nov 22 08:19:58 AM 2025 AUC 0.925948332034823
#
# [mbo] 61: num_leaves=67; min_data_in_leaf=6429; lambda_l2=0.574; learning_rate=0.0997; num_iterations=1773; early_stopping_rounds=498; feature_fraction=0.0614 : y = 0.926 : 138.4 secs : infill_ei
#
# Sat Nov 22 08:23:43 AM 2025 AUC 0.932732797420964
#
# [mbo] 62: num_leaves=764; min_data_in_leaf=233; lambda_l2=0.525; learning_rate=0.0248; num_iterations=2287; early_stopping_rounds=469; feature_fraction=0.191 : y = 0.933 : 224.4 secs : infill_ei
#
# Sat Nov 22 08:25:05 AM 2025 AUC 0.935171782529364
#
# [mbo] 63: num_leaves=479; min_data_in_leaf=431; lambda_l2=0.0477; learning_rate=0.0423; num_iterations=2714; early_stopping_rounds=193; feature_fraction=0.084 : y = 0.935 : 81.0 secs : infill_ei
#
# Sat Nov 22 08:28:02 AM 2025 AUC 0.937518160691841
#
# [mbo] 64: num_leaves=644; min_data_in_leaf=49; lambda_l2=0.207; learning_rate=0.0335; num_iterations=4038; early_stopping_rounds=303; feature_fraction=0.189 : y = 0.938 : 175.9 secs : infill_ei
#
# Saved the current state after iteration 65 in the file HT.RDATA.
#
# Sat Nov 22 08:28:42 AM 2025 AUC 0.935173124659015
#
# [mbo] 65: num_leaves=351; min_data_in_leaf=74; lambda_l2=0.0594; learning_rate=0.0734; num_iterations=4451; early_stopping_rounds=84; feature_fraction=0.196 : y = 0.935 : 38.2 secs : infill_ei
#
# Sat Nov 22 08:30:37 AM 2025 AUC 0.932811983070377
#
# [mbo] 66: num_leaves=1597; min_data_in_leaf=554; lambda_l2=1.42; learning_rate=0.0624; num_iterations=1687; early_stopping_rounds=301; feature_fraction=0.14 : y = 0.933 : 114.1 secs : infill_ei
#
# Sat Nov 22 08:34:00 AM 2025 AUC 0.937847653521178
#
# [mbo] 67: num_leaves=1526; min_data_in_leaf=476; lambda_l2=0.467; learning_rate=0.0233; num_iterations=1507; early_stopping_rounds=296; feature_fraction=0.185 : y = 0.938 : 202.2 secs : infill_ei
#
# Sat Nov 22 08:34:19 AM 2025 AUC 0.914663034863831
#
# [mbo] 68: num_leaves=1980; min_data_in_leaf=549; lambda_l2=4.78; learning_rate=0.0287; num_iterations=203; early_stopping_rounds=314; feature_fraction=0.0525 : y = 0.915 : 17.9 secs : infill_ei
#
# Sat Nov 22 08:38:25 AM 2025 AUC 0.936820588805699
#
# [mbo] 69: num_leaves=1352; min_data_in_leaf=271; lambda_l2=0.382; learning_rate=0.0278; num_iterations=1368; early_stopping_rounds=197; feature_fraction=0.399 : y = 0.937 : 244.5 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Sat Nov 22 08:46:18 AM 2025 AUC 0.933405204376148
#
# [mbo] 70: num_leaves=1544; min_data_in_leaf=479; lambda_l2=0.686; learning_rate=0.0198; num_iterations=2331; early_stopping_rounds=379; feature_fraction=0.481 : y = 0.933 : 471.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf lambda_l2 learning_rate num_iterations
#         <int>            <int>     <num>         <num>          <int>
# 1:        919              519 0.5559374    0.02590609           2486
#    early_stopping_rounds feature_fraction
#                    <int>            <num>
# 1:                   297       0.09324469

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6296700
#
# $envios
# [1] 1523

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_411757990
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Sat Nov 22 08:53:08 AM 2025"
# Inicio: Sat Nov 22 02:48:20 AM 2025
# Fin:    Sat Nov 22 08:53:08 AM 2025
# Duración (hh:mm:ss): 06:04:48
