# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/src/workflows/610_14a_WorkFlow_01_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 13 08:09:00 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660356 35.3 1454477    77.7 1454477  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 999983 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63105
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31
  )
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200


PARAM$hipeparametertuning$hs <- makeParamSet(
  # 6 Existentes (Ajustados para velocidad)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L), # Reducido
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1), # Reducido
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L), # Reducido
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L), # Reducido
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L), # Reducido

  # 10 Nuevos Hiperparámetros
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L), # Reducido
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeNumericParam("subsample", lower = 0.5, upper = 0.9),
  makeNumericParam("colsample_bytree", lower = 0.5, upper = 0.9),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 13 08:27:50 PM 2025 AUC 0.924356230736245
#
# Thu Nov 13 08:35:17 PM 2025 AUC 0.930379708610231
#
# Thu Nov 13 08:37:54 PM 2025 AUC 0.917386551458257
#
# Thu Nov 13 08:39:06 PM 2025 AUC 0.914001700478268
#
# Thu Nov 13 08:42:30 PM 2025 AUC 0.925723189785857
#
# Thu Nov 13 08:45:36 PM 2025 AUC 0.922968468677043
#
# Thu Nov 13 08:50:07 PM 2025 AUC 0.924529365461233
#
# Thu Nov 13 08:52:47 PM 2025 AUC 0.920135904048467
#
# Thu Nov 13 08:55:42 PM 2025 AUC 0.924769606668774
#
# Thu Nov 13 08:56:23 PM 2025 AUC 0.91524149274344
#
# Thu Nov 13 08:56:53 PM 2025 AUC 0.918430057261962
#
# Thu Nov 13 08:57:56 PM 2025 AUC 0.915162307094028
#
# Thu Nov 13 09:05:18 PM 2025 AUC 0.922425577233186
#
# Thu Nov 13 09:06:19 PM 2025 AUC 0.916596372626192
#
# Thu Nov 13 09:07:58 PM 2025 AUC 0.920177845600063
#
# Thu Nov 13 09:11:57 PM 2025 AUC 0.925252102278332
#
# Thu Nov 13 09:13:05 PM 2025 AUC 0.9196111313549
#
# Thu Nov 13 09:13:49 PM 2025 AUC 0.91278673761164
#
# Thu Nov 13 09:15:02 PM 2025 AUC 0.916347743108332
#
# Thu Nov 13 09:16:49 PM 2025 AUC 0.924014323207636
#
# Thu Nov 13 09:18:57 PM 2025 AUC 0.920096311223761
#
# Thu Nov 13 09:19:56 PM 2025 AUC 0.913070598032841
#
# Thu Nov 13 09:24:30 PM 2025 AUC 0.925745670457512
#
# Thu Nov 13 09:27:57 PM 2025 AUC 0.922586968323727
#
# Thu Nov 13 09:29:42 PM 2025 AUC 0.923084227359447
#
# Thu Nov 13 09:31:58 PM 2025 AUC 0.921091164827614
#
# Thu Nov 13 09:33:07 PM 2025 AUC 0.916494706305124
#
# Thu Nov 13 09:34:57 PM 2025 AUC 0.921370327795035
#
# Thu Nov 13 09:36:19 PM 2025 AUC 0.915134122371355
#
# Thu Nov 13 09:36:42 PM 2025 AUC 0.913777229294127
#
# Thu Nov 13 09:37:13 PM 2025 AUC 0.916610129455115
#
# Thu Nov 13 09:40:02 PM 2025 AUC 0.921152902791563
#
# Thu Nov 13 09:43:05 PM 2025 AUC 0.928245386932623
#
# Thu Nov 13 09:46:41 PM 2025 AUC 0.923702949128589
#
# Thu Nov 13 09:47:38 PM 2025 AUC 0.917453322408398
#
# Thu Nov 13 09:50:18 PM 2025 AUC 0.916552753412532
#
# Thu Nov 13 09:52:30 PM 2025 AUC 0.917667392087743
#
# Thu Nov 13 09:54:33 PM 2025 AUC 0.914983468318023
#
# Thu Nov 13 09:55:43 PM 2025 AUC 0.917748590931633
#
# Thu Nov 13 09:58:30 PM 2025 AUC 0.918145525775935
#
# Thu Nov 13 10:01:57 PM 2025 AUC 0.925843981454452
#
# Thu Nov 13 10:02:33 PM 2025 AUC 0.915116674685891
#
# Thu Nov 13 10:04:09 PM 2025 AUC 0.928133990171585
#
# Thu Nov 13 10:05:19 PM 2025 AUC 0.917493250765517
#
# Thu Nov 13 10:09:39 PM 2025 AUC 0.930612568104692
#
# Thu Nov 13 10:11:30 PM 2025 AUC 0.916658781654967
#
# Thu Nov 13 10:12:08 PM 2025 AUC 0.920582833222272
#
# Thu Nov 13 10:14:13 PM 2025 AUC 0.911770745465783
#
# Thu Nov 13 10:15:27 PM 2025 AUC 0.908108409180435
#
# Thu Nov 13 10:17:04 PM 2025 AUC 0.924746454932293
#
# Thu Nov 13 10:19:13 PM 2025 AUC 0.927674310766094
#
# Thu Nov 13 10:22:15 PM 2025 AUC 0.924092502259811
#
# Thu Nov 13 10:24:03 PM 2025 AUC 0.919512484825547
#
# Thu Nov 13 10:24:31 PM 2025 AUC 0.918304903672
#
# Thu Nov 13 10:37:58 PM 2025 AUC 0.921173370268741
#
# Thu Nov 13 10:39:11 PM 2025 AUC 0.919657099295449
#
# Thu Nov 13 10:39:59 PM 2025 AUC 0.916713137905835
#
# Thu Nov 13 10:41:02 PM 2025 AUC 0.915853168331914
#
# Thu Nov 13 10:42:34 PM 2025 AUC 0.925010183408727
#
# Thu Nov 13 10:43:30 PM 2025 AUC 0.917235897404925
#
# Thu Nov 13 10:46:43 PM 2025 AUC 0.927367298608413
#
# Thu Nov 13 10:49:26 PM 2025 AUC 0.920372454399467
#
# Thu Nov 13 10:53:40 PM 2025 AUC 0.925701380179027
#
# Thu Nov 13 10:53:48 PM 2025 AUC 0.912745634891076
#
# [mbo] 0: num_leaves=13; learning_rate=0.0714; feature_fraction=0.408; min_data_in_leaf=1041; num_iterations=2056; early_stopping_rounds=268; bagging_fraction=0.806; bagging_freq=3; lambda_l1=0.39; lambda_l2=0.249; max_depth=17; min_child_weight=3.76; subsample=0.817; colsample_bytree=0.771; min_gain_to_split=0.0398; scale_pos_weight=3.11 : y = 0.924 : 246.1 secs : initdesign
#
# [mbo] 0: num_leaves=43; learning_rate=0.0188; feature_fraction=0.456; min_data_in_leaf=2336; num_iterations=3030; early_stopping_rounds=284; bagging_fraction=0.777; bagging_freq=2; lambda_l1=0.356; lambda_l2=0.222; max_depth=27; min_child_weight=6.5; subsample=0.646; colsample_bytree=0.748; min_gain_to_split=0.0656; scale_pos_weight=2.59 : y = 0.93 : 446.8 secs : initdesign
#
# [mbo] 0: num_leaves=9; learning_rate=0.0205; feature_fraction=0.547; min_data_in_leaf=4352; num_iterations=2642; early_stopping_rounds=195; bagging_fraction=0.606; bagging_freq=3; lambda_l1=0.344; lambda_l2=0.27; max_depth=18; min_child_weight=5.9; subsample=0.728; colsample_bytree=0.844; min_gain_to_split=0.0277; scale_pos_weight=2.86 : y = 0.917 : 157.6 secs : initdesign
#
# [mbo] 0: num_leaves=17; learning_rate=0.0421; feature_fraction=0.638; min_data_in_leaf=6787; num_iterations=3098; early_stopping_rounds=464; bagging_fraction=0.659; bagging_freq=3; lambda_l1=0.309; lambda_l2=0.0436; max_depth=3; min_child_weight=7.9; subsample=0.698; colsample_bytree=0.689; min_gain_to_split=0.0653; scale_pos_weight=4.59 : y = 0.914 : 71.1 secs : initdesign
#
# [mbo] 0: num_leaves=28; learning_rate=0.0654; feature_fraction=0.498; min_data_in_leaf=3331; num_iterations=4091; early_stopping_rounds=213; bagging_fraction=0.71; bagging_freq=5; lambda_l1=0.242; lambda_l2=0.241; max_depth=26; min_child_weight=4.88; subsample=0.594; colsample_bytree=0.606; min_gain_to_split=0.0604; scale_pos_weight=3.39 : y = 0.926 : 204.0 secs : initdesign
#
# [mbo] 0: num_leaves=29; learning_rate=0.0555; feature_fraction=0.356; min_data_in_leaf=6346; num_iterations=1849; early_stopping_rounds=219; bagging_fraction=0.814; bagging_freq=3; lambda_l1=0.285; lambda_l2=0.119; max_depth=10; min_child_weight=2.64; subsample=0.593; colsample_bytree=0.725; min_gain_to_split=0.0781; scale_pos_weight=3.7 : y = 0.923 : 186.8 secs : initdesign
#
# [mbo] 0: num_leaves=42; learning_rate=0.0747; feature_fraction=0.459; min_data_in_leaf=4570; num_iterations=2130; early_stopping_rounds=380; bagging_fraction=0.676; bagging_freq=2; lambda_l1=0.423; lambda_l2=0.431; max_depth=25; min_child_weight=3.65; subsample=0.703; colsample_bytree=0.645; min_gain_to_split=0.0696; scale_pos_weight=4.21 : y = 0.925 : 270.1 secs : initdesign
#
# [mbo] 0: num_leaves=17; learning_rate=0.07; feature_fraction=0.586; min_data_in_leaf=2034; num_iterations=2256; early_stopping_rounds=368; bagging_fraction=0.716; bagging_freq=3; lambda_l1=0.326; lambda_l2=0.279; max_depth=9; min_child_weight=4.34; subsample=0.667; colsample_bytree=0.766; min_gain_to_split=0.056; scale_pos_weight=3.57 : y = 0.92 : 160.5 secs : initdesign
#
# [mbo] 0: num_leaves=21; learning_rate=0.0472; feature_fraction=0.54; min_data_in_leaf=1579; num_iterations=3886; early_stopping_rounds=414; bagging_fraction=0.654; bagging_freq=4; lambda_l1=0.198; lambda_l2=0.353; max_depth=24; min_child_weight=8.82; subsample=0.685; colsample_bytree=0.74; min_gain_to_split=0.00885; scale_pos_weight=3.36 : y = 0.925 : 174.9 secs : initdesign
#
# [mbo] 0: num_leaves=5; learning_rate=0.088; feature_fraction=0.687; min_data_in_leaf=6553; num_iterations=2724; early_stopping_rounds=178; bagging_fraction=0.827; bagging_freq=3; lambda_l1=0.278; lambda_l2=0.188; max_depth=20; min_child_weight=2.2; subsample=0.831; colsample_bytree=0.695; min_gain_to_split=0.0351; scale_pos_weight=4.64 : y = 0.915 : 40.6 secs : initdesign
#
# [mbo] 0: num_leaves=51; learning_rate=0.0525; feature_fraction=0.504; min_data_in_leaf=1238; num_iterations=1097; early_stopping_rounds=96; bagging_fraction=0.757; bagging_freq=2; lambda_l1=0.0509; lambda_l2=0.205; max_depth=19; min_child_weight=8.57; subsample=0.801; colsample_bytree=0.661; min_gain_to_split=0.0744; scale_pos_weight=2.39 : y = 0.918 : 30.2 secs : initdesign
#
# [mbo] 0: num_leaves=33; learning_rate=0.0575; feature_fraction=0.418; min_data_in_leaf=7876; num_iterations=3290; early_stopping_rounds=207; bagging_fraction=0.517; bagging_freq=3; lambda_l1=0.259; lambda_l2=0.0626; max_depth=12; min_child_weight=4; subsample=0.716; colsample_bytree=0.569; min_gain_to_split=0.0821; scale_pos_weight=2.3 : y = 0.915 : 63.5 secs : initdesign
#
# [mbo] 0: num_leaves=49; learning_rate=0.0057; feature_fraction=0.523; min_data_in_leaf=4181; num_iterations=2421; early_stopping_rounds=346; bagging_fraction=0.836; bagging_freq=1; lambda_l1=0.0608; lambda_l2=0.343; max_depth=12; min_child_weight=3.36; subsample=0.622; colsample_bytree=0.708; min_gain_to_split=0.0454; scale_pos_weight=3.31 : y = 0.922 : 442.0 secs : initdesign
#
# [mbo] 0: num_leaves=57; learning_rate=0.0427; feature_fraction=0.674; min_data_in_leaf=4397; num_iterations=1406; early_stopping_rounds=271; bagging_fraction=0.622; bagging_freq=2; lambda_l1=0.332; lambda_l2=0.0716; max_depth=24; min_child_weight=9.04; subsample=0.572; colsample_bytree=0.808; min_gain_to_split=0.0878; scale_pos_weight=3.51 : y = 0.917 : 60.9 secs : initdesign
#
# [mbo] 0: num_leaves=28; learning_rate=0.0217; feature_fraction=0.66; min_data_in_leaf=3874; num_iterations=3784; early_stopping_rounds=123; bagging_fraction=0.891; bagging_freq=4; lambda_l1=0.211; lambda_l2=0.186; max_depth=16; min_child_weight=7.04; subsample=0.747; colsample_bytree=0.828; min_gain_to_split=0.00731; scale_pos_weight=4.26 : y = 0.92 : 98.7 secs : initdesign
#
# [mbo] 0: num_leaves=15; learning_rate=0.0684; feature_fraction=0.354; min_data_in_leaf=2639; num_iterations=4539; early_stopping_rounds=310; bagging_fraction=0.857; bagging_freq=2; lambda_l1=0.114; lambda_l2=0.0174; max_depth=7; min_child_weight=6.7; subsample=0.738; colsample_bytree=0.547; min_gain_to_split=0.00563; scale_pos_weight=3.68 : y = 0.925 : 238.6 secs : initdesign
#
# [mbo] 0: num_leaves=10; learning_rate=0.0847; feature_fraction=0.652; min_data_in_leaf=5738; num_iterations=1288; early_stopping_rounds=158; bagging_fraction=0.735; bagging_freq=4; lambda_l1=0.391; lambda_l2=0.165; max_depth=27; min_child_weight=7.28; subsample=0.638; colsample_bytree=0.672; min_gain_to_split=0.0576; scale_pos_weight=2.99 : y = 0.92 : 68.3 secs : initdesign
#
# [mbo] 0: num_leaves=54; learning_rate=0.0492; feature_fraction=0.488; min_data_in_leaf=5501; num_iterations=278; early_stopping_rounds=112; bagging_fraction=0.567; bagging_freq=3; lambda_l1=0.0887; lambda_l2=0.0943; max_depth=20; min_child_weight=1.32; subsample=0.737; colsample_bytree=0.593; min_gain_to_split=0.0379; scale_pos_weight=4.41 : y = 0.913 : 44.1 secs : initdesign
#
# [mbo] 0: num_leaves=24; learning_rate=0.0604; feature_fraction=0.581; min_data_in_leaf=3155; num_iterations=444; early_stopping_rounds=328; bagging_fraction=0.589; bagging_freq=1; lambda_l1=0.251; lambda_l2=0.154; max_depth=22; min_child_weight=9.84; subsample=0.545; colsample_bytree=0.642; min_gain_to_split=0.025; scale_pos_weight=1.82 : y = 0.916 : 73.5 secs : initdesign
#
# [mbo] 0: num_leaves=59; learning_rate=0.0723; feature_fraction=0.518; min_data_in_leaf=1878; num_iterations=552; early_stopping_rounds=492; bagging_fraction=0.706; bagging_freq=4; lambda_l1=0.152; lambda_l2=0.373; max_depth=16; min_child_weight=4.55; subsample=0.785; colsample_bytree=0.563; min_gain_to_split=0.079; scale_pos_weight=2.34 : y = 0.924 : 106.5 secs : initdesign
#
# [mbo] 0: num_leaves=51; learning_rate=0.0827; feature_fraction=0.7; min_data_in_leaf=6988; num_iterations=3328; early_stopping_rounds=448; bagging_fraction=0.749; bagging_freq=5; lambda_l1=0.361; lambda_l2=0.331; max_depth=10; min_child_weight=2.87; subsample=0.616; colsample_bytree=0.681; min_gain_to_split=0.0296; scale_pos_weight=1.44 : y = 0.92 : 127.5 secs : initdesign
#
# [mbo] 0: num_leaves=26; learning_rate=0.0116; feature_fraction=0.385; min_data_in_leaf=3758; num_iterations=4229; early_stopping_rounds=50; bagging_fraction=0.637; bagging_freq=3; lambda_l1=0.104; lambda_l2=0.488; max_depth=19; min_child_weight=1.15; subsample=0.656; colsample_bytree=0.703; min_gain_to_split=0.0451; scale_pos_weight=3.88 : y = 0.913 : 59.4 secs : initdesign
#
# [mbo] 0: num_leaves=41; learning_rate=0.0386; feature_fraction=0.606; min_data_in_leaf=6411; num_iterations=3205; early_stopping_rounds=356; bagging_fraction=0.755; bagging_freq=3; lambda_l1=0.438; lambda_l2=0.0487; max_depth=20; min_child_weight=3.21; subsample=0.711; colsample_bytree=0.63; min_gain_to_split=0.0434; scale_pos_weight=3.49 : y = 0.926 : 274.3 secs : initdesign
#
# [mbo] 0: num_leaves=38; learning_rate=0.0403; feature_fraction=0.485; min_data_in_leaf=5220; num_iterations=1777; early_stopping_rounds=314; bagging_fraction=0.786; bagging_freq=5; lambda_l1=0.194; lambda_l2=0.482; max_depth=13; min_child_weight=7.66; subsample=0.601; colsample_bytree=0.895; min_gain_to_split=0.0728; scale_pos_weight=1.53 : y = 0.923 : 206.6 secs : initdesign
#
# [mbo] 0: num_leaves=34; learning_rate=0.0315; feature_fraction=0.676; min_data_in_leaf=3329; num_iterations=4266; early_stopping_rounds=200; bagging_fraction=0.663; bagging_freq=2; lambda_l1=0.239; lambda_l2=0.409; max_depth=29; min_child_weight=4.07; subsample=0.895; colsample_bytree=0.716; min_gain_to_split=0.0862; scale_pos_weight=2.45 : y = 0.923 : 104.6 secs : initdesign
#
# [mbo] 0: num_leaves=37; learning_rate=0.0965; feature_fraction=0.573; min_data_in_leaf=251; num_iterations=3703; early_stopping_rounds=230; bagging_fraction=0.615; bagging_freq=4; lambda_l1=0.431; lambda_l2=0.497; max_depth=6; min_child_weight=2.13; subsample=0.79; colsample_bytree=0.594; min_gain_to_split=0.0714; scale_pos_weight=1.92 : y = 0.921 : 136.8 secs : initdesign
#
# [mbo] 0: num_leaves=61; learning_rate=0.045; feature_fraction=0.321; min_data_in_leaf=5570; num_iterations=1644; early_stopping_rounds=365; bagging_fraction=0.535; bagging_freq=5; lambda_l1=0.317; lambda_l2=0.175; max_depth=15; min_child_weight=8.24; subsample=0.585; colsample_bytree=0.687; min_gain_to_split=0.0956; scale_pos_weight=4.93 : y = 0.916 : 68.2 secs : initdesign
#
# [mbo] 0: num_leaves=52; learning_rate=0.0586; feature_fraction=0.618; min_data_in_leaf=7239; num_iterations=938; early_stopping_rounds=387; bagging_fraction=0.844; bagging_freq=4; lambda_l1=0.0417; lambda_l2=0.219; max_depth=14; min_child_weight=7.44; subsample=0.835; colsample_bytree=0.835; min_gain_to_split=0.0204; scale_pos_weight=4.53 : y = 0.921 : 110.2 secs : initdesign
#
# [mbo] 0: num_leaves=4; learning_rate=0.0329; feature_fraction=0.715; min_data_in_leaf=1346; num_iterations=2388; early_stopping_rounds=323; bagging_fraction=0.699; bagging_freq=5; lambda_l1=0.0664; lambda_l2=0.162; max_depth=15; min_child_weight=2.75; subsample=0.854; colsample_bytree=0.759; min_gain_to_split=0.0498; scale_pos_weight=2.8 : y = 0.915 : 82.5 secs : initdesign
#
# [mbo] 0: num_leaves=45; learning_rate=0.0296; feature_fraction=0.625; min_data_in_leaf=5796; num_iterations=1362; early_stopping_rounds=70; bagging_fraction=0.586; bagging_freq=3; lambda_l1=0.46; lambda_l2=0.349; max_depth=21; min_child_weight=4.38; subsample=0.679; colsample_bytree=0.851; min_gain_to_split=0.0419; scale_pos_weight=4.7 : y = 0.914 : 22.4 secs : initdesign
#
# [mbo] 0: num_leaves=22; learning_rate=0.0937; feature_fraction=0.753; min_data_in_leaf=8056; num_iterations=3533; early_stopping_rounds=247; bagging_fraction=0.772; bagging_freq=5; lambda_l1=0.147; lambda_l2=0.253; max_depth=30; min_child_weight=0.154; subsample=0.771; colsample_bytree=0.557; min_gain_to_split=0.0622; scale_pos_weight=1.37 : y = 0.917 : 31.6 secs : initdesign
#
# [mbo] 0: num_leaves=19; learning_rate=0.0455; feature_fraction=0.445; min_data_in_leaf=914; num_iterations=1222; early_stopping_rounds=409; bagging_fraction=0.846; bagging_freq=2; lambda_l1=0.0184; lambda_l2=0.289; max_depth=4; min_child_weight=6.1; subsample=0.523; colsample_bytree=0.586; min_gain_to_split=0.0315; scale_pos_weight=1.57 : y = 0.921 : 168.6 secs : initdesign
#
# [mbo] 0: num_leaves=39; learning_rate=0.0131; feature_fraction=0.4; min_data_in_leaf=699; num_iterations=2497; early_stopping_rounds=188; bagging_fraction=0.611; bagging_freq=3; lambda_l1=0.373; lambda_l2=0.0105; max_depth=12; min_child_weight=3.47; subsample=0.688; colsample_bytree=0.664; min_gain_to_split=0.0588; scale_pos_weight=1.67 : y = 0.928 : 183.2 secs : initdesign
#
# [mbo] 0: num_leaves=25; learning_rate=0.0333; feature_fraction=0.369; min_data_in_leaf=402; num_iterations=3549; early_stopping_rounds=245; bagging_fraction=0.824; bagging_freq=1; lambda_l1=0.296; lambda_l2=0.362; max_depth=4; min_child_weight=5.74; subsample=0.888; colsample_bytree=0.775; min_gain_to_split=0.0526; scale_pos_weight=3.03 : y = 0.924 : 216.4 secs : initdesign
#
# [mbo] 0: num_leaves=35; learning_rate=0.0633; feature_fraction=0.467; min_data_in_leaf=7058; num_iterations=559; early_stopping_rounds=172; bagging_fraction=0.504; bagging_freq=5; lambda_l1=0.0316; lambda_l2=0.389; max_depth=24; min_child_weight=7.6; subsample=0.531; colsample_bytree=0.581; min_gain_to_split=0.0254; scale_pos_weight=1.3 : y = 0.917 : 56.7 secs : initdesign
#
# [mbo] 0: num_leaves=56; learning_rate=0.0257; feature_fraction=0.529; min_data_in_leaf=6202; num_iterations=1026; early_stopping_rounds=472; bagging_fraction=0.598; bagging_freq=1; lambda_l1=0.176; lambda_l2=0.303; max_depth=21; min_child_weight=0.412; subsample=0.555; colsample_bytree=0.799; min_gain_to_split=0.00255; scale_pos_weight=2.02 : y = 0.917 : 160.4 secs : initdesign
#
# [mbo] 0: num_leaves=54; learning_rate=0.016; feature_fraction=0.795; min_data_in_leaf=5290; num_iterations=3406; early_stopping_rounds=344; bagging_fraction=0.691; bagging_freq=4; lambda_l1=0.447; lambda_l2=0.45; max_depth=6; min_child_weight=5.02; subsample=0.658; colsample_bytree=0.609; min_gain_to_split=0.0907; scale_pos_weight=3.98 : y = 0.918 : 131.6 secs : initdesign
#
# [mbo] 0: num_leaves=5; learning_rate=0.0533; feature_fraction=0.426; min_data_in_leaf=4679; num_iterations=1010; early_stopping_rounds=428; bagging_fraction=0.639; bagging_freq=3; lambda_l1=0.0827; lambda_l2=0.23; max_depth=22; min_child_weight=5.37; subsample=0.768; colsample_bytree=0.65; min_gain_to_split=0.013; scale_pos_weight=4.97 : y = 0.915 : 123.3 secs : initdesign
#
# [mbo] 0: num_leaves=7; learning_rate=0.0853; feature_fraction=0.739; min_data_in_leaf=8172; num_iterations=4792; early_stopping_rounds=499; bagging_fraction=0.686; bagging_freq=4; lambda_l1=0.298; lambda_l2=0.284; max_depth=8; min_child_weight=9.15; subsample=0.755; colsample_bytree=0.861; min_gain_to_split=0.0683; scale_pos_weight=1.47 : y = 0.918 : 69.7 secs : initdesign
#
# [mbo] 0: num_leaves=31; learning_rate=0.0275; feature_fraction=0.332; min_data_in_leaf=7508; num_iterations=1948; early_stopping_rounds=454; bagging_fraction=0.523; bagging_freq=3; lambda_l1=0.41; lambda_l2=0.442; max_depth=14; min_child_weight=8.6; subsample=0.863; colsample_bytree=0.793; min_gain_to_split=0.0157; scale_pos_weight=1.04 : y = 0.918 : 166.9 secs : initdesign
#
# [mbo] 0: num_leaves=35; learning_rate=0.0139; feature_fraction=0.726; min_data_in_leaf=2212; num_iterations=4008; early_stopping_rounds=292; bagging_fraction=0.508; bagging_freq=1; lambda_l1=0.159; lambda_l2=0.0856; max_depth=18; min_child_weight=0.261; subsample=0.798; colsample_bytree=0.867; min_gain_to_split=0.00387; scale_pos_weight=3.86 : y = 0.926 : 207.2 secs : initdesign
#
# [mbo] 0: num_leaves=12; learning_rate=0.0894; feature_fraction=0.566; min_data_in_leaf=2973; num_iterations=2904; early_stopping_rounds=61; bagging_fraction=0.766; bagging_freq=4; lambda_l1=0.209; lambda_l2=0.148; max_depth=7; min_child_weight=0.593; subsample=0.67; colsample_bytree=0.874; min_gain_to_split=0.0923; scale_pos_weight=4.37 : y = 0.915 : 35.6 secs : initdesign
#
# [mbo] 0: num_leaves=48; learning_rate=0.0369; feature_fraction=0.768; min_data_in_leaf=52; num_iterations=790; early_stopping_rounds=298; bagging_fraction=0.725; bagging_freq=5; lambda_l1=0.0273; lambda_l2=0.0582; max_depth=13; min_child_weight=5.96; subsample=0.579; colsample_bytree=0.733; min_gain_to_split=0.0983; scale_pos_weight=1.14 : y = 0.928 : 95.8 secs : initdesign
#
# [mbo] 0: num_leaves=62; learning_rate=0.0618; feature_fraction=0.377; min_data_in_leaf=6722; num_iterations=4449; early_stopping_rounds=104; bagging_fraction=0.628; bagging_freq=2; lambda_l1=0.166; lambda_l2=0.314; max_depth=4; min_child_weight=9.96; subsample=0.778; colsample_bytree=0.721; min_gain_to_split=0.0535; scale_pos_weight=4.11 : y = 0.917 : 70.9 secs : initdesign
#
# [mbo] 0: num_leaves=46; learning_rate=0.0183; feature_fraction=0.602; min_data_in_leaf=1703; num_iterations=1483; early_stopping_rounds=475; bagging_fraction=0.886; bagging_freq=2; lambda_l1=0.273; lambda_l2=0.425; max_depth=30; min_child_weight=4.83; subsample=0.568; colsample_bytree=0.504; min_gain_to_split=0.0946; scale_pos_weight=1.69 : y = 0.931 : 259.8 secs : initdesign
#
# [mbo] 0: num_leaves=42; learning_rate=0.0905; feature_fraction=0.326; min_data_in_leaf=5029; num_iterations=4376; early_stopping_rounds=234; bagging_fraction=0.865; bagging_freq=4; lambda_l1=0.483; lambda_l2=0.391; max_depth=3; min_child_weight=1.77; subsample=0.537; colsample_bytree=0.843; min_gain_to_split=0.00938; scale_pos_weight=3.13 : y = 0.917 : 111.1 secs : initdesign
#
# [mbo] 0: num_leaves=22; learning_rate=0.0799; feature_fraction=0.315; min_data_in_leaf=840; num_iterations=1876; early_stopping_rounds=72; bagging_fraction=0.559; bagging_freq=5; lambda_l1=0.134; lambda_l2=0.105; max_depth=22; min_child_weight=9.54; subsample=0.633; colsample_bytree=0.82; min_gain_to_split=0.0195; scale_pos_weight=3.78 : y = 0.921 : 37.4 secs : initdesign
#
# [mbo] 0: num_leaves=15; learning_rate=0.0067; feature_fraction=0.556; min_data_in_leaf=6085; num_iterations=786; early_stopping_rounds=131; bagging_fraction=0.556; bagging_freq=1; lambda_l1=0.49; lambda_l2=0.415; max_depth=26; min_child_weight=2.36; subsample=0.88; colsample_bytree=0.515; min_gain_to_split=0.0897; scale_pos_weight=2.89 : y = 0.912 : 125.6 secs : initdesign
#
# [mbo] 0: num_leaves=2; learning_rate=0.0241; feature_fraction=0.714; min_data_in_leaf=2773; num_iterations=2993; early_stopping_rounds=87; bagging_fraction=0.871; bagging_freq=5; lambda_l1=0.343; lambda_l2=0.000436; max_depth=15; min_child_weight=6.84; subsample=0.561; colsample_bytree=0.553; min_gain_to_split=0.0221; scale_pos_weight=1.96 : y = 0.908 : 73.6 secs : initdesign
#
# [mbo] 0: num_leaves=14; learning_rate=0.0779; feature_fraction=0.694; min_data_in_leaf=4773; num_iterations=4762; early_stopping_rounds=165; bagging_fraction=0.796; bagging_freq=1; lambda_l1=0.098; lambda_l2=0.327; max_depth=26; min_child_weight=8.39; subsample=0.862; colsample_bytree=0.633; min_gain_to_split=0.000352; scale_pos_weight=2.1 : y = 0.925 : 96.9 secs : initdesign
#
# [mbo] 0: num_leaves=60; learning_rate=0.0955; feature_fraction=0.596; min_data_in_leaf=614; num_iterations=2595; early_stopping_rounds=397; bagging_fraction=0.811; bagging_freq=1; lambda_l1=0.0144; lambda_l2=0.2; max_depth=23; min_child_weight=0.968; subsample=0.808; colsample_bytree=0.525; min_gain_to_split=0.018; scale_pos_weight=4.81 : y = 0.928 : 128.8 secs : initdesign
#
# [mbo] 0: num_leaves=30; learning_rate=0.0752; feature_fraction=0.748; min_data_in_leaf=2532; num_iterations=3946; early_stopping_rounds=444; bagging_fraction=0.67; bagging_freq=5; lambda_l1=0.405; lambda_l2=0.128; max_depth=17; min_child_weight=9.44; subsample=0.871; colsample_bytree=0.521; min_gain_to_split=0.0836; scale_pos_weight=3.2 : y = 0.924 : 181.8 secs : initdesign
#
# [mbo] 0: num_leaves=47; learning_rate=0.0542; feature_fraction=0.387; min_data_in_leaf=3602; num_iterations=669; early_stopping_rounds=333; bagging_fraction=0.85; bagging_freq=4; lambda_l1=0.465; lambda_l2=0.259; max_depth=28; min_child_weight=1.89; subsample=0.844; colsample_bytree=0.803; min_gain_to_split=0.0852; scale_pos_weight=2.17 : y = 0.92 : 108.4 secs : initdesign
#
# [mbo] 0: num_leaves=32; learning_rate=0.0977; feature_fraction=0.347; min_data_in_leaf=267; num_iterations=198; early_stopping_rounds=389; bagging_fraction=0.545; bagging_freq=1; lambda_l1=0.119; lambda_l2=0.309; max_depth=9; min_child_weight=0.767; subsample=0.629; colsample_bytree=0.88; min_gain_to_split=0.0365; scale_pos_weight=2.53 : y = 0.918 : 28.0 secs : initdesign
#
# [mbo] 0: num_leaves=18; learning_rate=0.00943; feature_fraction=0.475; min_data_in_leaf=7355; num_iterations=4924; early_stopping_rounds=435; bagging_fraction=0.896; bagging_freq=1; lambda_l1=0.227; lambda_l2=0.112; max_depth=11; min_child_weight=5.6; subsample=0.82; colsample_bytree=0.625; min_gain_to_split=0.0993; scale_pos_weight=1.8 : y = 0.921 : 807.1 secs : initdesign
#
# [mbo] 0: num_leaves=63; learning_rate=0.0921; feature_fraction=0.791; min_data_in_leaf=4054; num_iterations=2838; early_stopping_rounds=260; bagging_fraction=0.646; bagging_freq=5; lambda_l1=0.475; lambda_l2=0.0904; max_depth=29; min_child_weight=1.47; subsample=0.511; colsample_bytree=0.89; min_gain_to_split=0.0342; scale_pos_weight=1.19 : y = 0.92 : 72.5 secs : initdesign
#
# [mbo] 0: num_leaves=3; learning_rate=0.0764; feature_fraction=0.628; min_data_in_leaf=4894; num_iterations=4635; early_stopping_rounds=279; bagging_fraction=0.539; bagging_freq=1; lambda_l1=0.494; lambda_l2=0.405; max_depth=8; min_child_weight=6.31; subsample=0.762; colsample_bytree=0.783; min_gain_to_split=0.064; scale_pos_weight=4.85 : y = 0.917 : 48.8 secs : initdesign
#
# [mbo] 0: num_leaves=40; learning_rate=0.035; feature_fraction=0.733; min_data_in_leaf=5990; num_iterations=1603; early_stopping_rounds=81; bagging_fraction=0.575; bagging_freq=1; lambda_l1=0.00608; lambda_l2=0.465; max_depth=28; min_child_weight=8.08; subsample=0.609; colsample_bytree=0.754; min_gain_to_split=0.0751; scale_pos_weight=4.46 : y = 0.916 : 62.4 secs : initdesign
#
# [mbo] 0: num_leaves=48; learning_rate=0.0673; feature_fraction=0.647; min_data_in_leaf=7673; num_iterations=4929; early_stopping_rounds=143; bagging_fraction=0.722; bagging_freq=1; lambda_l1=0.0773; lambda_l2=0.025; max_depth=11; min_child_weight=1.63; subsample=0.513; colsample_bytree=0.537; min_gain_to_split=0.0307; scale_pos_weight=2.67 : y = 0.925 : 92.1 secs : initdesign
#
# [mbo] 0: num_leaves=11; learning_rate=0.099; feature_fraction=0.411; min_data_in_leaf=7689; num_iterations=400; early_stopping_rounds=115; bagging_fraction=0.74; bagging_freq=4; lambda_l1=0.18; lambda_l2=0.377; max_depth=7; min_child_weight=5.18; subsample=0.842; colsample_bytree=0.511; min_gain_to_split=0.0513; scale_pos_weight=2.73 : y = 0.917 : 56.2 secs : initdesign
#
# [mbo] 0: num_leaves=24; learning_rate=0.0266; feature_fraction=0.301; min_data_in_leaf=2147; num_iterations=4576; early_stopping_rounds=140; bagging_fraction=0.79; bagging_freq=2; lambda_l1=0.376; lambda_l2=0.14; max_depth=29; min_child_weight=6.99; subsample=0.504; colsample_bytree=0.885; min_gain_to_split=0.0805; scale_pos_weight=4 : y = 0.927 : 193.4 secs : initdesign
#
# [mbo] 0: num_leaves=59; learning_rate=0.00968; feature_fraction=0.784; min_data_in_leaf=3534; num_iterations=2187; early_stopping_rounds=151; bagging_fraction=0.877; bagging_freq=2; lambda_l1=0.421; lambda_l2=0.454; max_depth=5; min_child_weight=9.34; subsample=0.724; colsample_bytree=0.815; min_gain_to_split=0.0122; scale_pos_weight=2.23 : y = 0.92 : 162.3 secs : initdesign
#
# [mbo] 0: num_leaves=56; learning_rate=0.0499; feature_fraction=0.44; min_data_in_leaf=1511; num_iterations=3651; early_stopping_rounds=417; bagging_fraction=0.528; bagging_freq=5; lambda_l1=0.132; lambda_l2=0.472; max_depth=5; min_child_weight=2.99; subsample=0.543; colsample_bytree=0.543; min_gain_to_split=0.0484; scale_pos_weight=4.17 : y = 0.926 : 253.9 secs : initdesign
#
# [mbo] 0: num_leaves=7; learning_rate=0.081; feature_fraction=0.775; min_data_in_leaf=2898; num_iterations=150; early_stopping_rounds=483; bagging_fraction=0.576; bagging_freq=2; lambda_l1=0.221; lambda_l2=0.035; max_depth=23; min_child_weight=0.928; subsample=0.886; colsample_bytree=0.615; min_gain_to_split=0.0145; scale_pos_weight=1.11 : y = 0.913 : 8.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 13 11:00:51 PM 2025 AUC 0.929109382895497
#
# [mbo] 1: num_leaves=44; learning_rate=0.0334; feature_fraction=0.532; min_data_in_leaf=1473; num_iterations=3069; early_stopping_rounds=429; bagging_fraction=0.779; bagging_freq=4; lambda_l1=0.267; lambda_l2=0.143; max_depth=24; min_child_weight=4.72; subsample=0.633; colsample_bytree=0.624; min_gain_to_split=0.0591; scale_pos_weight=1.84 : y = 0.929 : 418.3 secs : infill_ei
#
# Thu Nov 13 11:03:34 PM 2025 AUC 0.926815683321825
#
# [mbo] 2: num_leaves=35; learning_rate=0.0549; feature_fraction=0.473; min_data_in_leaf=1734; num_iterations=3761; early_stopping_rounds=305; bagging_fraction=0.785; bagging_freq=2; lambda_l1=0.315; lambda_l2=0.173; max_depth=27; min_child_weight=5.7; subsample=0.732; colsample_bytree=0.634; min_gain_to_split=0.0394; scale_pos_weight=3.95 : y = 0.927 : 160.7 secs : infill_ei
#
# Thu Nov 13 11:05:46 PM 2025 AUC 0.926178842802394
#
# [mbo] 3: num_leaves=41; learning_rate=0.0284; feature_fraction=0.575; min_data_in_leaf=311; num_iterations=2564; early_stopping_rounds=298; bagging_fraction=0.751; bagging_freq=3; lambda_l1=0.311; lambda_l2=0.13; max_depth=27; min_child_weight=6.56; subsample=0.518; colsample_bytree=0.592; min_gain_to_split=0.0963; scale_pos_weight=2.96 : y = 0.926 : 130.5 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Thu Nov 13 11:09:50 PM 2025 AUC 0.929350966232689
#
# [mbo] 4: num_leaves=40; learning_rate=0.0419; feature_fraction=0.346; min_data_in_leaf=1074; num_iterations=2952; early_stopping_rounds=365; bagging_fraction=0.8; bagging_freq=2; lambda_l1=0.384; lambda_l2=0.166; max_depth=28; min_child_weight=2.39; subsample=0.541; colsample_bytree=0.667; min_gain_to_split=0.0644; scale_pos_weight=1.75 : y = 0.929 : 241.9 secs : infill_ei
#
# Thu Nov 13 11:13:50 PM 2025 AUC 0.928761771315871
#
# [mbo] 5: num_leaves=41; learning_rate=0.0186; feature_fraction=0.394; min_data_in_leaf=1672; num_iterations=4555; early_stopping_rounds=254; bagging_fraction=0.735; bagging_freq=2; lambda_l1=0.114; lambda_l2=0.00517; max_depth=18; min_child_weight=5.89; subsample=0.602; colsample_bytree=0.779; min_gain_to_split=0.0415; scale_pos_weight=1.46 : y = 0.929 : 237.6 secs : infill_ei
#
# Thu Nov 13 11:18:32 PM 2025 AUC 0.928231965636112
#
# [mbo] 6: num_leaves=44; learning_rate=0.0271; feature_fraction=0.499; min_data_in_leaf=770; num_iterations=3549; early_stopping_rounds=457; bagging_fraction=0.816; bagging_freq=2; lambda_l1=0.368; lambda_l2=0.395; max_depth=28; min_child_weight=6.31; subsample=0.743; colsample_bytree=0.576; min_gain_to_split=0.0296; scale_pos_weight=1.85 : y = 0.928 : 280.0 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Thu Nov 13 11:25:14 PM 2025 AUC 0.928964432893182
#
# [mbo] 7: num_leaves=43; learning_rate=0.0199; feature_fraction=0.422; min_data_in_leaf=587; num_iterations=2652; early_stopping_rounds=373; bagging_fraction=0.819; bagging_freq=2; lambda_l1=0.401; lambda_l2=0.323; max_depth=26; min_child_weight=5.5; subsample=0.692; colsample_bytree=0.739; min_gain_to_split=0.0612; scale_pos_weight=1.76 : y = 0.929 : 400.7 secs : infill_ei
#
# Thu Nov 13 11:32:49 PM 2025 AUC 0.930601831067483
#
# [mbo] 8: num_leaves=42; learning_rate=0.0187; feature_fraction=0.426; min_data_in_leaf=2289; num_iterations=3635; early_stopping_rounds=391; bagging_fraction=0.794; bagging_freq=2; lambda_l1=0.397; lambda_l2=0.115; max_depth=23; min_child_weight=2.42; subsample=0.543; colsample_bytree=0.696; min_gain_to_split=0.0717; scale_pos_weight=2.04 : y = 0.931 : 453.2 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Thu Nov 13 11:40:49 PM 2025 AUC 0.931557427379042
#
# [mbo] 9: num_leaves=43; learning_rate=0.0174; feature_fraction=0.373; min_data_in_leaf=1658; num_iterations=3321; early_stopping_rounds=356; bagging_fraction=0.727; bagging_freq=1; lambda_l1=0.409; lambda_l2=0.0225; max_depth=21; min_child_weight=7.84; subsample=0.795; colsample_bytree=0.753; min_gain_to_split=0.0197; scale_pos_weight=2.5 : y = 0.932 : 477.3 secs : infill_ei
#
# Thu Nov 13 11:43:52 PM 2025 AUC 0.924190813256751
#
# [mbo] 10: num_leaves=43; learning_rate=0.026; feature_fraction=0.406; min_data_in_leaf=1683; num_iterations=3101; early_stopping_rounds=357; bagging_fraction=0.662; bagging_freq=2; lambda_l1=0.36; lambda_l2=0.0727; max_depth=17; min_child_weight=6.83; subsample=0.531; colsample_bytree=0.737; min_gain_to_split=0.0481; scale_pos_weight=1.55 : y = 0.924 : 181.1 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Thu Nov 13 11:48:12 PM 2025 AUC 0.932422765471567
#
# [mbo] 11: num_leaves=42; learning_rate=0.0357; feature_fraction=0.547; min_data_in_leaf=1810; num_iterations=4661; early_stopping_rounds=454; bagging_fraction=0.74; bagging_freq=1; lambda_l1=0.425; lambda_l2=0.0254; max_depth=22; min_child_weight=6.9; subsample=0.772; colsample_bytree=0.803; min_gain_to_split=0.038; scale_pos_weight=2.87 : y = 0.932 : 258.8 secs : infill_ei
#
# Fri Nov 14 12:01:46 AM 2025 AUC 0.927721285303882
#
# [mbo] 12: num_leaves=43; learning_rate=0.00892; feature_fraction=0.529; min_data_in_leaf=2409; num_iterations=4349; early_stopping_rounds=400; bagging_fraction=0.754; bagging_freq=1; lambda_l1=0.365; lambda_l2=0.0237; max_depth=23; min_child_weight=7.28; subsample=0.796; colsample_bytree=0.859; min_gain_to_split=0.0496; scale_pos_weight=2.8 : y = 0.928 : 811.9 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Fri Nov 14 12:06:06 AM 2025 AUC 0.929854264851839
#
# [mbo] 13: num_leaves=42; learning_rate=0.0343; feature_fraction=0.412; min_data_in_leaf=2096; num_iterations=4410; early_stopping_rounds=383; bagging_fraction=0.755; bagging_freq=1; lambda_l1=0.407; lambda_l2=0.0489; max_depth=25; min_child_weight=3.24; subsample=0.775; colsample_bytree=0.722; min_gain_to_split=0.019; scale_pos_weight=2.57 : y = 0.93 : 257.5 secs : infill_ei
#
# Fri Nov 14 12:09:53 AM 2025 AUC 0.928673526291313
#
# [mbo] 14: num_leaves=43; learning_rate=0.0558; feature_fraction=0.55; min_data_in_leaf=905; num_iterations=4353; early_stopping_rounds=467; bagging_fraction=0.722; bagging_freq=1; lambda_l1=0.41; lambda_l2=0.0399; max_depth=20; min_child_weight=7.75; subsample=0.75; colsample_bytree=0.664; min_gain_to_split=0.0292; scale_pos_weight=4.32 : y = 0.929 : 225.2 secs : infill_ei
#
# Fri Nov 14 12:17:41 AM 2025 AUC 0.930734030838113
#
# [mbo] 15: num_leaves=40; learning_rate=0.0205; feature_fraction=0.358; min_data_in_leaf=1589; num_iterations=3117; early_stopping_rounds=465; bagging_fraction=0.744; bagging_freq=3; lambda_l1=0.478; lambda_l2=0.0942; max_depth=24; min_child_weight=4.1; subsample=0.696; colsample_bytree=0.839; min_gain_to_split=0.0345; scale_pos_weight=2.6 : y = 0.931 : 465.8 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Fri Nov 14 12:21:36 AM 2025 AUC 0.930612232572279
#
# [mbo] 16: num_leaves=38; learning_rate=0.0315; feature_fraction=0.391; min_data_in_leaf=985; num_iterations=4718; early_stopping_rounds=396; bagging_fraction=0.729; bagging_freq=1; lambda_l1=0.412; lambda_l2=0.119; max_depth=21; min_child_weight=8.11; subsample=0.732; colsample_bytree=0.874; min_gain_to_split=0.0609; scale_pos_weight=3.21 : y = 0.931 : 232.1 secs : infill_ei
#
# Fri Nov 14 12:25:44 AM 2025 AUC 0.928925846665714
#
# [mbo] 17: num_leaves=47; learning_rate=0.0452; feature_fraction=0.401; min_data_in_leaf=2054; num_iterations=4690; early_stopping_rounds=434; bagging_fraction=0.763; bagging_freq=2; lambda_l1=0.369; lambda_l2=0.36; max_depth=28; min_child_weight=6.86; subsample=0.619; colsample_bytree=0.523; min_gain_to_split=0.0772; scale_pos_weight=2.07 : y = 0.929 : 246.1 secs : infill_ei
#
# Fri Nov 14 12:32:40 AM 2025 AUC 0.929151659979506
#
# [mbo] 18: num_leaves=40; learning_rate=0.0284; feature_fraction=0.414; min_data_in_leaf=1826; num_iterations=4131; early_stopping_rounds=462; bagging_fraction=0.732; bagging_freq=1; lambda_l1=0.438; lambda_l2=0.246; max_depth=23; min_child_weight=8.36; subsample=0.719; colsample_bytree=0.74; min_gain_to_split=0.0359; scale_pos_weight=2 : y = 0.929 : 414.3 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Fri Nov 14 12:34:26 AM 2025 AUC 0.922134335098905
#
# [mbo] 19: num_leaves=36; learning_rate=0.0671; feature_fraction=0.614; min_data_in_leaf=1733; num_iterations=4840; early_stopping_rounds=450; bagging_fraction=0.738; bagging_freq=2; lambda_l1=0.37; lambda_l2=0.182; max_depth=23; min_child_weight=7.14; subsample=0.541; colsample_bytree=0.762; min_gain_to_split=0.0328; scale_pos_weight=2.21 : y = 0.922 : 103.7 secs : infill_ei
#
# Fri Nov 14 12:39:08 AM 2025 AUC 0.92871915869945
#
# [mbo] 20: num_leaves=59; learning_rate=0.0212; feature_fraction=0.5; min_data_in_leaf=1323; num_iterations=3675; early_stopping_rounds=367; bagging_fraction=0.743; bagging_freq=1; lambda_l1=0.429; lambda_l2=0.00964; max_depth=21; min_child_weight=6.5; subsample=0.707; colsample_bytree=0.628; min_gain_to_split=0.0694; scale_pos_weight=3.14 : y = 0.929 : 279.6 secs : infill_ei
#
# Fri Nov 14 12:47:26 AM 2025 AUC 0.932129174610397
#
# [mbo] 21: num_leaves=47; learning_rate=0.0127; feature_fraction=0.354; min_data_in_leaf=1459; num_iterations=3329; early_stopping_rounds=295; bagging_fraction=0.829; bagging_freq=3; lambda_l1=0.162; lambda_l2=0.281; max_depth=28; min_child_weight=3.84; subsample=0.59; colsample_bytree=0.758; min_gain_to_split=0.0787; scale_pos_weight=1.79 : y = 0.932 : 495.2 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Fri Nov 14 12:53:39 AM 2025 AUC 0.934063854502409
#
# [mbo] 22: num_leaves=52; learning_rate=0.0169; feature_fraction=0.333; min_data_in_leaf=460; num_iterations=3292; early_stopping_rounds=346; bagging_fraction=0.802; bagging_freq=2; lambda_l1=0.333; lambda_l2=0.0685; max_depth=28; min_child_weight=3.17; subsample=0.604; colsample_bytree=0.675; min_gain_to_split=0.0542; scale_pos_weight=3.2 : y = 0.934 : 370.8 secs : infill_ei
#
# Fri Nov 14 12:59:37 AM 2025 AUC 0.929965661612877
#
# [mbo] 23: num_leaves=47; learning_rate=0.027; feature_fraction=0.566; min_data_in_leaf=570; num_iterations=4689; early_stopping_rounds=441; bagging_fraction=0.678; bagging_freq=2; lambda_l1=0.449; lambda_l2=0.0928; max_depth=18; min_child_weight=4.7; subsample=0.79; colsample_bytree=0.83; min_gain_to_split=0.045; scale_pos_weight=1.88 : y = 0.93 : 355.7 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Fri Nov 14 01:06:49 AM 2025 AUC 0.934063183437583
#
# [mbo] 24: num_leaves=48; learning_rate=0.0165; feature_fraction=0.331; min_data_in_leaf=975; num_iterations=3357; early_stopping_rounds=362; bagging_fraction=0.876; bagging_freq=3; lambda_l1=0.309; lambda_l2=0.0371; max_depth=30; min_child_weight=3.48; subsample=0.571; colsample_bytree=0.616; min_gain_to_split=0.0843; scale_pos_weight=3.32 : y = 0.934 : 429.6 secs : infill_ei
#
# Fri Nov 14 01:15:30 AM 2025 AUC 0.929530476073519
#
# [mbo] 25: num_leaves=48; learning_rate=0.0195; feature_fraction=0.371; min_data_in_leaf=2596; num_iterations=3224; early_stopping_rounds=469; bagging_fraction=0.834; bagging_freq=2; lambda_l1=0.427; lambda_l2=0.0425; max_depth=29; min_child_weight=3.68; subsample=0.606; colsample_bytree=0.728; min_gain_to_split=0.0714; scale_pos_weight=3.11 : y = 0.93 : 519.1 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Fri Nov 14 01:22:01 AM 2025 AUC 0.93370382822351
#
# [mbo] 26: num_leaves=57; learning_rate=0.0161; feature_fraction=0.514; min_data_in_leaf=798; num_iterations=3334; early_stopping_rounds=375; bagging_fraction=0.824; bagging_freq=2; lambda_l1=0.252; lambda_l2=0.0934; max_depth=28; min_child_weight=1.95; subsample=0.576; colsample_bytree=0.816; min_gain_to_split=0.0858; scale_pos_weight=1.84 : y = 0.934 : 388.3 secs : infill_ei
#
# Fri Nov 14 01:30:04 AM 2025 AUC 0.935038911693909
#
# [mbo] 27: num_leaves=51; learning_rate=0.0169; feature_fraction=0.43; min_data_in_leaf=118; num_iterations=3618; early_stopping_rounds=367; bagging_fraction=0.824; bagging_freq=3; lambda_l1=0.215; lambda_l2=0.0451; max_depth=30; min_child_weight=3.75; subsample=0.57; colsample_bytree=0.545; min_gain_to_split=0.0502; scale_pos_weight=3.35 : y = 0.935 : 478.9 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Fri Nov 14 01:33:55 AM 2025 AUC 0.928904372591297
#
# [mbo] 28: num_leaves=56; learning_rate=0.0275; feature_fraction=0.541; min_data_in_leaf=830; num_iterations=4205; early_stopping_rounds=398; bagging_fraction=0.871; bagging_freq=2; lambda_l1=0.209; lambda_l2=0.331; max_depth=30; min_child_weight=3.25; subsample=0.544; colsample_bytree=0.709; min_gain_to_split=0.0647; scale_pos_weight=3.42 : y = 0.929 : 228.3 secs : infill_ei
#
# Fri Nov 14 01:38:37 AM 2025 AUC 0.935671054759561
#
# [mbo] 29: num_leaves=60; learning_rate=0.0122; feature_fraction=0.444; min_data_in_leaf=459; num_iterations=1586; early_stopping_rounds=232; bagging_fraction=0.814; bagging_freq=3; lambda_l1=0.197; lambda_l2=0.031; max_depth=27; min_child_weight=1.79; subsample=0.65; colsample_bytree=0.643; min_gain_to_split=0.0203; scale_pos_weight=3.84 : y = 0.936 : 279.6 secs : infill_ei
#
# Fri Nov 14 01:43:37 AM 2025 AUC 0.934460453814299
#
# [mbo] 30: num_leaves=57; learning_rate=0.0129; feature_fraction=0.433; min_data_in_leaf=212; num_iterations=1781; early_stopping_rounds=336; bagging_fraction=0.819; bagging_freq=3; lambda_l1=0.117; lambda_l2=0.0227; max_depth=29; min_child_weight=2.66; subsample=0.607; colsample_bytree=0.615; min_gain_to_split=0.0289; scale_pos_weight=2.37 : y = 0.934 : 297.0 secs : infill_ei
#
# Saved the current state after iteration 31 in the file HT.RDATA.
#
# Fri Nov 14 01:47:53 AM 2025 AUC 0.933661551139502
#
# [mbo] 31: num_leaves=56; learning_rate=0.0138; feature_fraction=0.418; min_data_in_leaf=114; num_iterations=1895; early_stopping_rounds=257; bagging_fraction=0.84; bagging_freq=4; lambda_l1=0.181; lambda_l2=0.0425; max_depth=29; min_child_weight=2.08; subsample=0.599; colsample_bytree=0.682; min_gain_to_split=0.0749; scale_pos_weight=3.66 : y = 0.934 : 254.0 secs : infill_ei
#
# Fri Nov 14 01:55:26 AM 2025 AUC 0.934277924181754
#
# [mbo] 32: num_leaves=57; learning_rate=0.0135; feature_fraction=0.553; min_data_in_leaf=457; num_iterations=3292; early_stopping_rounds=255; bagging_fraction=0.835; bagging_freq=3; lambda_l1=0.258; lambda_l2=0.0558; max_depth=30; min_child_weight=3.02; subsample=0.665; colsample_bytree=0.63; min_gain_to_split=0.00806; scale_pos_weight=1.9 : y = 0.934 : 449.9 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Fri Nov 14 02:00:19 AM 2025 AUC 0.932360691975206
#
# [mbo] 33: num_leaves=61; learning_rate=0.0134; feature_fraction=0.448; min_data_in_leaf=26; num_iterations=2814; early_stopping_rounds=224; bagging_fraction=0.809; bagging_freq=2; lambda_l1=0.128; lambda_l2=0.0815; max_depth=28; min_child_weight=0.512; subsample=0.692; colsample_bytree=0.587; min_gain_to_split=0.0497; scale_pos_weight=3.44 : y = 0.932 : 290.3 secs : infill_ei
#
# Fri Nov 14 02:06:27 AM 2025 AUC 0.933888706582945
#
# [mbo] 34: num_leaves=59; learning_rate=0.0112; feature_fraction=0.498; min_data_in_leaf=265; num_iterations=2411; early_stopping_rounds=188; bagging_fraction=0.844; bagging_freq=2; lambda_l1=0.255; lambda_l2=0.0547; max_depth=29; min_child_weight=2.61; subsample=0.554; colsample_bytree=0.511; min_gain_to_split=0.0381; scale_pos_weight=4.33 : y = 0.934 : 365.2 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Fri Nov 14 02:11:59 AM 2025 AUC 0.930020017863746
#
# [mbo] 35: num_leaves=58; learning_rate=0.0117; feature_fraction=0.563; min_data_in_leaf=1030; num_iterations=1606; early_stopping_rounds=413; bagging_fraction=0.84; bagging_freq=4; lambda_l1=0.351; lambda_l2=0.0392; max_depth=25; min_child_weight=1.74; subsample=0.736; colsample_bytree=0.611; min_gain_to_split=0.0183; scale_pos_weight=2.73 : y = 0.93 : 328.9 secs : infill_ei
#
# Fri Nov 14 02:20:45 AM 2025 AUC 0.934520849648597
#
# [mbo] 36: num_leaves=52; learning_rate=0.0129; feature_fraction=0.541; min_data_in_leaf=586; num_iterations=3496; early_stopping_rounds=354; bagging_fraction=0.805; bagging_freq=3; lambda_l1=0.184; lambda_l2=0.0208; max_depth=29; min_child_weight=4.42; subsample=0.576; colsample_bytree=0.775; min_gain_to_split=0.0597; scale_pos_weight=3.9 : y = 0.935 : 523.6 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Fri Nov 14 02:27:40 AM 2025 AUC 0.934415492470988
#
# [mbo] 37: num_leaves=50; learning_rate=0.0152; feature_fraction=0.471; min_data_in_leaf=347; num_iterations=3283; early_stopping_rounds=237; bagging_fraction=0.824; bagging_freq=3; lambda_l1=0.281; lambda_l2=0.0788; max_depth=27; min_child_weight=1.1; subsample=0.625; colsample_bytree=0.815; min_gain_to_split=0.00438; scale_pos_weight=4.23 : y = 0.934 : 411.1 secs : infill_ei
#
# Fri Nov 14 02:32:29 AM 2025 AUC 0.933346150671501
#
# [mbo] 38: num_leaves=55; learning_rate=0.0125; feature_fraction=0.363; min_data_in_leaf=841; num_iterations=2096; early_stopping_rounds=252; bagging_fraction=0.815; bagging_freq=3; lambda_l1=0.344; lambda_l2=0.105; max_depth=29; min_child_weight=3.33; subsample=0.555; colsample_bytree=0.57; min_gain_to_split=0.0191; scale_pos_weight=4.05 : y = 0.933 : 286.7 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Fri Nov 14 02:38:48 AM 2025 AUC 0.932490878551359
#
# [mbo] 39: num_leaves=45; learning_rate=0.0155; feature_fraction=0.579; min_data_in_leaf=37; num_iterations=3338; early_stopping_rounds=223; bagging_fraction=0.771; bagging_freq=2; lambda_l1=0.276; lambda_l2=0.00361; max_depth=25; min_child_weight=2.78; subsample=0.822; colsample_bytree=0.826; min_gain_to_split=0.0453; scale_pos_weight=1.21 : y = 0.932 : 375.9 secs : infill_ei
#
# Fri Nov 14 02:44:49 AM 2025 AUC 0.934551047565746
#
# [mbo] 40: num_leaves=59; learning_rate=0.0111; feature_fraction=0.445; min_data_in_leaf=403; num_iterations=2031; early_stopping_rounds=312; bagging_fraction=0.826; bagging_freq=3; lambda_l1=0.255; lambda_l2=0.0814; max_depth=28; min_child_weight=0.692; subsample=0.599; colsample_bytree=0.762; min_gain_to_split=0.0557; scale_pos_weight=2.93 : y = 0.935 : 359.1 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Fri Nov 14 02:50:49 AM 2025 AUC 0.931510117308842
#
# [mbo] 41: num_leaves=54; learning_rate=0.0121; feature_fraction=0.54; min_data_in_leaf=531; num_iterations=1774; early_stopping_rounds=230; bagging_fraction=0.87; bagging_freq=2; lambda_l1=0.25; lambda_l2=0.0187; max_depth=28; min_child_weight=6.28; subsample=0.543; colsample_bytree=0.747; min_gain_to_split=0.0181; scale_pos_weight=1.98 : y = 0.932 : 356.2 secs : infill_ei
#
# Fri Nov 14 02:58:35 AM 2025 AUC 0.929417066118004
#
# [mbo] 42: num_leaves=50; learning_rate=0.0108; feature_fraction=0.374; min_data_in_leaf=726; num_iterations=2949; early_stopping_rounds=400; bagging_fraction=0.832; bagging_freq=3; lambda_l1=0.124; lambda_l2=0.0442; max_depth=25; min_child_weight=1.66; subsample=0.72; colsample_bytree=0.694; min_gain_to_split=0.0615; scale_pos_weight=3.48 : y = 0.929 : 463.3 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Fri Nov 14 03:01:10 AM 2025 AUC 0.930840730145373
#
# [mbo] 43: num_leaves=55; learning_rate=0.0121; feature_fraction=0.758; min_data_in_leaf=39; num_iterations=2298; early_stopping_rounds=138; bagging_fraction=0.774; bagging_freq=4; lambda_l1=0.315; lambda_l2=0.00356; max_depth=30; min_child_weight=2.04; subsample=0.656; colsample_bytree=0.758; min_gain_to_split=0.00534; scale_pos_weight=4.6 : y = 0.931 : 151.8 secs : infill_ei
#
# Fri Nov 14 03:03:30 AM 2025 AUC 0.929057710903931
#
# [mbo] 44: num_leaves=53; learning_rate=0.0132; feature_fraction=0.346; min_data_in_leaf=293; num_iterations=910; early_stopping_rounds=249; bagging_fraction=0.801; bagging_freq=3; lambda_l1=0.243; lambda_l2=0.00575; max_depth=22; min_child_weight=1.11; subsample=0.624; colsample_bytree=0.631; min_gain_to_split=0.0358; scale_pos_weight=2.09 : y = 0.929 : 135.9 secs : infill_ei
#
# Fri Nov 14 03:07:41 AM 2025 AUC 0.931712107821328
#
# ...
#
# [mbo] 63: num_leaves=45; learning_rate=0.0402; feature_fraction=0.497; min_data_in_leaf=650; num_iterations=4527; early_stopping_rounds=497; bagging_fraction=0.739; bagging_freq=3; lambda_l1=0.352; lambda_l2=0.22; max_depth=26; min_child_weight=1.35; subsample=0.729; colsample_bytree=0.803; min_gain_to_split=0.0781; scale_pos_weight=3.22 : y = 0.927 : 236.2 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Fri Nov 14 04:51:53 AM 2025 AUC 0.930778656649011
#
# [mbo] 64: num_leaves=46; learning_rate=0.0128; feature_fraction=0.407; min_data_in_leaf=20; num_iterations=3737; early_stopping_rounds=173; bagging_fraction=0.816; bagging_freq=3; lambda_l1=0.338; lambda_l2=0.0632; max_depth=30; min_child_weight=7.83; subsample=0.675; colsample_bytree=0.754; min_gain_to_split=0.0589; scale_pos_weight=2.43 : y = 0.931 : 292.2 secs : infill_ei
#
# Fri Nov 14 04:56:08 AM 2025 AUC 0.931962415001252
#
# [mbo] 65: num_leaves=58; learning_rate=0.014; feature_fraction=0.495; min_data_in_leaf=131; num_iterations=3436; early_stopping_rounds=118; bagging_fraction=0.713; bagging_freq=3; lambda_l1=0.223; lambda_l2=0.113; max_depth=24; min_child_weight=3.31; subsample=0.536; colsample_bytree=0.858; min_gain_to_split=0.0725; scale_pos_weight=4.15 : y = 0.932 : 250.6 secs : infill_ei
#
# Fri Nov 14 04:57:56 AM 2025 AUC 0.929969688001831
#
# [mbo] 66: num_leaves=54; learning_rate=0.013; feature_fraction=0.417; min_data_in_leaf=86; num_iterations=3669; early_stopping_rounds=198; bagging_fraction=0.81; bagging_freq=3; lambda_l1=0.227; lambda_l2=0.0872; max_depth=29; min_child_weight=2.55; subsample=0.554; colsample_bytree=0.746; min_gain_to_split=0.0121; scale_pos_weight=3.7 : y = 0.93 : 103.7 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Fri Nov 14 05:03:44 AM 2025 AUC 0.931966441390205
#
# [mbo] 67: num_leaves=58; learning_rate=0.0106; feature_fraction=0.458; min_data_in_leaf=588; num_iterations=1772; early_stopping_rounds=350; bagging_fraction=0.815; bagging_freq=3; lambda_l1=0.155; lambda_l2=0.362; max_depth=30; min_child_weight=7.49; subsample=0.586; colsample_bytree=0.525; min_gain_to_split=0.0749; scale_pos_weight=3.5 : y = 0.932 : 344.9 secs : infill_ei
#
# Fri Nov 14 05:09:10 AM 2025 AUC 0.930278713353989
#
# [mbo] 68: num_leaves=63; learning_rate=0.0437; feature_fraction=0.548; min_data_in_leaf=1277; num_iterations=4968; early_stopping_rounds=426; bagging_fraction=0.811; bagging_freq=1; lambda_l1=0.0335; lambda_l2=0.0292; max_depth=19; min_child_weight=5.1; subsample=0.815; colsample_bytree=0.619; min_gain_to_split=0.0253; scale_pos_weight=1.24 : y = 0.93 : 322.4 secs : infill_ei
#
# Saved the current state after iteration 69 in the file HT.RDATA.
#
# Fri Nov 14 05:13:37 AM 2025 AUC 0.931984560140494
#
# [mbo] 69: num_leaves=56; learning_rate=0.0126; feature_fraction=0.489; min_data_in_leaf=149; num_iterations=3154; early_stopping_rounds=258; bagging_fraction=0.757; bagging_freq=4; lambda_l1=0.455; lambda_l2=0.111; max_depth=26; min_child_weight=1.51; subsample=0.646; colsample_bytree=0.771; min_gain_to_split=0.0596; scale_pos_weight=4.09 : y = 0.932 : 263.0 secs : infill_ei
#
# Fri Nov 14 05:20:08 AM 2025 AUC 0.93354981884605
#
# [mbo] 70: num_leaves=51; learning_rate=0.0151; feature_fraction=0.534; min_data_in_leaf=46; num_iterations=3841; early_stopping_rounds=151; bagging_fraction=0.785; bagging_freq=3; lambda_l1=0.24; lambda_l2=0.393; max_depth=26; min_child_weight=3.86; subsample=0.594; colsample_bytree=0.878; min_gain_to_split=0.0898; scale_pos_weight=2.06 : y = 0.934 : 386.0 secs : infill_ei
#
# Saved the current state after iteration 71 in the file HT.RDATA.
#
# Fri Nov 14 05:26:44 AM 2025 AUC 0.932812654135202
#
# [mbo] 71: num_leaves=52; learning_rate=0.0192; feature_fraction=0.6; min_data_in_leaf=115; num_iterations=3911; early_stopping_rounds=349; bagging_fraction=0.716; bagging_freq=3; lambda_l1=0.205; lambda_l2=0.185; max_depth=22; min_child_weight=7.92; subsample=0.798; colsample_bytree=0.873; min_gain_to_split=0.0384; scale_pos_weight=2.14 : y = 0.933 : 391.1 secs : infill_ei
#
# Fri Nov 14 05:31:18 AM 2025 AUC 0.932274460145124
#
# [mbo] 72: num_leaves=61; learning_rate=0.0123; feature_fraction=0.593; min_data_in_leaf=69; num_iterations=1609; early_stopping_rounds=275; bagging_fraction=0.754; bagging_freq=3; lambda_l1=0.182; lambda_l2=0.276; max_depth=24; min_child_weight=4.05; subsample=0.607; colsample_bytree=0.847; min_gain_to_split=0.057; scale_pos_weight=1.35 : y = 0.932 : 269.6 secs : infill_ei
#
# Saved the current state after iteration 73 in the file HT.RDATA.
#
# Fri Nov 14 05:39:02 AM 2025 AUC 0.930558211853823
#
# [mbo] 73: num_leaves=52; learning_rate=0.016; feature_fraction=0.635; min_data_in_leaf=95; num_iterations=3453; early_stopping_rounds=352; bagging_fraction=0.788; bagging_freq=4; lambda_l1=0.273; lambda_l2=0.236; max_depth=26; min_child_weight=5.22; subsample=0.613; colsample_bytree=0.844; min_gain_to_split=0.044; scale_pos_weight=1.06 : y = 0.931 : 460.7 secs : infill_ei
#
# Fri Nov 14 05:48:37 AM 2025 AUC 0.934920468752202
#
# [mbo] 74: num_leaves=50; learning_rate=0.0119; feature_fraction=0.483; min_data_in_leaf=545; num_iterations=3183; early_stopping_rounds=294; bagging_fraction=0.878; bagging_freq=2; lambda_l1=0.3; lambda_l2=0.133; max_depth=27; min_child_weight=2.91; subsample=0.584; colsample_bytree=0.6; min_gain_to_split=0.0555; scale_pos_weight=2.08 : y = 0.935 : 570.8 secs : infill_ei
#
# Saved the current state after iteration 75 in the file HT.RDATA.
#
# Fri Nov 14 05:55:20 AM 2025 AUC 0.934859737385491
#
# [mbo] 75: num_leaves=59; learning_rate=0.016; feature_fraction=0.506; min_data_in_leaf=223; num_iterations=3203; early_stopping_rounds=244; bagging_fraction=0.785; bagging_freq=3; lambda_l1=0.151; lambda_l2=0.0649; max_depth=27; min_child_weight=7.17; subsample=0.824; colsample_bytree=0.891; min_gain_to_split=0.0635; scale_pos_weight=2.13 : y = 0.935 : 398.8 secs : infill_ei
#
# Fri Nov 14 06:02:58 AM 2025 AUC 0.933457882964952
#
# [mbo] 76: num_leaves=56; learning_rate=0.0168; feature_fraction=0.523; min_data_in_leaf=42; num_iterations=3437; early_stopping_rounds=211; bagging_fraction=0.791; bagging_freq=2; lambda_l1=0.366; lambda_l2=0.00939; max_depth=23; min_child_weight=8.57; subsample=0.844; colsample_bytree=0.563; min_gain_to_split=0.00104; scale_pos_weight=2.78 : y = 0.933 : 452.6 secs : infill_ei
#
# Saved the current state after iteration 77 in the file HT.RDATA.
#
# Fri Nov 14 06:08:46 AM 2025 AUC 0.934311812955443
#
# [mbo] 77: num_leaves=59; learning_rate=0.0183; feature_fraction=0.497; min_data_in_leaf=76; num_iterations=4108; early_stopping_rounds=255; bagging_fraction=0.743; bagging_freq=2; lambda_l1=0.385; lambda_l2=0.0373; max_depth=20; min_child_weight=4.27; subsample=0.783; colsample_bytree=0.568; min_gain_to_split=0.00124; scale_pos_weight=2.58 : y = 0.934 : 343.5 secs : infill_ei
#
# Fri Nov 14 06:15:18 AM 2025 AUC 0.934231956241205
#
# [mbo] 78: num_leaves=62; learning_rate=0.0131; feature_fraction=0.503; min_data_in_leaf=617; num_iterations=1854; early_stopping_rounds=224; bagging_fraction=0.861; bagging_freq=3; lambda_l1=0.457; lambda_l2=0.1; max_depth=27; min_child_weight=0.688; subsample=0.683; colsample_bytree=0.56; min_gain_to_split=0.0046; scale_pos_weight=4.22 : y = 0.934 : 388.1 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Fri Nov 14 06:20:30 AM 2025 AUC 0.931834241619575
#
# [mbo] 79: num_leaves=51; learning_rate=0.0155; feature_fraction=0.506; min_data_in_leaf=107; num_iterations=3879; early_stopping_rounds=379; bagging_fraction=0.845; bagging_freq=3; lambda_l1=0.228; lambda_l2=0.277; max_depth=20; min_child_weight=7.38; subsample=0.629; colsample_bytree=0.642; min_gain_to_split=0.0451; scale_pos_weight=2.35 : y = 0.932 : 308.0 secs : infill_ei
#
# Fri Nov 14 06:28:20 AM 2025 AUC 0.933205227058139
#
# [mbo] 80: num_leaves=45; learning_rate=0.0128; feature_fraction=0.489; min_data_in_leaf=55; num_iterations=2689; early_stopping_rounds=334; bagging_fraction=0.822; bagging_freq=2; lambda_l1=0.0279; lambda_l2=0.118; max_depth=27; min_child_weight=3.86; subsample=0.562; colsample_bytree=0.638; min_gain_to_split=0.0772; scale_pos_weight=3.27 : y = 0.933 : 465.2 secs : infill_ei
#
# Saved the current state after iteration 81 in the file HT.RDATA.
#
# Fri Nov 14 06:33:52 AM 2025 AUC 0.933178048932705
#
# [mbo] 81: num_leaves=56; learning_rate=0.0158; feature_fraction=0.477; min_data_in_leaf=406; num_iterations=2739; early_stopping_rounds=333; bagging_fraction=0.816; bagging_freq=2; lambda_l1=0.244; lambda_l2=0.0984; max_depth=27; min_child_weight=5.57; subsample=0.659; colsample_bytree=0.554; min_gain_to_split=0.022; scale_pos_weight=2.79 : y = 0.933 : 328.8 secs : infill_ei
#
# Fri Nov 14 06:38:03 AM 2025 AUC 0.932528793714002
#
# [mbo] 82: num_leaves=62; learning_rate=0.0107; feature_fraction=0.46; min_data_in_leaf=52; num_iterations=1758; early_stopping_rounds=143; bagging_fraction=0.788; bagging_freq=4; lambda_l1=0.253; lambda_l2=0.0517; max_depth=28; min_child_weight=1.13; subsample=0.603; colsample_bytree=0.572; min_gain_to_split=0.0326; scale_pos_weight=3.22 : y = 0.933 : 246.5 secs : infill_ei
#
# Fri Nov 14 06:45:54 AM 2025 AUC 0.936452509748894
#
# [mbo] 83: num_leaves=57; learning_rate=0.0128; feature_fraction=0.595; min_data_in_leaf=194; num_iterations=3481; early_stopping_rounds=240; bagging_fraction=0.797; bagging_freq=3; lambda_l1=0.201; lambda_l2=0.118; max_depth=23; min_child_weight=6.59; subsample=0.656; colsample_bytree=0.838; min_gain_to_split=0.0663; scale_pos_weight=4 : y = 0.936 : 466.4 secs : infill_ei
#
# Saved the current state after iteration 84 in the file HT.RDATA.
#
# Fri Nov 14 06:49:31 AM 2025 AUC 0.933002901013241
#
# [mbo] 84: num_leaves=52; learning_rate=0.0135; feature_fraction=0.527; min_data_in_leaf=27; num_iterations=3521; early_stopping_rounds=230; bagging_fraction=0.861; bagging_freq=2; lambda_l1=0.285; lambda_l2=0.15; max_depth=25; min_child_weight=6.05; subsample=0.601; colsample_bytree=0.895; min_gain_to_split=0.0673; scale_pos_weight=3.74 : y = 0.933 : 213.0 secs : infill_ei
#
# Fri Nov 14 06:53:27 AM 2025 AUC 0.928804383932292
#
# [mbo] 85: num_leaves=61; learning_rate=0.0154; feature_fraction=0.591; min_data_in_leaf=83; num_iterations=3600; early_stopping_rounds=149; bagging_fraction=0.733; bagging_freq=2; lambda_l1=0.39; lambda_l2=0.103; max_depth=19; min_child_weight=5.46; subsample=0.772; colsample_bytree=0.853; min_gain_to_split=0.0784; scale_pos_weight=1.53 : y = 0.929 : 229.7 secs : infill_ei
#
# Fri Nov 14 07:01:18 AM 2025 AUC 0.932116759911124
#
# [mbo] 86: num_leaves=60; learning_rate=0.0168; feature_fraction=0.546; min_data_in_leaf=211; num_iterations=4176; early_stopping_rounds=399; bagging_fraction=0.773; bagging_freq=4; lambda_l1=0.0878; lambda_l2=0.146; max_depth=24; min_child_weight=7.89; subsample=0.638; colsample_bytree=0.822; min_gain_to_split=0.0802; scale_pos_weight=2.75 : y = 0.932 : 465.5 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Fri Nov 14 07:03:52 AM 2025 AUC 0.929181857896655
#
# [mbo] 87: num_leaves=56; learning_rate=0.0128; feature_fraction=0.558; min_data_in_leaf=365; num_iterations=3918; early_stopping_rounds=173; bagging_fraction=0.788; bagging_freq=3; lambda_l1=0.378; lambda_l2=0.0769; max_depth=23; min_child_weight=3.57; subsample=0.704; colsample_bytree=0.638; min_gain_to_split=0.0131; scale_pos_weight=2.14 : y = 0.929 : 148.8 secs : infill_ei
#
# Fri Nov 14 07:06:58 AM 2025 AUC 0.931849340578149
#
# [mbo] 88: num_leaves=47; learning_rate=0.0217; feature_fraction=0.627; min_data_in_leaf=180; num_iterations=2943; early_stopping_rounds=338; bagging_fraction=0.769; bagging_freq=2; lambda_l1=0.25; lambda_l2=0.00577; max_depth=29; min_child_weight=7.26; subsample=0.869; colsample_bytree=0.839; min_gain_to_split=0.0283; scale_pos_weight=3.92 : y = 0.932 : 181.9 secs : infill_ei
#
# Fri Nov 14 07:14:21 AM 2025 AUC 0.932959281799581
#
# [mbo] 89: num_leaves=63; learning_rate=0.0181; feature_fraction=0.512; min_data_in_leaf=33; num_iterations=4786; early_stopping_rounds=354; bagging_fraction=0.763; bagging_freq=3; lambda_l1=0.294; lambda_l2=0.00982; max_depth=13; min_child_weight=6.92; subsample=0.832; colsample_bytree=0.822; min_gain_to_split=0.0558; scale_pos_weight=4.6 : y = 0.933 : 438.6 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Fri Nov 14 07:20:06 AM 2025 AUC 0.932598248923444
#
# [mbo] 90: num_leaves=57; learning_rate=0.0139; feature_fraction=0.711; min_data_in_leaf=19; num_iterations=4343; early_stopping_rounds=245; bagging_fraction=0.793; bagging_freq=4; lambda_l1=0.139; lambda_l2=0.24; max_depth=24; min_child_weight=7.68; subsample=0.8; colsample_bytree=0.817; min_gain_to_split=0.0536; scale_pos_weight=3.53 : y = 0.933 : 341.3 secs : infill_ei
#
# Fri Nov 14 07:24:39 AM 2025 AUC 0.934405426498605
#
# [mbo] 91: num_leaves=55; learning_rate=0.0244; feature_fraction=0.52; min_data_in_leaf=73; num_iterations=3902; early_stopping_rounds=421; bagging_fraction=0.767; bagging_freq=2; lambda_l1=0.238; lambda_l2=0.167; max_depth=19; min_child_weight=3.43; subsample=0.831; colsample_bytree=0.689; min_gain_to_split=0.00111; scale_pos_weight=4.27 : y = 0.934 : 268.5 secs : infill_ei
#
# Saved the current state after iteration 92 in the file HT.RDATA.
#
# Fri Nov 14 07:28:55 AM 2025 AUC 0.930355885808925
#
# [mbo] 92: num_leaves=55; learning_rate=0.0192; feature_fraction=0.498; min_data_in_leaf=20; num_iterations=4299; early_stopping_rounds=283; bagging_fraction=0.752; bagging_freq=4; lambda_l1=0.247; lambda_l2=0.0953; max_depth=25; min_child_weight=6.86; subsample=0.831; colsample_bytree=0.747; min_gain_to_split=0.0336; scale_pos_weight=4.5 : y = 0.93 : 250.1 secs : infill_ei
#
# Fri Nov 14 07:33:35 AM 2025 AUC 0.927326028121643
#
# [mbo] 93: num_leaves=55; learning_rate=0.0318; feature_fraction=0.486; min_data_in_leaf=30; num_iterations=3785; early_stopping_rounds=408; bagging_fraction=0.776; bagging_freq=2; lambda_l1=0.248; lambda_l2=0.0432; max_depth=20; min_child_weight=7.78; subsample=0.83; colsample_bytree=0.835; min_gain_to_split=0.00294; scale_pos_weight=1.78 : y = 0.927 : 275.5 secs : infill_ei
#
# Fri Nov 14 07:41:15 AM 2025 AUC 0.935303982299994
#
# [mbo] 94: num_leaves=59; learning_rate=0.0118; feature_fraction=0.564; min_data_in_leaf=27; num_iterations=2676; early_stopping_rounds=208; bagging_fraction=0.785; bagging_freq=4; lambda_l1=0.0969; lambda_l2=0.237; max_depth=20; min_child_weight=7.88; subsample=0.586; colsample_bytree=0.874; min_gain_to_split=0.0741; scale_pos_weight=4.05 : y = 0.935 : 455.0 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Fri Nov 14 07:44:03 AM 2025 AUC 0.930126381638593
#
# [mbo] 95: num_leaves=47; learning_rate=0.0129; feature_fraction=0.619; min_data_in_leaf=117; num_iterations=3765; early_stopping_rounds=247; bagging_fraction=0.774; bagging_freq=3; lambda_l1=0.195; lambda_l2=0.0625; max_depth=26; min_child_weight=8.68; subsample=0.595; colsample_bytree=0.842; min_gain_to_split=0.0812; scale_pos_weight=3.21 : y = 0.93 : 162.3 secs : infill_ei
#
# Fri Nov 14 07:47:53 AM 2025 AUC 0.931459451914514
#
# [mbo] 96: num_leaves=61; learning_rate=0.0179; feature_fraction=0.451; min_data_in_leaf=476; num_iterations=1195; early_stopping_rounds=297; bagging_fraction=0.755; bagging_freq=1; lambda_l1=0.283; lambda_l2=0.035; max_depth=20; min_child_weight=1.97; subsample=0.861; colsample_bytree=0.606; min_gain_to_split=0.000256; scale_pos_weight=3.98 : y = 0.931 : 225.3 secs : infill_ei
#
# Fri Nov 14 07:57:35 AM 2025 AUC 0.936068325136276
#
# [mbo] 97: num_leaves=59; learning_rate=0.015; feature_fraction=0.575; min_data_in_leaf=43; num_iterations=2989; early_stopping_rounds=314; bagging_fraction=0.787; bagging_freq=3; lambda_l1=0.197; lambda_l2=0.16; max_depth=18; min_child_weight=4.44; subsample=0.861; colsample_bytree=0.794; min_gain_to_split=0.0809; scale_pos_weight=3.76 : y = 0.936 : 576.8 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
