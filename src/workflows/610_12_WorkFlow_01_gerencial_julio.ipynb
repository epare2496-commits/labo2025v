# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/src/workflows/610_12_WorkFlow_01_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 13 10:32:08 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660365 35.3 1454488    77.7 1454488  77.7
# Vcells 1226532  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63102
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31
  )
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200


PARAM$hipeparametertuning$hs <- makeParamSet(
  # 6 Existentes (Ajustados para velocidad)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L), # Reducido
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1), # Reducido
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L), # Reducido
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L), # Reducido
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L), # Reducido

  # 10 Nuevos Hiperparámetros
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L), # Reducido
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeNumericParam("subsample", lower = 0.5, upper = 0.9),
  makeNumericParam("colsample_bytree", lower = 0.5, upper = 0.9),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Thu Nov 13 10:49:05 AM 2025 AUC 0.925564482954618
#
# [mbo] 45: num_leaves=35; learning_rate=0.0277; feature_fraction=0.315; min_data_in_leaf=217; num_iterations=4145; early_stopping_rounds=379; bagging_fraction=0.816; bagging_freq=4; lambda_l1=0.0835; lambda_l2=0.218; max_depth=24; min_child_weight=2.84; subsample=0.758; colsample_bytree=0.677; min_gain_to_split=0.0569; scale_pos_weight=3.65 : y = 0.926 : 208.9 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Thu Nov 13 10:51:56 AM 2025 AUC 0.933880318272625
#
# [mbo] 46: num_leaves=60; learning_rate=0.0269; feature_fraction=0.71; min_data_in_leaf=9; num_iterations=3497; early_stopping_rounds=304; bagging_fraction=0.884; bagging_freq=4; lambda_l1=0.0955; lambda_l2=0.304; max_depth=21; min_child_weight=1.44; subsample=0.606; colsample_bytree=0.614; min_gain_to_split=0.0326; scale_pos_weight=4.4 : y = 0.934 : 168.6 secs : infill_ei
#
# Thu Nov 13 10:55:52 AM 2025 AUC 0.933245155415258
#
# [mbo] 47: num_leaves=61; learning_rate=0.0264; feature_fraction=0.634; min_data_in_leaf=650; num_iterations=2844; early_stopping_rounds=385; bagging_fraction=0.657; bagging_freq=4; lambda_l1=0.0778; lambda_l2=0.247; max_depth=22; min_child_weight=1.05; subsample=0.706; colsample_bytree=0.578; min_gain_to_split=0.0114; scale_pos_weight=2.72 : y = 0.933 : 233.5 secs : infill_ei
#
# Thu Nov 13 11:00:10 AM 2025 AUC 0.931847998448498
#
# [mbo] 48: num_leaves=62; learning_rate=0.0218; feature_fraction=0.647; min_data_in_leaf=700; num_iterations=2547; early_stopping_rounds=386; bagging_fraction=0.833; bagging_freq=5; lambda_l1=0.264; lambda_l2=0.377; max_depth=22; min_child_weight=6.76; subsample=0.572; colsample_bytree=0.548; min_gain_to_split=0.0252; scale_pos_weight=3.64 : y = 0.932 : 255.6 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Thu Nov 13 11:02:02 AM 2025 AUC 0.931445695085591
#
# [mbo] 49: num_leaves=61; learning_rate=0.0502; feature_fraction=0.624; min_data_in_leaf=562; num_iterations=4287; early_stopping_rounds=356; bagging_fraction=0.656; bagging_freq=4; lambda_l1=0.105; lambda_l2=0.278; max_depth=30; min_child_weight=5.09; subsample=0.862; colsample_bytree=0.689; min_gain_to_split=0.0185; scale_pos_weight=4.49 : y = 0.931 : 109.9 secs : infill_ei
#
# Thu Nov 13 11:08:25 AM 2025 AUC 0.931289672513654
#
# [mbo] 50: num_leaves=56; learning_rate=0.00893; feature_fraction=0.636; min_data_in_leaf=474; num_iterations=3568; early_stopping_rounds=398; bagging_fraction=0.699; bagging_freq=4; lambda_l1=0.111; lambda_l2=0.295; max_depth=22; min_child_weight=6.35; subsample=0.72; colsample_bytree=0.57; min_gain_to_split=0.0149; scale_pos_weight=3.12 : y = 0.931 : 380.3 secs : infill_ei
#
# Thu Nov 13 11:12:18 AM 2025 AUC 0.933222003678777
#
# [mbo] 51: num_leaves=46; learning_rate=0.0529; feature_fraction=0.594; min_data_in_leaf=617; num_iterations=2046; early_stopping_rounds=458; bagging_fraction=0.841; bagging_freq=4; lambda_l1=0.124; lambda_l2=0.262; max_depth=26; min_child_weight=5.37; subsample=0.86; colsample_bytree=0.703; min_gain_to_split=0.0278; scale_pos_weight=3.79 : y = 0.933 : 228.7 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Thu Nov 13 11:15:59 AM 2025 AUC 0.926739181931714
#
# [mbo] 52: num_leaves=60; learning_rate=0.0237; feature_fraction=0.633; min_data_in_leaf=1660; num_iterations=4257; early_stopping_rounds=436; bagging_fraction=0.863; bagging_freq=5; lambda_l1=0.0135; lambda_l2=0.336; max_depth=26; min_child_weight=3.98; subsample=0.656; colsample_bytree=0.883; min_gain_to_split=0.0338; scale_pos_weight=1.81 : y = 0.927 : 218.6 secs : infill_ei
#
# Thu Nov 13 11:23:53 AM 2025 AUC 0.933776638757081
#
# [mbo] 53: num_leaves=61; learning_rate=0.0126; feature_fraction=0.423; min_data_in_leaf=717; num_iterations=4277; early_stopping_rounds=348; bagging_fraction=0.828; bagging_freq=4; lambda_l1=0.219; lambda_l2=0.405; max_depth=24; min_child_weight=2.56; subsample=0.746; colsample_bytree=0.647; min_gain_to_split=0.0466; scale_pos_weight=4.33 : y = 0.934 : 470.8 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Thu Nov 13 11:27:49 AM 2025 AUC 0.932081193475371
#
# [mbo] 54: num_leaves=61; learning_rate=0.041; feature_fraction=0.456; min_data_in_leaf=184; num_iterations=4122; early_stopping_rounds=285; bagging_fraction=0.797; bagging_freq=4; lambda_l1=0.201; lambda_l2=0.334; max_depth=21; min_child_weight=1.3; subsample=0.735; colsample_bytree=0.538; min_gain_to_split=0.0621; scale_pos_weight=2.01 : y = 0.932 : 232.3 secs : infill_ei
#
# Thu Nov 13 11:31:38 AM 2025 AUC 0.924250873558637
#
# [mbo] 55: num_leaves=43; learning_rate=0.0547; feature_fraction=0.398; min_data_in_leaf=508; num_iterations=4099; early_stopping_rounds=448; bagging_fraction=0.643; bagging_freq=3; lambda_l1=0.057; lambda_l2=0.209; max_depth=30; min_child_weight=4.88; subsample=0.744; colsample_bytree=0.611; min_gain_to_split=0.0671; scale_pos_weight=3.94 : y = 0.924 : 226.6 secs : infill_ei
#
# Thu Nov 13 11:33:51 AM 2025 AUC 0.936005916107502
#
# [mbo] 56: num_leaves=61; learning_rate=0.0413; feature_fraction=0.467; min_data_in_leaf=272; num_iterations=3466; early_stopping_rounds=189; bagging_fraction=0.866; bagging_freq=4; lambda_l1=0.0302; lambda_l2=0.319; max_depth=13; min_child_weight=8.41; subsample=0.757; colsample_bytree=0.706; min_gain_to_split=0.0244; scale_pos_weight=3.88 : y = 0.936 : 129.3 secs : infill_ei
#
# Thu Nov 13 11:37:55 AM 2025 AUC 0.932924386428653
#
# [mbo] 57: num_leaves=63; learning_rate=0.0211; feature_fraction=0.529; min_data_in_leaf=392; num_iterations=3511; early_stopping_rounds=318; bagging_fraction=0.86; bagging_freq=5; lambda_l1=0.186; lambda_l2=0.298; max_depth=21; min_child_weight=8.55; subsample=0.81; colsample_bytree=0.629; min_gain_to_split=0.0229; scale_pos_weight=4.47 : y = 0.933 : 240.6 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Thu Nov 13 11:41:39 AM 2025 AUC 0.933737045932374
#
# [mbo] 58: num_leaves=62; learning_rate=0.0342; feature_fraction=0.493; min_data_in_leaf=150; num_iterations=3393; early_stopping_rounds=234; bagging_fraction=0.875; bagging_freq=4; lambda_l1=0.272; lambda_l2=0.248; max_depth=12; min_child_weight=4.4; subsample=0.534; colsample_bytree=0.734; min_gain_to_split=0.0226; scale_pos_weight=2.23 : y = 0.934 : 221.3 secs : infill_ei
#
# Thu Nov 13 11:44:28 AM 2025 AUC 0.935045622342164
#
# [mbo] 59: num_leaves=62; learning_rate=0.0566; feature_fraction=0.394; min_data_in_leaf=35; num_iterations=3640; early_stopping_rounds=256; bagging_fraction=0.874; bagging_freq=4; lambda_l1=0.161; lambda_l2=0.393; max_depth=18; min_child_weight=6.51; subsample=0.552; colsample_bytree=0.677; min_gain_to_split=0.0223; scale_pos_weight=2.92 : y = 0.935 : 165.7 secs : infill_ei
#
# Thu Nov 13 11:54:27 AM 2025 AUC 0.929988813349358
#
# [mbo] 60: num_leaves=62; learning_rate=0.0087; feature_fraction=0.5; min_data_in_leaf=708; num_iterations=4250; early_stopping_rounds=351; bagging_fraction=0.761; bagging_freq=2; lambda_l1=0.415; lambda_l2=0.266; max_depth=27; min_child_weight=6.79; subsample=0.85; colsample_bytree=0.598; min_gain_to_split=0.0703; scale_pos_weight=2.61 : y = 0.93 : 595.9 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Thu Nov 13 12:00:41 PM 2025 AUC 0.934173238068971
#
# [mbo] 61: num_leaves=61; learning_rate=0.0176; feature_fraction=0.6; min_data_in_leaf=141; num_iterations=3481; early_stopping_rounds=477; bagging_fraction=0.87; bagging_freq=4; lambda_l1=0.067; lambda_l2=0.278; max_depth=15; min_child_weight=5.49; subsample=0.582; colsample_bytree=0.706; min_gain_to_split=0.0188; scale_pos_weight=3.18 : y = 0.934 : 369.3 secs : infill_ei
#
# Thu Nov 13 12:03:41 PM 2025 AUC 0.929817691818847
#
# [mbo] 62: num_leaves=63; learning_rate=0.041; feature_fraction=0.531; min_data_in_leaf=226; num_iterations=4724; early_stopping_rounds=192; bagging_fraction=0.819; bagging_freq=2; lambda_l1=0.0222; lambda_l2=0.355; max_depth=11; min_child_weight=7.72; subsample=0.822; colsample_bytree=0.503; min_gain_to_split=0.0518; scale_pos_weight=1.39 : y = 0.93 : 177.2 secs : infill_ei
#
# Thu Nov 13 12:08:51 PM 2025 AUC 0.929655629663481
#
# [mbo] 63: num_leaves=58; learning_rate=0.0145; feature_fraction=0.427; min_data_in_leaf=712; num_iterations=2884; early_stopping_rounds=321; bagging_fraction=0.867; bagging_freq=4; lambda_l1=0.0286; lambda_l2=0.346; max_depth=15; min_child_weight=1.41; subsample=0.588; colsample_bytree=0.695; min_gain_to_split=0.0281; scale_pos_weight=1.97 : y = 0.93 : 307.6 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Thu Nov 13 12:10:18 PM 2025 AUC 0.929065428149425
#
# [mbo] 64: num_leaves=61; learning_rate=0.0412; feature_fraction=0.45; min_data_in_leaf=97; num_iterations=4052; early_stopping_rounds=219; bagging_fraction=0.884; bagging_freq=3; lambda_l1=0.119; lambda_l2=0.305; max_depth=21; min_child_weight=4.74; subsample=0.635; colsample_bytree=0.661; min_gain_to_split=0.0209; scale_pos_weight=4.04 : y = 0.929 : 84.0 secs : infill_ei
#
# Thu Nov 13 12:15:19 PM 2025 AUC 0.93278212068564
#
# [mbo] 65: num_leaves=62; learning_rate=0.0259; feature_fraction=0.38; min_data_in_leaf=125; num_iterations=3501; early_stopping_rounds=237; bagging_fraction=0.858; bagging_freq=2; lambda_l1=0.0724; lambda_l2=0.453; max_depth=12; min_child_weight=4.03; subsample=0.772; colsample_bytree=0.682; min_gain_to_split=0.0476; scale_pos_weight=4.41 : y = 0.933 : 298.2 secs : infill_ei
#
# Thu Nov 13 12:17:47 PM 2025 AUC 0.926757300682003
#
# [mbo] 66: num_leaves=51; learning_rate=0.0464; feature_fraction=0.686; min_data_in_leaf=333; num_iterations=3177; early_stopping_rounds=435; bagging_fraction=0.626; bagging_freq=4; lambda_l1=0.0306; lambda_l2=0.331; max_depth=28; min_child_weight=2.77; subsample=0.744; colsample_bytree=0.621; min_gain_to_split=0.0154; scale_pos_weight=4.14 : y = 0.927 : 143.8 secs : infill_ei
#
# Thu Nov 13 12:20:20 PM 2025 AUC 0.928418521657611
#
# [mbo] 67: num_leaves=63; learning_rate=0.0423; feature_fraction=0.585; min_data_in_leaf=381; num_iterations=2923; early_stopping_rounds=322; bagging_fraction=0.845; bagging_freq=4; lambda_l1=0.206; lambda_l2=0.32; max_depth=10; min_child_weight=3.69; subsample=0.625; colsample_bytree=0.884; min_gain_to_split=0.0396; scale_pos_weight=4.12 : y = 0.928 : 150.3 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Thu Nov 13 12:26:35 PM 2025 AUC 0.929497593897068
#
# [mbo] 68: num_leaves=48; learning_rate=0.019; feature_fraction=0.426; min_data_in_leaf=553; num_iterations=2610; early_stopping_rounds=482; bagging_fraction=0.849; bagging_freq=3; lambda_l1=0.379; lambda_l2=0.247; max_depth=29; min_child_weight=3.14; subsample=0.716; colsample_bytree=0.516; min_gain_to_split=0.0172; scale_pos_weight=3.18 : y = 0.929 : 371.3 secs : infill_ei
#
# Thu Nov 13 12:30:46 PM 2025 AUC 0.934629897682746
#
# [mbo] 69: num_leaves=63; learning_rate=0.0146; feature_fraction=0.597; min_data_in_leaf=42; num_iterations=1626; early_stopping_rounds=480; bagging_fraction=0.865; bagging_freq=4; lambda_l1=0.267; lambda_l2=0.319; max_depth=21; min_child_weight=2.62; subsample=0.779; colsample_bytree=0.521; min_gain_to_split=0.05; scale_pos_weight=3.3 : y = 0.935 : 246.5 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Thu Nov 13 12:33:09 PM 2025 AUC 0.92894362988359
#
# [mbo] 70: num_leaves=63; learning_rate=0.0415; feature_fraction=0.353; min_data_in_leaf=3; num_iterations=3750; early_stopping_rounds=276; bagging_fraction=0.865; bagging_freq=4; lambda_l1=0.189; lambda_l2=0.283; max_depth=23; min_child_weight=3.66; subsample=0.653; colsample_bytree=0.585; min_gain_to_split=0.0553; scale_pos_weight=3.98 : y = 0.929 : 139.7 secs : infill_ei
#
# Thu Nov 13 12:37:42 PM 2025 AUC 0.935486176400126
#
# [mbo] 71: num_leaves=63; learning_rate=0.0277; feature_fraction=0.467; min_data_in_leaf=105; num_iterations=4398; early_stopping_rounds=448; bagging_fraction=0.855; bagging_freq=4; lambda_l1=0.243; lambda_l2=0.301; max_depth=18; min_child_weight=1.91; subsample=0.774; colsample_bytree=0.634; min_gain_to_split=0.0473; scale_pos_weight=2.59 : y = 0.935 : 268.8 secs : infill_ei
#
# Thu Nov 13 12:42:00 PM 2025 AUC 0.931342015570046
#
# [mbo] 72: num_leaves=56; learning_rate=0.0427; feature_fraction=0.414; min_data_in_leaf=33; num_iterations=3657; early_stopping_rounds=375; bagging_fraction=0.86; bagging_freq=5; lambda_l1=0.0188; lambda_l2=0.206; max_depth=9; min_child_weight=8.45; subsample=0.767; colsample_bytree=0.677; min_gain_to_split=0.0406; scale_pos_weight=3.41 : y = 0.931 : 254.5 secs : infill_ei
#
# Saved the current state after iteration 73 in the file HT.RDATA.
#
# Thu Nov 13 12:46:01 PM 2025 AUC 0.931475221937914
#
# [mbo] 73: num_leaves=61; learning_rate=0.0114; feature_fraction=0.501; min_data_in_leaf=18; num_iterations=4573; early_stopping_rounds=171; bagging_fraction=0.875; bagging_freq=4; lambda_l1=0.293; lambda_l2=0.371; max_depth=12; min_child_weight=8.12; subsample=0.695; colsample_bytree=0.692; min_gain_to_split=0.0421; scale_pos_weight=3.67 : y = 0.931 : 238.4 secs : infill_ei
#
# Thu Nov 13 12:50:14 PM 2025 AUC 0.928475897700194
#
# [mbo] 74: num_leaves=58; learning_rate=0.0492; feature_fraction=0.334; min_data_in_leaf=117; num_iterations=1809; early_stopping_rounds=434; bagging_fraction=0.87; bagging_freq=4; lambda_l1=0.109; lambda_l2=0.459; max_depth=16; min_child_weight=7.31; subsample=0.755; colsample_bytree=0.61; min_gain_to_split=0.0215; scale_pos_weight=2.64 : y = 0.928 : 248.6 secs : infill_ei
#
# Thu Nov 13 01:00:43 PM 2025 AUC 0.934470184254269
#
# [mbo] 75: num_leaves=61; learning_rate=0.0107; feature_fraction=0.537; min_data_in_leaf=225; num_iterations=4551; early_stopping_rounds=435; bagging_fraction=0.84; bagging_freq=4; lambda_l1=0.275; lambda_l2=0.428; max_depth=20; min_child_weight=2.42; subsample=0.632; colsample_bytree=0.547; min_gain_to_split=0.0503; scale_pos_weight=2.31 : y = 0.934 : 624.1 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Thu Nov 13 01:05:39 PM 2025 AUC 0.934451729971567
#
# [mbo] 76: num_leaves=61; learning_rate=0.0209; feature_fraction=0.484; min_data_in_leaf=616; num_iterations=3910; early_stopping_rounds=466; bagging_fraction=0.881; bagging_freq=4; lambda_l1=0.193; lambda_l2=0.357; max_depth=21; min_child_weight=3.66; subsample=0.576; colsample_bytree=0.61; min_gain_to_split=0.0357; scale_pos_weight=4.61 : y = 0.934 : 292.1 secs : infill_ei
#
# Thu Nov 13 01:09:23 PM 2025 AUC 0.934050097673485
#
# [mbo] 77: num_leaves=62; learning_rate=0.0478; feature_fraction=0.489; min_data_in_leaf=525; num_iterations=3925; early_stopping_rounds=232; bagging_fraction=0.866; bagging_freq=5; lambda_l1=0.222; lambda_l2=0.394; max_depth=12; min_child_weight=8.2; subsample=0.641; colsample_bytree=0.8; min_gain_to_split=0.0186; scale_pos_weight=2.58 : y = 0.934 : 220.1 secs : infill_ei
#
# Thu Nov 13 01:16:01 PM 2025 AUC 0.932774403440147
#
# [mbo] 78: num_leaves=63; learning_rate=0.0116; feature_fraction=0.634; min_data_in_leaf=33; num_iterations=4710; early_stopping_rounds=420; bagging_fraction=0.847; bagging_freq=4; lambda_l1=0.102; lambda_l2=0.363; max_depth=13; min_child_weight=5.82; subsample=0.804; colsample_bytree=0.578; min_gain_to_split=0.0475; scale_pos_weight=4.62 : y = 0.933 : 394.4 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Thu Nov 13 01:20:59 PM 2025 AUC 0.92881377883985
#
# [mbo] 79: num_leaves=63; learning_rate=0.032; feature_fraction=0.565; min_data_in_leaf=218; num_iterations=3339; early_stopping_rounds=473; bagging_fraction=0.733; bagging_freq=5; lambda_l1=0.192; lambda_l2=0.388; max_depth=25; min_child_weight=7.22; subsample=0.818; colsample_bytree=0.768; min_gain_to_split=0.05; scale_pos_weight=3.19 : y = 0.929 : 294.9 secs : infill_ei
#
# Thu Nov 13 01:24:05 PM 2025 AUC 0.933772612368127
#
# [mbo] 80: num_leaves=55; learning_rate=0.02; feature_fraction=0.701; min_data_in_leaf=266; num_iterations=3121; early_stopping_rounds=454; bagging_fraction=0.855; bagging_freq=4; lambda_l1=0.0911; lambda_l2=0.356; max_depth=21; min_child_weight=5.68; subsample=0.712; colsample_bytree=0.704; min_gain_to_split=0.048; scale_pos_weight=4.01 : y = 0.934 : 181.1 secs : infill_ei
#
# Thu Nov 13 01:35:08 PM 2025 AUC 0.93363705727337
#
# [mbo] 81: num_leaves=61; learning_rate=0.0116; feature_fraction=0.483; min_data_in_leaf=591; num_iterations=3818; early_stopping_rounds=455; bagging_fraction=0.83; bagging_freq=4; lambda_l1=0.127; lambda_l2=0.186; max_depth=21; min_child_weight=1.49; subsample=0.666; colsample_bytree=0.703; min_gain_to_split=0.0493; scale_pos_weight=2.98 : y = 0.934 : 659.1 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Thu Nov 13 01:40:26 PM 2025 AUC 0.932439877624618
#
# [mbo] 82: num_leaves=63; learning_rate=0.0198; feature_fraction=0.42; min_data_in_leaf=988; num_iterations=3492; early_stopping_rounds=242; bagging_fraction=0.638; bagging_freq=5; lambda_l1=0.0708; lambda_l2=0.452; max_depth=16; min_child_weight=2.19; subsample=0.676; colsample_bytree=0.612; min_gain_to_split=0.016; scale_pos_weight=3.02 : y = 0.932 : 314.3 secs : infill_ei
#
# Thu Nov 13 01:45:17 PM 2025 AUC 0.933585385281804
#
# [mbo] 83: num_leaves=61; learning_rate=0.0162; feature_fraction=0.447; min_data_in_leaf=57; num_iterations=2884; early_stopping_rounds=190; bagging_fraction=0.868; bagging_freq=5; lambda_l1=0.0933; lambda_l2=0.465; max_depth=12; min_child_weight=3.72; subsample=0.745; colsample_bytree=0.775; min_gain_to_split=0.0217; scale_pos_weight=3.45 : y = 0.934 : 286.8 secs : infill_ei
#
# Saved the current state after iteration 84 in the file HT.RDATA.
#
# Thu Nov 13 01:47:35 PM 2025 AUC 0.933150535274858
#
# [mbo] 84: num_leaves=62; learning_rate=0.0304; feature_fraction=0.325; min_data_in_leaf=328; num_iterations=3628; early_stopping_rounds=337; bagging_fraction=0.844; bagging_freq=4; lambda_l1=0.0413; lambda_l2=0.376; max_depth=14; min_child_weight=7.66; subsample=0.858; colsample_bytree=0.719; min_gain_to_split=0.0206; scale_pos_weight=3.5 : y = 0.933 : 134.4 secs : infill_ei
#
# Thu Nov 13 01:49:36 PM 2025 AUC 0.936369968775354
#
# [mbo] 85: num_leaves=63; learning_rate=0.0546; feature_fraction=0.587; min_data_in_leaf=137; num_iterations=3380; early_stopping_rounds=236; bagging_fraction=0.833; bagging_freq=4; lambda_l1=0.0614; lambda_l2=0.374; max_depth=11; min_child_weight=6.79; subsample=0.689; colsample_bytree=0.682; min_gain_to_split=0.0255; scale_pos_weight=2.95 : y = 0.936 : 116.6 secs : infill_ei
#
# Thu Nov 13 01:55:05 PM 2025 AUC 0.933264616295199
#
# [mbo] 86: num_leaves=63; learning_rate=0.0159; feature_fraction=0.658; min_data_in_leaf=25; num_iterations=3892; early_stopping_rounds=470; bagging_fraction=0.846; bagging_freq=5; lambda_l1=0.124; lambda_l2=0.434; max_depth=18; min_child_weight=6.2; subsample=0.631; colsample_bytree=0.538; min_gain_to_split=0.0451; scale_pos_weight=4.27 : y = 0.933 : 324.7 secs : infill_ei
#
# Thu Nov 13 01:57:15 PM 2025 AUC 0.929626773875983
#
# [mbo] 87: num_leaves=62; learning_rate=0.0603; feature_fraction=0.575; min_data_in_leaf=81; num_iterations=4403; early_stopping_rounds=264; bagging_fraction=0.819; bagging_freq=5; lambda_l1=0.0715; lambda_l2=0.325; max_depth=16; min_child_weight=6.64; subsample=0.552; colsample_bytree=0.64; min_gain_to_split=0.0132; scale_pos_weight=2.49 : y = 0.93 : 126.2 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Thu Nov 13 02:00:03 PM 2025 AUC 0.924388777380284
#
# [mbo] 88: num_leaves=61; learning_rate=0.0292; feature_fraction=0.637; min_data_in_leaf=460; num_iterations=3326; early_stopping_rounds=393; bagging_fraction=0.745; bagging_freq=3; lambda_l1=0.259; lambda_l2=0.269; max_depth=22; min_child_weight=4.18; subsample=0.74; colsample_bytree=0.52; min_gain_to_split=0.0694; scale_pos_weight=4.71 : y = 0.924 : 164.7 secs : infill_ei
#
# Thu Nov 13 02:03:12 PM 2025 AUC 0.934775183217474
#
# [mbo] 89: num_leaves=61; learning_rate=0.0494; feature_fraction=0.51; min_data_in_leaf=11; num_iterations=3465; early_stopping_rounds=188; bagging_fraction=0.857; bagging_freq=5; lambda_l1=0.08; lambda_l2=0.438; max_depth=14; min_child_weight=3.63; subsample=0.756; colsample_bytree=0.767; min_gain_to_split=0.0192; scale_pos_weight=3.37 : y = 0.935 : 185.4 secs : infill_ei
#
# Thu Nov 13 02:13:34 PM 2025 AUC 0.929967003742528
#
# [mbo] 90: num_leaves=61; learning_rate=0.00603; feature_fraction=0.5; min_data_in_leaf=997; num_iterations=3535; early_stopping_rounds=493; bagging_fraction=0.876; bagging_freq=4; lambda_l1=0.103; lambda_l2=0.416; max_depth=10; min_child_weight=4.22; subsample=0.806; colsample_bytree=0.565; min_gain_to_split=0.0492; scale_pos_weight=3.95 : y = 0.93 : 616.3 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Thu Nov 13 02:19:45 PM 2025 AUC 0.929718709757081
#
# [mbo] 91: num_leaves=49; learning_rate=0.00891; feature_fraction=0.68; min_data_in_leaf=1021; num_iterations=4192; early_stopping_rounds=400; bagging_fraction=0.626; bagging_freq=5; lambda_l1=0.0924; lambda_l2=0.279; max_depth=29; min_child_weight=2.84; subsample=0.861; colsample_bytree=0.519; min_gain_to_split=0.0132; scale_pos_weight=3.28 : y = 0.93 : 367.3 secs : infill_ei
#
# Thu Nov 13 02:21:36 PM 2025 AUC 0.93055418546487
#
# [mbo] 92: num_leaves=63; learning_rate=0.031; feature_fraction=0.617; min_data_in_leaf=255; num_iterations=3592; early_stopping_rounds=118; bagging_fraction=0.874; bagging_freq=5; lambda_l1=0.251; lambda_l2=0.494; max_depth=7; min_child_weight=3.42; subsample=0.615; colsample_bytree=0.576; min_gain_to_split=0.0146; scale_pos_weight=2.31 : y = 0.931 : 107.1 secs : infill_ei
#
# Thu Nov 13 02:24:12 PM 2025 AUC 0.929807625846464
#
# [mbo] 93: num_leaves=54; learning_rate=0.03; feature_fraction=0.686; min_data_in_leaf=713; num_iterations=1726; early_stopping_rounds=476; bagging_fraction=0.831; bagging_freq=5; lambda_l1=0.228; lambda_l2=0.174; max_depth=23; min_child_weight=1.41; subsample=0.557; colsample_bytree=0.67; min_gain_to_split=0.0253; scale_pos_weight=2.11 : y = 0.93 : 152.2 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Thu Nov 13 02:27:57 PM 2025 AUC 0.927954815863167
#
# [mbo] 94: num_leaves=63; learning_rate=0.0424; feature_fraction=0.5; min_data_in_leaf=427; num_iterations=3822; early_stopping_rounds=407; bagging_fraction=0.666; bagging_freq=4; lambda_l1=0.161; lambda_l2=0.271; max_depth=27; min_child_weight=0.256; subsample=0.819; colsample_bytree=0.71; min_gain_to_split=0.0172; scale_pos_weight=3.43 : y = 0.928 : 221.1 secs : infill_ei
#
# Thu Nov 13 02:30:22 PM 2025 AUC 0.932866674853657
#
# [mbo] 95: num_leaves=59; learning_rate=0.0541; feature_fraction=0.524; min_data_in_leaf=120; num_iterations=3552; early_stopping_rounds=169; bagging_fraction=0.861; bagging_freq=4; lambda_l1=0.283; lambda_l2=0.386; max_depth=12; min_child_weight=7.85; subsample=0.746; colsample_bytree=0.653; min_gain_to_split=0.0421; scale_pos_weight=2.8 : y = 0.933 : 140.1 secs : infill_ei
#
# Thu Nov 13 02:32:23 PM 2025 AUC 0.925488652629333
#
# [mbo] 96: num_leaves=58; learning_rate=0.0554; feature_fraction=0.661; min_data_in_leaf=351; num_iterations=4752; early_stopping_rounds=379; bagging_fraction=0.799; bagging_freq=2; lambda_l1=0.32; lambda_l2=0.277; max_depth=27; min_child_weight=0.839; subsample=0.873; colsample_bytree=0.522; min_gain_to_split=0.0735; scale_pos_weight=2.61 : y = 0.925 : 116.5 secs : infill_ei
#
# Thu Nov 13 02:36:09 PM 2025 AUC 0.930090479670427
#
# [mbo] 97: num_leaves=63; learning_rate=0.0326; feature_fraction=0.351; min_data_in_leaf=658; num_iterations=4346; early_stopping_rounds=412; bagging_fraction=0.807; bagging_freq=2; lambda_l1=0.271; lambda_l2=0.149; max_depth=10; min_child_weight=6.25; subsample=0.519; colsample_bytree=0.719; min_gain_to_split=0.0502; scale_pos_weight=1.51 : y = 0.93 : 221.8 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.
#
# Thu Nov 13 02:37:13 PM 2025 AUC 0.929090593080382
#
# [mbo] 98: num_leaves=48; learning_rate=0.0537; feature_fraction=0.739; min_data_in_leaf=277; num_iterations=2493; early_stopping_rounds=295; bagging_fraction=0.898; bagging_freq=4; lambda_l1=0.0951; lambda_l2=0.277; max_depth=10; min_child_weight=7.57; subsample=0.657; colsample_bytree=0.724; min_gain_to_split=0.0216; scale_pos_weight=4.56 : y = 0.929 : 58.7 secs : infill_ei
#
# Thu Nov 13 02:38:56 PM 2025 AUC 0.930096854786269
#
# [mbo] 99: num_leaves=63; learning_rate=0.0455; feature_fraction=0.729; min_data_in_leaf=229; num_iterations=4452; early_stopping_rounds=383; bagging_fraction=0.724; bagging_freq=3; lambda_l1=0.159; lambda_l2=0.227; max_depth=28; min_child_weight=6.51; subsample=0.862; colsample_bytree=0.524; min_gain_to_split=0.0276; scale_pos_weight=4.52 : y = 0.93 : 99.6 secs : infill_ei
#
# Thu Nov 13 02:41:10 PM 2025 AUC 0.931484616845472
#
# [mbo] 100: num_leaves=62; learning_rate=0.0267; feature_fraction=0.33; min_data_in_leaf=16; num_iterations=3604; early_stopping_rounds=234; bagging_fraction=0.841; bagging_freq=4; lambda_l1=0.156; lambda_l2=0.405; max_depth=13; min_child_weight=4.52; subsample=0.795; colsample_bytree=0.717; min_gain_to_split=0.0314; scale_pos_weight=2.51 : y = 0.931 : 128.7 secs : infill_ei
#
# Thu Nov 13 02:45:02 PM 2025 AUC 0.935198960654798
#
# [mbo] 101: num_leaves=58; learning_rate=0.0288; feature_fraction=0.601; min_data_in_leaf=49; num_iterations=3135; early_stopping_rounds=236; bagging_fraction=0.86; bagging_freq=4; lambda_l1=0.101; lambda_l2=0.404; max_depth=12; min_child_weight=5.18; subsample=0.62; colsample_bytree=0.576; min_gain_to_split=0.0245; scale_pos_weight=2.81 : y = 0.935 : 226.6 secs : infill_ei
#
# Thu Nov 13 02:48:34 PM 2025 AUC 0.931406102260884
#
# [mbo] 102: num_leaves=62; learning_rate=0.025; feature_fraction=0.43; min_data_in_leaf=8; num_iterations=3788; early_stopping_rounds=371; bagging_fraction=0.848; bagging_freq=4; lambda_l1=0.092; lambda_l2=0.333; max_depth=17; min_child_weight=7.22; subsample=0.599; colsample_bytree=0.764; min_gain_to_split=0.0421; scale_pos_weight=3.08 : y = 0.931 : 207.6 secs : infill_ei
#
# Saved the current state after iteration 103 in the file HT.RDATA.
#
# Thu Nov 13 02:54:28 PM 2025 AUC 0.93141046418225
#
# [mbo] 103: num_leaves=52; learning_rate=0.018; feature_fraction=0.586; min_data_in_leaf=228; num_iterations=3462; early_stopping_rounds=392; bagging_fraction=0.863; bagging_freq=5; lambda_l1=0.154; lambda_l2=0.276; max_depth=27; min_child_weight=3.31; subsample=0.757; colsample_bytree=0.782; min_gain_to_split=0.075; scale_pos_weight=4.39 : y = 0.931 : 349.6 secs : infill_ei
#
# Thu Nov 13 02:57:15 PM 2025 AUC 0.929630129200111
#
# [mbo] 104: num_leaves=49; learning_rate=0.056; feature_fraction=0.502; min_data_in_leaf=369; num_iterations=3287; early_stopping_rounds=269; bagging_fraction=0.667; bagging_freq=4; lambda_l1=0.15; lambda_l2=0.254; max_depth=19; min_child_weight=6.11; subsample=0.897; colsample_bytree=0.614; min_gain_to_split=0.0229; scale_pos_weight=3.64 : y = 0.93 : 161.7 secs : infill_ei
#
# Thu Nov 13 03:00:16 PM 2025 AUC 0.931606415111306
#
# [mbo] 105: num_leaves=54; learning_rate=0.014; feature_fraction=0.647; min_data_in_leaf=33; num_iterations=2992; early_stopping_rounds=431; bagging_fraction=0.876; bagging_freq=4; lambda_l1=0.103; lambda_l2=0.409; max_depth=30; min_child_weight=5.56; subsample=0.826; colsample_bytree=0.726; min_gain_to_split=0.0494; scale_pos_weight=4.87 : y = 0.932 : 175.5 secs : infill_ei
#
# Saved the current state after iteration 106 in the file HT.RDATA.
#
# Thu Nov 13 03:03:02 PM 2025 AUC 0.929832119712596
#
# [mbo] 106: num_leaves=59; learning_rate=0.0158; feature_fraction=0.683; min_data_in_leaf=710; num_iterations=3509; early_stopping_rounds=166; bagging_fraction=0.86; bagging_freq=4; lambda_l1=0.0524; lambda_l2=0.397; max_depth=24; min_child_weight=6.37; subsample=0.865; colsample_bytree=0.74; min_gain_to_split=0.0248; scale_pos_weight=2.64 : y = 0.93 : 159.6 secs : infill_ei
#
# Thu Nov 13 03:10:28 PM 2025 AUC 0.93500636504987
#
# [mbo] 107: num_leaves=62; learning_rate=0.0134; feature_fraction=0.47; min_data_in_leaf=160; num_iterations=4607; early_stopping_rounds=331; bagging_fraction=0.869; bagging_freq=5; lambda_l1=0.173; lambda_l2=0.35; max_depth=19; min_child_weight=1.95; subsample=0.77; colsample_bytree=0.586; min_gain_to_split=0.0488; scale_pos_weight=3.42 : y = 0.935 : 440.4 secs : infill_ei
#
# Saved the current state after iteration 108 in the file HT.RDATA.
#
# Thu Nov 13 03:13:28 PM 2025 AUC 0.933434731228471
#
# [mbo] 108: num_leaves=60; learning_rate=0.0339; feature_fraction=0.695; min_data_in_leaf=447; num_iterations=3378; early_stopping_rounds=274; bagging_fraction=0.865; bagging_freq=5; lambda_l1=0.203; lambda_l2=0.209; max_depth=20; min_child_weight=4.26; subsample=0.599; colsample_bytree=0.676; min_gain_to_split=0.0224; scale_pos_weight=3.1 : y = 0.933 : 175.2 secs : infill_ei
#
# Thu Nov 13 03:19:10 PM 2025 AUC 0.931230283276595
#
# [mbo] 109: num_leaves=62; learning_rate=0.016; feature_fraction=0.488; min_data_in_leaf=37; num_iterations=4143; early_stopping_rounds=382; bagging_fraction=0.848; bagging_freq=4; lambda_l1=0.153; lambda_l2=0.337; max_depth=19; min_child_weight=4.91; subsample=0.78; colsample_bytree=0.686; min_gain_to_split=0.056; scale_pos_weight=2.26 : y = 0.931 : 337.7 secs : infill_ei
#
# Thu Nov 13 03:24:07 PM 2025 AUC 0.931413819506378
#
# [mbo] 110: num_leaves=62; learning_rate=0.0181; feature_fraction=0.391; min_data_in_leaf=97; num_iterations=4322; early_stopping_rounds=386; bagging_fraction=0.848; bagging_freq=5; lambda_l1=0.269; lambda_l2=0.386; max_depth=11; min_child_weight=0.607; subsample=0.733; colsample_bytree=0.567; min_gain_to_split=0.0216; scale_pos_weight=3.33 : y = 0.931 : 292.3 secs : infill_ei
#
# Saved the current state after iteration 111 in the file HT.RDATA.
#
# Thu Nov 13 03:27:09 PM 2025 AUC 0.932087568591213
#
# [mbo] 111: num_leaves=52; learning_rate=0.0261; feature_fraction=0.646; min_data_in_leaf=132; num_iterations=4717; early_stopping_rounds=357; bagging_fraction=0.838; bagging_freq=2; lambda_l1=0.152; lambda_l2=0.444; max_depth=11; min_child_weight=6.21; subsample=0.817; colsample_bytree=0.666; min_gain_to_split=0.0419; scale_pos_weight=3.7 : y = 0.932 : 177.4 secs : infill_ei
#
# Thu Nov 13 03:31:12 PM 2025 AUC 0.933744763177868
#
# [mbo] 112: num_leaves=56; learning_rate=0.0204; feature_fraction=0.324; min_data_in_leaf=311; num_iterations=2612; early_stopping_rounds=450; bagging_fraction=0.856; bagging_freq=4; lambda_l1=0.225; lambda_l2=0.117; max_depth=20; min_child_weight=3.61; subsample=0.779; colsample_bytree=0.59; min_gain_to_split=0.047; scale_pos_weight=4.01 : y = 0.934 : 239.0 secs : infill_ei
#
# Thu Nov 13 03:33:55 PM 2025 AUC 0.938166409313306
#
# [mbo] 113: num_leaves=62; learning_rate=0.0502; feature_fraction=0.545; min_data_in_leaf=107; num_iterations=3692; early_stopping_rounds=143; bagging_fraction=0.86; bagging_freq=4; lambda_l1=0.0228; lambda_l2=0.4; max_depth=11; min_child_weight=6.94; subsample=0.548; colsample_bytree=0.686; min_gain_to_split=0.00791; scale_pos_weight=3.05 : y = 0.938 : 156.2 secs : infill_ei
#
# Thu Nov 13 03:36:38 PM 2025 AUC 0.930671621809338
#
# [mbo] 114: num_leaves=59; learning_rate=0.0287; feature_fraction=0.634; min_data_in_leaf=10; num_iterations=3604; early_stopping_rounds=448; bagging_fraction=0.881; bagging_freq=2; lambda_l1=0.365; lambda_l2=0.384; max_depth=17; min_child_weight=3.48; subsample=0.794; colsample_bytree=0.643; min_gain_to_split=0.0628; scale_pos_weight=2.8 : y = 0.931 : 158.5 secs : infill_ei
#
# Saved the current state after iteration 115 in the file HT.RDATA.
#
# Thu Nov 13 03:37:37 PM 2025 AUC 0.934058485983804
#
# [mbo] 115: num_leaves=63; learning_rate=0.0514; feature_fraction=0.618; min_data_in_leaf=266; num_iterations=3178; early_stopping_rounds=188; bagging_fraction=0.852; bagging_freq=4; lambda_l1=0.2; lambda_l2=0.351; max_depth=11; min_child_weight=9.18; subsample=0.587; colsample_bytree=0.702; min_gain_to_split=0.00548; scale_pos_weight=3.37 : y = 0.934 : 53.5 secs : infill_ei
#
# Thu Nov 13 03:40:09 PM 2025 AUC 0.924141825524488
#
# [mbo] 116: num_leaves=52; learning_rate=0.054; feature_fraction=0.778; min_data_in_leaf=502; num_iterations=3860; early_stopping_rounds=477; bagging_fraction=0.854; bagging_freq=4; lambda_l1=0.198; lambda_l2=0.205; max_depth=26; min_child_weight=1.92; subsample=0.823; colsample_bytree=0.617; min_gain_to_split=0.0391; scale_pos_weight=4.43 : y = 0.924 : 146.8 secs : infill_ei
#
# Thu Nov 13 03:41:03 PM 2025 AUC 0.928563136127513
#
# [mbo] 117: num_leaves=56; learning_rate=0.0552; feature_fraction=0.496; min_data_in_leaf=1013; num_iterations=2527; early_stopping_rounds=94; bagging_fraction=0.859; bagging_freq=4; lambda_l1=0.0345; lambda_l2=0.378; max_depth=18; min_child_weight=4.03; subsample=0.541; colsample_bytree=0.72; min_gain_to_split=0.0172; scale_pos_weight=3.47 : y = 0.929 : 48.6 secs : infill_ei
#
# Thu Nov 13 03:44:50 PM 2025 AUC 0.931637955158106
#
# [mbo] 118: num_leaves=59; learning_rate=0.0327; feature_fraction=0.696; min_data_in_leaf=1117; num_iterations=4068; early_stopping_rounds=471; bagging_fraction=0.887; bagging_freq=4; lambda_l1=0.241; lambda_l2=0.419; max_depth=24; min_child_weight=5.82; subsample=0.722; colsample_bytree=0.6; min_gain_to_split=0.00623; scale_pos_weight=2.86 : y = 0.932 : 220.8 secs : infill_ei
#
# Thu Nov 13 03:52:09 PM 2025 AUC 0.933241800091131
#
# [mbo] 119: num_leaves=58; learning_rate=0.0064; feature_fraction=0.711; min_data_in_leaf=116; num_iterations=3690; early_stopping_rounds=366; bagging_fraction=0.868; bagging_freq=3; lambda_l1=0.0605; lambda_l2=0.167; max_depth=19; min_child_weight=5.97; subsample=0.799; colsample_bytree=0.57; min_gain_to_split=0.024; scale_pos_weight=4.12 : y = 0.933 : 433.6 secs : infill_ei
#
# Saved the current state after iteration 120 in the file HT.RDATA.
#
# Thu Nov 13 03:55:25 PM 2025 AUC 0.924813225882433
#
# [mbo] 120: num_leaves=62; learning_rate=0.0508; feature_fraction=0.51; min_data_in_leaf=4021; num_iterations=3527; early_stopping_rounds=203; bagging_fraction=0.869; bagging_freq=4; lambda_l1=0.000674; lambda_l2=0.432; max_depth=11; min_child_weight=8.12; subsample=0.771; colsample_bytree=0.57; min_gain_to_split=0.0114; scale_pos_weight=3.55 : y = 0.925 : 190.8 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves learning_rate feature_fraction min_data_in_leaf num_iterations
#         <int>         <num>            <num>            <int>          <int>
# 1:         62    0.05018507        0.5451284              107           3692
#    early_stopping_rounds bagging_fraction bagging_freq  lambda_l1 lambda_l2
#                    <int>            <num>        <int>      <num>     <num>
# 1:                   143        0.8595576            4 0.02282497 0.3997193
#    max_depth min_child_weight subsample colsample_bytree min_gain_to_split
#        <int>            <num>     <num>            <num>             <num>
# 1:        11         6.942734 0.5480392        0.6857088       0.007907288
#    scale_pos_weight
#               <num>
# 1:         3.052059

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5589600
#
# $envios
# [1] 1033

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1704793926
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 13 04:07:24 PM 2025"
