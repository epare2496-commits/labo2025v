# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/src/workflows/610_5_WorkFlow_01_gerencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Nov 08 05:26:45 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454480    77.7 1438387  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 100009. # mi semilla

PARAM$experimento <- 6305 #
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16551

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  # learning_rate= 0.03,
  feature_fraction= 0.5,
  num_iterations= 4000,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 500
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower = 2L, upper = 400L), # aumente a 400
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.2),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
} # termino de noche pero no subio a kaggle corri de nuevo
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Nov 08 05:43:57 PM 2025 AUC 0.926349984591465
#
# Sat Nov 08 05:46:19 PM 2025 AUC 0.925066326211424
#
# Sat Nov 08 05:49:07 PM 2025 AUC 0.928154984371343
#
# Sat Nov 08 05:51:21 PM 2025 AUC 0.925301509109572
#
# Sat Nov 08 05:53:25 PM 2025 AUC 0.923692533696032
#
# Sat Nov 08 05:55:44 PM 2025 AUC 0.925779752953689
#
# Sat Nov 08 05:58:06 PM 2025 AUC 0.925083240843507
#
# Sat Nov 08 06:00:55 PM 2025 AUC 0.92266931430862
#
# Sat Nov 08 06:02:52 PM 2025 AUC 0.921033576703222
#
# Sat Nov 08 06:07:48 PM 2025 AUC 0.932192715586254
#
# Sat Nov 08 06:10:12 PM 2025 AUC 0.921283704721499
#
# Sat Nov 08 06:16:26 PM 2025 AUC 0.925320277399966
#
# [mbo] 0: num_leaves=188; learning_rate=0.0635; min_data_in_leaf=4274 : y = 0.926 : 172.8 secs : initdesign
#
# [mbo] 0: num_leaves=115; learning_rate=0.121; min_data_in_leaf=2218 : y = 0.925 : 141.8 secs : initdesign
#
# [mbo] 0: num_leaves=308; learning_rate=0.0503; min_data_in_leaf=4922 : y = 0.928 : 168.3 secs : initdesign
#
# [mbo] 0: num_leaves=75; learning_rate=0.08; min_data_in_leaf=3977 : y = 0.925 : 133.6 secs : initdesign
#
# [mbo] 0: num_leaves=224; learning_rate=0.115; min_data_in_leaf=7089 : y = 0.924 : 124.0 secs : initdesign
#
# [mbo] 0: num_leaves=238; learning_rate=0.092; min_data_in_leaf=3150 : y = 0.926 : 139.3 secs : initdesign
#
# [mbo] 0: num_leaves=377; learning_rate=0.16; min_data_in_leaf=1875 : y = 0.925 : 141.3 secs : initdesign
#
# [mbo] 0: num_leaves=48; learning_rate=0.199; min_data_in_leaf=5838 : y = 0.923 : 169.3 secs : initdesign
#
# [mbo] 0: num_leaves=269; learning_rate=0.177; min_data_in_leaf=6611 : y = 0.921 : 117.1 secs : initdesign
#
# [mbo] 0: num_leaves=351; learning_rate=0.0275; min_data_in_leaf=547 : y = 0.932 : 296.3 secs : initdesign
#
# [mbo] 0: num_leaves=28; learning_rate=0.143; min_data_in_leaf=1089 : y = 0.921 : 144.1 secs : initdesign
#
# [mbo] 0: num_leaves=150; learning_rate=0.0124; min_data_in_leaf=7848 : y = 0.925 : 373.9 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Sat Nov 08 06:27:25 PM 2025 AUC 0.940621995046098
#
# [mbo] 1: num_leaves=400; learning_rate=0.00503; min_data_in_leaf=4 : y = 0.941 : 658.0 secs : infill_ei
#
# Saved the current state after iteration 2 in the file HT.RDATA.
#
# Sat Nov 08 06:37:14 PM 2025 AUC 0.928839911117084
#
# [mbo] 2: num_leaves=400; learning_rate=0.005; min_data_in_leaf=3944 : y = 0.929 : 588.2 secs : infill_ei
#
# Sat Nov 08 06:40:37 PM 2025 AUC 0.930323069472796
#
# [mbo] 3: num_leaves=400; learning_rate=0.066; min_data_in_leaf=2 : y = 0.93 : 203.1 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Sat Nov 08 06:50:10 PM 2025 AUC 0.938468739211129
#
# [mbo] 4: num_leaves=176; learning_rate=0.00502; min_data_in_leaf=7 : y = 0.938 : 572.0 secs : infill_ei
#
# Sat Nov 08 07:00:58 PM 2025 AUC 0.939711617108339
#
# [mbo] 5: num_leaves=351; learning_rate=0.00501; min_data_in_leaf=2 : y = 0.94 : 647.3 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Sat Nov 08 07:11:10 PM 2025 AUC 0.914410223852412
#
# [mbo] 6: num_leaves=2; learning_rate=0.00508; min_data_in_leaf=2 : y = 0.914 : 611.2 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Sat Nov 08 07:20:20 PM 2025 AUC 0.939335092764013
#
# [mbo] 7: num_leaves=249; learning_rate=0.005; min_data_in_leaf=2 : y = 0.939 : 549.5 secs : infill_ei
#
# Sat Nov 08 07:22:35 PM 2025 AUC 0.923632058093651
#
# [mbo] 8: num_leaves=400; learning_rate=0.102; min_data_in_leaf=8192 : y = 0.924 : 135.0 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Sat Nov 08 07:33:18 PM 2025 AUC 0.93264361797029
#
# [mbo] 9: num_leaves=209; learning_rate=0.005; min_data_in_leaf=1267 : y = 0.933 : 642.5 secs : infill_ei
#
# Saved the current state after iteration 10 in the file HT.RDATA.
#
# Sat Nov 08 07:36:51 PM 2025 AUC 0.934916666473577
#
# [mbo] 10: num_leaves=197; learning_rate=0.0433; min_data_in_leaf=2 : y = 0.935 : 212.5 secs : infill_ei
#
# Sat Nov 08 07:38:50 PM 2025 AUC 0.899699823207339
#
# [mbo] 11: num_leaves=201; learning_rate=0.2; min_data_in_leaf=3 : y = 0.9 : 118.9 secs : infill_ei
#
# Sat Nov 08 07:49:59 PM 2025 AUC 0.940430141410958
#
# [mbo] 12: num_leaves=299; learning_rate=0.00506; min_data_in_leaf=4 : y = 0.94 : 668.7 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Sat Nov 08 07:52:22 PM 2025 AUC 0.913381791051001
#
# [mbo] 13: num_leaves=2; learning_rate=0.149; min_data_in_leaf=8192 : y = 0.913 : 142.1 secs : infill_ei
#
# Sat Nov 08 07:54:36 PM 2025 AUC 0.924671265283992
#
# [mbo] 14: num_leaves=400; learning_rate=0.137; min_data_in_leaf=5104 : y = 0.925 : 133.4 secs : infill_ei
#
# Sat Nov 08 08:06:04 PM 2025 AUC 0.926607874803918
#
# [mbo] 15: num_leaves=400; learning_rate=0.00502; min_data_in_leaf=8190 : y = 0.927 : 687.6 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Sat Nov 08 08:13:55 PM 2025 AUC 0.931646581506514
#
# [mbo] 16: num_leaves=400; learning_rate=0.00501; min_data_in_leaf=1704 : y = 0.932 : 471.1 secs : infill_ei
#
# Sat Nov 08 08:24:43 PM 2025 AUC 0.939601787853441
#
# [mbo] 17: num_leaves=317; learning_rate=0.00502; min_data_in_leaf=2 : y = 0.94 : 647.3 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Sat Nov 08 08:34:58 PM 2025 AUC 0.939182397660683
#
# [mbo] 18: num_leaves=285; learning_rate=0.00513; min_data_in_leaf=2 : y = 0.939 : 614.3 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Sat Nov 08 08:39:26 PM 2025 AUC 0.938064641699434
#
# [mbo] 19: num_leaves=134; learning_rate=0.0241; min_data_in_leaf=2 : y = 0.938 : 267.5 secs : infill_ei
#
# Sat Nov 08 08:43:51 PM 2025 AUC 0.930424325558009
#
# [mbo] 20: num_leaves=135; learning_rate=0.0645; min_data_in_leaf=2 : y = 0.93 : 264.9 secs : infill_ei
#
# Sat Nov 08 08:53:53 PM 2025 AUC 0.937448068603894
#
# [mbo] 21: num_leaves=119; learning_rate=0.00505; min_data_in_leaf=2 : y = 0.937 : 601.4 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Sat Nov 08 09:03:22 PM 2025 AUC 0.92944165494614
#
# [mbo] 22: num_leaves=124; learning_rate=0.00504; min_data_in_leaf=2780 : y = 0.929 : 567.6 secs : infill_ei
#
# Sat Nov 08 09:07:15 PM 2025 AUC 0.922504107011694
#
# [mbo] 23: num_leaves=400; learning_rate=0.2; min_data_in_leaf=8187 : y = 0.923 : 232.7 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Sat Nov 08 09:18:02 PM 2025 AUC 0.926646338213861
#
# [mbo] 24: num_leaves=296; learning_rate=0.00507; min_data_in_leaf=8186 : y = 0.927 : 646.8 secs : infill_ei
#
# Saved the current state after iteration 25 in the file HT.RDATA.
#
# Sat Nov 08 09:30:15 PM 2025 AUC 0.940280921916961
#
# [mbo] 25: num_leaves=383; learning_rate=0.00501; min_data_in_leaf=4 : y = 0.94 : 731.7 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Sat Nov 08 09:40:54 PM 2025 AUC 0.939154129371448
#
# [mbo] 26: num_leaves=222; learning_rate=0.00511; min_data_in_leaf=3 : y = 0.939 : 638.9 secs : infill_ei
#
# Saved the current state after iteration 27 in the file HT.RDATA.
#
# Sat Nov 08 09:45:42 PM 2025 AUC 0.937122983277685
#
# [mbo] 27: num_leaves=236; learning_rate=0.0166; min_data_in_leaf=3 : y = 0.937 : 287.7 secs : infill_ei
#
# Sat Nov 08 09:48:58 PM 2025 AUC 0.919572546393592
#
# [mbo] 28: num_leaves=308; learning_rate=0.113; min_data_in_leaf=3 : y = 0.92 : 195.5 secs : infill_ei
#
# Sat Nov 08 09:54:52 PM 2025 AUC 0.93281206916926
#
# [mbo] 29: num_leaves=99; learning_rate=0.0354; min_data_in_leaf=2 : y = 0.933 : 353.6 secs : infill_ei
#
# Saved the current state after iteration 30 in the file HT.RDATA.
#
# Sat Nov 08 10:03:11 PM 2025 AUC 0.911798766853809
#
# [mbo] 30: num_leaves=2; learning_rate=0.00508; min_data_in_leaf=8186 : y = 0.912 : 498.3 secs : infill_ei
#
# Sat Nov 08 10:05:28 PM 2025 AUC 0.920928960862322
#
# [mbo] 31: num_leaves=132; learning_rate=0.2; min_data_in_leaf=8192 : y = 0.921 : 136.1 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Sat Nov 08 10:08:35 PM 2025 AUC 0.920806619413827
#
# [mbo] 32: num_leaves=400; learning_rate=0.2; min_data_in_leaf=3564 : y = 0.921 : 186.7 secs : infill_ei
#
# Sat Nov 08 10:16:43 PM 2025 AUC 0.926735545520055
#
# [mbo] 33: num_leaves=121; learning_rate=0.0865; min_data_in_leaf=8192 : y = 0.927 : 487.4 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Sat Nov 08 10:21:35 PM 2025 AUC 0.923394094708037
#
# [mbo] 34: num_leaves=101; learning_rate=0.16; min_data_in_leaf=5007 : y = 0.923 : 291.2 secs : infill_ei
#
# Sat Nov 08 10:32:12 PM 2025 AUC 0.937977519758839
#
# [mbo] 35: num_leaves=147; learning_rate=0.00505; min_data_in_leaf=2 : y = 0.938 : 636.6 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Sat Nov 08 10:34:11 PM 2025 AUC 0.914669504308597
#
# [mbo] 36: num_leaves=2; learning_rate=0.2; min_data_in_leaf=2250 : y = 0.915 : 118.7 secs : infill_ei
#
# Sat Nov 08 10:36:15 PM 2025 AUC 0.92209004608658
#
# [mbo] 37: num_leaves=336; learning_rate=0.151; min_data_in_leaf=8192 : y = 0.922 : 123.4 secs : infill_ei
#
# Sat Nov 08 10:38:44 PM 2025 AUC 0.923788692220891
#
# [mbo] 38: num_leaves=244; learning_rate=0.0463; min_data_in_leaf=8192 : y = 0.924 : 148.2 secs : infill_ei
#
# Sat Nov 08 10:43:48 PM 2025 AUC 0.927113460108115
#
# [mbo] 39: num_leaves=356; learning_rate=0.0808; min_data_in_leaf=6179 : y = 0.927 : 303.9 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Sat Nov 08 10:58:33 PM 2025 AUC 0.939937531714935
#
# [mbo] 40: num_leaves=396; learning_rate=0.005; min_data_in_leaf=3 : y = 0.94 : 883.9 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Sat Nov 08 11:09:45 PM 2025 AUC 0.929044508653109
#
# [mbo] 41: num_leaves=257; learning_rate=0.00502; min_data_in_leaf=5048 : y = 0.929 : 672.0 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Sat Nov 08 11:18:19 PM 2025 AUC 0.93887190989367
#
# [mbo] 42: num_leaves=198; learning_rate=0.00518; min_data_in_leaf=3 : y = 0.939 : 513.3 secs : infill_ei
#
# Sat Nov 08 11:29:30 PM 2025 AUC 0.940148153640469
#
# [mbo] 43: num_leaves=369; learning_rate=0.00504; min_data_in_leaf=3 : y = 0.94 : 670.5 secs : infill_ei
#
# Saved the current state after iteration 44 in the file HT.RDATA.
#
# Sat Nov 08 11:32:15 PM 2025 AUC 0.927148216201437
#
# [mbo] 44: num_leaves=116; learning_rate=0.0399; min_data_in_leaf=6026 : y = 0.927 : 164.0 secs : infill_ei
#
# Sat Nov 08 11:34:39 PM 2025 AUC 0.907103682060527
#
# [mbo] 45: num_leaves=400; learning_rate=0.169; min_data_in_leaf=2 : y = 0.907 : 143.5 secs : infill_ei
#
# Sat Nov 08 11:37:50 PM 2025 AUC 0.92504153353152
#
# [mbo] 46: num_leaves=363; learning_rate=0.106; min_data_in_leaf=3215 : y = 0.925 : 190.7 secs : infill_ei
#
# Sat Nov 08 11:40:11 PM 2025 AUC 0.924763484784941
#
# [mbo] 47: num_leaves=306; learning_rate=0.154; min_data_in_leaf=3673 : y = 0.925 : 140.8 secs : infill_ei
#
# Saved the current state after iteration 48 in the file HT.RDATA.
#
# Sat Nov 08 11:50:07 PM 2025 AUC 0.934212971437443
#
# [mbo] 48: num_leaves=129; learning_rate=0.0158; min_data_in_leaf=695 : y = 0.934 : 595.4 secs : infill_ei
#
# Sat Nov 08 11:58:41 PM 2025 AUC 0.92935152081079
#
# [mbo] 49: num_leaves=300; learning_rate=0.00503; min_data_in_leaf=2722 : y = 0.929 : 513.3 secs : infill_ei
#
# Saved the current state after iteration 50 in the file HT.RDATA.
#
# Sun Nov 09 12:02:23 AM 2025 AUC 0.93387282513746
#
# [mbo] 50: num_leaves=300; learning_rate=0.0524; min_data_in_leaf=2 : y = 0.934 : 220.8 secs : infill_ei
#
# Sun Nov 09 12:08:38 AM 2025 AUC 0.939682421989949
#
# [mbo] 51: num_leaves=400; learning_rate=0.0157; min_data_in_leaf=3 : y = 0.94 : 374.5 secs : infill_ei
#
# Sun Nov 09 12:10:40 AM 2025 AUC 0.922144497299452
#
# [mbo] 52: num_leaves=346; learning_rate=0.2; min_data_in_leaf=5661 : y = 0.922 : 121.3 secs : infill_ei
#
# Saved the current state after iteration 53 in the file HT.RDATA.
#
# Sun Nov 09 12:21:15 AM 2025 AUC 0.928651301383988
#
# [mbo] 53: num_leaves=349; learning_rate=0.00502; min_data_in_leaf=6113 : y = 0.929 : 634.7 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Sun Nov 09 12:38:53 AM 2025 AUC 0.940087446330799
#
# [mbo] 54: num_leaves=301; learning_rate=0.00501; min_data_in_leaf=174 : y = 0.94 : 1057.3 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Sun Nov 09 12:58:11 AM 2025 AUC 0.939796885390624
#
# [mbo] 55: num_leaves=400; learning_rate=0.00504; min_data_in_leaf=153 : y = 0.94 : 1157.0 secs : infill_ei
#
# Saved the current state after iteration 56 in the file HT.RDATA.
#
# Sun Nov 09 01:00:47 AM 2025 AUC 0.926467228479606
#
# [mbo] 56: num_leaves=400; learning_rate=0.0417; min_data_in_leaf=5725 : y = 0.926 : 155.7 secs : infill_ei
#
# Sun Nov 09 01:03:01 AM 2025 AUC 0.923451326408375
#
# [mbo] 57: num_leaves=70; learning_rate=0.117; min_data_in_leaf=6605 : y = 0.923 : 133.3 secs : infill_ei
#
# Sun Nov 09 01:13:19 AM 2025 AUC 0.940096251207774
#
# [mbo] 58: num_leaves=303; learning_rate=0.00502; min_data_in_leaf=3 : y = 0.94 : 617.0 secs : infill_ei
#
# Saved the current state after iteration 59 in the file HT.RDATA.
#
# Sun Nov 09 01:15:43 AM 2025 AUC 0.925060533529203
#
# [mbo] 59: num_leaves=146; learning_rate=0.1; min_data_in_leaf=5505 : y = 0.925 : 143.6 secs : infill_ei
#
# Sun Nov 09 01:24:24 AM 2025 AUC 0.928651764798565
#
# [mbo] 60: num_leaves=69; learning_rate=0.005; min_data_in_leaf=4753 : y = 0.929 : 519.8 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Sun Nov 09 01:34:24 AM 2025 AUC 0.926538362617273
#
# [mbo] 61: num_leaves=89; learning_rate=0.00501; min_data_in_leaf=8192 : y = 0.927 : 599.1 secs : infill_ei
#
# Sun Nov 09 01:38:56 AM 2025 AUC 0.929277606185658
#
# [mbo] 62: num_leaves=295; learning_rate=0.0713; min_data_in_leaf=1758 : y = 0.929 : 271.7 secs : infill_ei
#
# Saved the current state after iteration 63 in the file HT.RDATA.
#
# Sun Nov 09 01:50:08 AM 2025 AUC 0.940087678038088
#
# [mbo] 63: num_leaves=333; learning_rate=0.00501; min_data_in_leaf=4 : y = 0.94 : 670.7 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Sun Nov 09 02:06:05 AM 2025 AUC 0.939584409806779
#
# [mbo] 64: num_leaves=262; learning_rate=0.00503; min_data_in_leaf=94 : y = 0.94 : 956.8 secs : infill_ei
#
# Saved the current state after iteration 65 in the file HT.RDATA.
#
# Sun Nov 09 02:08:18 AM 2025 AUC 0.924644850653067
#
# [mbo] 65: num_leaves=281; learning_rate=0.087; min_data_in_leaf=6534 : y = 0.925 : 131.9 secs : infill_ei
#
# Sun Nov 09 02:18:27 AM 2025 AUC 0.913369742271983
#
# [mbo] 66: num_leaves=2; learning_rate=0.0051; min_data_in_leaf=3569 : y = 0.913 : 608.9 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Sun Nov 09 02:22:39 AM 2025 AUC 0.937045361335932
#
# [mbo] 67: num_leaves=162; learning_rate=0.0216; min_data_in_leaf=2 : y = 0.937 : 250.9 secs : infill_ei
#
# Sun Nov 09 02:43:00 AM 2025 AUC 0.93902645865531
#
# [mbo] 68: num_leaves=250; learning_rate=0.00505; min_data_in_leaf=420 : y = 0.939 : 1220.5 secs : infill_ei
#
# Saved the current state after iteration 69 in the file HT.RDATA.
#
# Sun Nov 09 02:52:05 AM 2025 AUC 0.92806554535786
#
# [mbo] 69: num_leaves=137; learning_rate=0.00501; min_data_in_leaf=4598 : y = 0.928 : 544.4 secs : infill_ei
#
# Sun Nov 09 02:53:43 AM 2025 AUC 0.900034408532389
#
# [mbo] 70: num_leaves=67; learning_rate=0.2; min_data_in_leaf=3 : y = 0.9 : 97.4 secs : infill_ei
#
# Saved the current state after iteration 71 in the file HT.RDATA.
#
# Sun Nov 09 03:02:31 AM 2025 AUC 0.93416848363799
#
# [mbo] 71: num_leaves=297; learning_rate=0.00508; min_data_in_leaf=697 : y = 0.934 : 527.2 secs : infill_ei
#
# Sun Nov 09 03:08:38 AM 2025 AUC 0.931487862013675
#
# [mbo] 72: num_leaves=57; learning_rate=0.0341; min_data_in_leaf=1942 : y = 0.931 : 366.8 secs : infill_ei
#
# Saved the current state after iteration 73 in the file HT.RDATA.
#
# Sun Nov 09 03:19:27 AM 2025 AUC 0.938338983129392
#
# [mbo] 73: num_leaves=212; learning_rate=0.00502; min_data_in_leaf=226 : y = 0.938 : 648.1 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Sun Nov 09 03:21:32 AM 2025 AUC 0.925173143271568
#
# [mbo] 74: num_leaves=30; learning_rate=0.111; min_data_in_leaf=4958 : y = 0.925 : 124.7 secs : infill_ei
#
# Sun Nov 09 03:29:57 AM 2025 AUC 0.931400276658503
#
# [mbo] 75: num_leaves=249; learning_rate=0.00503; min_data_in_leaf=2047 : y = 0.931 : 504.1 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Sun Nov 09 03:40:52 AM 2025 AUC 0.933023849631238
#
# [mbo] 76: num_leaves=117; learning_rate=0.0356; min_data_in_leaf=1646 : y = 0.933 : 654.1 secs : infill_ei
#
# Saved the current state after iteration 77 in the file HT.RDATA.
#
# Sun Nov 09 03:51:09 AM 2025 AUC 0.928353557517859
#
# [mbo] 77: num_leaves=200; learning_rate=0.00501; min_data_in_leaf=5919 : y = 0.928 : 616.5 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Sun Nov 09 04:03:21 AM 2025 AUC 0.926727667472236
#
# [mbo] 78: num_leaves=375; learning_rate=0.00501; min_data_in_leaf=7199 : y = 0.927 : 731.6 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Sun Nov 09 04:12:48 AM 2025 AUC 0.929750984176709
#
# [mbo] 79: num_leaves=179; learning_rate=0.0426; min_data_in_leaf=2255 : y = 0.93 : 566.2 secs : infill_ei
#
# Sun Nov 09 04:14:55 AM 2025 AUC 0.925444124945838
#
# [mbo] 80: num_leaves=220; learning_rate=0.2; min_data_in_leaf=4728 : y = 0.925 : 126.6 secs : infill_ei
#
# Saved the current state after iteration 81 in the file HT.RDATA.
#
# Sun Nov 09 04:22:35 AM 2025 AUC 0.9322249228994
#
# [mbo] 81: num_leaves=82; learning_rate=0.00512; min_data_in_leaf=1275 : y = 0.932 : 458.9 secs : infill_ei
#
# Sun Nov 09 04:25:30 AM 2025 AUC 0.92623552119079
#
# [mbo] 82: num_leaves=400; learning_rate=0.0326; min_data_in_leaf=2449 : y = 0.926 : 173.8 secs : infill_ei
#
# Saved the current state after iteration 83 in the file HT.RDATA.
#
# Sun Nov 09 04:27:41 AM 2025 AUC 0.925985393172513
#
# [mbo] 83: num_leaves=262; learning_rate=0.2; min_data_in_leaf=2555 : y = 0.926 : 130.4 secs : infill_ei
#
# Sun Nov 09 04:39:43 AM 2025 AUC 0.928553752615396
#
# [mbo] 84: num_leaves=338; learning_rate=0.00503; min_data_in_leaf=4249 : y = 0.929 : 721.0 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Sun Nov 09 04:46:50 AM 2025 AUC 0.928487716038083
#
# [mbo] 85: num_leaves=220; learning_rate=0.00503; min_data_in_leaf=3591 : y = 0.928 : 426.2 secs : infill_ei
#
# Sun Nov 09 04:48:59 AM 2025 AUC 0.923655460529822
#
# [mbo] 86: num_leaves=168; learning_rate=0.2; min_data_in_leaf=3387 : y = 0.924 : 128.7 secs : infill_ei
#
# Sun Nov 09 04:58:48 AM 2025 AUC 0.928169581930539
#
# [mbo] 87: num_leaves=44; learning_rate=0.00502; min_data_in_leaf=6053 : y = 0.928 : 588.1 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Sun Nov 09 05:03:21 AM 2025 AUC 0.923887399525927
#
# [mbo] 88: num_leaves=178; learning_rate=0.2; min_data_in_leaf=6174 : y = 0.924 : 272.2 secs : infill_ei
#
# Sun Nov 09 05:07:50 AM 2025 AUC 0.924038240970946
#
# [mbo] 89: num_leaves=331; learning_rate=0.2; min_data_in_leaf=2391 : y = 0.924 : 268.3 secs : infill_ei
#
# Sun Nov 09 05:11:17 AM 2025 AUC 0.920306131669984
#
# [mbo] 90: num_leaves=191; learning_rate=0.138; min_data_in_leaf=8192 : y = 0.92 : 205.8 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Sun Nov 09 05:24:06 AM 2025 AUC 0.926771460149822
#
# [mbo] 91: num_leaves=247; learning_rate=0.00501; min_data_in_leaf=6858 : y = 0.927 : 768.1 secs : infill_ei
#
# Warning message in gzfile(file, "wb"):
# “cannot open compressed file './.~HT.RDATA', probable reason 'Transport endpoint is not connected'”
# Error in gzfile(file, "wb"): cannot open the connection
# Traceback:
#
# 1. mboTemplate(opt.problem)
# 2. mboTemplate.OptProblem(opt.problem)
# 3. mboTemplate(opt.state)
# 4. mboTemplate.OptState(opt.state)
# 5. finalizeMboLoop(opt.state)
# 6. saveOptState(opt.state)
# 7. save2(file = backup.fn, opt.state = opt.state)
# 8. save(list = ls(args, all.names = TRUE), envir = args, file = file,
#  .     ascii = ascii, version = version, compress = compress, compression_level = compression_level,
#  .     eval.promises = eval.promises, precheck = precheck)
# 9. gzfile(file, "wb")
# 10. .handleSimpleError(function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . }, "cannot open the connection", base::quote(gzfile(file, "wb")))

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
