# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/src/workflows/610_11a_WorkFlow_01_gerencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 12 12:23:10 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660356 35.3 1454477    77.7 1454477  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 100009. # mi semilla

PARAM$experimento <- 6311 #
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16551

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120



# parametros fijos del LightGBM

PARAM$lgbm$param_fijos <- list(

objective= "binary",

metric= "auc",

first_metric_only= TRUE,

boost_from_average= TRUE,

feature_pre_filter= FALSE,

verbosity= -100,

force_row_wise= TRUE, # para evitar warning

seed= PARAM$semilla_primigenia,

max_bin= 31

# learning_rate= 0.03,

# feature_fraction= 0.5,

# num_iterations= 4000, # valor grande, lo limita early_stopping_rounds

# early_stopping_rounds= 500

)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # 6 Existentes (Ajustados para velocidad)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L), # Reducido
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1), # Reducido
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L), # Reducido
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L), # Reducido
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L), # Reducido

  # 10 Nuevos Hiperparámetros
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L), # Reducido
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeNumericParam("subsample", lower = 0.5, upper = 0.9),
  makeNumericParam("colsample_bytree", lower = 0.5, upper = 0.9),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
} #
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 12 12:41:43 AM 2025 AUC 0.925390253001189
#
# Wed Nov 12 12:42:50 AM 2025 AUC 0.927514545425055
#
# Wed Nov 12 12:44:01 AM 2025 AUC 0.927200582048709
#
# Wed Nov 12 12:45:31 AM 2025 AUC 0.922767558199078
#
# Wed Nov 12 12:46:32 AM 2025 AUC 0.924940972568174
#
# Wed Nov 12 12:47:19 AM 2025 AUC 0.925412033486337
#
# Wed Nov 12 12:48:37 AM 2025 AUC 0.924362399468
#
# Wed Nov 12 12:50:03 AM 2025 AUC 0.923814875144527
#
# Wed Nov 12 12:50:57 AM 2025 AUC 0.929852471969211
#
# Wed Nov 12 12:53:45 AM 2025 AUC 0.92194129000716
#
# Wed Nov 12 12:54:44 AM 2025 AUC 0.926245600457854
#
# Wed Nov 12 12:56:12 AM 2025 AUC 0.923815686120038
#
# Wed Nov 12 12:57:58 AM 2025 AUC 0.926947325982033
#
# Wed Nov 12 12:59:05 AM 2025 AUC 0.927467045430848
#
# Wed Nov 12 01:01:31 AM 2025 AUC 0.926774472344577
#
# Wed Nov 12 01:03:06 AM 2025 AUC 0.925219021314754
#
# Wed Nov 12 01:03:37 AM 2025 AUC 0.92381232636435
#
# Wed Nov 12 01:05:13 AM 2025 AUC 0.926079813892706
#
# Wed Nov 12 01:06:08 AM 2025 AUC 0.926146777299173
#
# Wed Nov 12 01:09:28 AM 2025 AUC 0.924929155496444
#
# Wed Nov 12 01:12:34 AM 2025 AUC 0.932089605842731
#
# Wed Nov 12 01:13:20 AM 2025 AUC 0.924688875037942
#
# Wed Nov 12 01:13:40 AM 2025 AUC 0.922769064296456
#
# Wed Nov 12 01:15:19 AM 2025 AUC 0.928788703806256
#
# Wed Nov 12 01:16:17 AM 2025 AUC 0.923531265423016
#
# Wed Nov 12 01:17:15 AM 2025 AUC 0.923378570319687
#
# Wed Nov 12 01:18:33 AM 2025 AUC 0.924836125019985
#
# Wed Nov 12 01:20:09 AM 2025 AUC 0.92481260673017
#
# Wed Nov 12 01:21:20 AM 2025 AUC 0.928293081915478
#
# Wed Nov 12 01:21:43 AM 2025 AUC 0.923122765472833
#
# Wed Nov 12 01:24:19 AM 2025 AUC 0.924487289696672
#
# Wed Nov 12 01:24:46 AM 2025 AUC 0.923332228861923
#
# Wed Nov 12 01:25:06 AM 2025 AUC 0.923584789806733
#
# Wed Nov 12 01:25:45 AM 2025 AUC 0.923547948347811
#
# Wed Nov 12 01:26:26 AM 2025 AUC 0.922534460666529
#
# Wed Nov 12 01:27:22 AM 2025 AUC 0.924498643353824
#
# Wed Nov 12 01:28:58 AM 2025 AUC 0.918268961186712
#
# Wed Nov 12 01:29:43 AM 2025 AUC 0.931609044925726
#
# Wed Nov 12 01:30:06 AM 2025 AUC 0.924999131097667
#
# Wed Nov 12 01:33:19 AM 2025 AUC 0.932335678983454
#
# Wed Nov 12 01:33:38 AM 2025 AUC 0.91740237592654
#
# Wed Nov 12 01:34:34 AM 2025 AUC 0.928689533086642
#
# Wed Nov 12 01:36:08 AM 2025 AUC 0.928721972107077
#
# Wed Nov 12 01:38:50 AM 2025 AUC 0.928130423398729
#
# Wed Nov 12 01:39:19 AM 2025 AUC 0.922408875315991
#
# Wed Nov 12 01:40:01 AM 2025 AUC 0.924742399421659
#
# Wed Nov 12 01:40:47 AM 2025 AUC 0.92284355818981
#
# Wed Nov 12 01:42:16 AM 2025 AUC 0.926802508926523
#
# Wed Nov 12 01:42:54 AM 2025 AUC 0.9249984359758
#
# Wed Nov 12 01:44:00 AM 2025 AUC 0.924936338422398
#
# Wed Nov 12 01:44:57 AM 2025 AUC 0.925338813983071
#
# Wed Nov 12 01:45:39 AM 2025 AUC 0.923930728788936
#
# Wed Nov 12 01:51:35 AM 2025 AUC 0.922211228998631
#
# Wed Nov 12 01:52:26 AM 2025 AUC 0.92993472805674
#
# Wed Nov 12 01:53:55 AM 2025 AUC 0.924994033537313
#
# Wed Nov 12 01:54:18 AM 2025 AUC 0.913648022725851
#
# Wed Nov 12 01:56:32 AM 2025 AUC 0.929166618394315
#
# Wed Nov 12 01:56:58 AM 2025 AUC 0.914401187268148
#
# Wed Nov 12 01:58:14 AM 2025 AUC 0.927939033178167
#
# Wed Nov 12 01:59:20 AM 2025 AUC 0.919558180541685
#
# Wed Nov 12 02:01:05 AM 2025 AUC 0.928261106309621
#
# Wed Nov 12 02:02:04 AM 2025 AUC 0.925873826112948
#
# Wed Nov 12 02:02:47 AM 2025 AUC 0.925522326155814
#
# Wed Nov 12 02:04:09 AM 2025 AUC 0.92463257016676
#
# [mbo] 0: num_leaves=23; learning_rate=0.0661; feature_fraction=0.793; min_data_in_leaf=3183; num_iterations=666; early_stopping_rounds=328; bagging_fraction=0.654; bagging_freq=4; lambda_l1=0.232; lambda_l2=0.217; max_depth=20; min_child_weight=3.99; subsample=0.677; colsample_bytree=0.67; min_gain_to_split=0.0371; scale_pos_weight=1.4 : y = 0.925 : 58.9 secs : initdesign
#
# [mbo] 0: num_leaves=34; learning_rate=0.0431; feature_fraction=0.674; min_data_in_leaf=3877; num_iterations=805; early_stopping_rounds=379; bagging_fraction=0.619; bagging_freq=2; lambda_l1=0.308; lambda_l2=0.288; max_depth=15; min_child_weight=6.57; subsample=0.617; colsample_bytree=0.688; min_gain_to_split=0.0503; scale_pos_weight=3.11 : y = 0.928 : 67.2 secs : initdesign
#
# [mbo] 0: num_leaves=32; learning_rate=0.0493; feature_fraction=0.471; min_data_in_leaf=3644; num_iterations=2900; early_stopping_rounds=255; bagging_fraction=0.739; bagging_freq=2; lambda_l1=0.188; lambda_l2=0.202; max_depth=21; min_child_weight=2.78; subsample=0.685; colsample_bytree=0.576; min_gain_to_split=0.0415; scale_pos_weight=3.62 : y = 0.927 : 70.3 secs : initdesign
#
# [mbo] 0: num_leaves=31; learning_rate=0.0711; feature_fraction=0.585; min_data_in_leaf=6762; num_iterations=2192; early_stopping_rounds=395; bagging_fraction=0.632; bagging_freq=3; lambda_l1=0.208; lambda_l2=0.348; max_depth=8; min_child_weight=1.96; subsample=0.649; colsample_bytree=0.635; min_gain_to_split=0.0718; scale_pos_weight=2.25 : y = 0.923 : 90.5 secs : initdesign
#
# [mbo] 0: num_leaves=39; learning_rate=0.0591; feature_fraction=0.487; min_data_in_leaf=3430; num_iterations=4371; early_stopping_rounds=236; bagging_fraction=0.756; bagging_freq=3; lambda_l1=0.108; lambda_l2=0.0859; max_depth=8; min_child_weight=5.18; subsample=0.804; colsample_bytree=0.655; min_gain_to_split=0.059; scale_pos_weight=2.86 : y = 0.925 : 60.6 secs : initdesign
#
# [mbo] 0: num_leaves=42; learning_rate=0.0392; feature_fraction=0.685; min_data_in_leaf=4656; num_iterations=1311; early_stopping_rounds=204; bagging_fraction=0.732; bagging_freq=2; lambda_l1=0.157; lambda_l2=0.0611; max_depth=17; min_child_weight=7.62; subsample=0.751; colsample_bytree=0.679; min_gain_to_split=0.0613; scale_pos_weight=1.48 : y = 0.925 : 47.7 secs : initdesign
#
# [mbo] 0: num_leaves=47; learning_rate=0.0214; feature_fraction=0.558; min_data_in_leaf=4972; num_iterations=3464; early_stopping_rounds=133; bagging_fraction=0.576; bagging_freq=3; lambda_l1=0.346; lambda_l2=0.415; max_depth=18; min_child_weight=3.65; subsample=0.828; colsample_bytree=0.646; min_gain_to_split=0.0143; scale_pos_weight=2.02 : y = 0.924 : 78.1 secs : initdesign
#
# [mbo] 0: num_leaves=11; learning_rate=0.0703; feature_fraction=0.385; min_data_in_leaf=1659; num_iterations=1992; early_stopping_rounds=491; bagging_fraction=0.664; bagging_freq=3; lambda_l1=0.33; lambda_l2=0.043; max_depth=28; min_child_weight=3.52; subsample=0.731; colsample_bytree=0.739; min_gain_to_split=0.0244; scale_pos_weight=2.09 : y = 0.924 : 85.2 secs : initdesign
#
# [mbo] 0: num_leaves=45; learning_rate=0.0411; feature_fraction=0.784; min_data_in_leaf=3238; num_iterations=3152; early_stopping_rounds=308; bagging_fraction=0.642; bagging_freq=4; lambda_l1=0.319; lambda_l2=0.0653; max_depth=14; min_child_weight=1.55; subsample=0.671; colsample_bytree=0.891; min_gain_to_split=0.0359; scale_pos_weight=3.78 : y = 0.93 : 54.4 secs : initdesign
#
# [mbo] 0: num_leaves=6; learning_rate=0.0289; feature_fraction=0.504; min_data_in_leaf=4595; num_iterations=2119; early_stopping_rounds=412; bagging_fraction=0.546; bagging_freq=5; lambda_l1=0.401; lambda_l2=0.294; max_depth=8; min_child_weight=9.53; subsample=0.664; colsample_bytree=0.791; min_gain_to_split=0.0313; scale_pos_weight=3.72 : y = 0.922 : 167.5 secs : initdesign
#
# [mbo] 0: num_leaves=22; learning_rate=0.0862; feature_fraction=0.35; min_data_in_leaf=3790; num_iterations=3647; early_stopping_rounds=296; bagging_fraction=0.841; bagging_freq=4; lambda_l1=0.295; lambda_l2=0.143; max_depth=25; min_child_weight=3.03; subsample=0.783; colsample_bytree=0.819; min_gain_to_split=0.0307; scale_pos_weight=3.27 : y = 0.926 : 59.6 secs : initdesign
#
# [mbo] 0: num_leaves=45; learning_rate=0.0648; feature_fraction=0.566; min_data_in_leaf=7335; num_iterations=2730; early_stopping_rounds=404; bagging_fraction=0.619; bagging_freq=5; lambda_l1=0.0855; lambda_l2=0.185; max_depth=6; min_child_weight=8.28; subsample=0.564; colsample_bytree=0.696; min_gain_to_split=0.0846; scale_pos_weight=3.44 : y = 0.924 : 87.6 secs : initdesign
#
# [mbo] 0: num_leaves=30; learning_rate=0.0502; feature_fraction=0.545; min_data_in_leaf=5794; num_iterations=3848; early_stopping_rounds=316; bagging_fraction=0.728; bagging_freq=3; lambda_l1=0.267; lambda_l2=0.41; max_depth=12; min_child_weight=7.34; subsample=0.881; colsample_bytree=0.758; min_gain_to_split=0.0135; scale_pos_weight=4.31 : y = 0.927 : 105.8 secs : initdesign
#
# [mbo] 0: num_leaves=24; learning_rate=0.0755; feature_fraction=0.372; min_data_in_leaf=524; num_iterations=4638; early_stopping_rounds=299; bagging_fraction=0.87; bagging_freq=2; lambda_l1=0.247; lambda_l2=0.481; max_depth=11; min_child_weight=5.77; subsample=0.858; colsample_bytree=0.684; min_gain_to_split=0.081; scale_pos_weight=4.05 : y = 0.927 : 67.7 secs : initdesign
#
# [mbo] 0: num_leaves=36; learning_rate=0.0603; feature_fraction=0.579; min_data_in_leaf=5330; num_iterations=1813; early_stopping_rounds=342; bagging_fraction=0.626; bagging_freq=2; lambda_l1=0.183; lambda_l2=0.252; max_depth=20; min_child_weight=4.66; subsample=0.852; colsample_bytree=0.507; min_gain_to_split=0.0759; scale_pos_weight=2.61 : y = 0.927 : 145.7 secs : initdesign
#
# [mbo] 0: num_leaves=52; learning_rate=0.0531; feature_fraction=0.693; min_data_in_leaf=6010; num_iterations=767; early_stopping_rounds=419; bagging_fraction=0.767; bagging_freq=2; lambda_l1=0.354; lambda_l2=0.247; max_depth=26; min_child_weight=3.76; subsample=0.611; colsample_bytree=0.711; min_gain_to_split=0.00582; scale_pos_weight=3.41 : y = 0.925 : 94.5 secs : initdesign
#
# [mbo] 0: num_leaves=39; learning_rate=0.0849; feature_fraction=0.738; min_data_in_leaf=7470; num_iterations=2253; early_stopping_rounds=138; bagging_fraction=0.782; bagging_freq=4; lambda_l1=0.0941; lambda_l2=0.337; max_depth=29; min_child_weight=0.617; subsample=0.733; colsample_bytree=0.745; min_gain_to_split=0.0665; scale_pos_weight=3.9 : y = 0.924 : 31.6 secs : initdesign
#
# [mbo] 0: num_leaves=22; learning_rate=0.0134; feature_fraction=0.72; min_data_in_leaf=4049; num_iterations=2475; early_stopping_rounds=363; bagging_fraction=0.646; bagging_freq=4; lambda_l1=0.111; lambda_l2=0.0246; max_depth=7; min_child_weight=3.2; subsample=0.653; colsample_bytree=0.533; min_gain_to_split=0.0427; scale_pos_weight=3.16 : y = 0.926 : 96.3 secs : initdesign
#
# [mbo] 0: num_leaves=14; learning_rate=0.0375; feature_fraction=0.435; min_data_in_leaf=2482; num_iterations=1475; early_stopping_rounds=188; bagging_fraction=0.714; bagging_freq=4; lambda_l1=0.376; lambda_l2=0.234; max_depth=10; min_child_weight=2.93; subsample=0.539; colsample_bytree=0.836; min_gain_to_split=0.0748; scale_pos_weight=2.31 : y = 0.926 : 54.3 secs : initdesign
#
# [mbo] 0: num_leaves=6; learning_rate=0.0308; feature_fraction=0.557; min_data_in_leaf=4109; num_iterations=2702; early_stopping_rounds=269; bagging_fraction=0.599; bagging_freq=1; lambda_l1=0.218; lambda_l2=0.19; max_depth=22; min_child_weight=8.56; subsample=0.519; colsample_bytree=0.624; min_gain_to_split=0.0837; scale_pos_weight=4.75 : y = 0.925 : 200.5 secs : initdesign
#
# [mbo] 0: num_leaves=47; learning_rate=0.0327; feature_fraction=0.517; min_data_in_leaf=764; num_iterations=4996; early_stopping_rounds=355; bagging_fraction=0.684; bagging_freq=4; lambda_l1=0.137; lambda_l2=0.117; max_depth=19; min_child_weight=2.31; subsample=0.642; colsample_bytree=0.809; min_gain_to_split=0.0876; scale_pos_weight=2.33 : y = 0.932 : 185.9 secs : initdesign
#
# [mbo] 0: num_leaves=15; learning_rate=0.0831; feature_fraction=0.318; min_data_in_leaf=2961; num_iterations=4002; early_stopping_rounds=285; bagging_fraction=0.604; bagging_freq=5; lambda_l1=0.395; lambda_l2=0.0935; max_depth=13; min_child_weight=7.15; subsample=0.836; colsample_bytree=0.588; min_gain_to_split=0.0288; scale_pos_weight=1.37 : y = 0.925 : 46.0 secs : initdesign
#
# [mbo] 0: num_leaves=10; learning_rate=0.0894; feature_fraction=0.342; min_data_in_leaf=208; num_iterations=495; early_stopping_rounds=78; bagging_fraction=0.706; bagging_freq=2; lambda_l1=0.481; lambda_l2=0.437; max_depth=16; min_child_weight=5.98; subsample=0.552; colsample_bytree=0.529; min_gain_to_split=0.0517; scale_pos_weight=3.35 : y = 0.923 : 19.7 secs : initdesign
#
# [mbo] 0: num_leaves=33; learning_rate=0.0459; feature_fraction=0.623; min_data_in_leaf=2697; num_iterations=3052; early_stopping_rounds=466; bagging_fraction=0.831; bagging_freq=2; lambda_l1=0.092; lambda_l2=0.241; max_depth=14; min_child_weight=0.0642; subsample=0.812; colsample_bytree=0.555; min_gain_to_split=0.0159; scale_pos_weight=4.82 : y = 0.929 : 99.3 secs : initdesign
#
# [mbo] 0: num_leaves=51; learning_rate=0.0264; feature_fraction=0.418; min_data_in_leaf=6328; num_iterations=359; early_stopping_rounds=320; bagging_fraction=0.791; bagging_freq=5; lambda_l1=0.141; lambda_l2=0.443; max_depth=15; min_child_weight=2.04; subsample=0.761; colsample_bytree=0.731; min_gain_to_split=0.00327; scale_pos_weight=1.92 : y = 0.924 : 57.6 secs : initdesign
#
# [mbo] 0: num_leaves=48; learning_rate=0.0953; feature_fraction=0.473; min_data_in_leaf=4368; num_iterations=1343; early_stopping_rounds=243; bagging_fraction=0.661; bagging_freq=3; lambda_l1=0.0378; lambda_l2=0.159; max_depth=29; min_child_weight=2.35; subsample=0.578; colsample_bytree=0.598; min_gain_to_split=0.0394; scale_pos_weight=3.23 : y = 0.923 : 58.4 secs : initdesign
#
# [mbo] 0: num_leaves=57; learning_rate=0.0676; feature_fraction=0.616; min_data_in_leaf=1793; num_iterations=1562; early_stopping_rounds=428; bagging_fraction=0.891; bagging_freq=5; lambda_l1=0.425; lambda_l2=0.449; max_depth=24; min_child_weight=5.38; subsample=0.848; colsample_bytree=0.817; min_gain_to_split=0.0932; scale_pos_weight=4.67 : y = 0.925 : 78.0 secs : initdesign
#
# [mbo] 0: num_leaves=49; learning_rate=0.0273; feature_fraction=0.46; min_data_in_leaf=7045; num_iterations=624; early_stopping_rounds=332; bagging_fraction=0.541; bagging_freq=1; lambda_l1=0.0724; lambda_l2=0.00783; max_depth=18; min_child_weight=5.06; subsample=0.813; colsample_bytree=0.869; min_gain_to_split=0.0475; scale_pos_weight=3.54 : y = 0.925 : 96.2 secs : initdesign
#
# [mbo] 0: num_leaves=55; learning_rate=0.0635; feature_fraction=0.501; min_data_in_leaf=291; num_iterations=4011; early_stopping_rounds=280; bagging_fraction=0.588; bagging_freq=4; lambda_l1=0.494; lambda_l2=0.374; max_depth=21; min_child_weight=7.96; subsample=0.622; colsample_bytree=0.853; min_gain_to_split=0.0124; scale_pos_weight=1.51 : y = 0.928 : 70.6 secs : initdesign
#
# [mbo] 0: num_leaves=13; learning_rate=0.0913; feature_fraction=0.648; min_data_in_leaf=7623; num_iterations=1919; early_stopping_rounds=110; bagging_fraction=0.697; bagging_freq=5; lambda_l1=0.0289; lambda_l2=0.17; max_depth=22; min_child_weight=9.03; subsample=0.696; colsample_bytree=0.513; min_gain_to_split=0.0689; scale_pos_weight=2.69 : y = 0.923 : 23.3 secs : initdesign
#
# [mbo] 0: num_leaves=11; learning_rate=0.0179; feature_fraction=0.442; min_data_in_leaf=7238; num_iterations=3182; early_stopping_rounds=213; bagging_fraction=0.885; bagging_freq=1; lambda_l1=0.239; lambda_l2=0.207; max_depth=27; min_child_weight=2.63; subsample=0.634; colsample_bytree=0.662; min_gain_to_split=0.00802; scale_pos_weight=4.42 : y = 0.924 : 155.9 secs : initdesign
#
# [mbo] 0: num_leaves=53; learning_rate=0.0478; feature_fraction=0.663; min_data_in_leaf=6898; num_iterations=4740; early_stopping_rounds=174; bagging_fraction=0.608; bagging_freq=1; lambda_l1=0.124; lambda_l2=0.138; max_depth=4; min_child_weight=1.34; subsample=0.582; colsample_bytree=0.767; min_gain_to_split=0.0655; scale_pos_weight=2.97 : y = 0.923 : 26.6 secs : initdesign
#
# [mbo] 0: num_leaves=17; learning_rate=0.0616; feature_fraction=0.789; min_data_in_leaf=1291; num_iterations=4866; early_stopping_rounds=205; bagging_fraction=0.571; bagging_freq=2; lambda_l1=0.223; lambda_l2=0.375; max_depth=22; min_child_weight=5.83; subsample=0.514; colsample_bytree=0.541; min_gain_to_split=0.0493; scale_pos_weight=1.65 : y = 0.924 : 20.2 secs : initdesign
#
# [mbo] 0: num_leaves=30; learning_rate=0.0209; feature_fraction=0.76; min_data_in_leaf=8033; num_iterations=1016; early_stopping_rounds=74; bagging_fraction=0.56; bagging_freq=3; lambda_l1=0.438; lambda_l2=0.314; max_depth=16; min_child_weight=8; subsample=0.512; colsample_bytree=0.828; min_gain_to_split=0.0627; scale_pos_weight=2.77 : y = 0.924 : 38.8 secs : initdesign
#
# [mbo] 0: num_leaves=4; learning_rate=0.0543; feature_fraction=0.748; min_data_in_leaf=6250; num_iterations=2363; early_stopping_rounds=266; bagging_fraction=0.691; bagging_freq=5; lambda_l1=0.375; lambda_l2=0.261; max_depth=3; min_child_weight=4.12; subsample=0.822; colsample_bytree=0.843; min_gain_to_split=0.0438; scale_pos_weight=1.98 : y = 0.923 : 41.5 secs : initdesign
#
# [mbo] 0: num_leaves=20; learning_rate=0.0185; feature_fraction=0.494; min_data_in_leaf=6925; num_iterations=328; early_stopping_rounds=442; bagging_fraction=0.673; bagging_freq=3; lambda_l1=0.412; lambda_l2=0.274; max_depth=12; min_child_weight=9.53; subsample=0.864; colsample_bytree=0.559; min_gain_to_split=0.0463; scale_pos_weight=4.48 : y = 0.924 : 55.5 secs : initdesign
#
# [mbo] 0: num_leaves=3; learning_rate=0.0802; feature_fraction=0.333; min_data_in_leaf=7846; num_iterations=4190; early_stopping_rounds=193; bagging_fraction=0.551; bagging_freq=3; lambda_l1=0.487; lambda_l2=0.429; max_depth=5; min_child_weight=6.17; subsample=0.776; colsample_bytree=0.778; min_gain_to_split=0.0972; scale_pos_weight=3.99 : y = 0.918 : 95.9 secs : initdesign
#
# [mbo] 0: num_leaves=38; learning_rate=0.0237; feature_fraction=0.773; min_data_in_leaf=394; num_iterations=3527; early_stopping_rounds=183; bagging_fraction=0.818; bagging_freq=3; lambda_l1=0.0441; lambda_l2=0.113; max_depth=18; min_child_weight=9.22; subsample=0.72; colsample_bytree=0.848; min_gain_to_split=0.0184; scale_pos_weight=1.71 : y = 0.932 : 45.4 secs : initdesign
#
# [mbo] 0: num_leaves=37; learning_rate=0.0441; feature_fraction=0.595; min_data_in_leaf=2138; num_iterations=148; early_stopping_rounds=389; bagging_fraction=0.523; bagging_freq=2; lambda_l1=0.415; lambda_l2=0.327; max_depth=6; min_child_weight=4.23; subsample=0.707; colsample_bytree=0.896; min_gain_to_split=0.0918; scale_pos_weight=4.09 : y = 0.925 : 22.6 secs : initdesign
#
# [mbo] 0: num_leaves=55; learning_rate=0.0162; feature_fraction=0.327; min_data_in_leaf=1176; num_iterations=1187; early_stopping_rounds=473; bagging_fraction=0.795; bagging_freq=3; lambda_l1=0.475; lambda_l2=0.331; max_depth=27; min_child_weight=1.01; subsample=0.569; colsample_bytree=0.608; min_gain_to_split=0.039; scale_pos_weight=4.57 : y = 0.932 : 192.7 secs : initdesign
#
# [mbo] 0: num_leaves=26; learning_rate=0.0872; feature_fraction=0.639; min_data_in_leaf=5447; num_iterations=1022; early_stopping_rounds=103; bagging_fraction=0.511; bagging_freq=3; lambda_l1=0.455; lambda_l2=0.178; max_depth=19; min_child_weight=1.78; subsample=0.742; colsample_bytree=0.724; min_gain_to_split=0.0341; scale_pos_weight=4.36 : y = 0.917 : 19.8 secs : initdesign
#
# [mbo] 0: num_leaves=19; learning_rate=0.0342; feature_fraction=0.705; min_data_in_leaf=970; num_iterations=1138; early_stopping_rounds=352; bagging_fraction=0.846; bagging_freq=4; lambda_l1=0.298; lambda_l2=0.0986; max_depth=26; min_child_weight=0.315; subsample=0.69; colsample_bytree=0.55; min_gain_to_split=0.0212; scale_pos_weight=1.78 : y = 0.929 : 55.5 secs : initdesign
#
# [mbo] 0: num_leaves=25; learning_rate=0.0124; feature_fraction=0.713; min_data_in_leaf=2322; num_iterations=4499; early_stopping_rounds=381; bagging_fraction=0.781; bagging_freq=1; lambda_l1=0.361; lambda_l2=0.356; max_depth=11; min_child_weight=1.2; subsample=0.53; colsample_bytree=0.629; min_gain_to_split=0.0788; scale_pos_weight=4.55 : y = 0.929 : 94.0 secs : initdesign
#
# [mbo] 0: num_leaves=41; learning_rate=0.0246; feature_fraction=0.389; min_data_in_leaf=5651; num_iterations=3760; early_stopping_rounds=451; bagging_fraction=0.877; bagging_freq=5; lambda_l1=0.0613; lambda_l2=0.463; max_depth=9; min_child_weight=0.857; subsample=0.872; colsample_bytree=0.603; min_gain_to_split=0.09; scale_pos_weight=4.81 : y = 0.928 : 162.4 secs : initdesign
#
# [mbo] 0: num_leaves=28; learning_rate=0.077; feature_fraction=0.61; min_data_in_leaf=1851; num_iterations=4417; early_stopping_rounds=148; bagging_fraction=0.865; bagging_freq=4; lambda_l1=0.0545; lambda_l2=0.0506; max_depth=10; min_child_weight=4.91; subsample=0.626; colsample_bytree=0.52; min_gain_to_split=0.055; scale_pos_weight=4.88 : y = 0.922 : 29.2 secs : initdesign
#
# [mbo] 0: num_leaves=50; learning_rate=0.0907; feature_fraction=0.413; min_data_in_leaf=2668; num_iterations=4812; early_stopping_rounds=87; bagging_fraction=0.856; bagging_freq=1; lambda_l1=0.00898; lambda_l2=0.105; max_depth=23; min_child_weight=9.19; subsample=0.501; colsample_bytree=0.804; min_gain_to_split=0.0674; scale_pos_weight=2.51 : y = 0.925 : 42.1 secs : initdesign
#
# [mbo] 0: num_leaves=13; learning_rate=0.0931; feature_fraction=0.534; min_data_in_leaf=6473; num_iterations=3354; early_stopping_rounds=99; bagging_fraction=0.5; bagging_freq=2; lambda_l1=0.0165; lambda_l2=0.0212; max_depth=28; min_child_weight=7.47; subsample=0.891; colsample_bytree=0.769; min_gain_to_split=0.0221; scale_pos_weight=1.05 : y = 0.923 : 45.6 secs : initdesign
#
# [mbo] 0: num_leaves=28; learning_rate=0.0778; feature_fraction=0.451; min_data_in_leaf=1035; num_iterations=2605; early_stopping_rounds=150; bagging_fraction=0.533; bagging_freq=4; lambda_l1=0.172; lambda_l2=0.00514; max_depth=9; min_child_weight=9.79; subsample=0.715; colsample_bytree=0.884; min_gain_to_split=0.0951; scale_pos_weight=2.15 : y = 0.927 : 89.2 secs : initdesign
#
# [mbo] 0: num_leaves=62; learning_rate=0.0389; feature_fraction=0.368; min_data_in_leaf=2261; num_iterations=3295; early_stopping_rounds=67; bagging_fraction=0.567; bagging_freq=1; lambda_l1=0.322; lambda_l2=0.4; max_depth=13; min_child_weight=8.79; subsample=0.748; colsample_bytree=0.618; min_gain_to_split=0.0774; scale_pos_weight=4.98 : y = 0.925 : 37.4 secs : initdesign
#
# [mbo] 0: num_leaves=43; learning_rate=0.0968; feature_fraction=0.766; min_data_in_leaf=4838; num_iterations=2968; early_stopping_rounds=499; bagging_fraction=0.771; bagging_freq=1; lambda_l1=0.25; lambda_l2=0.129; max_depth=11; min_child_weight=1.71; subsample=0.791; colsample_bytree=0.735; min_gain_to_split=0.0994; scale_pos_weight=1.62 : y = 0.925 : 66.4 secs : initdesign
#
# [mbo] 0: num_leaves=9; learning_rate=0.0732; feature_fraction=0.676; min_data_in_leaf=819; num_iterations=906; early_stopping_rounds=458; bagging_fraction=0.675; bagging_freq=2; lambda_l1=0.28; lambda_l2=0.221; max_depth=15; min_child_weight=8.71; subsample=0.898; colsample_bytree=0.858; min_gain_to_split=0.00068; scale_pos_weight=4.21 : y = 0.925 : 56.6 secs : initdesign
#
# [mbo] 0: num_leaves=58; learning_rate=0.0988; feature_fraction=0.403; min_data_in_leaf=4313; num_iterations=3622; early_stopping_rounds=169; bagging_fraction=0.821; bagging_freq=4; lambda_l1=0.452; lambda_l2=0.476; max_depth=30; min_child_weight=0.775; subsample=0.662; colsample_bytree=0.505; min_gain_to_split=0.0957; scale_pos_weight=1.86 : y = 0.924 : 42.0 secs : initdesign
#
# [mbo] 0: num_leaves=5; learning_rate=0.00654; feature_fraction=0.301; min_data_in_leaf=6062; num_iterations=4132; early_stopping_rounds=250; bagging_fraction=0.585; bagging_freq=4; lambda_l1=0.285; lambda_l2=0.0762; max_depth=5; min_child_weight=6.36; subsample=0.595; colsample_bytree=0.583; min_gain_to_split=0.0197; scale_pos_weight=3.05 : y = 0.922 : 355.8 secs : initdesign
#
# [mbo] 0: num_leaves=63; learning_rate=0.014; feature_fraction=0.629; min_data_in_leaf=1424; num_iterations=439; early_stopping_rounds=436; bagging_fraction=0.808; bagging_freq=5; lambda_l1=0.0015; lambda_l2=0.036; max_depth=7; min_child_weight=6.52; subsample=0.591; colsample_bytree=0.665; min_gain_to_split=0.0606; scale_pos_weight=2.93 : y = 0.93 : 51.7 secs : initdesign
#
# [mbo] 0: num_leaves=18; learning_rate=0.0822; feature_fraction=0.356; min_data_in_leaf=5632; num_iterations=2794; early_stopping_rounds=371; bagging_fraction=0.836; bagging_freq=3; lambda_l1=0.201; lambda_l2=0.487; max_depth=24; min_child_weight=9.96; subsample=0.794; colsample_bytree=0.565; min_gain_to_split=0.0096; scale_pos_weight=2.5 : y = 0.925 : 88.2 secs : initdesign
#
# [mbo] 0: num_leaves=43; learning_rate=0.00581; feature_fraction=0.727; min_data_in_leaf=8133; num_iterations=219; early_stopping_rounds=483; bagging_fraction=0.719; bagging_freq=1; lambda_l1=0.17; lambda_l2=0.398; max_depth=29; min_child_weight=7.68; subsample=0.773; colsample_bytree=0.7; min_gain_to_split=0.0722; scale_pos_weight=1.25 : y = 0.914 : 23.2 secs : initdesign
#
# [mbo] 0: num_leaves=59; learning_rate=0.00824; feature_fraction=0.43; min_data_in_leaf=2913; num_iterations=2444; early_stopping_rounds=126; bagging_fraction=0.857; bagging_freq=5; lambda_l1=0.386; lambda_l2=0.272; max_depth=30; min_child_weight=6.84; subsample=0.886; colsample_bytree=0.754; min_gain_to_split=0.00199; scale_pos_weight=4.17 : y = 0.929 : 134.6 secs : initdesign
#
# [mbo] 0: num_leaves=2; learning_rate=0.0977; feature_fraction=0.659; min_data_in_leaf=7795; num_iterations=4597; early_stopping_rounds=161; bagging_fraction=0.746; bagging_freq=1; lambda_l1=0.263; lambda_l2=0.494; max_depth=23; min_child_weight=3.42; subsample=0.606; colsample_bytree=0.876; min_gain_to_split=0.0538; scale_pos_weight=2.42 : y = 0.914 : 25.9 secs : initdesign
#
# [mbo] 0: num_leaves=20; learning_rate=0.035; feature_fraction=0.603; min_data_in_leaf=83; num_iterations=4272; early_stopping_rounds=220; bagging_fraction=0.804; bagging_freq=5; lambda_l1=0.341; lambda_l2=0.39; max_depth=3; min_child_weight=4.73; subsample=0.534; colsample_bytree=0.866; min_gain_to_split=0.00681; scale_pos_weight=2.72 : y = 0.928 : 75.4 secs : initdesign
#
# [mbo] 0: num_leaves=60; learning_rate=0.0741; feature_fraction=0.4; min_data_in_leaf=6595; num_iterations=1529; early_stopping_rounds=226; bagging_fraction=0.517; bagging_freq=1; lambda_l1=0.437; lambda_l2=0.301; max_depth=5; min_child_weight=6.96; subsample=0.557; colsample_bytree=0.784; min_gain_to_split=0.027; scale_pos_weight=1.28 : y = 0.92 : 66.7 secs : initdesign
#
# [mbo] 0: num_leaves=57; learning_rate=0.0103; feature_fraction=0.315; min_data_in_leaf=3580; num_iterations=1651; early_stopping_rounds=59; bagging_fraction=0.709; bagging_freq=5; lambda_l1=0.0686; lambda_l2=0.455; max_depth=17; min_child_weight=4.47; subsample=0.548; colsample_bytree=0.799; min_gain_to_split=0.0865; scale_pos_weight=1.18 : y = 0.928 : 105.2 secs : initdesign
#
# [mbo] 0: num_leaves=8; learning_rate=0.0577; feature_fraction=0.535; min_data_in_leaf=2048; num_iterations=2085; early_stopping_rounds=120; bagging_fraction=0.762; bagging_freq=1; lambda_l1=0.466; lambda_l2=0.151; max_depth=25; min_child_weight=8.18; subsample=0.839; colsample_bytree=0.642; min_gain_to_split=0.0815; scale_pos_weight=1.08 : y = 0.926 : 58.2 secs : initdesign
#
# [mbo] 0: num_leaves=61; learning_rate=0.0555; feature_fraction=0.519; min_data_in_leaf=5101; num_iterations=1772; early_stopping_rounds=57; bagging_fraction=0.894; bagging_freq=1; lambda_l1=0.15; lambda_l2=0.363; max_depth=4; min_child_weight=0.269; subsample=0.7; colsample_bytree=0.569; min_gain_to_split=0.0262; scale_pos_weight=3.65 : y = 0.926 : 43.8 secs : initdesign
#
# [mbo] 0: num_leaves=35; learning_rate=0.0523; feature_fraction=0.733; min_data_in_leaf=5171; num_iterations=3916; early_stopping_rounds=452; bagging_fraction=0.525; bagging_freq=5; lambda_l1=0.133; lambda_l2=0.305; max_depth=25; min_child_weight=5.5; subsample=0.763; colsample_bytree=0.714; min_gain_to_split=0.0571; scale_pos_weight=3.84 : y = 0.925 : 81.5 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 12 02:06:17 AM 2025 AUC 0.930421313363255
#
# [mbo] 1: num_leaves=52; learning_rate=0.0211; feature_fraction=0.5; min_data_in_leaf=232; num_iterations=3206; early_stopping_rounds=326; bagging_fraction=0.813; bagging_freq=4; lambda_l1=0.251; lambda_l2=0.257; max_depth=19; min_child_weight=3.28; subsample=0.583; colsample_bytree=0.885; min_gain_to_split=0.0166; scale_pos_weight=3.49 : y = 0.93 : 124.5 secs : infill_ei
#
# Wed Nov 12 02:10:28 AM 2025 AUC 0.930840703556012
#
# [mbo] 2: num_leaves=56; learning_rate=0.0263; feature_fraction=0.384; min_data_in_leaf=103; num_iterations=1516; early_stopping_rounds=386; bagging_fraction=0.868; bagging_freq=3; lambda_l1=0.287; lambda_l2=0.356; max_depth=18; min_child_weight=3.84; subsample=0.571; colsample_bytree=0.558; min_gain_to_split=0.071; scale_pos_weight=4.4 : y = 0.931 : 248.8 secs : infill_ei
#
# Wed Nov 12 02:11:33 AM 2025 AUC 0.930769801125634
#
# [mbo] 3: num_leaves=44; learning_rate=0.0321; feature_fraction=0.718; min_data_in_leaf=99; num_iterations=3719; early_stopping_rounds=305; bagging_fraction=0.784; bagging_freq=5; lambda_l1=0.201; lambda_l2=0.029; max_depth=20; min_child_weight=4.52; subsample=0.589; colsample_bytree=0.829; min_gain_to_split=0.0446; scale_pos_weight=2.01 : y = 0.931 : 63.4 secs : infill_ei
#
# Wed Nov 12 02:13:56 AM 2025 AUC 0.932160044858531
#
# [mbo] 4: num_leaves=59; learning_rate=0.0269; feature_fraction=0.509; min_data_in_leaf=292; num_iterations=3636; early_stopping_rounds=352; bagging_fraction=0.757; bagging_freq=3; lambda_l1=0.247; lambda_l2=0.139; max_depth=21; min_child_weight=0.685; subsample=0.877; colsample_bytree=0.739; min_gain_to_split=0.0656; scale_pos_weight=3.96 : y = 0.932 : 141.1 secs : infill_ei
#
# Wed Nov 12 02:15:15 AM 2025 AUC 0.930829118191571
#
# [mbo] 5: num_leaves=60; learning_rate=0.023; feature_fraction=0.678; min_data_in_leaf=859; num_iterations=3810; early_stopping_rounds=333; bagging_fraction=0.755; bagging_freq=3; lambda_l1=0.179; lambda_l2=0.214; max_depth=12; min_child_weight=1.85; subsample=0.77; colsample_bytree=0.816; min_gain_to_split=0.0814; scale_pos_weight=2.93 : y = 0.931 : 77.5 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Wed Nov 12 02:19:05 AM 2025 AUC 0.935475312746913
#
# [mbo] 6: num_leaves=55; learning_rate=0.024; feature_fraction=0.334; min_data_in_leaf=828; num_iterations=4888; early_stopping_rounds=422; bagging_fraction=0.683; bagging_freq=2; lambda_l1=0.149; lambda_l2=0.141; max_depth=24; min_child_weight=0.1; subsample=0.601; colsample_bytree=0.621; min_gain_to_split=0.0584; scale_pos_weight=4.39 : y = 0.935 : 228.3 secs : infill_ei
#
# Wed Nov 12 02:22:50 AM 2025 AUC 0.933261581309563
#
# [mbo] 7: num_leaves=53; learning_rate=0.0165; feature_fraction=0.394; min_data_in_leaf=529; num_iterations=4157; early_stopping_rounds=421; bagging_fraction=0.696; bagging_freq=3; lambda_l1=0.113; lambda_l2=0.283; max_depth=26; min_child_weight=1.95; subsample=0.591; colsample_bytree=0.682; min_gain_to_split=0.0792; scale_pos_weight=4.94 : y = 0.933 : 222.7 secs : infill_ei
#
# Wed Nov 12 02:25:51 AM 2025 AUC 0.930901179158393
#
# [mbo] 8: num_leaves=49; learning_rate=0.0225; feature_fraction=0.346; min_data_in_leaf=737; num_iterations=4712; early_stopping_rounds=365; bagging_fraction=0.703; bagging_freq=3; lambda_l1=0.246; lambda_l2=0.139; max_depth=24; min_child_weight=3.37; subsample=0.734; colsample_bytree=0.633; min_gain_to_split=0.0405; scale_pos_weight=4.53 : y = 0.931 : 178.7 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Wed Nov 12 02:28:26 AM 2025 AUC 0.932255739968812
#
# [mbo] 9: num_leaves=63; learning_rate=0.0251; feature_fraction=0.538; min_data_in_leaf=506; num_iterations=4929; early_stopping_rounds=491; bagging_fraction=0.654; bagging_freq=3; lambda_l1=0.122; lambda_l2=0.0916; max_depth=29; min_child_weight=0.0202; subsample=0.551; colsample_bytree=0.632; min_gain_to_split=0.0684; scale_pos_weight=4.27 : y = 0.932 : 154.2 secs : infill_ei
#
# Wed Nov 12 02:32:11 AM 2025 AUC 0.932345874104162
#
# [mbo] 10: num_leaves=54; learning_rate=0.0211; feature_fraction=0.437; min_data_in_leaf=729; num_iterations=2569; early_stopping_rounds=400; bagging_fraction=0.668; bagging_freq=2; lambda_l1=0.172; lambda_l2=0.225; max_depth=24; min_child_weight=0.623; subsample=0.607; colsample_bytree=0.637; min_gain_to_split=0.0572; scale_pos_weight=2.46 : y = 0.932 : 221.7 secs : infill_ei
#
# Wed Nov 12 02:37:04 AM 2025 AUC 0.933419605680536
#
# [mbo] 11: num_leaves=61; learning_rate=0.0158; feature_fraction=0.313; min_data_in_leaf=1058; num_iterations=4734; early_stopping_rounds=416; bagging_fraction=0.686; bagging_freq=1; lambda_l1=0.243; lambda_l2=0.163; max_depth=20; min_child_weight=0.186; subsample=0.606; colsample_bytree=0.61; min_gain_to_split=0.0939; scale_pos_weight=4.25 : y = 0.933 : 291.5 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Wed Nov 12 02:38:46 AM 2025 AUC 0.934885617696876
#
# [mbo] 12: num_leaves=55; learning_rate=0.0249; feature_fraction=0.317; min_data_in_leaf=88; num_iterations=4983; early_stopping_rounds=408; bagging_fraction=0.698; bagging_freq=2; lambda_l1=0.0787; lambda_l2=0.116; max_depth=23; min_child_weight=3.52; subsample=0.608; colsample_bytree=0.83; min_gain_to_split=0.0524; scale_pos_weight=4.34 : y = 0.935 : 100.8 secs : infill_ei
#
# Wed Nov 12 02:42:00 AM 2025 AUC 0.932462654577725
#
# [mbo] 13: num_leaves=55; learning_rate=0.0246; feature_fraction=0.308; min_data_in_leaf=881; num_iterations=4768; early_stopping_rounds=454; bagging_fraction=0.784; bagging_freq=1; lambda_l1=0.0378; lambda_l2=0.0767; max_depth=22; min_child_weight=4.52; subsample=0.61; colsample_bytree=0.639; min_gain_to_split=0.0172; scale_pos_weight=4.36 : y = 0.932 : 191.5 secs : infill_ei
#
# Wed Nov 12 02:44:41 AM 2025 AUC 0.935101105475475
#
# [mbo] 14: num_leaves=56; learning_rate=0.0285; feature_fraction=0.367; min_data_in_leaf=212; num_iterations=4904; early_stopping_rounds=151; bagging_fraction=0.636; bagging_freq=2; lambda_l1=0.111; lambda_l2=0.29; max_depth=25; min_child_weight=0.576; subsample=0.611; colsample_bytree=0.807; min_gain_to_split=0.0479; scale_pos_weight=4.84 : y = 0.935 : 158.4 secs : infill_ei
#
# Wed Nov 12 02:45:54 AM 2025 AUC 0.931632447361897
#
# [mbo] 15: num_leaves=33; learning_rate=0.0309; feature_fraction=0.565; min_data_in_leaf=88; num_iterations=4059; early_stopping_rounds=163; bagging_fraction=0.787; bagging_freq=1; lambda_l1=0.13; lambda_l2=0.171; max_depth=28; min_child_weight=0.363; subsample=0.73; colsample_bytree=0.866; min_gain_to_split=0.0734; scale_pos_weight=3.61 : y = 0.932 : 71.5 secs : infill_ei
#
# Wed Nov 12 02:47:55 AM 2025 AUC 0.928765301370085
#
# [mbo] 16: num_leaves=51; learning_rate=0.029; feature_fraction=0.395; min_data_in_leaf=299; num_iterations=4787; early_stopping_rounds=365; bagging_fraction=0.674; bagging_freq=2; lambda_l1=0.0888; lambda_l2=0.219; max_depth=5; min_child_weight=0.775; subsample=0.615; colsample_bytree=0.739; min_gain_to_split=0.0857; scale_pos_weight=3.76 : y = 0.929 : 119.3 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Wed Nov 12 02:50:35 AM 2025 AUC 0.934324422643363
#
# [mbo] 17: num_leaves=61; learning_rate=0.0245; feature_fraction=0.315; min_data_in_leaf=416; num_iterations=4808; early_stopping_rounds=266; bagging_fraction=0.644; bagging_freq=2; lambda_l1=0.0852; lambda_l2=0.14; max_depth=26; min_child_weight=1.84; subsample=0.583; colsample_bytree=0.859; min_gain_to_split=0.0786; scale_pos_weight=4.55 : y = 0.934 : 157.9 secs : infill_ei
#
# Wed Nov 12 02:54:28 AM 2025 AUC 0.93351275201064
#
# [mbo] 18: num_leaves=59; learning_rate=0.0286; feature_fraction=0.618; min_data_in_leaf=779; num_iterations=4960; early_stopping_rounds=412; bagging_fraction=0.71; bagging_freq=2; lambda_l1=0.104; lambda_l2=0.274; max_depth=24; min_child_weight=0.932; subsample=0.612; colsample_bytree=0.843; min_gain_to_split=0.0616; scale_pos_weight=4.17 : y = 0.934 : 231.3 secs : infill_ei
#
# Wed Nov 12 02:56:15 AM 2025 AUC 0.935891227330338
#
# [mbo] 19: num_leaves=54; learning_rate=0.0321; feature_fraction=0.361; min_data_in_leaf=118; num_iterations=3826; early_stopping_rounds=190; bagging_fraction=0.736; bagging_freq=4; lambda_l1=0.06; lambda_l2=0.132; max_depth=24; min_child_weight=0.302; subsample=0.64; colsample_bytree=0.818; min_gain_to_split=0.0528; scale_pos_weight=3.53 : y = 0.936 : 104.9 secs : infill_ei
#
# Wed Nov 12 02:58:12 AM 2025 AUC 0.931080984014514
#
# [mbo] 20: num_leaves=55; learning_rate=0.0247; feature_fraction=0.458; min_data_in_leaf=512; num_iterations=3998; early_stopping_rounds=168; bagging_fraction=0.68; bagging_freq=4; lambda_l1=0.228; lambda_l2=0.0739; max_depth=24; min_child_weight=1.28; subsample=0.644; colsample_bytree=0.859; min_gain_to_split=0.0477; scale_pos_weight=3.14 : y = 0.931 : 114.3 secs : infill_ei
#
# Saved the current state after iteration 21 in the file HT.RDATA.
#
# Wed Nov 12 02:59:40 AM 2025 AUC 0.933633703215402
#
# [mbo] 21: num_leaves=57; learning_rate=0.027; feature_fraction=0.313; min_data_in_leaf=483; num_iterations=4128; early_stopping_rounds=279; bagging_fraction=0.766; bagging_freq=2; lambda_l1=0.0597; lambda_l2=0.392; max_depth=22; min_child_weight=0.603; subsample=0.717; colsample_bytree=0.783; min_gain_to_split=0.0536; scale_pos_weight=3.56 : y = 0.934 : 86.2 secs : infill_ei
#
# Wed Nov 12 03:02:10 AM 2025 AUC 0.930825179167661
#
# [mbo] 22: num_leaves=50; learning_rate=0.032; feature_fraction=0.451; min_data_in_leaf=301; num_iterations=3670; early_stopping_rounds=232; bagging_fraction=0.849; bagging_freq=4; lambda_l1=0.00693; lambda_l2=0.369; max_depth=23; min_child_weight=0.859; subsample=0.615; colsample_bytree=0.844; min_gain_to_split=0.0368; scale_pos_weight=3.53 : y = 0.931 : 148.2 secs : infill_ei
#
# Wed Nov 12 03:05:16 AM 2025 AUC 0.932024727801863
#
# [mbo] 23: num_leaves=56; learning_rate=0.0285; feature_fraction=0.437; min_data_in_leaf=49; num_iterations=3316; early_stopping_rounds=298; bagging_fraction=0.719; bagging_freq=3; lambda_l1=0.0778; lambda_l2=0.048; max_depth=21; min_child_weight=1.16; subsample=0.664; colsample_bytree=0.798; min_gain_to_split=0.0512; scale_pos_weight=4.37 : y = 0.932 : 184.0 secs : infill_ei
#
# Wed Nov 12 03:06:45 AM 2025 AUC 0.932822264289968
#
# [mbo] 24: num_leaves=57; learning_rate=0.0332; feature_fraction=0.314; min_data_in_leaf=31; num_iterations=4824; early_stopping_rounds=397; bagging_fraction=0.746; bagging_freq=4; lambda_l1=0.0459; lambda_l2=0.189; max_depth=24; min_child_weight=3.58; subsample=0.643; colsample_bytree=0.724; min_gain_to_split=0.0596; scale_pos_weight=1.93 : y = 0.933 : 86.9 secs : infill_ei
#
# Wed Nov 12 03:07:49 AM 2025 AUC 0.935061715236376
#
# [mbo] 25: num_leaves=46; learning_rate=0.0268; feature_fraction=0.423; min_data_in_leaf=284; num_iterations=4540; early_stopping_rounds=140; bagging_fraction=0.732; bagging_freq=2; lambda_l1=0.0262; lambda_l2=0.195; max_depth=23; min_child_weight=0.293; subsample=0.767; colsample_bytree=0.765; min_gain_to_split=0.0181; scale_pos_weight=3.74 : y = 0.935 : 61.0 secs : infill_ei
#
# Wed Nov 12 03:10:28 AM 2025 AUC 0.933605898340744
#
# [mbo] 26: num_leaves=58; learning_rate=0.0223; feature_fraction=0.306; min_data_in_leaf=231; num_iterations=4843; early_stopping_rounds=414; bagging_fraction=0.732; bagging_freq=2; lambda_l1=0.0403; lambda_l2=0.177; max_depth=24; min_child_weight=0.0361; subsample=0.601; colsample_bytree=0.758; min_gain_to_split=0.0489; scale_pos_weight=3.91 : y = 0.934 : 157.0 secs : infill_ei
#
# Saved the current state after iteration 27 in the file HT.RDATA.
#
# Wed Nov 12 03:11:38 AM 2025 AUC 0.932660532602374
#
# [mbo] 27: num_leaves=48; learning_rate=0.0258; feature_fraction=0.347; min_data_in_leaf=20; num_iterations=4389; early_stopping_rounds=68; bagging_fraction=0.782; bagging_freq=4; lambda_l1=0.0572; lambda_l2=0.108; max_depth=24; min_child_weight=3.4; subsample=0.636; colsample_bytree=0.825; min_gain_to_split=0.0456; scale_pos_weight=3.31 : y = 0.933 : 66.7 secs : infill_ei
#
# Wed Nov 12 03:14:49 AM 2025 AUC 0.932262227772899
#
# [mbo] 28: num_leaves=52; learning_rate=0.0345; feature_fraction=0.495; min_data_in_leaf=549; num_iterations=3977; early_stopping_rounds=224; bagging_fraction=0.684; bagging_freq=4; lambda_l1=0.0428; lambda_l2=0.176; max_depth=24; min_child_weight=0.00332; subsample=0.865; colsample_bytree=0.891; min_gain_to_split=0.0368; scale_pos_weight=1.65 : y = 0.932 : 187.7 secs : infill_ei
#
# Wed Nov 12 03:15:52 AM 2025 AUC 0.93234819117705
#
# [mbo] 29: num_leaves=63; learning_rate=0.0278; feature_fraction=0.303; min_data_in_leaf=366; num_iterations=4040; early_stopping_rounds=167; bagging_fraction=0.723; bagging_freq=2; lambda_l1=0.0713; lambda_l2=0.224; max_depth=23; min_child_weight=0.646; subsample=0.702; colsample_bytree=0.653; min_gain_to_split=0.0748; scale_pos_weight=1.75 : y = 0.932 : 61.8 secs : infill_ei
#
# Wed Nov 12 03:16:56 AM 2025 AUC 0.930571923100985
#
# [mbo] 30: num_leaves=54; learning_rate=0.0346; feature_fraction=0.336; min_data_in_leaf=355; num_iterations=2313; early_stopping_rounds=78; bagging_fraction=0.691; bagging_freq=2; lambda_l1=0.0752; lambda_l2=0.18; max_depth=27; min_child_weight=4.5; subsample=0.543; colsample_bytree=0.761; min_gain_to_split=0.0348; scale_pos_weight=4.98 : y = 0.931 : 60.3 secs : infill_ei
#
# Wed Nov 12 03:18:25 AM 2025 AUC 0.931182008392438
#
# [mbo] 31: num_leaves=62; learning_rate=0.0174; feature_fraction=0.713; min_data_in_leaf=2; num_iterations=4138; early_stopping_rounds=166; bagging_fraction=0.674; bagging_freq=5; lambda_l1=0.0517; lambda_l2=0.168; max_depth=25; min_child_weight=6.08; subsample=0.74; colsample_bytree=0.819; min_gain_to_split=0.0117; scale_pos_weight=4.79 : y = 0.931 : 86.9 secs : infill_ei
#
# Wed Nov 12 03:19:33 AM 2025 AUC 0.93174528881155
#
# [mbo] 32: num_leaves=55; learning_rate=0.0381; feature_fraction=0.385; min_data_in_leaf=106; num_iterations=4900; early_stopping_rounds=197; bagging_fraction=0.638; bagging_freq=4; lambda_l1=0.0215; lambda_l2=0.236; max_depth=25; min_child_weight=2.56; subsample=0.672; colsample_bytree=0.806; min_gain_to_split=0.0496; scale_pos_weight=4.16 : y = 0.932 : 64.5 secs : infill_ei
#
# Wed Nov 12 03:21:20 AM 2025 AUC 0.932366959467444
#
# [mbo] 33: num_leaves=57; learning_rate=0.0271; feature_fraction=0.422; min_data_in_leaf=1054; num_iterations=3054; early_stopping_rounds=197; bagging_fraction=0.771; bagging_freq=4; lambda_l1=0.108; lambda_l2=0.24; max_depth=26; min_child_weight=0.0215; subsample=0.53; colsample_bytree=0.76; min_gain_to_split=0.0331; scale_pos_weight=4.47 : y = 0.932 : 105.0 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Wed Nov 12 03:24:17 AM 2025 AUC 0.931137520592985
#
# [mbo] 34: num_leaves=60; learning_rate=0.0304; feature_fraction=0.36; min_data_in_leaf=7; num_iterations=4581; early_stopping_rounds=419; bagging_fraction=0.87; bagging_freq=1; lambda_l1=0.157; lambda_l2=0.209; max_depth=21; min_child_weight=4.3; subsample=0.772; colsample_bytree=0.693; min_gain_to_split=0.0308; scale_pos_weight=3.9 : y = 0.931 : 175.1 secs : infill_ei
#
# Wed Nov 12 03:26:57 AM 2025 AUC 0.930268154845347
#
# [mbo] 35: num_leaves=54; learning_rate=0.0264; feature_fraction=0.362; min_data_in_leaf=1429; num_iterations=4402; early_stopping_rounds=263; bagging_fraction=0.745; bagging_freq=2; lambda_l1=0.0714; lambda_l2=0.31; max_depth=23; min_child_weight=0.74; subsample=0.85; colsample_bytree=0.796; min_gain_to_split=0.08; scale_pos_weight=4.87 : y = 0.93 : 156.0 secs : infill_ei
#
# Wed Nov 12 03:28:44 AM 2025 AUC 0.93128534984325
#
# [mbo] 36: num_leaves=58; learning_rate=0.0327; feature_fraction=0.699; min_data_in_leaf=1106; num_iterations=1307; early_stopping_rounds=382; bagging_fraction=0.765; bagging_freq=3; lambda_l1=0.0593; lambda_l2=0.133; max_depth=22; min_child_weight=1.07; subsample=0.641; colsample_bytree=0.763; min_gain_to_split=0.0104; scale_pos_weight=2.65 : y = 0.931 : 105.7 secs : infill_ei
#
# Wed Nov 12 03:31:24 AM 2025 AUC 0.933604276389722
#
# [mbo] 37: num_leaves=62; learning_rate=0.0315; feature_fraction=0.313; min_data_in_leaf=23; num_iterations=4749; early_stopping_rounds=417; bagging_fraction=0.548; bagging_freq=1; lambda_l1=0.143; lambda_l2=0.179; max_depth=24; min_child_weight=2.18; subsample=0.55; colsample_bytree=0.747; min_gain_to_split=0.0616; scale_pos_weight=4.05 : y = 0.934 : 156.4 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Wed Nov 12 03:33:56 AM 2025 AUC 0.932103276572771
#
# [mbo] 38: num_leaves=60; learning_rate=0.0149; feature_fraction=0.709; min_data_in_leaf=1076; num_iterations=4740; early_stopping_rounds=173; bagging_fraction=0.738; bagging_freq=2; lambda_l1=0.0657; lambda_l2=0.103; max_depth=24; min_child_weight=2.61; subsample=0.548; colsample_bytree=0.86; min_gain_to_split=0.0291; scale_pos_weight=3.21 : y = 0.932 : 149.8 secs : infill_ei
#
# Wed Nov 12 03:35:23 AM 2025 AUC 0.932184605831146
#
# [mbo] 39: num_leaves=55; learning_rate=0.0305; feature_fraction=0.565; min_data_in_leaf=20; num_iterations=2585; early_stopping_rounds=156; bagging_fraction=0.727; bagging_freq=4; lambda_l1=0.0643; lambda_l2=0.13; max_depth=27; min_child_weight=0.577; subsample=0.793; colsample_bytree=0.784; min_gain_to_split=0.0109; scale_pos_weight=3.08 : y = 0.932 : 84.4 secs : infill_ei
#
# Wed Nov 12 03:37:01 AM 2025 AUC 0.932234191190952
#
# [mbo] 40: num_leaves=60; learning_rate=0.0309; feature_fraction=0.746; min_data_in_leaf=575; num_iterations=4787; early_stopping_rounds=431; bagging_fraction=0.701; bagging_freq=4; lambda_l1=0.344; lambda_l2=0.179; max_depth=23; min_child_weight=0.185; subsample=0.6; colsample_bytree=0.691; min_gain_to_split=0.0415; scale_pos_weight=4.55 : y = 0.932 : 96.7 secs : infill_ei
#
# Wed Nov 12 03:37:53 AM 2025 AUC 0.934481751892469
#
# [mbo] 41: num_leaves=45; learning_rate=0.0305; feature_fraction=0.766; min_data_in_leaf=13; num_iterations=4633; early_stopping_rounds=166; bagging_fraction=0.835; bagging_freq=2; lambda_l1=0.116; lambda_l2=0.158; max_depth=22; min_child_weight=0.137; subsample=0.602; colsample_bytree=0.625; min_gain_to_split=0.0105; scale_pos_weight=3.48 : y = 0.934 : 49.8 secs : infill_ei
#
# Wed Nov 12 03:39:56 AM 2025 AUC 0.932886215501681
#
# [mbo] 42: num_leaves=54; learning_rate=0.0324; feature_fraction=0.773; min_data_in_leaf=328; num_iterations=3849; early_stopping_rounds=388; bagging_fraction=0.739; bagging_freq=3; lambda_l1=0.182; lambda_l2=0.142; max_depth=26; min_child_weight=0.334; subsample=0.617; colsample_bytree=0.819; min_gain_to_split=0.0422; scale_pos_weight=2.76 : y = 0.933 : 119.7 secs : infill_ei
#
# Wed Nov 12 03:41:09 AM 2025 AUC 0.929551947615616
#
# [mbo] 43: num_leaves=47; learning_rate=0.0247; feature_fraction=0.337; min_data_in_leaf=357; num_iterations=4757; early_stopping_rounds=169; bagging_fraction=0.574; bagging_freq=2; lambda_l1=0.0834; lambda_l2=0.165; max_depth=26; min_child_weight=0.981; subsample=0.613; colsample_bytree=0.791; min_gain_to_split=0.05; scale_pos_weight=4.17 : y = 0.93 : 70.2 secs : infill_ei
#
# Wed Nov 12 03:41:54 AM 2025 AUC 0.930507276767405
#
# [mbo] 44: num_leaves=46; learning_rate=0.0325; feature_fraction=0.728; min_data_in_leaf=72; num_iterations=4505; early_stopping_rounds=159; bagging_fraction=0.762; bagging_freq=2; lambda_l1=0.00282; lambda_l2=0.154; max_depth=20; min_child_weight=0.466; subsample=0.727; colsample_bytree=0.65; min_gain_to_split=0.0273; scale_pos_weight=4.06 : y = 0.931 : 43.2 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Wed Nov 12 03:46:59 AM 2025 AUC 0.93498270305089
#
# [mbo] 45: num_leaves=60; learning_rate=0.0325; feature_fraction=0.424; min_data_in_leaf=117; num_iterations=4487; early_stopping_rounds=414; bagging_fraction=0.677; bagging_freq=1; lambda_l1=0.149; lambda_l2=0.325; max_depth=22; min_child_weight=1.63; subsample=0.554; colsample_bytree=0.614; min_gain_to_split=0.0216; scale_pos_weight=3.23 : y = 0.935 : 302.5 secs : infill_ei
#
# Wed Nov 12 03:49:21 AM 2025 AUC 0.9327200813756
#
# [mbo] 46: num_leaves=51; learning_rate=0.0289; feature_fraction=0.354; min_data_in_leaf=279; num_iterations=4856; early_stopping_rounds=162; bagging_fraction=0.739; bagging_freq=3; lambda_l1=0.0926; lambda_l2=0.272; max_depth=21; min_child_weight=1.34; subsample=0.556; colsample_bytree=0.578; min_gain_to_split=0.00819; scale_pos_weight=3.43 : y = 0.933 : 139.1 secs : infill_ei
#
# Wed Nov 12 03:51:06 AM 2025 AUC 0.928407777023442
#
# ...
#
# [mbo] 85: num_leaves=54; learning_rate=0.0155; feature_fraction=0.8; min_data_in_leaf=121; num_iterations=3820; early_stopping_rounds=384; bagging_fraction=0.816; bagging_freq=2; lambda_l1=0.31; lambda_l2=0.142; max_depth=23; min_child_weight=2.72; subsample=0.685; colsample_bytree=0.681; min_gain_to_split=0.0247; scale_pos_weight=4.23 : y = 0.934 : 161.3 secs : infill_ei
#
# Wed Nov 12 05:28:20 AM 2025 AUC 0.934220386070685
#
# [mbo] 86: num_leaves=57; learning_rate=0.0169; feature_fraction=0.64; min_data_in_leaf=514; num_iterations=1922; early_stopping_rounds=386; bagging_fraction=0.732; bagging_freq=3; lambda_l1=0.149; lambda_l2=0.0174; max_depth=22; min_child_weight=5.75; subsample=0.781; colsample_bytree=0.723; min_gain_to_split=0.0821; scale_pos_weight=3.01 : y = 0.934 : 80.7 secs : infill_ei
#
# Wed Nov 12 05:30:11 AM 2025 AUC 0.932515715546864
#
# [mbo] 87: num_leaves=61; learning_rate=0.0145; feature_fraction=0.592; min_data_in_leaf=517; num_iterations=1413; early_stopping_rounds=355; bagging_fraction=0.767; bagging_freq=3; lambda_l1=0.23; lambda_l2=0.183; max_depth=22; min_child_weight=5.58; subsample=0.584; colsample_bytree=0.834; min_gain_to_split=0.0756; scale_pos_weight=4.69 : y = 0.933 : 105.9 secs : infill_ei
#
# Wed Nov 12 05:33:57 AM 2025 AUC 0.933463630065411
#
# [mbo] 88: num_leaves=60; learning_rate=0.0159; feature_fraction=0.568; min_data_in_leaf=344; num_iterations=4280; early_stopping_rounds=463; bagging_fraction=0.738; bagging_freq=2; lambda_l1=0.358; lambda_l2=0.0228; max_depth=17; min_child_weight=6.11; subsample=0.619; colsample_bytree=0.666; min_gain_to_split=0.0436; scale_pos_weight=3.75 : y = 0.933 : 221.6 secs : infill_ei
#
# Wed Nov 12 05:36:57 AM 2025 AUC 0.931847935140496
#
# [mbo] 89: num_leaves=31; learning_rate=0.0188; feature_fraction=0.518; min_data_in_leaf=581; num_iterations=1706; early_stopping_rounds=439; bagging_fraction=0.708; bagging_freq=3; lambda_l1=0.375; lambda_l2=0.123; max_depth=21; min_child_weight=1.82; subsample=0.656; colsample_bytree=0.603; min_gain_to_split=0.0809; scale_pos_weight=4.72 : y = 0.932 : 174.4 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Wed Nov 12 05:38:21 AM 2025 AUC 0.933007398413732
#
# [mbo] 90: num_leaves=63; learning_rate=0.016; feature_fraction=0.795; min_data_in_leaf=222; num_iterations=3057; early_stopping_rounds=344; bagging_fraction=0.721; bagging_freq=3; lambda_l1=0.339; lambda_l2=0.124; max_depth=24; min_child_weight=6.54; subsample=0.525; colsample_bytree=0.661; min_gain_to_split=0.0651; scale_pos_weight=4.73 : y = 0.933 : 79.6 secs : infill_ei
#
# Wed Nov 12 05:40:16 AM 2025 AUC 0.931260557163347
#
# [mbo] 91: num_leaves=58; learning_rate=0.0157; feature_fraction=0.329; min_data_in_leaf=984; num_iterations=3422; early_stopping_rounds=359; bagging_fraction=0.732; bagging_freq=3; lambda_l1=0.374; lambda_l2=0.0917; max_depth=17; min_child_weight=5.85; subsample=0.625; colsample_bytree=0.703; min_gain_to_split=0.0984; scale_pos_weight=4.49 : y = 0.931 : 111.1 secs : infill_ei
#
# Wed Nov 12 05:42:31 AM 2025 AUC 0.933468032503898
#
# [mbo] 92: num_leaves=44; learning_rate=0.0274; feature_fraction=0.525; min_data_in_leaf=106; num_iterations=4972; early_stopping_rounds=408; bagging_fraction=0.815; bagging_freq=2; lambda_l1=0.279; lambda_l2=0.134; max_depth=22; min_child_weight=0.675; subsample=0.804; colsample_bytree=0.776; min_gain_to_split=0.0104; scale_pos_weight=3.4 : y = 0.933 : 131.6 secs : infill_ei
#
# Wed Nov 12 05:46:30 AM 2025 AUC 0.931281642526629
#
# [mbo] 93: num_leaves=57; learning_rate=0.0183; feature_fraction=0.644; min_data_in_leaf=1080; num_iterations=1753; early_stopping_rounds=355; bagging_fraction=0.793; bagging_freq=3; lambda_l1=0.372; lambda_l2=0.0553; max_depth=22; min_child_weight=6.56; subsample=0.628; colsample_bytree=0.626; min_gain_to_split=0.0552; scale_pos_weight=2.24 : y = 0.931 : 235.0 secs : infill_ei
#
# Wed Nov 12 05:50:15 AM 2025 AUC 0.932996276463869
#
# [mbo] 94: num_leaves=56; learning_rate=0.0154; feature_fraction=0.622; min_data_in_leaf=494; num_iterations=2918; early_stopping_rounds=370; bagging_fraction=0.888; bagging_freq=3; lambda_l1=0.104; lambda_l2=0.0307; max_depth=19; min_child_weight=8.58; subsample=0.783; colsample_bytree=0.714; min_gain_to_split=0.0488; scale_pos_weight=3.68 : y = 0.933 : 220.1 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Wed Nov 12 05:52:32 AM 2025 AUC 0.934430544581641
#
# [mbo] 95: num_leaves=61; learning_rate=0.015; feature_fraction=0.655; min_data_in_leaf=485; num_iterations=4834; early_stopping_rounds=361; bagging_fraction=0.796; bagging_freq=3; lambda_l1=0.387; lambda_l2=0.131; max_depth=21; min_child_weight=4.74; subsample=0.766; colsample_bytree=0.692; min_gain_to_split=0.0426; scale_pos_weight=4.6 : y = 0.934 : 132.7 secs : infill_ei
#
# Wed Nov 12 05:53:38 AM 2025 AUC 0.930851362091297
#
# [mbo] 96: num_leaves=57; learning_rate=0.0163; feature_fraction=0.657; min_data_in_leaf=619; num_iterations=509; early_stopping_rounds=422; bagging_fraction=0.645; bagging_freq=2; lambda_l1=0.161; lambda_l2=0.0703; max_depth=19; min_child_weight=3.32; subsample=0.586; colsample_bytree=0.662; min_gain_to_split=0.0898; scale_pos_weight=4.51 : y = 0.931 : 62.0 secs : infill_ei
#
# Wed Nov 12 05:55:46 AM 2025 AUC 0.935988312684352
#
# [mbo] 97: num_leaves=63; learning_rate=0.015; feature_fraction=0.691; min_data_in_leaf=13; num_iterations=4490; early_stopping_rounds=365; bagging_fraction=0.852; bagging_freq=2; lambda_l1=0.441; lambda_l2=0.122; max_depth=22; min_child_weight=7.78; subsample=0.739; colsample_bytree=0.644; min_gain_to_split=0.0746; scale_pos_weight=4.25 : y = 0.936 : 124.6 secs : infill_ei
#
# Wed Nov 12 05:58:07 AM 2025 AUC 0.932534483837258
#
# [mbo] 98: num_leaves=62; learning_rate=0.0156; feature_fraction=0.348; min_data_in_leaf=354; num_iterations=4024; early_stopping_rounds=403; bagging_fraction=0.825; bagging_freq=4; lambda_l1=0.235; lambda_l2=0.0737; max_depth=22; min_child_weight=8.31; subsample=0.768; colsample_bytree=0.691; min_gain_to_split=0.0753; scale_pos_weight=4.13 : y = 0.933 : 137.1 secs : infill_ei
#
# Wed Nov 12 06:03:03 AM 2025 AUC 0.936156763883321
#
# [mbo] 99: num_leaves=60; learning_rate=0.015; feature_fraction=0.57; min_data_in_leaf=304; num_iterations=4716; early_stopping_rounds=397; bagging_fraction=0.805; bagging_freq=1; lambda_l1=0.317; lambda_l2=0.337; max_depth=23; min_child_weight=1.28; subsample=0.744; colsample_bytree=0.543; min_gain_to_split=0.0688; scale_pos_weight=4.34 : y = 0.936 : 291.0 secs : infill_ei
#
# Saved the current state after iteration 100 in the file HT.RDATA.
#
# Wed Nov 12 06:08:24 AM 2025 AUC 0.933890666598699
#
# [mbo] 100: num_leaves=53; learning_rate=0.0151; feature_fraction=0.605; min_data_in_leaf=624; num_iterations=4617; early_stopping_rounds=405; bagging_fraction=0.803; bagging_freq=1; lambda_l1=0.456; lambda_l2=0.275; max_depth=23; min_child_weight=6.03; subsample=0.621; colsample_bytree=0.58; min_gain_to_split=0.0725; scale_pos_weight=4.79 : y = 0.934 : 315.7 secs : infill_ei
#
# Wed Nov 12 06:09:28 AM 2025 AUC 0.932337996056342
#
# [mbo] 101: num_leaves=57; learning_rate=0.0294; feature_fraction=0.588; min_data_in_leaf=54; num_iterations=4459; early_stopping_rounds=116; bagging_fraction=0.726; bagging_freq=2; lambda_l1=0.162; lambda_l2=0.196; max_depth=23; min_child_weight=0.0548; subsample=0.7; colsample_bytree=0.769; min_gain_to_split=0.0247; scale_pos_weight=2.88 : y = 0.932 : 59.6 secs : infill_ei
#
# Wed Nov 12 06:13:11 AM 2025 AUC 0.932904983792075
#
# [mbo] 102: num_leaves=63; learning_rate=0.0146; feature_fraction=0.618; min_data_in_leaf=96; num_iterations=4067; early_stopping_rounds=400; bagging_fraction=0.833; bagging_freq=2; lambda_l1=0.38; lambda_l2=0.376; max_depth=21; min_child_weight=5.85; subsample=0.798; colsample_bytree=0.717; min_gain_to_split=0.0681; scale_pos_weight=3.95 : y = 0.933 : 218.9 secs : infill_ei
#
# Saved the current state after iteration 103 in the file HT.RDATA.
#
# Wed Nov 12 06:14:54 AM 2025 AUC 0.93127167911321
#
# [mbo] 103: num_leaves=60; learning_rate=0.0313; feature_fraction=0.731; min_data_in_leaf=24; num_iterations=4988; early_stopping_rounds=376; bagging_fraction=0.675; bagging_freq=2; lambda_l1=0.235; lambda_l2=0.366; max_depth=25; min_child_weight=0.145; subsample=0.544; colsample_bytree=0.572; min_gain_to_split=0.0139; scale_pos_weight=1.91 : y = 0.931 : 100.5 secs : infill_ei
#
# Wed Nov 12 06:19:26 AM 2025 AUC 0.933019215485462
#
# [mbo] 104: num_leaves=56; learning_rate=0.0107; feature_fraction=0.579; min_data_in_leaf=47; num_iterations=2339; early_stopping_rounds=431; bagging_fraction=0.785; bagging_freq=2; lambda_l1=0.285; lambda_l2=0.121; max_depth=21; min_child_weight=7.31; subsample=0.589; colsample_bytree=0.585; min_gain_to_split=0.0262; scale_pos_weight=4.44 : y = 0.933 : 266.0 secs : infill_ei
#
# Wed Nov 12 06:21:32 AM 2025 AUC 0.932603532609325
#
# [mbo] 105: num_leaves=59; learning_rate=0.0151; feature_fraction=0.602; min_data_in_leaf=87; num_iterations=4392; early_stopping_rounds=392; bagging_fraction=0.862; bagging_freq=2; lambda_l1=0.311; lambda_l2=0.0404; max_depth=21; min_child_weight=4; subsample=0.624; colsample_bytree=0.66; min_gain_to_split=0.0795; scale_pos_weight=4.56 : y = 0.933 : 120.7 secs : infill_ei
#
# Wed Nov 12 06:27:03 AM 2025 AUC 0.931811093681574
#
# [mbo] 106: num_leaves=47; learning_rate=0.0193; feature_fraction=0.403; min_data_in_leaf=737; num_iterations=4743; early_stopping_rounds=468; bagging_fraction=0.728; bagging_freq=2; lambda_l1=0.192; lambda_l2=0.125; max_depth=21; min_child_weight=0.148; subsample=0.563; colsample_bytree=0.521; min_gain_to_split=0.0692; scale_pos_weight=3.88 : y = 0.932 : 327.0 secs : infill_ei
#
# Saved the current state after iteration 107 in the file HT.RDATA.
#
# Wed Nov 12 06:29:38 AM 2025 AUC 0.935016995729635
#
# [mbo] 107: num_leaves=59; learning_rate=0.0164; feature_fraction=0.571; min_data_in_leaf=256; num_iterations=2880; early_stopping_rounds=319; bagging_fraction=0.821; bagging_freq=1; lambda_l1=0.431; lambda_l2=0.119; max_depth=25; min_child_weight=2.12; subsample=0.802; colsample_bytree=0.617; min_gain_to_split=0.0699; scale_pos_weight=4.13 : y = 0.935 : 150.0 secs : infill_ei
#
# Wed Nov 12 06:32:06 AM 2025 AUC 0.935091837183922
#
# [mbo] 108: num_leaves=63; learning_rate=0.0136; feature_fraction=0.682; min_data_in_leaf=475; num_iterations=2666; early_stopping_rounds=325; bagging_fraction=0.766; bagging_freq=3; lambda_l1=0.451; lambda_l2=0.0447; max_depth=27; min_child_weight=3.63; subsample=0.75; colsample_bytree=0.739; min_gain_to_split=0.0768; scale_pos_weight=4.47 : y = 0.935 : 143.5 secs : infill_ei
#
# Wed Nov 12 06:33:46 AM 2025 AUC 0.931869483918356
#
# [mbo] 109: num_leaves=49; learning_rate=0.0158; feature_fraction=0.716; min_data_in_leaf=30; num_iterations=3124; early_stopping_rounds=326; bagging_fraction=0.757; bagging_freq=2; lambda_l1=0.308; lambda_l2=0.134; max_depth=24; min_child_weight=7.82; subsample=0.743; colsample_bytree=0.66; min_gain_to_split=0.0794; scale_pos_weight=4.6 : y = 0.932 : 95.2 secs : infill_ei
#
# Wed Nov 12 06:37:55 AM 2025 AUC 0.934116812912584
#
# [mbo] 110: num_leaves=63; learning_rate=0.0114; feature_fraction=0.717; min_data_in_leaf=339; num_iterations=4646; early_stopping_rounds=367; bagging_fraction=0.713; bagging_freq=3; lambda_l1=0.472; lambda_l2=0.0291; max_depth=22; min_child_weight=6.87; subsample=0.702; colsample_bytree=0.762; min_gain_to_split=0.0798; scale_pos_weight=3.88 : y = 0.934 : 243.9 secs : infill_ei
#
# Saved the current state after iteration 111 in the file HT.RDATA.
#
# Wed Nov 12 06:40:03 AM 2025 AUC 0.933674020283656
#
# [mbo] 111: num_leaves=37; learning_rate=0.0144; feature_fraction=0.69; min_data_in_leaf=142; num_iterations=3469; early_stopping_rounds=348; bagging_fraction=0.833; bagging_freq=4; lambda_l1=0.477; lambda_l2=0.0809; max_depth=23; min_child_weight=1.83; subsample=0.812; colsample_bytree=0.649; min_gain_to_split=0.071; scale_pos_weight=4.35 : y = 0.934 : 122.8 secs : infill_ei
#
# Wed Nov 12 06:42:07 AM 2025 AUC 0.932108374133125
#
# [mbo] 112: num_leaves=59; learning_rate=0.0143; feature_fraction=0.711; min_data_in_leaf=784; num_iterations=2089; early_stopping_rounds=276; bagging_fraction=0.835; bagging_freq=3; lambda_l1=0.464; lambda_l2=0.0571; max_depth=22; min_child_weight=7.97; subsample=0.834; colsample_bytree=0.579; min_gain_to_split=0.0771; scale_pos_weight=4.46 : y = 0.932 : 119.1 secs : infill_ei
#
# Wed Nov 12 06:47:05 AM 2025 AUC 0.934039886092697
#
# [mbo] 113: num_leaves=58; learning_rate=0.0103; feature_fraction=0.542; min_data_in_leaf=652; num_iterations=2870; early_stopping_rounds=251; bagging_fraction=0.79; bagging_freq=2; lambda_l1=0.0679; lambda_l2=0.0184; max_depth=19; min_child_weight=6.42; subsample=0.747; colsample_bytree=0.813; min_gain_to_split=0.0775; scale_pos_weight=3.4 : y = 0.934 : 293.8 secs : infill_ei
#
# Wed Nov 12 06:48:34 AM 2025 AUC 0.929368898857451
#
# [mbo] 114: num_leaves=63; learning_rate=0.013; feature_fraction=0.69; min_data_in_leaf=2106; num_iterations=4701; early_stopping_rounds=262; bagging_fraction=0.814; bagging_freq=2; lambda_l1=0.442; lambda_l2=0.178; max_depth=24; min_child_weight=0.208; subsample=0.594; colsample_bytree=0.664; min_gain_to_split=0.0371; scale_pos_weight=4.43 : y = 0.929 : 84.1 secs : infill_ei
#
# Saved the current state after iteration 115 in the file HT.RDATA.
#
# Wed Nov 12 06:52:53 AM 2025 AUC 0.931924861960383
#
# [mbo] 115: num_leaves=56; learning_rate=0.0156; feature_fraction=0.425; min_data_in_leaf=448; num_iterations=4597; early_stopping_rounds=406; bagging_fraction=0.733; bagging_freq=1; lambda_l1=0.108; lambda_l2=0.0615; max_depth=24; min_child_weight=7.64; subsample=0.77; colsample_bytree=0.655; min_gain_to_split=0.0616; scale_pos_weight=2.68 : y = 0.932 : 254.4 secs : infill_ei
#
# Wed Nov 12 06:55:51 AM 2025 AUC 0.929711130523033
#
# [mbo] 116: num_leaves=52; learning_rate=0.0289; feature_fraction=0.379; min_data_in_leaf=57; num_iterations=4518; early_stopping_rounds=482; bagging_fraction=0.659; bagging_freq=1; lambda_l1=0.174; lambda_l2=0.342; max_depth=25; min_child_weight=2.96; subsample=0.525; colsample_bytree=0.706; min_gain_to_split=0.074; scale_pos_weight=3.47 : y = 0.93 : 174.0 secs : infill_ei
#
# Wed Nov 12 06:59:15 AM 2025 AUC 0.934872642088702
#
# [mbo] 117: num_leaves=62; learning_rate=0.0122; feature_fraction=0.558; min_data_in_leaf=233; num_iterations=4364; early_stopping_rounds=264; bagging_fraction=0.787; bagging_freq=4; lambda_l1=0.437; lambda_l2=0.23; max_depth=27; min_child_weight=1.22; subsample=0.763; colsample_bytree=0.552; min_gain_to_split=0.0432; scale_pos_weight=4.65 : y = 0.935 : 198.8 secs : infill_ei
#
# Saved the current state after iteration 118 in the file HT.RDATA.
#
# Wed Nov 12 07:03:28 AM 2025 AUC 0.9353740566617
#
# [mbo] 118: num_leaves=63; learning_rate=0.0149; feature_fraction=0.53; min_data_in_leaf=273; num_iterations=2322; early_stopping_rounds=468; bagging_fraction=0.849; bagging_freq=4; lambda_l1=0.446; lambda_l2=0.312; max_depth=24; min_child_weight=1.2; subsample=0.734; colsample_bytree=0.58; min_gain_to_split=0.064; scale_pos_weight=4.14 : y = 0.935 : 247.1 secs : infill_ei
#
# Wed Nov 12 07:04:31 AM 2025 AUC 0.934290129964618
#
# [mbo] 119: num_leaves=63; learning_rate=0.0139; feature_fraction=0.719; min_data_in_leaf=416; num_iterations=407; early_stopping_rounds=346; bagging_fraction=0.788; bagging_freq=4; lambda_l1=0.0894; lambda_l2=0.0529; max_depth=23; min_child_weight=1.94; subsample=0.755; colsample_bytree=0.544; min_gain_to_split=0.0916; scale_pos_weight=3.49 : y = 0.934 : 57.7 secs : infill_ei
#
# Wed Nov 12 07:07:34 AM 2025 AUC 0.932544910665255
#
# [mbo] 120: num_leaves=61; learning_rate=0.0146; feature_fraction=0.533; min_data_in_leaf=44; num_iterations=2060; early_stopping_rounds=426; bagging_fraction=0.841; bagging_freq=2; lambda_l1=0.122; lambda_l2=0.0298; max_depth=21; min_child_weight=1.27; subsample=0.754; colsample_bytree=0.622; min_gain_to_split=0.0553; scale_pos_weight=2.92 : y = 0.933 : 177.1 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves learning_rate feature_fraction min_data_in_leaf num_iterations
#         <int>         <num>            <num>            <int>          <int>
# 1:         60    0.01501363        0.5704454              304           4716
#    early_stopping_rounds bagging_fraction bagging_freq lambda_l1 lambda_l2
#                    <int>            <num>        <int>     <num>     <num>
# 1:                   397        0.8054246            1 0.3172127 0.3370133
#    max_depth min_child_weight subsample colsample_bytree min_gain_to_split
#        <int>            <num>     <num>            <num>             <num>
# 1:        23          1.27777 0.7435072        0.5426038        0.06875417
#    scale_pos_weight
#               <num>
# 1:         4.338969

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 240562

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves learning_rate feature_fraction min_data_in_leaf num_iterations
#         <int>         <num>            <num>            <int>          <int>
# 1:         60    0.01501363        0.5704454              304           4716
#    early_stopping_rounds bagging_fraction bagging_freq lambda_l1 lambda_l2
#                    <int>            <num>        <int>     <num>     <num>
# 1:                   397        0.8054246            1 0.3172127 0.3370133
#    max_depth min_child_weight subsample colsample_bytree min_gain_to_split
#        <int>            <num>     <num>            <num>             <num>
# 1:        23          1.27777 0.7435072        0.5426038        0.06875417
#    scale_pos_weight
#               <num>
# 1:         4.338969

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)
# Out:
# Error in init(env = env): For early stopping, valids must have at least one element
# Traceback:
#
# 1. f(env)
# 2. init(env = env)
# 3. stop("For early stopping, valids must have at least one element")
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "For early stopping, valids must have at least one element",
#  .     base::quote(init(env = env)))

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
