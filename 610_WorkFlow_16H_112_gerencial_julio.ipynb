# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_16H_112_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 17 09:54:12 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454488    77.7 1438389  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63112
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),   # filas
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 17 10:10:29 PM 2025 AUC 0.923214749468013
#
# Mon Nov 17 10:13:46 PM 2025 AUC 0.932325796604278
#
# Mon Nov 17 10:14:59 PM 2025 AUC 0.918493808420387
#
# Mon Nov 17 10:17:22 PM 2025 AUC 0.923793878412449
#
# Mon Nov 17 10:21:58 PM 2025 AUC 0.920378493982897
#
# Mon Nov 17 10:26:47 PM 2025 AUC 0.922382293551939
#
# Mon Nov 17 10:28:14 PM 2025 AUC 0.920766369452055
#
# Mon Nov 17 10:29:46 PM 2025 AUC 0.92377106220838
#
# Mon Nov 17 10:33:23 PM 2025 AUC 0.924130081890041
#
# Mon Nov 17 10:39:36 PM 2025 AUC 0.924699144862093
#
# Mon Nov 17 10:41:15 PM 2025 AUC 0.925692656336295
#
# Mon Nov 17 10:43:19 PM 2025 AUC 0.920016790041935
#
# Mon Nov 17 10:45:49 PM 2025 AUC 0.922904717518617
#
# Mon Nov 17 10:47:00 PM 2025 AUC 0.922824189739553
#
# Mon Nov 17 10:52:12 PM 2025 AUC 0.918872624514401
#
# Mon Nov 17 10:53:28 PM 2025 AUC 0.919136352990835
#
# Mon Nov 17 10:53:48 PM 2025 AUC 0.92000773066679
#
# Mon Nov 17 10:55:13 PM 2025 AUC 0.919673204851262
#
# Mon Nov 17 10:58:15 PM 2025 AUC 0.920003033213011
#
# Mon Nov 17 10:59:49 PM 2025 AUC 0.918962547201022
#
# Mon Nov 17 11:02:37 PM 2025 AUC 0.920748586234179
#
# Mon Nov 17 11:08:45 PM 2025 AUC 0.924574997869369
#
# Mon Nov 17 11:10:46 PM 2025 AUC 0.926625436443786
#
# Mon Nov 17 11:14:15 PM 2025 AUC 0.926939494782135
#
# Mon Nov 17 11:15:00 PM 2025 AUC 0.914666390187959
#
# Mon Nov 17 11:18:23 PM 2025 AUC 0.925828546963465
#
# Mon Nov 17 11:22:03 PM 2025 AUC 0.922311496212846
#
# Mon Nov 17 11:24:00 PM 2025 AUC 0.9295851678568
#
# Mon Nov 17 11:24:27 PM 2025 AUC 0.918014668134956
#
# Mon Nov 17 11:26:39 PM 2025 AUC 0.919008850673984
#
# Mon Nov 17 11:27:36 PM 2025 AUC 0.919222920353329
#
# Mon Nov 17 11:33:44 PM 2025 AUC 0.90662938230496
#
# Mon Nov 17 11:34:54 PM 2025 AUC 0.914698601299584
#
# Mon Nov 17 11:35:35 PM 2025 AUC 0.918818603795945
#
# Mon Nov 17 11:36:16 PM 2025 AUC 0.92310637249869
#
# Mon Nov 17 11:36:45 PM 2025 AUC 0.913956068070132
#
# Mon Nov 17 11:40:04 PM 2025 AUC 0.923887827488023
#
# Mon Nov 17 11:43:22 PM 2025 AUC 0.918813235277341
#
# Mon Nov 17 11:46:18 PM 2025 AUC 0.910772536537802
#
# Mon Nov 17 11:55:47 PM 2025 AUC 0.92340231208675
#
# Mon Nov 17 11:56:03 PM 2025 AUC 0.911507688054174
#
# Mon Nov 17 11:59:55 PM 2025 AUC 0.926384859703832
#
# Tue Nov 18 12:00:38 AM 2025 AUC 0.916141390674481
#
# Tue Nov 18 12:01:09 AM 2025 AUC 0.922168223872594
#
# Tue Nov 18 12:02:59 AM 2025 AUC 0.925458454712184
#
# Tue Nov 18 12:04:31 AM 2025 AUC 0.909661588719132
#
# Tue Nov 18 12:09:09 AM 2025 AUC 0.925622530062027
#
# Tue Nov 18 12:10:07 AM 2025 AUC 0.916602747742035
#
# Tue Nov 18 12:12:07 AM 2025 AUC 0.915004606860027
#
# Tue Nov 18 12:13:09 AM 2025 AUC 0.920614373269072
#
# Tue Nov 18 12:14:58 AM 2025 AUC 0.917457013264938
#
# Tue Nov 18 12:16:20 AM 2025 AUC 0.923124826781392
#
# Tue Nov 18 12:16:53 AM 2025 AUC 0.917980443828854
#
# Tue Nov 18 12:19:12 AM 2025 AUC 0.92507963861817
#
# Tue Nov 18 12:21:06 AM 2025 AUC 0.911592242222191
#
# Tue Nov 18 12:26:45 AM 2025 AUC 0.924734711297846
#
# Tue Nov 18 12:29:34 AM 2025 AUC 0.923065102011919
#
# Tue Nov 18 12:31:00 AM 2025 AUC 0.913498401859118
#
# Tue Nov 18 12:33:53 AM 2025 AUC 0.922153795978845
#
# Tue Nov 18 12:38:07 AM 2025 AUC 0.925842303792389
#
# Tue Nov 18 12:38:23 AM 2025 AUC 0.919995651499931
#
# Tue Nov 18 12:39:00 AM 2025 AUC 0.924836713151327
#
# Tue Nov 18 12:44:59 AM 2025 AUC 0.917944206328276
#
# Tue Nov 18 12:46:09 AM 2025 AUC 0.923103688239388
#
# [mbo] 0: num_leaves=27; max_depth=28; min_child_weight=2.64; min_data_in_leaf=5224; min_gain_to_split=0.0757; lambda_l1=0.241; lambda_l2=0.236; scale_pos_weight=2.32; learning_rate=0.0459; num_iterations=2500; early_stopping_rounds=341; feature_fraction=0.464; bagging_fraction=0.797; bagging_freq=1; max_delta_step=7.25; path_smooth=2.04 : y = 0.923 : 161.8 secs : initdesign
#
# [mbo] 0: num_leaves=31; max_depth=22; min_child_weight=5.79; min_data_in_leaf=1674; min_gain_to_split=0.0413; lambda_l1=0.232; lambda_l2=0.154; scale_pos_weight=3.28; learning_rate=0.0564; num_iterations=3133; early_stopping_rounds=253; feature_fraction=0.478; bagging_fraction=0.779; bagging_freq=4; max_delta_step=5.13; path_smooth=2.8 : y = 0.932 : 196.5 secs : initdesign
#
# [mbo] 0: num_leaves=28; max_depth=29; min_child_weight=4.46; min_data_in_leaf=4572; min_gain_to_split=0.0833; lambda_l1=0.206; lambda_l2=0.39; scale_pos_weight=4.35; learning_rate=0.0553; num_iterations=860; early_stopping_rounds=368; feature_fraction=0.649; bagging_fraction=0.616; bagging_freq=2; max_delta_step=6.21; path_smooth=1.19 : y = 0.918 : 72.8 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=18; min_child_weight=6.37; min_data_in_leaf=1949; min_gain_to_split=0.047; lambda_l1=0.172; lambda_l2=0.284; scale_pos_weight=2.27; learning_rate=0.0523; num_iterations=970; early_stopping_rounds=347; feature_fraction=0.461; bagging_fraction=0.769; bagging_freq=3; max_delta_step=7.77; path_smooth=6.5 : y = 0.924 : 142.9 secs : initdesign
#
# [mbo] 0: num_leaves=26; max_depth=19; min_child_weight=7.53; min_data_in_leaf=5656; min_gain_to_split=0.0565; lambda_l1=0.084; lambda_l2=0.116; scale_pos_weight=1.75; learning_rate=0.0758; num_iterations=2379; early_stopping_rounds=442; feature_fraction=0.598; bagging_fraction=0.761; bagging_freq=5; max_delta_step=8.06; path_smooth=6.24 : y = 0.92 : 276.6 secs : initdesign
#
# [mbo] 0: num_leaves=41; max_depth=19; min_child_weight=1.65; min_data_in_leaf=4224; min_gain_to_split=0.0402; lambda_l1=0.318; lambda_l2=0.294; scale_pos_weight=1.64; learning_rate=0.0207; num_iterations=3375; early_stopping_rounds=450; feature_fraction=0.667; bagging_fraction=0.611; bagging_freq=3; max_delta_step=2.03; path_smooth=5.81 : y = 0.922 : 288.9 secs : initdesign
#
# [mbo] 0: num_leaves=15; max_depth=26; min_child_weight=6.21; min_data_in_leaf=290; min_gain_to_split=0.0108; lambda_l1=0.349; lambda_l2=0.233; scale_pos_weight=3.17; learning_rate=0.0826; num_iterations=2235; early_stopping_rounds=300; feature_fraction=0.633; bagging_fraction=0.707; bagging_freq=1; max_delta_step=8.79; path_smooth=5.52 : y = 0.921 : 87.1 secs : initdesign
#
# [mbo] 0: num_leaves=15; max_depth=8; min_child_weight=3.26; min_data_in_leaf=6469; min_gain_to_split=0.0206; lambda_l1=0.155; lambda_l2=0.275; scale_pos_weight=1.94; learning_rate=0.0872; num_iterations=4317; early_stopping_rounds=355; feature_fraction=0.369; bagging_fraction=0.732; bagging_freq=2; max_delta_step=4.45; path_smooth=5.76 : y = 0.924 : 91.9 secs : initdesign
#
# [mbo] 0: num_leaves=45; max_depth=24; min_child_weight=6.64; min_data_in_leaf=4724; min_gain_to_split=0.0426; lambda_l1=0.132; lambda_l2=0.337; scale_pos_weight=3.88; learning_rate=0.0589; num_iterations=1389; early_stopping_rounds=318; feature_fraction=0.53; bagging_fraction=0.632; bagging_freq=4; max_delta_step=4.34; path_smooth=9.21 : y = 0.924 : 217.2 secs : initdesign
#
# [mbo] 0: num_leaves=48; max_depth=20; min_child_weight=7.99; min_data_in_leaf=3675; min_gain_to_split=0.0912; lambda_l1=0.104; lambda_l2=0.174; scale_pos_weight=2.2; learning_rate=0.044; num_iterations=4778; early_stopping_rounds=428; feature_fraction=0.578; bagging_fraction=0.728; bagging_freq=3; max_delta_step=5.78; path_smooth=2.33 : y = 0.925 : 372.8 secs : initdesign
#
# [mbo] 0: num_leaves=45; max_depth=15; min_child_weight=4.08; min_data_in_leaf=3218; min_gain_to_split=0.0946; lambda_l1=0.163; lambda_l2=0.434; scale_pos_weight=3.98; learning_rate=0.05; num_iterations=2576; early_stopping_rounds=140; feature_fraction=0.621; bagging_fraction=0.8; bagging_freq=1; max_delta_step=8.67; path_smooth=3.96 : y = 0.926 : 98.9 secs : initdesign
#
# [mbo] 0: num_leaves=12; max_depth=9; min_child_weight=5.66; min_data_in_leaf=6556; min_gain_to_split=0.0537; lambda_l1=0.212; lambda_l2=0.377; scale_pos_weight=4.14; learning_rate=0.0604; num_iterations=3517; early_stopping_rounds=405; feature_fraction=0.543; bagging_fraction=0.839; bagging_freq=4; max_delta_step=1.56; path_smooth=0.597 : y = 0.92 : 124.5 secs : initdesign
#
# [mbo] 0: num_leaves=13; max_depth=15; min_child_weight=2.12; min_data_in_leaf=4246; min_gain_to_split=0.0555; lambda_l1=0.265; lambda_l2=0.0647; scale_pos_weight=4.3; learning_rate=0.0896; num_iterations=1258; early_stopping_rounds=203; feature_fraction=0.495; bagging_fraction=0.74; bagging_freq=4; max_delta_step=3.36; path_smooth=5.97 : y = 0.923 : 150.0 secs : initdesign
#
# [mbo] 0: num_leaves=23; max_depth=12; min_child_weight=4.33; min_data_in_leaf=570; min_gain_to_split=0.0317; lambda_l1=0.407; lambda_l2=0.323; scale_pos_weight=1.46; learning_rate=0.0536; num_iterations=1969; early_stopping_rounds=304; feature_fraction=0.333; bagging_fraction=0.543; bagging_freq=2; max_delta_step=4.83; path_smooth=4.41 : y = 0.923 : 70.1 secs : initdesign
#
# [mbo] 0: num_leaves=14; max_depth=21; min_child_weight=0.643; min_data_in_leaf=5280; min_gain_to_split=0.05; lambda_l1=0.202; lambda_l2=0.261; scale_pos_weight=3.66; learning_rate=0.00694; num_iterations=3573; early_stopping_rounds=120; feature_fraction=0.643; bagging_fraction=0.814; bagging_freq=2; max_delta_step=0.789; path_smooth=6.92 : y = 0.919 : 312.2 secs : initdesign
#
# [mbo] 0: num_leaves=59; max_depth=11; min_child_weight=9.88; min_data_in_leaf=4944; min_gain_to_split=0.00578; lambda_l1=0.224; lambda_l2=0.305; scale_pos_weight=1.09; learning_rate=0.0397; num_iterations=2870; early_stopping_rounds=227; feature_fraction=0.669; bagging_fraction=0.59; bagging_freq=3; max_delta_step=1.53; path_smooth=3.45 : y = 0.919 : 76.1 secs : initdesign
#
# [mbo] 0: num_leaves=39; max_depth=6; min_child_weight=9.37; min_data_in_leaf=6387; min_gain_to_split=0.0506; lambda_l1=0.416; lambda_l2=0.182; scale_pos_weight=3.1; learning_rate=0.0843; num_iterations=1819; early_stopping_rounds=73; feature_fraction=0.779; bagging_fraction=0.575; bagging_freq=4; max_delta_step=8.4; path_smooth=6.29 : y = 0.92 : 20.2 secs : initdesign
#
# [mbo] 0: num_leaves=16; max_depth=9; min_child_weight=8.87; min_data_in_leaf=3085; min_gain_to_split=0.0602; lambda_l1=0.334; lambda_l2=0.00412; scale_pos_weight=2.84; learning_rate=0.0221; num_iterations=3010; early_stopping_rounds=154; feature_fraction=0.734; bagging_fraction=0.674; bagging_freq=5; max_delta_step=1.35; path_smooth=4.76 : y = 0.92 : 85.2 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=14; min_child_weight=3.94; min_data_in_leaf=3331; min_gain_to_split=0.0624; lambda_l1=0.0715; lambda_l2=0.309; scale_pos_weight=1.74; learning_rate=0.0623; num_iterations=1478; early_stopping_rounds=423; feature_fraction=0.441; bagging_fraction=0.829; bagging_freq=2; max_delta_step=1.8; path_smooth=8.2 : y = 0.92 : 182.1 secs : initdesign
#
# [mbo] 0: num_leaves=43; max_depth=10; min_child_weight=3.69; min_data_in_leaf=7100; min_gain_to_split=0.0647; lambda_l1=0.425; lambda_l2=0.407; scale_pos_weight=4.84; learning_rate=0.0301; num_iterations=3197; early_stopping_rounds=399; feature_fraction=0.695; bagging_fraction=0.656; bagging_freq=2; max_delta_step=4.14; path_smooth=7.51 : y = 0.919 : 94.1 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=23; min_child_weight=3.48; min_data_in_leaf=4790; min_gain_to_split=0.0138; lambda_l1=0.112; lambda_l2=0.219; scale_pos_weight=3.69; learning_rate=0.0151; num_iterations=1664; early_stopping_rounds=221; feature_fraction=0.613; bagging_fraction=0.583; bagging_freq=2; max_delta_step=8.21; path_smooth=2.88 : y = 0.921 : 167.2 secs : initdesign
#
# [mbo] 0: num_leaves=52; max_depth=10; min_child_weight=4.92; min_data_in_leaf=6815; min_gain_to_split=0.0448; lambda_l1=0.305; lambda_l2=0.48; scale_pos_weight=3.34; learning_rate=0.0369; num_iterations=3811; early_stopping_rounds=328; feature_fraction=0.305; bagging_fraction=0.662; bagging_freq=5; max_delta_step=0.763; path_smooth=4.1 : y = 0.925 : 368.3 secs : initdesign
#
# [mbo] 0: num_leaves=29; max_depth=17; min_child_weight=8.13; min_data_in_leaf=1251; min_gain_to_split=0.00111; lambda_l1=0.288; lambda_l2=0.189; scale_pos_weight=2.8; learning_rate=0.0582; num_iterations=4219; early_stopping_rounds=392; feature_fraction=0.554; bagging_fraction=0.787; bagging_freq=3; max_delta_step=2.29; path_smooth=8.5 : y = 0.927 : 120.7 secs : initdesign
#
# [mbo] 0: num_leaves=57; max_depth=20; min_child_weight=6.9; min_data_in_leaf=5853; min_gain_to_split=0.0269; lambda_l1=0.0181; lambda_l2=0.125; scale_pos_weight=2.57; learning_rate=0.0494; num_iterations=4098; early_stopping_rounds=162; feature_fraction=0.382; bagging_fraction=0.809; bagging_freq=1; max_delta_step=1.14; path_smooth=4.55 : y = 0.927 : 209.1 secs : initdesign
#
# [mbo] 0: num_leaves=56; max_depth=4; min_child_weight=2.99; min_data_in_leaf=3045; min_gain_to_split=0.037; lambda_l1=0.431; lambda_l2=0.36; scale_pos_weight=4.06; learning_rate=0.0795; num_iterations=329; early_stopping_rounds=207; feature_fraction=0.562; bagging_fraction=0.554; bagging_freq=5; max_delta_step=3.7; path_smooth=8.33 : y = 0.915 : 45.2 secs : initdesign
#
# [mbo] 0: num_leaves=38; max_depth=13; min_child_weight=0.105; min_data_in_leaf=2366; min_gain_to_split=0.0459; lambda_l1=0.136; lambda_l2=0.252; scale_pos_weight=2.06; learning_rate=0.0434; num_iterations=2165; early_stopping_rounds=416; feature_fraction=0.79; bagging_fraction=0.57; bagging_freq=4; max_delta_step=9.34; path_smooth=9.58 : y = 0.926 : 202.9 secs : initdesign
#
# [mbo] 0: num_leaves=30; max_depth=20; min_child_weight=0.893; min_data_in_leaf=5024; min_gain_to_split=0.0697; lambda_l1=0.449; lambda_l2=0.142; scale_pos_weight=3.62; learning_rate=0.0664; num_iterations=1895; early_stopping_rounds=474; feature_fraction=0.605; bagging_fraction=0.647; bagging_freq=1; max_delta_step=7.01; path_smooth=1.39 : y = 0.922 : 219.9 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=21; min_child_weight=4.58; min_data_in_leaf=934; min_gain_to_split=0.0776; lambda_l1=0.442; lambda_l2=0.425; scale_pos_weight=4.73; learning_rate=0.0778; num_iterations=3300; early_stopping_rounds=334; feature_fraction=0.685; bagging_fraction=0.869; bagging_freq=3; max_delta_step=0.436; path_smooth=7.07 : y = 0.93 : 117.9 secs : initdesign
#
# [mbo] 0: num_leaves=22; max_depth=21; min_child_weight=6.47; min_data_in_leaf=2790; min_gain_to_split=0.0582; lambda_l1=0.296; lambda_l2=0.269; scale_pos_weight=3.77; learning_rate=0.0886; num_iterations=169; early_stopping_rounds=457; feature_fraction=0.455; bagging_fraction=0.888; bagging_freq=4; max_delta_step=6.03; path_smooth=0.897 : y = 0.918 : 26.3 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=29; min_child_weight=1.45; min_data_in_leaf=5513; min_gain_to_split=0.0922; lambda_l1=0.243; lambda_l2=0.456; scale_pos_weight=1.5; learning_rate=0.0256; num_iterations=2943; early_stopping_rounds=264; feature_fraction=0.705; bagging_fraction=0.622; bagging_freq=5; max_delta_step=4.88; path_smooth=3.11 : y = 0.919 : 132.7 secs : initdesign
#
# [mbo] 0: num_leaves=11; max_depth=25; min_child_weight=8.55; min_data_in_leaf=1649; min_gain_to_split=0.0864; lambda_l1=0.495; lambda_l2=0.136; scale_pos_weight=1.25; learning_rate=0.0951; num_iterations=2014; early_stopping_rounds=274; feature_fraction=0.541; bagging_fraction=0.627; bagging_freq=5; max_delta_step=3.04; path_smooth=1.48 : y = 0.919 : 56.3 secs : initdesign
#
# [mbo] 0: num_leaves=5; max_depth=11; min_child_weight=9.55; min_data_in_leaf=2511; min_gain_to_split=0.0391; lambda_l1=0.0414; lambda_l2=0.493; scale_pos_weight=2.05; learning_rate=0.00919; num_iterations=2800; early_stopping_rounds=196; feature_fraction=0.523; bagging_fraction=0.681; bagging_freq=4; max_delta_step=0.137; path_smooth=5.32 : y = 0.907 : 368.3 secs : initdesign
#
# [mbo] 0: num_leaves=9; max_depth=3; min_child_weight=5.17; min_data_in_leaf=201; min_gain_to_split=0.0661; lambda_l1=0.304; lambda_l2=0.0773; scale_pos_weight=2.4; learning_rate=0.0131; num_iterations=1209; early_stopping_rounds=212; feature_fraction=0.657; bagging_fraction=0.792; bagging_freq=1; max_delta_step=9.79; path_smooth=1.74 : y = 0.915 : 69.5 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=24; min_child_weight=3.76; min_data_in_leaf=469; min_gain_to_split=0.026; lambda_l1=0.17; lambda_l2=0.329; scale_pos_weight=3.4; learning_rate=0.0717; num_iterations=1710; early_stopping_rounds=80; feature_fraction=0.51; bagging_fraction=0.501; bagging_freq=1; max_delta_step=0.944; path_smooth=2.63 : y = 0.919 : 41.5 secs : initdesign
#
# [mbo] 0: num_leaves=48; max_depth=8; min_child_weight=2.91; min_data_in_leaf=3875; min_gain_to_split=0.0638; lambda_l1=0.184; lambda_l2=0.167; scale_pos_weight=2.51; learning_rate=0.0744; num_iterations=376; early_stopping_rounds=182; feature_fraction=0.794; bagging_fraction=0.864; bagging_freq=2; max_delta_step=5.9; path_smooth=9.23 : y = 0.923 : 40.5 secs : initdesign
#
# [mbo] 0: num_leaves=63; max_depth=14; min_child_weight=2.81; min_data_in_leaf=6705; min_gain_to_split=0.0335; lambda_l1=0.273; lambda_l2=0.0981; scale_pos_weight=4.96; learning_rate=0.0812; num_iterations=485; early_stopping_rounds=50; feature_fraction=0.431; bagging_fraction=0.561; bagging_freq=5; max_delta_step=2.77; path_smooth=0.687 : y = 0.914 : 29.0 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=22; min_child_weight=5.1; min_data_in_leaf=2116; min_gain_to_split=0.0893; lambda_l1=0.277; lambda_l2=0.157; scale_pos_weight=4.1; learning_rate=0.0379; num_iterations=2456; early_stopping_rounds=287; feature_fraction=0.361; bagging_fraction=0.508; bagging_freq=3; max_delta_step=5.17; path_smooth=9.01 : y = 0.924 : 199.7 secs : initdesign
#
# [mbo] 0: num_leaves=34; max_depth=25; min_child_weight=7.47; min_data_in_leaf=6933; min_gain_to_split=0.0995; lambda_l1=0.0275; lambda_l2=0.213; scale_pos_weight=1.31; learning_rate=0.0305; num_iterations=4742; early_stopping_rounds=241; feature_fraction=0.484; bagging_fraction=0.754; bagging_freq=3; max_delta_step=7.56; path_smooth=9.82 : y = 0.919 : 198.2 secs : initdesign
#
# [mbo] 0: num_leaves=2; max_depth=17; min_child_weight=3.34; min_data_in_leaf=3522; min_gain_to_split=0.0304; lambda_l1=0.478; lambda_l2=0.349; scale_pos_weight=1.92; learning_rate=0.0772; num_iterations=3453; early_stopping_rounds=280; feature_fraction=0.343; bagging_fraction=0.894; bagging_freq=3; max_delta_step=7.45; path_smooth=8.79 : y = 0.911 : 175.2 secs : initdesign
#
# [mbo] 0: num_leaves=17; max_depth=6; min_child_weight=9.5; min_data_in_leaf=5444; min_gain_to_split=0.0981; lambda_l1=0.371; lambda_l2=0.199; scale_pos_weight=4.92; learning_rate=0.0107; num_iterations=4495; early_stopping_rounds=315; feature_fraction=0.372; bagging_fraction=0.744; bagging_freq=4; max_delta_step=8.57; path_smooth=3.33 : y = 0.923 : 569.8 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=29; min_child_weight=1.32; min_data_in_leaf=1892; min_gain_to_split=0.0795; lambda_l1=0.0506; lambda_l2=0.451; scale_pos_weight=1.2; learning_rate=0.0412; num_iterations=746; early_stopping_rounds=99; feature_fraction=0.775; bagging_fraction=0.522; bagging_freq=1; max_delta_step=3.8; path_smooth=7.84 : y = 0.912 : 15.9 secs : initdesign
#
# [mbo] 0: num_leaves=37; max_depth=15; min_child_weight=8.92; min_data_in_leaf=6162; min_gain_to_split=0.0345; lambda_l1=0.0952; lambda_l2=0.0185; scale_pos_weight=4.66; learning_rate=0.0675; num_iterations=4055; early_stopping_rounds=499; feature_fraction=0.395; bagging_fraction=0.855; bagging_freq=2; max_delta_step=8.96; path_smooth=7.38 : y = 0.926 : 232.1 secs : initdesign
#
# [mbo] 0: num_leaves=9; max_depth=28; min_child_weight=6.09; min_data_in_leaf=8115; min_gain_to_split=0.00936; lambda_l1=0.394; lambda_l2=0.0359; scale_pos_weight=1.43; learning_rate=0.0863; num_iterations=587; early_stopping_rounds=387; feature_fraction=0.75; bagging_fraction=0.719; bagging_freq=4; max_delta_step=3.13; path_smooth=0.434 : y = 0.916 : 42.2 secs : initdesign
#
# [mbo] 0: num_leaves=61; max_depth=9; min_child_weight=7.88; min_data_in_leaf=1138; min_gain_to_split=0.0018; lambda_l1=0.145; lambda_l2=0.0937; scale_pos_weight=2.93; learning_rate=0.0922; num_iterations=3768; early_stopping_rounds=142; feature_fraction=0.744; bagging_fraction=0.565; bagging_freq=4; max_delta_step=7.84; path_smooth=0.972 : y = 0.922 : 31.5 secs : initdesign
#
# [mbo] 0: num_leaves=22; max_depth=5; min_child_weight=4.77; min_data_in_leaf=855; min_gain_to_split=0.0852; lambda_l1=0.252; lambda_l2=0.472; scale_pos_weight=4.4; learning_rate=0.0331; num_iterations=1539; early_stopping_rounds=291; feature_fraction=0.763; bagging_fraction=0.64; bagging_freq=2; max_delta_step=2.55; path_smooth=1.94 : y = 0.925 : 110.1 secs : initdesign
#
# [mbo] 0: num_leaves=4; max_depth=24; min_child_weight=1.06; min_data_in_leaf=2826; min_gain_to_split=0.0798; lambda_l1=0.00345; lambda_l2=0.313; scale_pos_weight=4.25; learning_rate=0.0178; num_iterations=4005; early_stopping_rounds=90; feature_fraction=0.308; bagging_fraction=0.849; bagging_freq=5; max_delta_step=7.15; path_smooth=3.86 : y = 0.91 : 91.8 secs : initdesign
#
# [mbo] 0: num_leaves=61; max_depth=7; min_child_weight=6.79; min_data_in_leaf=646; min_gain_to_split=0.015; lambda_l1=0.338; lambda_l2=0.00833; scale_pos_weight=2.18; learning_rate=0.00564; num_iterations=2246; early_stopping_rounds=184; feature_fraction=0.321; bagging_fraction=0.597; bagging_freq=3; max_delta_step=3.54; path_smooth=2.42 : y = 0.926 : 277.7 secs : initdesign
#
# [mbo] 0: num_leaves=44; max_depth=3; min_child_weight=1.18; min_data_in_leaf=4050; min_gain_to_split=0.0677; lambda_l1=0.485; lambda_l2=0.468; scale_pos_weight=4.62; learning_rate=0.0969; num_iterations=4565; early_stopping_rounds=166; feature_fraction=0.59; bagging_fraction=0.696; bagging_freq=1; max_delta_step=9.18; path_smooth=3.71 : y = 0.917 : 58.3 secs : initdesign
#
# [mbo] 0: num_leaves=35; max_depth=12; min_child_weight=8.32; min_data_in_leaf=7510; min_gain_to_split=0.00653; lambda_l1=0.089; lambda_l2=0.372; scale_pos_weight=1.83; learning_rate=0.0931; num_iterations=2707; early_stopping_rounds=485; feature_fraction=0.511; bagging_fraction=0.549; bagging_freq=2; max_delta_step=6.59; path_smooth=0.144 : y = 0.915 : 120.0 secs : initdesign
#
# [mbo] 0: num_leaves=32; max_depth=18; min_child_weight=2.23; min_data_in_leaf=6095; min_gain_to_split=0.0965; lambda_l1=0.376; lambda_l2=0.394; scale_pos_weight=2.95; learning_rate=0.0728; num_iterations=453; early_stopping_rounds=117; feature_fraction=0.387; bagging_fraction=0.836; bagging_freq=3; max_delta_step=0.526; path_smooth=4.34 : y = 0.921 : 61.6 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=4; min_child_weight=1.83; min_data_in_leaf=7856; min_gain_to_split=0.012; lambda_l1=0.361; lambda_l2=0.21; scale_pos_weight=1.14; learning_rate=0.0263; num_iterations=4951; early_stopping_rounds=366; feature_fraction=0.711; bagging_fraction=0.714; bagging_freq=2; max_delta_step=6.51; path_smooth=6.73 : y = 0.917 : 108.9 secs : initdesign
#
# [mbo] 0: num_leaves=50; max_depth=11; min_child_weight=0.462; min_data_in_leaf=7731; min_gain_to_split=0.0157; lambda_l1=0.383; lambda_l2=0.0557; scale_pos_weight=4.55; learning_rate=0.0975; num_iterations=4259; early_stopping_rounds=170; feature_fraction=0.421; bagging_fraction=0.876; bagging_freq=3; max_delta_step=2.43; path_smooth=9.43 : y = 0.923 : 82.2 secs : initdesign
#
# [mbo] 0: num_leaves=54; max_depth=16; min_child_weight=9.7; min_data_in_leaf=7370; min_gain_to_split=0.00441; lambda_l1=0.0571; lambda_l2=0.0236; scale_pos_weight=4.5; learning_rate=0.0647; num_iterations=1099; early_stopping_rounds=112; feature_fraction=0.753; bagging_fraction=0.706; bagging_freq=5; max_delta_step=9.38; path_smooth=9.93 : y = 0.918 : 32.9 secs : initdesign
#
# [mbo] 0: num_leaves=58; max_depth=30; min_child_weight=5.56; min_data_in_leaf=2586; min_gain_to_split=0.0711; lambda_l1=0.46; lambda_l2=0.109; scale_pos_weight=1.05; learning_rate=0.0635; num_iterations=3881; early_stopping_rounds=374; feature_fraction=0.715; bagging_fraction=0.825; bagging_freq=3; max_delta_step=5.52; path_smooth=7.26 : y = 0.925 : 139.7 secs : initdesign
#
# [mbo] 0: num_leaves=3; max_depth=16; min_child_weight=2.48; min_data_in_leaf=7677; min_gain_to_split=0.0238; lambda_l1=0.0148; lambda_l2=0.491; scale_pos_weight=3.19; learning_rate=0.0167; num_iterations=1059; early_stopping_rounds=462; feature_fraction=0.403; bagging_fraction=0.513; bagging_freq=4; max_delta_step=2.93; path_smooth=6.64 : y = 0.912 : 113.5 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=27; min_child_weight=9.11; min_data_in_leaf=6008; min_gain_to_split=0.0826; lambda_l1=0.327; lambda_l2=0.404; scale_pos_weight=4.76; learning_rate=0.0353; num_iterations=4405; early_stopping_rounds=257; feature_fraction=0.439; bagging_fraction=0.683; bagging_freq=1; max_delta_step=3.98; path_smooth=0.174 : y = 0.925 : 339.3 secs : initdesign
#
# [mbo] 0: num_leaves=40; max_depth=7; min_child_weight=7.22; min_data_in_leaf=4467; min_gain_to_split=0.0179; lambda_l1=0.0649; lambda_l2=0.44; scale_pos_weight=2.49; learning_rate=0.0234; num_iterations=3629; early_stopping_rounds=105; feature_fraction=0.326; bagging_fraction=0.665; bagging_freq=1; max_delta_step=9.62; path_smooth=8.65 : y = 0.923 : 169.0 secs : initdesign
#
# [mbo] 0: num_leaves=50; max_depth=4; min_child_weight=7.12; min_data_in_leaf=8056; min_gain_to_split=0.0287; lambda_l1=0.405; lambda_l2=0.0498; scale_pos_weight=3.55; learning_rate=0.0471; num_iterations=700; early_stopping_rounds=435; feature_fraction=0.586; bagging_fraction=0.692; bagging_freq=5; max_delta_step=0.257; path_smooth=5.07 : y = 0.913 : 86.0 secs : initdesign
#
# [mbo] 0: num_leaves=36; max_depth=27; min_child_weight=0.299; min_data_in_leaf=2210; min_gain_to_split=0.0232; lambda_l1=0.192; lambda_l2=0.042; scale_pos_weight=2.72; learning_rate=0.07; num_iterations=4678; early_stopping_rounds=233; feature_fraction=0.349; bagging_fraction=0.526; bagging_freq=5; max_delta_step=6.77; path_smooth=3.13 : y = 0.922 : 172.4 secs : initdesign
#
# [mbo] 0: num_leaves=24; max_depth=13; min_child_weight=1.9; min_data_in_leaf=1402; min_gain_to_split=0.0888; lambda_l1=0.355; lambda_l2=0.357; scale_pos_weight=3.82; learning_rate=0.0283; num_iterations=1580; early_stopping_rounds=490; feature_fraction=0.567; bagging_fraction=0.861; bagging_freq=5; max_delta_step=9.99; path_smooth=7.97 : y = 0.926 : 254.0 secs : initdesign
#
# [mbo] 0: num_leaves=21; max_depth=30; min_child_weight=5.39; min_data_in_leaf=1439; min_gain_to_split=0.0191; lambda_l1=0.462; lambda_l2=0.421; scale_pos_weight=2.68; learning_rate=0.0333; num_iterations=901; early_stopping_rounds=64; feature_fraction=0.729; bagging_fraction=0.601; bagging_freq=5; max_delta_step=6.34; path_smooth=1.59 : y = 0.92 : 16.2 secs : initdesign
#
# [mbo] 0: num_leaves=62; max_depth=23; min_child_weight=0.597; min_data_in_leaf=103; min_gain_to_split=0.0741; lambda_l1=0.124; lambda_l2=0.0807; scale_pos_weight=3.05; learning_rate=0.019; num_iterations=222; early_stopping_rounds=63; feature_fraction=0.413; bagging_fraction=0.763; bagging_freq=1; max_delta_step=4.65; path_smooth=7.79 : y = 0.925 : 36.8 secs : initdesign
#
# [mbo] 0: num_leaves=7; max_depth=27; min_child_weight=8.68; min_data_in_leaf=7222; min_gain_to_split=0.052; lambda_l1=0.472; lambda_l2=0.122; scale_pos_weight=1.58; learning_rate=0.0123; num_iterations=2703; early_stopping_rounds=472; feature_fraction=0.501; bagging_fraction=0.532; bagging_freq=1; max_delta_step=5.41; path_smooth=5.27 : y = 0.918 : 359.7 secs : initdesign
#
# [mbo] 0: num_leaves=33; max_depth=6; min_child_weight=7.79; min_data_in_leaf=3763; min_gain_to_split=0.0719; lambda_l1=0.0367; lambda_l2=0.244; scale_pos_weight=3.46; learning_rate=0.0989; num_iterations=4880; early_stopping_rounds=133; feature_fraction=0.675; bagging_fraction=0.885; bagging_freq=4; max_delta_step=2.11; path_smooth=4.9 : y = 0.923 : 69.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Nov 18 12:50:02 AM 2025 AUC 0.928280282303551
#
# [mbo] 1: num_leaves=37; max_depth=18; min_child_weight=4.7; min_data_in_leaf=1423; min_gain_to_split=0.0492; lambda_l1=0.213; lambda_l2=0.149; scale_pos_weight=4.14; learning_rate=0.0441; num_iterations=2860; early_stopping_rounds=362; feature_fraction=0.447; bagging_fraction=0.815; bagging_freq=3; max_delta_step=4.48; path_smooth=4.53 : y = 0.928 : 230.2 secs : infill_ei
#
# Tue Nov 18 12:53:39 AM 2025 AUC 0.929232523290982
#
# [mbo] 2: num_leaves=58; max_depth=22; min_child_weight=5.24; min_data_in_leaf=2252; min_gain_to_split=0.0653; lambda_l1=0.26; lambda_l2=0.133; scale_pos_weight=3.23; learning_rate=0.0635; num_iterations=3590; early_stopping_rounds=234; feature_fraction=0.532; bagging_fraction=0.794; bagging_freq=4; max_delta_step=2.87; path_smooth=7.52 : y = 0.929 : 214.2 secs : infill_ei
#
# Tue Nov 18 12:56:18 AM 2025 AUC 0.92836382987433
#
# [mbo] 3: num_leaves=40; max_depth=23; min_child_weight=7.33; min_data_in_leaf=889; min_gain_to_split=0.0485; lambda_l1=0.294; lambda_l2=0.253; scale_pos_weight=4.26; learning_rate=0.0669; num_iterations=3548; early_stopping_rounds=229; feature_fraction=0.469; bagging_fraction=0.831; bagging_freq=4; max_delta_step=3.42; path_smooth=1.79 : y = 0.928 : 158.2 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Tue Nov 18 12:58:14 AM 2025 AUC 0.928147411468095
#
# [mbo] 4: num_leaves=31; max_depth=18; min_child_weight=4.48; min_data_in_leaf=1505; min_gain_to_split=0.0851; lambda_l1=0.159; lambda_l2=0.382; scale_pos_weight=2.94; learning_rate=0.0501; num_iterations=2827; early_stopping_rounds=173; feature_fraction=0.506; bagging_fraction=0.772; bagging_freq=4; max_delta_step=2.6; path_smooth=7.47 : y = 0.928 : 114.0 secs : infill_ei
#
# Tue Nov 18 12:59:36 AM 2025 AUC 0.927090819900293
#
# [mbo] 5: num_leaves=31; max_depth=25; min_child_weight=6.68; min_data_in_leaf=2025; min_gain_to_split=0.0394; lambda_l1=0.465; lambda_l2=0.124; scale_pos_weight=3.43; learning_rate=0.0615; num_iterations=3196; early_stopping_rounds=204; feature_fraction=0.395; bagging_fraction=0.78; bagging_freq=4; max_delta_step=9.14; path_smooth=5.64 : y = 0.927 : 79.9 secs : infill_ei
#
# Tue Nov 18 01:01:52 AM 2025 AUC 0.928265183344976
#
# [mbo] 6: num_leaves=38; max_depth=19; min_child_weight=3.52; min_data_in_leaf=1320; min_gain_to_split=0.0904; lambda_l1=0.298; lambda_l2=0.155; scale_pos_weight=4.4; learning_rate=0.0549; num_iterations=3322; early_stopping_rounds=257; feature_fraction=0.533; bagging_fraction=0.73; bagging_freq=4; max_delta_step=5.38; path_smooth=3.7 : y = 0.928 : 135.1 secs : infill_ei
#
# Tue Nov 18 01:04:28 AM 2025 AUC 0.93465942453507
#
# [mbo] 7: num_leaves=54; max_depth=19; min_child_weight=5.58; min_data_in_leaf=356; min_gain_to_split=0.0704; lambda_l1=0.225; lambda_l2=0.241; scale_pos_weight=4.44; learning_rate=0.0434; num_iterations=3569; early_stopping_rounds=275; feature_fraction=0.316; bagging_fraction=0.863; bagging_freq=3; max_delta_step=3.86; path_smooth=3.53 : y = 0.935 : 154.0 secs : infill_ei
#
# Tue Nov 18 01:06:07 AM 2025 AUC 0.927754503012746
#
# [mbo] 8: num_leaves=53; max_depth=18; min_child_weight=6.8; min_data_in_leaf=687; min_gain_to_split=0.0781; lambda_l1=0.316; lambda_l2=0.133; scale_pos_weight=3.84; learning_rate=0.0518; num_iterations=3777; early_stopping_rounds=182; feature_fraction=0.356; bagging_fraction=0.877; bagging_freq=3; max_delta_step=1.93; path_smooth=3.3 : y = 0.928 : 97.3 secs : infill_ei
#
# Tue Nov 18 01:08:45 AM 2025 AUC 0.933195496618169
#
# [mbo] 9: num_leaves=55; max_depth=20; min_child_weight=4.09; min_data_in_leaf=321; min_gain_to_split=0.0732; lambda_l1=0.14; lambda_l2=0.38; scale_pos_weight=3.86; learning_rate=0.0412; num_iterations=4041; early_stopping_rounds=327; feature_fraction=0.343; bagging_fraction=0.838; bagging_freq=3; max_delta_step=7.87; path_smooth=7.97 : y = 0.933 : 156.4 secs : infill_ei
#
# Saved the current state after iteration 10 in the file HT.RDATA.
#
# Tue Nov 18 01:11:56 AM 2025 AUC 0.929511686258404
#
# [mbo] 10: num_leaves=56; max_depth=23; min_child_weight=3.9; min_data_in_leaf=920; min_gain_to_split=0.0398; lambda_l1=0.126; lambda_l2=0.328; scale_pos_weight=4.56; learning_rate=0.0441; num_iterations=2966; early_stopping_rounds=344; feature_fraction=0.368; bagging_fraction=0.892; bagging_freq=2; max_delta_step=2.94; path_smooth=5.99 : y = 0.93 : 189.0 secs : infill_ei
#
# Tue Nov 18 01:13:59 AM 2025 AUC 0.931970467779158
#
# [mbo] 11: num_leaves=60; max_depth=20; min_child_weight=7.55; min_data_in_leaf=455; min_gain_to_split=0.0567; lambda_l1=0.179; lambda_l2=0.31; scale_pos_weight=3.58; learning_rate=0.0487; num_iterations=4138; early_stopping_rounds=278; feature_fraction=0.52; bagging_fraction=0.801; bagging_freq=2; max_delta_step=6.1; path_smooth=5.28 : y = 0.932 : 120.4 secs : infill_ei
#
# Tue Nov 18 01:16:38 AM 2025 AUC 0.93510098519027
#
# [mbo] 12: num_leaves=55; max_depth=13; min_child_weight=5.55; min_data_in_leaf=321; min_gain_to_split=0.0346; lambda_l1=0.155; lambda_l2=0.321; scale_pos_weight=3.76; learning_rate=0.0353; num_iterations=3759; early_stopping_rounds=308; feature_fraction=0.326; bagging_fraction=0.769; bagging_freq=4; max_delta_step=5.51; path_smooth=2.27 : y = 0.935 : 156.8 secs : infill_ei
#
# Tue Nov 18 01:23:44 AM 2025 AUC 0.933121343954947
#
# [mbo] 13: num_leaves=55; max_depth=20; min_child_weight=4.92; min_data_in_leaf=606; min_gain_to_split=0.0572; lambda_l1=0.212; lambda_l2=0.331; scale_pos_weight=4.91; learning_rate=0.0228; num_iterations=3738; early_stopping_rounds=288; feature_fraction=0.383; bagging_fraction=0.821; bagging_freq=4; max_delta_step=8.61; path_smooth=1.4 : y = 0.933 : 423.8 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Tue Nov 18 01:26:36 AM 2025 AUC 0.930677325860355
#
# [mbo] 14: num_leaves=54; max_depth=21; min_child_weight=5.83; min_data_in_leaf=1068; min_gain_to_split=0.0533; lambda_l1=0.193; lambda_l2=0.293; scale_pos_weight=2.37; learning_rate=0.0457; num_iterations=3960; early_stopping_rounds=298; feature_fraction=0.365; bagging_fraction=0.726; bagging_freq=2; max_delta_step=6.99; path_smooth=4.24 : y = 0.931 : 169.8 secs : infill_ei
#
# Tue Nov 18 01:28:01 AM 2025 AUC 0.927704173150831
#
# [mbo] 15: num_leaves=54; max_depth=12; min_child_weight=4.18; min_data_in_leaf=562; min_gain_to_split=0.0955; lambda_l1=0.101; lambda_l2=0.286; scale_pos_weight=4.57; learning_rate=0.0374; num_iterations=3560; early_stopping_rounds=280; feature_fraction=0.374; bagging_fraction=0.805; bagging_freq=4; max_delta_step=4.37; path_smooth=7.45 : y = 0.928 : 83.7 secs : infill_ei
#
# Tue Nov 18 01:30:31 AM 2025 AUC 0.936043831270145
#
# [mbo] 16: num_leaves=56; max_depth=15; min_child_weight=4.02; min_data_in_leaf=242; min_gain_to_split=0.0418; lambda_l1=0.226; lambda_l2=0.293; scale_pos_weight=3.21; learning_rate=0.0406; num_iterations=3738; early_stopping_rounds=282; feature_fraction=0.333; bagging_fraction=0.772; bagging_freq=4; max_delta_step=7.36; path_smooth=7.63 : y = 0.936 : 148.1 secs : infill_ei
#
# Tue Nov 18 01:33:16 AM 2025 AUC 0.929785816239635
#
# [mbo] 17: num_leaves=55; max_depth=18; min_child_weight=8.45; min_data_in_leaf=442; min_gain_to_split=0.00907; lambda_l1=0.213; lambda_l2=0.373; scale_pos_weight=3.52; learning_rate=0.041; num_iterations=3737; early_stopping_rounds=234; feature_fraction=0.306; bagging_fraction=0.845; bagging_freq=4; max_delta_step=9.49; path_smooth=1.85 : y = 0.93 : 163.3 secs : infill_ei
#
# Tue Nov 18 01:37:30 AM 2025 AUC 0.933225023470492
#
# [mbo] 18: num_leaves=54; max_depth=18; min_child_weight=5.27; min_data_in_leaf=49; min_gain_to_split=0.0359; lambda_l1=0.272; lambda_l2=0.289; scale_pos_weight=3.58; learning_rate=0.0291; num_iterations=3738; early_stopping_rounds=307; feature_fraction=0.452; bagging_fraction=0.716; bagging_freq=4; max_delta_step=6.61; path_smooth=6.71 : y = 0.933 : 252.8 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Tue Nov 18 01:39:42 AM 2025 AUC 0.928777876871684
#
# [mbo] 19: num_leaves=56; max_depth=17; min_child_weight=4.08; min_data_in_leaf=1768; min_gain_to_split=0.0418; lambda_l1=0.188; lambda_l2=0.265; scale_pos_weight=3.55; learning_rate=0.0412; num_iterations=4471; early_stopping_rounds=277; feature_fraction=0.313; bagging_fraction=0.777; bagging_freq=4; max_delta_step=7.53; path_smooth=5.51 : y = 0.929 : 129.9 secs : infill_ei
#
# Tue Nov 18 01:41:40 AM 2025 AUC 0.932995183767747
#
# [mbo] 20: num_leaves=57; max_depth=15; min_child_weight=8.55; min_data_in_leaf=260; min_gain_to_split=0.0521; lambda_l1=0.257; lambda_l2=0.161; scale_pos_weight=2.39; learning_rate=0.0411; num_iterations=3398; early_stopping_rounds=309; feature_fraction=0.372; bagging_fraction=0.83; bagging_freq=4; max_delta_step=4.11; path_smooth=5.45 : y = 0.933 : 116.2 secs : infill_ei
#
# Tue Nov 18 01:43:32 AM 2025 AUC 0.930861197622551
#
# [mbo] 21: num_leaves=56; max_depth=10; min_child_weight=2.62; min_data_in_leaf=142; min_gain_to_split=0.0571; lambda_l1=0.23; lambda_l2=0.386; scale_pos_weight=3.05; learning_rate=0.0734; num_iterations=3071; early_stopping_rounds=360; feature_fraction=0.597; bagging_fraction=0.818; bagging_freq=3; max_delta_step=5.94; path_smooth=3.05 : y = 0.931 : 109.0 secs : infill_ei
#
# Tue Nov 18 01:45:59 AM 2025 AUC 0.925999668493976
#
# [mbo] 22: num_leaves=57; max_depth=13; min_child_weight=6.54; min_data_in_leaf=34; min_gain_to_split=0.0606; lambda_l1=0.225; lambda_l2=0.379; scale_pos_weight=3.45; learning_rate=0.0382; num_iterations=2963; early_stopping_rounds=281; feature_fraction=0.371; bagging_fraction=0.733; bagging_freq=2; max_delta_step=8.65; path_smooth=8.19 : y = 0.926 : 144.4 secs : infill_ei
#
# Tue Nov 18 01:47:42 AM 2025 AUC 0.929075494121808
#
# [mbo] 23: num_leaves=56; max_depth=12; min_child_weight=3.01; min_data_in_leaf=54; min_gain_to_split=0.0472; lambda_l1=0.214; lambda_l2=0.244; scale_pos_weight=3.5; learning_rate=0.0739; num_iterations=3718; early_stopping_rounds=364; feature_fraction=0.313; bagging_fraction=0.859; bagging_freq=3; max_delta_step=4.37; path_smooth=4.65 : y = 0.929 : 101.3 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Tue Nov 18 01:49:21 AM 2025 AUC 0.935111051162653
#
# [mbo] 24: num_leaves=60; max_depth=19; min_child_weight=1.12; min_data_in_leaf=426; min_gain_to_split=0.0343; lambda_l1=0.251; lambda_l2=0.305; scale_pos_weight=3.83; learning_rate=0.0461; num_iterations=3197; early_stopping_rounds=290; feature_fraction=0.433; bagging_fraction=0.768; bagging_freq=4; max_delta_step=5.24; path_smooth=2.23 : y = 0.935 : 97.0 secs : infill_ei
#
# Tue Nov 18 01:52:00 AM 2025 AUC 0.932968005642313
#
# [mbo] 25: num_leaves=58; max_depth=20; min_child_weight=4.33; min_data_in_leaf=102; min_gain_to_split=0.0445; lambda_l1=0.204; lambda_l2=0.158; scale_pos_weight=4.1; learning_rate=0.0488; num_iterations=3446; early_stopping_rounds=309; feature_fraction=0.509; bagging_fraction=0.819; bagging_freq=4; max_delta_step=6.4; path_smooth=8.93 : y = 0.933 : 156.7 secs : infill_ei
#
# Tue Nov 18 01:56:45 AM 2025 AUC 0.931021246583441
#
# [mbo] 26: num_leaves=53; max_depth=15; min_child_weight=0.879; min_data_in_leaf=28; min_gain_to_split=0.0668; lambda_l1=0.232; lambda_l2=0.339; scale_pos_weight=3.1; learning_rate=0.0181; num_iterations=3418; early_stopping_rounds=301; feature_fraction=0.569; bagging_fraction=0.753; bagging_freq=4; max_delta_step=3.2; path_smooth=4.71 : y = 0.931 : 282.9 secs : infill_ei
#
# Tue Nov 18 01:59:35 AM 2025 AUC 0.932100318822899
#
# [mbo] 27: num_leaves=59; max_depth=22; min_child_weight=4.05; min_data_in_leaf=155; min_gain_to_split=0.0619; lambda_l1=0.223; lambda_l2=0.319; scale_pos_weight=2.08; learning_rate=0.0455; num_iterations=3494; early_stopping_rounds=337; feature_fraction=0.418; bagging_fraction=0.841; bagging_freq=4; max_delta_step=5.27; path_smooth=2.6 : y = 0.932 : 168.4 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Tue Nov 18 02:01:45 AM 2025 AUC 0.929405993548383
#
# [mbo] 28: num_leaves=53; max_depth=15; min_child_weight=5.28; min_data_in_leaf=559; min_gain_to_split=0.039; lambda_l1=0.228; lambda_l2=0.209; scale_pos_weight=2.3; learning_rate=0.0469; num_iterations=3247; early_stopping_rounds=233; feature_fraction=0.344; bagging_fraction=0.75; bagging_freq=4; max_delta_step=4.25; path_smooth=6 : y = 0.929 : 127.9 secs : infill_ei
#
# Tue Nov 18 02:04:10 AM 2025 AUC 0.932698237582449
#
# [mbo] 29: num_leaves=58; max_depth=16; min_child_weight=1.25; min_data_in_leaf=327; min_gain_to_split=0.0339; lambda_l1=0.254; lambda_l2=0.3; scale_pos_weight=3.52; learning_rate=0.0395; num_iterations=4026; early_stopping_rounds=386; feature_fraction=0.341; bagging_fraction=0.816; bagging_freq=4; max_delta_step=8.16; path_smooth=5.76 : y = 0.933 : 141.1 secs : infill_ei
#
# Tue Nov 18 02:08:07 AM 2025 AUC 0.93583345244734
#
# [mbo] 30: num_leaves=53; max_depth=15; min_child_weight=6.04; min_data_in_leaf=151; min_gain_to_split=0.0149; lambda_l1=0.249; lambda_l2=0.313; scale_pos_weight=3.84; learning_rate=0.0196; num_iterations=2724; early_stopping_rounds=304; feature_fraction=0.397; bagging_fraction=0.767; bagging_freq=4; max_delta_step=3.39; path_smooth=2.52 : y = 0.936 : 235.1 secs : infill_ei
#
# Tue Nov 18 02:11:58 AM 2025 AUC 0.932642203669517
#
# [mbo] 31: num_leaves=48; max_depth=15; min_child_weight=5.3; min_data_in_leaf=194; min_gain_to_split=0.0321; lambda_l1=0.236; lambda_l2=0.369; scale_pos_weight=2.86; learning_rate=0.0398; num_iterations=2154; early_stopping_rounds=298; feature_fraction=0.352; bagging_fraction=0.835; bagging_freq=4; max_delta_step=6.45; path_smooth=5.08 : y = 0.933 : 229.3 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Tue Nov 18 02:15:16 AM 2025 AUC 0.93198892206186
#
# [mbo] 32: num_leaves=62; max_depth=21; min_child_weight=6.08; min_data_in_leaf=307; min_gain_to_split=0.0755; lambda_l1=0.255; lambda_l2=0.366; scale_pos_weight=4.1; learning_rate=0.038; num_iterations=3946; early_stopping_rounds=339; feature_fraction=0.433; bagging_fraction=0.799; bagging_freq=3; max_delta_step=4.57; path_smooth=2.62 : y = 0.932 : 196.2 secs : infill_ei
#
# Tue Nov 18 02:18:12 AM 2025 AUC 0.93273715934233
#
# [mbo] 33: num_leaves=54; max_depth=22; min_child_weight=2; min_data_in_leaf=11; min_gain_to_split=0.0546; lambda_l1=0.349; lambda_l2=0.422; scale_pos_weight=4.04; learning_rate=0.0315; num_iterations=3360; early_stopping_rounds=329; feature_fraction=0.525; bagging_fraction=0.842; bagging_freq=4; max_delta_step=5.3; path_smooth=7.62 : y = 0.933 : 173.2 secs : infill_ei
#
# Tue Nov 18 02:22:29 AM 2025 AUC 0.932747896379538
#
# [mbo] 34: num_leaves=55; max_depth=26; min_child_weight=2.23; min_data_in_leaf=611; min_gain_to_split=0.0257; lambda_l1=0.322; lambda_l2=0.254; scale_pos_weight=3.04; learning_rate=0.0235; num_iterations=3591; early_stopping_rounds=297; feature_fraction=0.372; bagging_fraction=0.803; bagging_freq=3; max_delta_step=8.14; path_smooth=2.22 : y = 0.933 : 255.2 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Tue Nov 18 02:27:10 AM 2025 AUC 0.932940827516879
#
# [mbo] 35: num_leaves=56; max_depth=16; min_child_weight=1.43; min_data_in_leaf=710; min_gain_to_split=0.0373; lambda_l1=0.247; lambda_l2=0.361; scale_pos_weight=3.93; learning_rate=0.0347; num_iterations=2746; early_stopping_rounds=328; feature_fraction=0.417; bagging_fraction=0.796; bagging_freq=4; max_delta_step=5.77; path_smooth=3.04 : y = 0.933 : 278.2 secs : infill_ei
#
# Tue Nov 18 02:28:30 AM 2025 AUC 0.930357899003402
#
# [mbo] 36: num_leaves=55; max_depth=25; min_child_weight=4.06; min_data_in_leaf=339; min_gain_to_split=0.0353; lambda_l1=0.17; lambda_l2=0.289; scale_pos_weight=4.36; learning_rate=0.0282; num_iterations=3574; early_stopping_rounds=248; feature_fraction=0.623; bagging_fraction=0.818; bagging_freq=4; max_delta_step=5.77; path_smooth=4.39 : y = 0.93 : 77.2 secs : infill_ei
#
# Tue Nov 18 02:30:19 AM 2025 AUC 0.929224470513076
#
# [mbo] 37: num_leaves=53; max_depth=11; min_child_weight=3.5; min_data_in_leaf=217; min_gain_to_split=0.0297; lambda_l1=0.234; lambda_l2=0.444; scale_pos_weight=3.45; learning_rate=0.0507; num_iterations=3721; early_stopping_rounds=341; feature_fraction=0.627; bagging_fraction=0.867; bagging_freq=4; max_delta_step=6.49; path_smooth=7.65 : y = 0.929 : 106.1 secs : infill_ei
#
# Tue Nov 18 02:33:18 AM 2025 AUC 0.930985344615275
#
# [mbo] 38: num_leaves=51; max_depth=18; min_child_weight=2; min_data_in_leaf=204; min_gain_to_split=0.0438; lambda_l1=0.393; lambda_l2=0.145; scale_pos_weight=4.01; learning_rate=0.0339; num_iterations=2784; early_stopping_rounds=309; feature_fraction=0.501; bagging_fraction=0.792; bagging_freq=4; max_delta_step=5.39; path_smooth=1.05 : y = 0.931 : 175.6 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Tue Nov 18 02:36:31 AM 2025 AUC 0.92979252688789
#
# [mbo] 39: num_leaves=50; max_depth=20; min_child_weight=7.01; min_data_in_leaf=177; min_gain_to_split=0.0479; lambda_l1=0.195; lambda_l2=0.267; scale_pos_weight=3.15; learning_rate=0.0444; num_iterations=4079; early_stopping_rounds=336; feature_fraction=0.382; bagging_fraction=0.772; bagging_freq=4; max_delta_step=6.73; path_smooth=5.16 : y = 0.93 : 189.3 secs : infill_ei
#
# Tue Nov 18 02:39:15 AM 2025 AUC 0.928284644224917
#
# [mbo] 40: num_leaves=57; max_depth=18; min_child_weight=7.74; min_data_in_leaf=145; min_gain_to_split=0.0342; lambda_l1=0.329; lambda_l2=0.261; scale_pos_weight=2.98; learning_rate=0.0517; num_iterations=3330; early_stopping_rounds=307; feature_fraction=0.314; bagging_fraction=0.837; bagging_freq=4; max_delta_step=9.21; path_smooth=7.68 : y = 0.928 : 161.4 secs : infill_ei
#
# Tue Nov 18 02:40:46 AM 2025 AUC 0.926441229149177
#
# [mbo] 41: num_leaves=54; max_depth=11; min_child_weight=4.61; min_data_in_leaf=67; min_gain_to_split=0.024; lambda_l1=0.259; lambda_l2=0.306; scale_pos_weight=3.69; learning_rate=0.0325; num_iterations=2950; early_stopping_rounds=205; feature_fraction=0.361; bagging_fraction=0.78; bagging_freq=3; max_delta_step=7.87; path_smooth=3.78 : y = 0.926 : 88.4 secs : infill_ei
#
# Tue Nov 18 02:45:27 AM 2025 AUC 0.934649694095099
#
# [mbo] 42: num_leaves=56; max_depth=18; min_child_weight=6.91; min_data_in_leaf=34; min_gain_to_split=0.0667; lambda_l1=0.259; lambda_l2=0.235; scale_pos_weight=4.56; learning_rate=0.0206; num_iterations=2488; early_stopping_rounds=304; feature_fraction=0.395; bagging_fraction=0.848; bagging_freq=4; max_delta_step=3.39; path_smooth=0.694 : y = 0.935 : 279.0 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Tue Nov 18 02:48:23 AM 2025 AUC 0.926319766415756
#
# [mbo] 43: num_leaves=53; max_depth=9; min_child_weight=5.18; min_data_in_leaf=225; min_gain_to_split=0.0584; lambda_l1=0.148; lambda_l2=0.123; scale_pos_weight=3.56; learning_rate=0.058; num_iterations=3811; early_stopping_rounds=293; feature_fraction=0.524; bagging_fraction=0.785; bagging_freq=3; max_delta_step=5.33; path_smooth=1.06 : y = 0.926 : 173.9 secs : infill_ei
#
# Tue Nov 18 02:53:08 AM 2025 AUC 0.933710874404178
#
# [mbo] 44: num_leaves=53; max_depth=17; min_child_weight=5.46; min_data_in_leaf=695; min_gain_to_split=0.0279; lambda_l1=0.272; lambda_l2=0.327; scale_pos_weight=3.54; learning_rate=0.0238; num_iterations=2496; early_stopping_rounds=361; feature_fraction=0.335; bagging_fraction=0.793; bagging_freq=4; max_delta_step=2.73; path_smooth=4.5 : y = 0.934 : 282.1 secs : infill_ei
#
# Tue Nov 18 02:55:50 AM 2025 AUC 0.930712556763696
#
# [mbo] 45: num_leaves=49; max_depth=8; min_child_weight=5.08; min_data_in_leaf=237; min_gain_to_split=0.00752; lambda_l1=0.248; lambda_l2=0.208; scale_pos_weight=3.47; learning_rate=0.0458; num_iterations=3260; early_stopping_rounds=292; feature_fraction=0.396; bagging_fraction=0.881; bagging_freq=4; max_delta_step=0.675; path_smooth=3.84 : y = 0.931 : 159.4 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Tue Nov 18 02:57:28 AM 2025 AUC 0.927426687845473
#
# [mbo] 46: num_leaves=58; max_depth=19; min_child_weight=1.93; min_data_in_leaf=2; min_gain_to_split=0.0424; lambda_l1=0.323; lambda_l2=0.272; scale_pos_weight=3.31; learning_rate=0.0342; num_iterations=3664; early_stopping_rounds=290; feature_fraction=0.647; bagging_fraction=0.812; bagging_freq=3; max_delta_step=4.55; path_smooth=1.94 : y = 0.927 : 95.7 secs : infill_ei
#
# Tue Nov 18 03:01:32 AM 2025 AUC 0.933019006569054
#
# ...
#
# Tue Nov 18 04:17:27 AM 2025 AUC 0.935337871073684
#
# [mbo] 66: num_leaves=55; max_depth=20; min_child_weight=7.25; min_data_in_leaf=10; min_gain_to_split=0.069; lambda_l1=0.311; lambda_l2=0.405; scale_pos_weight=3.86; learning_rate=0.0173; num_iterations=2161; early_stopping_rounds=294; feature_fraction=0.501; bagging_fraction=0.859; bagging_freq=3; max_delta_step=2.63; path_smooth=0.653 : y = 0.935 : 377.0 secs : infill_ei
#
# Tue Nov 18 04:19:10 AM 2025 AUC 0.930552507802806
#
# [mbo] 67: num_leaves=62; max_depth=9; min_child_weight=7.32; min_data_in_leaf=464; min_gain_to_split=0.0209; lambda_l1=0.213; lambda_l2=0.389; scale_pos_weight=2; learning_rate=0.0433; num_iterations=4018; early_stopping_rounds=290; feature_fraction=0.408; bagging_fraction=0.768; bagging_freq=4; max_delta_step=3.74; path_smooth=1.58 : y = 0.931 : 100.3 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Tue Nov 18 04:21:38 AM 2025 AUC 0.930354208146861
#
# [mbo] 68: num_leaves=58; max_depth=26; min_child_weight=2.69; min_data_in_leaf=199; min_gain_to_split=0.032; lambda_l1=0.109; lambda_l2=0.335; scale_pos_weight=2.69; learning_rate=0.0509; num_iterations=3506; early_stopping_rounds=271; feature_fraction=0.342; bagging_fraction=0.779; bagging_freq=3; max_delta_step=2.71; path_smooth=7.61 : y = 0.93 : 143.2 secs : infill_ei
#
# Tue Nov 18 04:29:30 AM 2025 AUC 0.932019119979009
#
# [mbo] 69: num_leaves=62; max_depth=21; min_child_weight=1.96; min_data_in_leaf=309; min_gain_to_split=0.0769; lambda_l1=0.415; lambda_l2=0.399; scale_pos_weight=2.52; learning_rate=0.00622; num_iterations=3397; early_stopping_rounds=275; feature_fraction=0.32; bagging_fraction=0.854; bagging_freq=3; max_delta_step=4.29; path_smooth=3.43 : y = 0.932 : 469.2 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Tue Nov 18 04:33:22 AM 2025 AUC 0.930837710353658
#
# [mbo] 70: num_leaves=52; max_depth=26; min_child_weight=6.88; min_data_in_leaf=461; min_gain_to_split=0.0633; lambda_l1=0.289; lambda_l2=0.416; scale_pos_weight=2.98; learning_rate=0.0185; num_iterations=2774; early_stopping_rounds=304; feature_fraction=0.346; bagging_fraction=0.804; bagging_freq=3; max_delta_step=5.57; path_smooth=2.14 : y = 0.931 : 229.1 secs : infill_ei
#
# Tue Nov 18 04:35:55 AM 2025 AUC 0.933948431352417
#
# [mbo] 71: num_leaves=61; max_depth=13; min_child_weight=3.07; min_data_in_leaf=196; min_gain_to_split=0.0221; lambda_l1=0.303; lambda_l2=0.327; scale_pos_weight=3.93; learning_rate=0.0295; num_iterations=2459; early_stopping_rounds=334; feature_fraction=0.475; bagging_fraction=0.725; bagging_freq=5; max_delta_step=4.06; path_smooth=3.45 : y = 0.934 : 149.8 secs : infill_ei
#
# Tue Nov 18 04:43:28 AM 2025 AUC 0.934112171169847
#
# [mbo] 72: num_leaves=63; max_depth=10; min_child_weight=5; min_data_in_leaf=211; min_gain_to_split=0.0521; lambda_l1=0.311; lambda_l2=0.391; scale_pos_weight=3.84; learning_rate=0.0127; num_iterations=3926; early_stopping_rounds=278; feature_fraction=0.381; bagging_fraction=0.833; bagging_freq=4; max_delta_step=2.17; path_smooth=6.56 : y = 0.934 : 449.4 secs : infill_ei
#
# Saved the current state after iteration 73 in the file HT.RDATA.
#
# Tue Nov 18 04:49:38 AM 2025 AUC 0.933548476716399
#
# [mbo] 73: num_leaves=59; max_depth=21; min_child_weight=4.93; min_data_in_leaf=233; min_gain_to_split=0.0311; lambda_l1=0.237; lambda_l2=0.387; scale_pos_weight=3.43; learning_rate=0.0135; num_iterations=2095; early_stopping_rounds=372; feature_fraction=0.525; bagging_fraction=0.86; bagging_freq=4; max_delta_step=1.39; path_smooth=2.4 : y = 0.934 : 367.3 secs : infill_ei
#
# Tue Nov 18 04:51:58 AM 2025 AUC 0.932507319639585
#
# [mbo] 74: num_leaves=57; max_depth=18; min_child_weight=5.12; min_data_in_leaf=14; min_gain_to_split=0.0428; lambda_l1=0.25; lambda_l2=0.302; scale_pos_weight=4.03; learning_rate=0.0398; num_iterations=3621; early_stopping_rounds=332; feature_fraction=0.361; bagging_fraction=0.762; bagging_freq=4; max_delta_step=1.53; path_smooth=2.62 : y = 0.933 : 135.5 secs : infill_ei
#
# Tue Nov 18 04:54:38 AM 2025 AUC 0.931264507582697
#
# [mbo] 75: num_leaves=55; max_depth=13; min_child_weight=7.13; min_data_in_leaf=566; min_gain_to_split=0.0621; lambda_l1=0.317; lambda_l2=0.459; scale_pos_weight=3.6; learning_rate=0.0608; num_iterations=2204; early_stopping_rounds=299; feature_fraction=0.503; bagging_fraction=0.833; bagging_freq=5; max_delta_step=3.43; path_smooth=3.3 : y = 0.931 : 155.0 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Tue Nov 18 04:57:09 AM 2025 AUC 0.931204782813224
#
# [mbo] 76: num_leaves=52; max_depth=15; min_child_weight=7.41; min_data_in_leaf=137; min_gain_to_split=0.00817; lambda_l1=0.396; lambda_l2=0.408; scale_pos_weight=3.63; learning_rate=0.0173; num_iterations=2325; early_stopping_rounds=292; feature_fraction=0.607; bagging_fraction=0.818; bagging_freq=4; max_delta_step=1.87; path_smooth=2.35 : y = 0.931 : 148.3 secs : infill_ei
#
# Tue Nov 18 05:05:04 AM 2025 AUC 0.933817238179025
#
# [mbo] 77: num_leaves=61; max_depth=23; min_child_weight=2.28; min_data_in_leaf=245; min_gain_to_split=0.0278; lambda_l1=0.171; lambda_l2=0.459; scale_pos_weight=2.05; learning_rate=0.0172; num_iterations=4137; early_stopping_rounds=287; feature_fraction=0.427; bagging_fraction=0.746; bagging_freq=4; max_delta_step=3.78; path_smooth=7.02 : y = 0.934 : 471.2 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Tue Nov 18 05:06:31 AM 2025 AUC 0.933175700205816
#
# [mbo] 78: num_leaves=57; max_depth=20; min_child_weight=2.34; min_data_in_leaf=14; min_gain_to_split=0.0621; lambda_l1=0.314; lambda_l2=0.47; scale_pos_weight=3.88; learning_rate=0.0414; num_iterations=3661; early_stopping_rounds=160; feature_fraction=0.304; bagging_fraction=0.754; bagging_freq=3; max_delta_step=6.49; path_smooth=6.53 : y = 0.933 : 84.3 secs : infill_ei
#
# Tue Nov 18 05:09:30 AM 2025 AUC 0.932124812689031
#
# [mbo] 79: num_leaves=57; max_depth=21; min_child_weight=6.52; min_data_in_leaf=255; min_gain_to_split=0.0679; lambda_l1=0.265; lambda_l2=0.479; scale_pos_weight=4.17; learning_rate=0.024; num_iterations=2182; early_stopping_rounds=241; feature_fraction=0.457; bagging_fraction=0.784; bagging_freq=4; max_delta_step=4.41; path_smooth=1.7 : y = 0.932 : 174.7 secs : infill_ei
#
# Tue Nov 18 05:12:14 AM 2025 AUC 0.929683143321328
#
# [mbo] 80: num_leaves=57; max_depth=22; min_child_weight=1.59; min_data_in_leaf=322; min_gain_to_split=0.0333; lambda_l1=0.408; lambda_l2=0.354; scale_pos_weight=4.39; learning_rate=0.0384; num_iterations=4005; early_stopping_rounds=287; feature_fraction=0.361; bagging_fraction=0.643; bagging_freq=5; max_delta_step=5.92; path_smooth=7.38 : y = 0.93 : 159.4 secs : infill_ei
#
# Tue Nov 18 05:18:40 AM 2025 AUC 0.932464707023163
#
# [mbo] 81: num_leaves=62; max_depth=17; min_child_weight=2.64; min_data_in_leaf=111; min_gain_to_split=0.046; lambda_l1=0.315; lambda_l2=0.32; scale_pos_weight=2.07; learning_rate=0.0104; num_iterations=3479; early_stopping_rounds=365; feature_fraction=0.37; bagging_fraction=0.764; bagging_freq=4; max_delta_step=7.88; path_smooth=7.92 : y = 0.932 : 382.4 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Tue Nov 18 05:20:58 AM 2025 AUC 0.932144273568971
#
# [mbo] 82: num_leaves=62; max_depth=27; min_child_weight=6.83; min_data_in_leaf=483; min_gain_to_split=0.0644; lambda_l1=0.232; lambda_l2=0.232; scale_pos_weight=4.35; learning_rate=0.0381; num_iterations=3377; early_stopping_rounds=280; feature_fraction=0.325; bagging_fraction=0.808; bagging_freq=2; max_delta_step=2.9; path_smooth=0.881 : y = 0.932 : 134.1 secs : infill_ei
#
# Tue Nov 18 05:25:15 AM 2025 AUC 0.93123330306831
#
# [mbo] 83: num_leaves=56; max_depth=19; min_child_weight=3.63; min_data_in_leaf=187; min_gain_to_split=0.036; lambda_l1=0.333; lambda_l2=0.374; scale_pos_weight=4.46; learning_rate=0.016; num_iterations=3443; early_stopping_rounds=334; feature_fraction=0.423; bagging_fraction=0.755; bagging_freq=3; max_delta_step=4.4; path_smooth=8.35 : y = 0.931 : 253.5 secs : infill_ei
#
# Tue Nov 18 05:29:44 AM 2025 AUC 0.929369084982978
#
# [mbo] 84: num_leaves=51; max_depth=24; min_child_weight=5.87; min_data_in_leaf=395; min_gain_to_split=0.0374; lambda_l1=0.273; lambda_l2=0.247; scale_pos_weight=3.63; learning_rate=0.0273; num_iterations=2458; early_stopping_rounds=435; feature_fraction=0.519; bagging_fraction=0.85; bagging_freq=4; max_delta_step=6.6; path_smooth=6.49 : y = 0.929 : 264.6 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Tue Nov 18 05:32:04 AM 2025 AUC 0.924325026221858
#
# [mbo] 85: num_leaves=61; max_depth=24; min_child_weight=3.86; min_data_in_leaf=466; min_gain_to_split=0.0273; lambda_l1=0.242; lambda_l2=0.348; scale_pos_weight=4.07; learning_rate=0.0887; num_iterations=3967; early_stopping_rounds=280; feature_fraction=0.37; bagging_fraction=0.772; bagging_freq=4; max_delta_step=6.72; path_smooth=3.55 : y = 0.924 : 135.7 secs : infill_ei
#
# Tue Nov 18 05:35:38 AM 2025 AUC 0.933493449400706
#
# [mbo] 86: num_leaves=58; max_depth=18; min_child_weight=4.96; min_data_in_leaf=64; min_gain_to_split=0.0303; lambda_l1=0.347; lambda_l2=0.401; scale_pos_weight=3.25; learning_rate=0.0387; num_iterations=2146; early_stopping_rounds=307; feature_fraction=0.437; bagging_fraction=0.867; bagging_freq=4; max_delta_step=2.73; path_smooth=4.73 : y = 0.933 : 211.0 secs : infill_ei
#
# Tue Nov 18 05:43:42 AM 2025 AUC 0.934585271871848
#
# [mbo] 87: num_leaves=55; max_depth=27; min_child_weight=3.22; min_data_in_leaf=581; min_gain_to_split=0.0534; lambda_l1=0.231; lambda_l2=0.278; scale_pos_weight=3.37; learning_rate=0.0109; num_iterations=3706; early_stopping_rounds=376; feature_fraction=0.328; bagging_fraction=0.888; bagging_freq=4; max_delta_step=3.29; path_smooth=4.44 : y = 0.935 : 480.3 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Tue Nov 18 05:49:10 AM 2025 AUC 0.931094728181837
#
# [mbo] 88: num_leaves=52; max_depth=15; min_child_weight=9.98; min_data_in_leaf=326; min_gain_to_split=0.0546; lambda_l1=0.274; lambda_l2=0.343; scale_pos_weight=4.7; learning_rate=0.0174; num_iterations=2047; early_stopping_rounds=314; feature_fraction=0.429; bagging_fraction=0.721; bagging_freq=4; max_delta_step=1.17; path_smooth=2.14 : y = 0.931 : 323.4 secs : infill_ei
#
# Tue Nov 18 05:50:40 AM 2025 AUC 0.927217651152319
#
# [mbo] 89: num_leaves=53; max_depth=27; min_child_weight=3.84; min_data_in_leaf=269; min_gain_to_split=0.0163; lambda_l1=0.242; lambda_l2=0.23; scale_pos_weight=3.34; learning_rate=0.0385; num_iterations=4669; early_stopping_rounds=178; feature_fraction=0.349; bagging_fraction=0.777; bagging_freq=3; max_delta_step=7.28; path_smooth=8.01 : y = 0.927 : 86.0 secs : infill_ei
#
# Tue Nov 18 05:55:40 AM 2025 AUC 0.930378030948168
#
# [mbo] 90: num_leaves=43; max_depth=23; min_child_weight=3.75; min_data_in_leaf=87; min_gain_to_split=0.0685; lambda_l1=0.131; lambda_l2=0.365; scale_pos_weight=3.88; learning_rate=0.0483; num_iterations=2516; early_stopping_rounds=294; feature_fraction=0.546; bagging_fraction=0.808; bagging_freq=4; max_delta_step=2.77; path_smooth=3.02 : y = 0.93 : 295.6 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Tue Nov 18 05:59:35 AM 2025 AUC 0.934157803577983
#
# [mbo] 91: num_leaves=54; max_depth=13; min_child_weight=3.83; min_data_in_leaf=102; min_gain_to_split=0.00576; lambda_l1=0.314; lambda_l2=0.423; scale_pos_weight=2.46; learning_rate=0.0168; num_iterations=1677; early_stopping_rounds=324; feature_fraction=0.337; bagging_fraction=0.803; bagging_freq=5; max_delta_step=4.76; path_smooth=3.17 : y = 0.934 : 231.2 secs : infill_ei
#
# Tue Nov 18 06:05:21 AM 2025 AUC 0.93415377718903
#
# [mbo] 92: num_leaves=61; max_depth=14; min_child_weight=7.47; min_data_in_leaf=223; min_gain_to_split=0.0179; lambda_l1=0.457; lambda_l2=0.0987; scale_pos_weight=3.75; learning_rate=0.0165; num_iterations=3421; early_stopping_rounds=385; feature_fraction=0.416; bagging_fraction=0.704; bagging_freq=5; max_delta_step=4.6; path_smooth=3.67 : y = 0.934 : 342.2 secs : infill_ei
#
# Tue Nov 18 06:10:48 AM 2025 AUC 0.932421087809504
#
# [mbo] 93: num_leaves=56; max_depth=9; min_child_weight=6.88; min_data_in_leaf=407; min_gain_to_split=0.0194; lambda_l1=0.313; lambda_l2=0.214; scale_pos_weight=2.36; learning_rate=0.0184; num_iterations=3434; early_stopping_rounds=411; feature_fraction=0.408; bagging_fraction=0.871; bagging_freq=5; max_delta_step=4.31; path_smooth=3.36 : y = 0.932 : 322.4 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Tue Nov 18 06:16:16 AM 2025 AUC 0.931704390575834
#
# [mbo] 94: num_leaves=56; max_depth=25; min_child_weight=6.21; min_data_in_leaf=617; min_gain_to_split=0.0528; lambda_l1=0.237; lambda_l2=0.401; scale_pos_weight=2.27; learning_rate=0.0203; num_iterations=3859; early_stopping_rounds=278; feature_fraction=0.317; bagging_fraction=0.85; bagging_freq=4; max_delta_step=3.75; path_smooth=4.01 : y = 0.932 : 323.0 secs : infill_ei
#
# Tue Nov 18 06:23:23 AM 2025 AUC 0.932126154818682
#
# [mbo] 95: num_leaves=54; max_depth=12; min_child_weight=8.43; min_data_in_leaf=120; min_gain_to_split=0.021; lambda_l1=0.0922; lambda_l2=0.322; scale_pos_weight=1.69; learning_rate=0.0162; num_iterations=2505; early_stopping_rounds=360; feature_fraction=0.491; bagging_fraction=0.781; bagging_freq=5; max_delta_step=5.44; path_smooth=3.19 : y = 0.932 : 423.1 secs : infill_ei
#
# Saved the current state after iteration 96 in the file HT.RDATA.
#
# Tue Nov 18 06:28:39 AM 2025 AUC 0.935074142597249
#
# [mbo] 96: num_leaves=63; max_depth=25; min_child_weight=2.83; min_data_in_leaf=5; min_gain_to_split=0.0532; lambda_l1=0.472; lambda_l2=0.31; scale_pos_weight=3.85; learning_rate=0.0129; num_iterations=2047; early_stopping_rounds=338; feature_fraction=0.387; bagging_fraction=0.831; bagging_freq=2; max_delta_step=2.51; path_smooth=4.56 : y = 0.935 : 312.1 secs : infill_ei
#
# Tue Nov 18 06:33:43 AM 2025 AUC 0.929366400723676
#
# [mbo] 97: num_leaves=33; max_depth=21; min_child_weight=6.06; min_data_in_leaf=30; min_gain_to_split=0.00195; lambda_l1=0.395; lambda_l2=0.195; scale_pos_weight=3.96; learning_rate=0.00822; num_iterations=2384; early_stopping_rounds=360; feature_fraction=0.326; bagging_fraction=0.771; bagging_freq=4; max_delta_step=4.96; path_smooth=2.07 : y = 0.929 : 298.0 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.
#
# Tue Nov 18 06:37:31 AM 2025 AUC 0.930351188355146
#
# [mbo] 98: num_leaves=61; max_depth=17; min_child_weight=3.9; min_data_in_leaf=24; min_gain_to_split=0.00966; lambda_l1=0.334; lambda_l2=0.377; scale_pos_weight=3.12; learning_rate=0.0137; num_iterations=2130; early_stopping_rounds=267; feature_fraction=0.368; bagging_fraction=0.865; bagging_freq=4; max_delta_step=4.13; path_smooth=2.35 : y = 0.93 : 221.8 secs : infill_ei
#
# Tue Nov 18 06:43:05 AM 2025 AUC 0.936056917034242
#
# [mbo] 99: num_leaves=57; max_depth=18; min_child_weight=4.21; min_data_in_leaf=241; min_gain_to_split=0.0263; lambda_l1=0.284; lambda_l2=0.253; scale_pos_weight=4.07; learning_rate=0.0238; num_iterations=3590; early_stopping_rounds=395; feature_fraction=0.333; bagging_fraction=0.797; bagging_freq=5; max_delta_step=6.5; path_smooth=2.09 : y = 0.936 : 329.9 secs : infill_ei
#
# Tue Nov 18 06:48:23 AM 2025 AUC 0.934512461338278
#
# [mbo] 100: num_leaves=55; max_depth=11; min_child_weight=4.08; min_data_in_leaf=48; min_gain_to_split=0.0232; lambda_l1=0.239; lambda_l2=0.426; scale_pos_weight=3.01; learning_rate=0.0225; num_iterations=3877; early_stopping_rounds=365; feature_fraction=0.369; bagging_fraction=0.73; bagging_freq=5; max_delta_step=6.16; path_smooth=4.56 : y = 0.935 : 313.8 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:         57        18          4.21125              241        0.02627992
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.2843858  0.253252         4.070503    0.02376603           3590
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   395        0.3327037        0.7970043            5
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       6.496498    2.090204

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5851500
#
# $envios
# [1] 1103

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1796245012
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 06:58:09 AM 2025"
# Inicio: Mon Nov 17 09:54:15 PM 2025
# Fin:    Tue Nov 18 06:58:09 AM 2025
# Duración (hh:mm:ss): 09:03:54
