# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_7HT_65172_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Nov 22 01:21:02 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454502    77.7 1437470  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65172 # 7 HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 70

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  #makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L)   # columnas
  #makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Nov 22 01:39:28 PM 2025 AUC 0.916974853187793
#
# Sat Nov 22 01:43:12 PM 2025 AUC 0.914224494000345
#
# Sat Nov 22 01:45:50 PM 2025 AUC 0.914066793766345
#
# Sat Nov 22 01:51:09 PM 2025 AUC 0.921303892377308
#
# Sat Nov 22 01:52:32 PM 2025 AUC 0.911957637019694
#
# Sat Nov 22 02:03:56 PM 2025 AUC 0.92350666266712
#
# Sat Nov 22 02:12:54 PM 2025 AUC 0.921979319124207
#
# Sat Nov 22 02:14:29 PM 2025 AUC 0.905767735068975
#
# Sat Nov 22 02:20:50 PM 2025 AUC 0.922671522491744
#
# Sat Nov 22 02:29:01 PM 2025 AUC 0.924078074366062
#
# Sat Nov 22 02:32:40 PM 2025 AUC 0.914829794472976
#
# Sat Nov 22 02:41:17 PM 2025 AUC 0.916152463244102
#
# Sat Nov 22 02:44:37 PM 2025 AUC 0.914284218769817
#
# Sat Nov 22 02:47:20 PM 2025 AUC 0.924719612339272
#
# Sat Nov 22 02:48:11 PM 2025 AUC 0.911483865252867
#
# Sat Nov 22 02:49:40 PM 2025 AUC 0.906780371890705
#
# Sat Nov 22 02:54:56 PM 2025 AUC 0.906543486007292
#
# Sat Nov 22 03:02:45 PM 2025 AUC 0.920430837039289
#
# Sat Nov 22 03:05:10 PM 2025 AUC 0.914771747365567
#
# Sat Nov 22 03:06:57 PM 2025 AUC 0.911512721040365
#
# Sat Nov 22 03:12:08 PM 2025 AUC 0.917014110480087
#
# Sat Nov 22 03:20:48 PM 2025 AUC 0.922055149449492
#
# Sat Nov 22 03:21:15 PM 2025 AUC 0.898849056717728
#
# Sat Nov 22 03:23:14 PM 2025 AUC 0.909634075061285
#
# Sat Nov 22 03:27:52 PM 2025 AUC 0.915850484072612
#
# Sat Nov 22 03:31:28 PM 2025 AUC 0.921768604768989
#
# Sat Nov 22 03:32:25 PM 2025 AUC 0.914840531510184
#
# Sat Nov 22 03:39:09 PM 2025 AUC 0.919015896854652
#
# [mbo] 0: num_leaves=4978; min_data_in_leaf=6051; lambda_l2=720; learning_rate=0.0902; num_iterations=3947; early_stopping_rounds=220; feature_fraction=0.354 : y = 0.917 : 348.4 secs : initdesign
#
# [mbo] 0: num_leaves=2336; min_data_in_leaf=3873; lambda_l2=673; learning_rate=0.0417; num_iterations=2289; early_stopping_rounds=277; feature_fraction=0.179 : y = 0.914 : 223.8 secs : initdesign
#
# [mbo] 0: num_leaves=4664; min_data_in_leaf=3240; lambda_l2=635; learning_rate=0.0333; num_iterations=1747; early_stopping_rounds=310; feature_fraction=0.14 : y = 0.914 : 158.4 secs : initdesign
#
# [mbo] 0: num_leaves=901; min_data_in_leaf=5374; lambda_l2=67.4; learning_rate=0.0459; num_iterations=2078; early_stopping_rounds=383; feature_fraction=0.475 : y = 0.921 : 318.4 secs : initdesign
#
# [mbo] 0: num_leaves=7002; min_data_in_leaf=5185; lambda_l2=503; learning_rate=0.0616; num_iterations=2930; early_stopping_rounds=61; feature_fraction=0.664 : y = 0.912 : 83.4 secs : initdesign
#
# [mbo] 0: num_leaves=2374; min_data_in_leaf=624; lambda_l2=457; learning_rate=0.0274; num_iterations=4533; early_stopping_rounds=271; feature_fraction=0.358 : y = 0.924 : 684.5 secs : initdesign
#
# [mbo] 0: num_leaves=4765; min_data_in_leaf=1461; lambda_l2=465; learning_rate=0.0529; num_iterations=3968; early_stopping_rounds=450; feature_fraction=0.844 : y = 0.922 : 537.2 secs : initdesign
#
# [mbo] 0: num_leaves=3353; min_data_in_leaf=4859; lambda_l2=602; learning_rate=0.0232; num_iterations=622; early_stopping_rounds=462; feature_fraction=0.574 : y = 0.906 : 95.5 secs : initdesign
#
# [mbo] 0: num_leaves=6365; min_data_in_leaf=3076; lambda_l2=180; learning_rate=0.0727; num_iterations=4862; early_stopping_rounds=193; feature_fraction=0.558 : y = 0.923 : 381.2 secs : initdesign
#
# [mbo] 0: num_leaves=6441; min_data_in_leaf=94; lambda_l2=371; learning_rate=0.0663; num_iterations=2512; early_stopping_rounds=254; feature_fraction=0.616 : y = 0.924 : 490.5 secs : initdesign
#
# [mbo] 0: num_leaves=3172; min_data_in_leaf=7612; lambda_l2=403; learning_rate=0.0575; num_iterations=3556; early_stopping_rounds=144; feature_fraction=0.642 : y = 0.915 : 219.0 secs : initdesign
#
# [mbo] 0: num_leaves=8067; min_data_in_leaf=1488; lambda_l2=562; learning_rate=0.0123; num_iterations=4306; early_stopping_rounds=165; feature_fraction=0.716 : y = 0.916 : 516.9 secs : initdesign
#
# [mbo] 0: num_leaves=703; min_data_in_leaf=3522; lambda_l2=709; learning_rate=0.022; num_iterations=2674; early_stopping_rounds=196; feature_fraction=0.0764 : y = 0.914 : 200.1 secs : initdesign
#
# [mbo] 0: num_leaves=3925; min_data_in_leaf=4488; lambda_l2=88.2; learning_rate=0.0942; num_iterations=1590; early_stopping_rounds=100; feature_fraction=0.189 : y = 0.925 : 163.1 secs : initdesign
#
# [mbo] 0: num_leaves=7898; min_data_in_leaf=381; lambda_l2=979; learning_rate=0.0839; num_iterations=397; early_stopping_rounds=67; feature_fraction=0.781 : y = 0.911 : 51.0 secs : initdesign
#
# [mbo] 0: num_leaves=209; min_data_in_leaf=2787; lambda_l2=866; learning_rate=0.0317; num_iterations=943; early_stopping_rounds=361; feature_fraction=0.891 : y = 0.907 : 89.1 secs : initdesign
#
# [mbo] 0: num_leaves=6057; min_data_in_leaf=5731; lambda_l2=274; learning_rate=0.00519; num_iterations=3386; early_stopping_rounds=147; feature_fraction=0.919 : y = 0.907 : 316.2 secs : initdesign
#
# [mbo] 0: num_leaves=1197; min_data_in_leaf=2428; lambda_l2=803; learning_rate=0.0892; num_iterations=3107; early_stopping_rounds=350; feature_fraction=0.424 : y = 0.92 : 468.4 secs : initdesign
#
# [mbo] 0: num_leaves=5840; min_data_in_leaf=4346; lambda_l2=957; learning_rate=0.098; num_iterations=1368; early_stopping_rounds=476; feature_fraction=0.747 : y = 0.915 : 145.0 secs : initdesign
#
# [mbo] 0: num_leaves=1483; min_data_in_leaf=7960; lambda_l2=316; learning_rate=0.0436; num_iterations=1158; early_stopping_rounds=324; feature_fraction=0.937 : y = 0.912 : 107.6 secs : initdesign
#
# [mbo] 0: num_leaves=5294; min_data_in_leaf=6744; lambda_l2=898; learning_rate=0.0747; num_iterations=2766; early_stopping_rounds=243; feature_fraction=0.267 : y = 0.917 : 310.4 secs : initdesign
#
# [mbo] 0: num_leaves=3757; min_data_in_leaf=6398; lambda_l2=155; learning_rate=0.0388; num_iterations=4747; early_stopping_rounds=428; feature_fraction=0.233 : y = 0.922 : 519.9 secs : initdesign
#
# [mbo] 0: num_leaves=7421; min_data_in_leaf=2330; lambda_l2=226; learning_rate=0.0174; num_iterations=191; early_stopping_rounds=398; feature_fraction=0.423 : y = 0.899 : 26.9 secs : initdesign
#
# [mbo] 0: num_leaves=1872; min_data_in_leaf=7448; lambda_l2=123; learning_rate=0.0112; num_iterations=1055; early_stopping_rounds=128; feature_fraction=0.295 : y = 0.91 : 119.2 secs : initdesign
#
# [mbo] 0: num_leaves=2852; min_data_in_leaf=6685; lambda_l2=824; learning_rate=0.0646; num_iterations=4227; early_stopping_rounds=411; feature_fraction=0.984 : y = 0.916 : 278.5 secs : initdesign
#
# [mbo] 0: num_leaves=7305; min_data_in_leaf=7049; lambda_l2=33.1; learning_rate=0.0819; num_iterations=2007; early_stopping_rounds=307; feature_fraction=0.799 : y = 0.922 : 215.6 secs : initdesign
#
# [mbo] 0: num_leaves=358; min_data_in_leaf=1884; lambda_l2=353; learning_rate=0.0783; num_iterations=667; early_stopping_rounds=499; feature_fraction=0.11 : y = 0.915 : 57.3 secs : initdesign
#
# [mbo] 0: num_leaves=4237; min_data_in_leaf=1133; lambda_l2=785; learning_rate=0.0506; num_iterations=3730; early_stopping_rounds=83; feature_fraction=0.518 : y = 0.919 : 403.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Sat Nov 22 03:40:35 PM 2025 AUC 0.931705732705485
#
# [mbo] 1: num_leaves=4601; min_data_in_leaf=32; lambda_l2=3.66; learning_rate=0.0867; num_iterations=2578; early_stopping_rounds=335; feature_fraction=0.318 : y = 0.932 : 85.4 secs : infill_ei
#
# Sat Nov 22 03:43:13 PM 2025 AUC 0.931538637563927
#
# [mbo] 2: num_leaves=2045; min_data_in_leaf=173; lambda_l2=60.8; learning_rate=0.0933; num_iterations=3239; early_stopping_rounds=312; feature_fraction=0.174 : y = 0.932 : 157.6 secs : infill_ei
#
# Sat Nov 22 03:45:43 PM 2025 AUC 0.926307351716483
#
# [mbo] 3: num_leaves=3385; min_data_in_leaf=4; lambda_l2=8.38; learning_rate=0.0977; num_iterations=3338; early_stopping_rounds=266; feature_fraction=0.596 : y = 0.926 : 149.6 secs : infill_ei
#
# Sat Nov 22 03:48:08 PM 2025 AUC 0.93090582343345
#
# [mbo] 4: num_leaves=4477; min_data_in_leaf=97; lambda_l2=1.14; learning_rate=0.0807; num_iterations=3064; early_stopping_rounds=356; feature_fraction=0.0502 : y = 0.931 : 144.1 secs : infill_ei
#
# Sat Nov 22 03:54:49 PM 2025 AUC 0.931046747046811
#
# [mbo] 5: num_leaves=3842; min_data_in_leaf=3; lambda_l2=97.5; learning_rate=0.0868; num_iterations=2885; early_stopping_rounds=340; feature_fraction=0.236 : y = 0.931 : 400.7 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Sat Nov 22 03:56:41 PM 2025 AUC 0.939044833169929
#
# [mbo] 6: num_leaves=994; min_data_in_leaf=73; lambda_l2=1.32; learning_rate=0.0943; num_iterations=2554; early_stopping_rounds=317; feature_fraction=0.106 : y = 0.939 : 110.8 secs : infill_ei
#
# Sat Nov 22 03:58:23 PM 2025 AUC 0.934507763884499
#
# [mbo] 7: num_leaves=570; min_data_in_leaf=2; lambda_l2=0.189; learning_rate=0.0701; num_iterations=2184; early_stopping_rounds=243; feature_fraction=0.0584 : y = 0.935 : 101.3 secs : infill_ei
#
# Sat Nov 22 04:01:24 PM 2025 AUC 0.929132199099565
#
# [mbo] 8: num_leaves=2481; min_data_in_leaf=508; lambda_l2=56.3; learning_rate=0.0995; num_iterations=2268; early_stopping_rounds=485; feature_fraction=0.0522 : y = 0.929 : 180.3 secs : infill_ei
#
# Sat Nov 22 04:02:46 PM 2025 AUC 0.914168627853619
#
# [mbo] 9: num_leaves=5; min_data_in_leaf=22; lambda_l2=5.51; learning_rate=0.0967; num_iterations=2577; early_stopping_rounds=257; feature_fraction=0.569 : y = 0.914 : 81.6 secs : infill_ei
#
# Sat Nov 22 04:04:19 PM 2025 AUC 0.931015878064837
#
# [mbo] 10: num_leaves=810; min_data_in_leaf=127; lambda_l2=0.108; learning_rate=0.0984; num_iterations=4275; early_stopping_rounds=249; feature_fraction=0.0507 : y = 0.931 : 92.3 secs : infill_ei
#
# Sat Nov 22 04:06:03 PM 2025 AUC 0.935522749433118
#
# [mbo] 11: num_leaves=2167; min_data_in_leaf=12; lambda_l2=3.39; learning_rate=0.0988; num_iterations=2541; early_stopping_rounds=166; feature_fraction=0.0983 : y = 0.936 : 103.7 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Sat Nov 22 04:09:47 PM 2025 AUC 0.934009498251541
#
# [mbo] 12: num_leaves=6003; min_data_in_leaf=197; lambda_l2=17.9; learning_rate=0.0526; num_iterations=3788; early_stopping_rounds=496; feature_fraction=0.5 : y = 0.934 : 222.8 secs : infill_ei
#
# Sat Nov 22 04:11:14 PM 2025 AUC 0.925289346376149
#
# [mbo] 13: num_leaves=36; min_data_in_leaf=5361; lambda_l2=0.748; learning_rate=0.0969; num_iterations=2551; early_stopping_rounds=333; feature_fraction=0.0974 : y = 0.925 : 87.0 secs : infill_ei
#
# Sat Nov 22 04:14:30 PM 2025 AUC 0.930679339054832
#
# [mbo] 14: num_leaves=4582; min_data_in_leaf=14; lambda_l2=1.85; learning_rate=0.0745; num_iterations=4797; early_stopping_rounds=488; feature_fraction=0.489 : y = 0.931 : 194.9 secs : infill_ei
#
# Sat Nov 22 04:17:29 PM 2025 AUC 0.935169433802475
#
# [mbo] 15: num_leaves=5292; min_data_in_leaf=80; lambda_l2=3.63e-05; learning_rate=0.0437; num_iterations=4844; early_stopping_rounds=402; feature_fraction=0.609 : y = 0.935 : 178.5 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Sat Nov 22 04:35:46 PM 2025 AUC 0.93088770468316
#
# [mbo] 16: num_leaves=7122; min_data_in_leaf=27; lambda_l2=54.6; learning_rate=0.0168; num_iterations=4998; early_stopping_rounds=495; feature_fraction=0.484 : y = 0.931 : 1096.7 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Sat Nov 22 04:37:37 PM 2025 AUC 0.93057968592824
#
# [mbo] 17: num_leaves=1243; min_data_in_leaf=1525; lambda_l2=2.55; learning_rate=0.0818; num_iterations=2241; early_stopping_rounds=228; feature_fraction=0.05 : y = 0.931 : 110.4 secs : infill_ei
#
# Sat Nov 22 04:40:23 PM 2025 AUC 0.931757404697051
#
# [mbo] 18: num_leaves=8145; min_data_in_leaf=6; lambda_l2=0.691; learning_rate=0.0624; num_iterations=3940; early_stopping_rounds=495; feature_fraction=0.644 : y = 0.932 : 165.5 secs : infill_ei
#
# Sat Nov 22 04:43:48 PM 2025 AUC 0.932373442206891
#
# [mbo] 19: num_leaves=80; min_data_in_leaf=3; lambda_l2=2.16; learning_rate=0.0532; num_iterations=3010; early_stopping_rounds=449; feature_fraction=0.102 : y = 0.932 : 204.3 secs : infill_ei
#
# Sat Nov 22 04:51:05 PM 2025 AUC 0.932250637343818
#
# [mbo] 20: num_leaves=3419; min_data_in_leaf=108; lambda_l2=11.6; learning_rate=0.0105; num_iterations=4502; early_stopping_rounds=498; feature_fraction=0.605 : y = 0.932 : 436.1 secs : infill_ei
#
# Saved the current state after iteration 21 in the file HT.RDATA.
#
# Sat Nov 22 04:54:46 PM 2025 AUC 0.935887473165795
#
# [mbo] 21: num_leaves=5715; min_data_in_leaf=74; lambda_l2=2.64; learning_rate=0.0241; num_iterations=3941; early_stopping_rounds=485; feature_fraction=0.663 : y = 0.936 : 219.8 secs : infill_ei
#
# Sat Nov 22 04:55:58 PM 2025 AUC 0.932415383758486
#
# [mbo] 22: num_leaves=7256; min_data_in_leaf=7; lambda_l2=16.3; learning_rate=0.0997; num_iterations=2892; early_stopping_rounds=61; feature_fraction=0.097 : y = 0.932 : 71.5 secs : infill_ei
#
# Sat Nov 22 05:01:32 PM 2025 AUC 0.928946649675305
#
# [mbo] 23: num_leaves=5731; min_data_in_leaf=5732; lambda_l2=0.591; learning_rate=0.0379; num_iterations=3917; early_stopping_rounds=498; feature_fraction=0.612 : y = 0.929 : 333.5 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Sat Nov 22 05:03:38 PM 2025 AUC 0.932920695572113
#
# [mbo] 24: num_leaves=6501; min_data_in_leaf=9; lambda_l2=4.51; learning_rate=0.0175; num_iterations=4884; early_stopping_rounds=61; feature_fraction=0.127 : y = 0.933 : 125.9 secs : infill_ei
#
# Sat Nov 22 05:06:25 PM 2025 AUC 0.91837771420557
#
# [mbo] 25: num_leaves=21; min_data_in_leaf=12; lambda_l2=828; learning_rate=0.0977; num_iterations=2550; early_stopping_rounds=321; feature_fraction=0.0754 : y = 0.918 : 166.2 secs : infill_ei
#
# Sat Nov 22 05:09:06 PM 2025 AUC 0.927897104288171
#
# [mbo] 26: num_leaves=5685; min_data_in_leaf=773; lambda_l2=1.17; learning_rate=0.0971; num_iterations=3698; early_stopping_rounds=500; feature_fraction=0.738 : y = 0.928 : 160.7 secs : infill_ei
#
# Sat Nov 22 05:27:41 PM 2025 AUC 0.923002692983145
#
# [mbo] 27: num_leaves=4935; min_data_in_leaf=14; lambda_l2=997; learning_rate=0.0447; num_iterations=4993; early_stopping_rounds=498; feature_fraction=0.602 : y = 0.923 : 1114.1 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Sat Nov 22 05:28:37 PM 2025 AUC 0.938384840914017
#
# [mbo] 28: num_leaves=423; min_data_in_leaf=105; lambda_l2=0.395; learning_rate=0.0316; num_iterations=4097; early_stopping_rounds=50; feature_fraction=0.108 : y = 0.938 : 55.2 secs : infill_ei
#
# Sat Nov 22 05:29:44 PM 2025 AUC 0.934479914694239
#
# [mbo] 29: num_leaves=856; min_data_in_leaf=8; lambda_l2=0.959; learning_rate=0.044; num_iterations=4895; early_stopping_rounds=50; feature_fraction=0.108 : y = 0.934 : 66.0 secs : infill_ei
#
# Sat Nov 22 05:31:36 PM 2025 AUC 0.935502617488352
#
# [mbo] 30: num_leaves=703; min_data_in_leaf=40; lambda_l2=0.661; learning_rate=0.0111; num_iterations=3691; early_stopping_rounds=52; feature_fraction=0.12 : y = 0.936 : 111.7 secs : infill_ei
#
# Sat Nov 22 05:32:20 PM 2025 AUC 0.92973313765083
#
# [mbo] 31: num_leaves=708; min_data_in_leaf=38; lambda_l2=15.5; learning_rate=0.0633; num_iterations=3621; early_stopping_rounds=52; feature_fraction=0.127 : y = 0.93 : 42.9 secs : infill_ei
#
# Sat Nov 22 05:40:35 PM 2025 AUC 0.938173119961561
#
# [mbo] 32: num_leaves=2425; min_data_in_leaf=293; lambda_l2=1.38; learning_rate=0.0125; num_iterations=4118; early_stopping_rounds=261; feature_fraction=0.135 : y = 0.938 : 495.0 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Sat Nov 22 05:44:09 PM 2025 AUC 0.935454636353326
#
# [mbo] 33: num_leaves=983; min_data_in_leaf=207; lambda_l2=0.277; learning_rate=0.0253; num_iterations=4192; early_stopping_rounds=283; feature_fraction=0.103 : y = 0.935 : 212.8 secs : infill_ei
#
# Sat Nov 22 05:46:52 PM 2025 AUC 0.934875842941304
#
# [mbo] 34: num_leaves=2145; min_data_in_leaf=134; lambda_l2=0.97; learning_rate=0.011; num_iterations=4185; early_stopping_rounds=108; feature_fraction=0.166 : y = 0.935 : 162.0 secs : infill_ei
#
# Sat Nov 22 05:50:52 PM 2025 AUC 0.9372148393907
#
# [mbo] 35: num_leaves=5101; min_data_in_leaf=117; lambda_l2=0.525; learning_rate=0.0235; num_iterations=2840; early_stopping_rounds=304; feature_fraction=0.165 : y = 0.937 : 239.8 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Sat Nov 22 05:57:12 PM 2025 AUC 0.938811973675469
#
# [mbo] 36: num_leaves=2613; min_data_in_leaf=13; lambda_l2=0.093; learning_rate=0.00936; num_iterations=2627; early_stopping_rounds=301; feature_fraction=0.117 : y = 0.939 : 379.5 secs : infill_ei
#
# Sat Nov 22 06:07:19 PM 2025 AUC 0.935956592842825
#
# [mbo] 37: num_leaves=6000; min_data_in_leaf=8; lambda_l2=6.79; learning_rate=0.0073; num_iterations=4048; early_stopping_rounds=266; feature_fraction=0.119 : y = 0.936 : 605.5 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Sat Nov 22 06:09:25 PM 2025 AUC 0.926063755184815
#
# [mbo] 38: num_leaves=2085; min_data_in_leaf=1224; lambda_l2=3.23; learning_rate=0.00889; num_iterations=4138; early_stopping_rounds=50; feature_fraction=0.0513 : y = 0.926 : 125.3 secs : infill_ei
#
# Sat Nov 22 06:12:59 PM 2025 AUC 0.938046624241948
#
# [mbo] 39: num_leaves=3322; min_data_in_leaf=12; lambda_l2=0.0755; learning_rate=0.0327; num_iterations=2731; early_stopping_rounds=157; feature_fraction=0.123 : y = 0.938 : 213.6 secs : infill_ei
#
# Sat Nov 22 06:16:39 PM 2025 AUC 0.937527555599398
#
# [mbo] 40: num_leaves=1911; min_data_in_leaf=3; lambda_l2=0.522; learning_rate=0.0279; num_iterations=2757; early_stopping_rounds=252; feature_fraction=0.131 : y = 0.938 : 218.5 secs : infill_ei
#
# Sat Nov 22 06:22:53 PM 2025 AUC 0.935069109611057
#
# [mbo] 41: num_leaves=3557; min_data_in_leaf=10; lambda_l2=4.2; learning_rate=0.0141; num_iterations=3609; early_stopping_rounds=303; feature_fraction=0.141 : y = 0.935 : 373.4 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Sat Nov 22 06:27:03 PM 2025 AUC 0.928122246537138
#
# [mbo] 42: num_leaves=3476; min_data_in_leaf=365; lambda_l2=18.3; learning_rate=0.00806; num_iterations=2365; early_stopping_rounds=279; feature_fraction=0.113 : y = 0.928 : 248.4 secs : infill_ei
#
# Sat Nov 22 06:29:06 PM 2025 AUC 0.938997523099729
#
# [mbo] 43: num_leaves=2015; min_data_in_leaf=80; lambda_l2=1.14; learning_rate=0.0347; num_iterations=3987; early_stopping_rounds=326; feature_fraction=0.283 : y = 0.939 : 121.9 secs : infill_ei
#
# Sat Nov 22 06:34:34 PM 2025 AUC 0.93723664899753
#
# [mbo] 44: num_leaves=2601; min_data_in_leaf=15; lambda_l2=2.27; learning_rate=0.01; num_iterations=4357; early_stopping_rounds=349; feature_fraction=0.294 : y = 0.937 : 327.2 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Sat Nov 22 06:36:58 PM 2025 AUC 0.933694433315953
#
# [mbo] 45: num_leaves=5322; min_data_in_leaf=7; lambda_l2=0.198; learning_rate=0.036; num_iterations=3897; early_stopping_rounds=238; feature_fraction=0.212 : y = 0.934 : 142.4 secs : infill_ei
#
# Sat Nov 22 06:38:50 PM 2025 AUC 0.933251866063514
#
# [mbo] 46: num_leaves=6258; min_data_in_leaf=1289; lambda_l2=0.0177; learning_rate=0.0721; num_iterations=2159; early_stopping_rounds=324; feature_fraction=0.119 : y = 0.933 : 111.4 secs : infill_ei
#
# Sat Nov 22 06:41:51 PM 2025 AUC 0.934035334247324
#
# [mbo] 47: num_leaves=2679; min_data_in_leaf=2; lambda_l2=0.975; learning_rate=0.0356; num_iterations=3416; early_stopping_rounds=462; feature_fraction=0.432 : y = 0.934 : 180.6 secs : infill_ei
#
# Sat Nov 22 06:42:43 PM 2025 AUC 0.93314717995073
#
# [mbo] 48: num_leaves=257; min_data_in_leaf=21; lambda_l2=0.485; learning_rate=0.034; num_iterations=784; early_stopping_rounds=56; feature_fraction=0.175 : y = 0.933 : 50.8 secs : infill_ei
#
# Sat Nov 22 06:53:49 PM 2025 AUC 0.9360663119418
#
# [mbo] 49: num_leaves=1940; min_data_in_leaf=325; lambda_l2=3.7; learning_rate=0.00529; num_iterations=3961; early_stopping_rounds=377; feature_fraction=0.326 : y = 0.936 : 665.4 secs : infill_ei
#
# Saved the current state after iteration 50 in the file HT.RDATA.
#
# Sat Nov 22 07:03:41 PM 2025 AUC 0.930686049703087
#
# [mbo] 50: num_leaves=6840; min_data_in_leaf=88; lambda_l2=49.5; learning_rate=0.0163; num_iterations=4003; early_stopping_rounds=321; feature_fraction=0.366 : y = 0.931 : 590.7 secs : infill_ei
#
# Sat Nov 22 07:05:57 PM 2025 AUC 0.929997201659677
#
# [mbo] 51: num_leaves=3637; min_data_in_leaf=606; lambda_l2=0.0603; learning_rate=0.0793; num_iterations=4083; early_stopping_rounds=399; feature_fraction=0.27 : y = 0.93 : 134.7 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Sat Nov 22 07:12:54 PM 2025 AUC 0.935006029517457
#
# [mbo] 52: num_leaves=6336; min_data_in_leaf=791; lambda_l2=0.681; learning_rate=0.0175; num_iterations=3894; early_stopping_rounds=349; feature_fraction=0.498 : y = 0.935 : 416.1 secs : infill_ei
#
# Sat Nov 22 07:20:13 PM 2025 AUC 0.929717032095017
#
# [mbo] 53: num_leaves=6587; min_data_in_leaf=44; lambda_l2=17.2; learning_rate=0.0154; num_iterations=4869; early_stopping_rounds=322; feature_fraction=0.631 : y = 0.93 : 439.0 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Sat Nov 22 07:23:01 PM 2025 AUC 0.930837039288832
#
# [mbo] 54: num_leaves=4486; min_data_in_leaf=207; lambda_l2=21.1; learning_rate=0.0536; num_iterations=4041; early_stopping_rounds=378; feature_fraction=0.59 : y = 0.931 : 166.9 secs : infill_ei
#
# Sat Nov 22 07:25:59 PM 2025 AUC 0.932617038738559
#
# [mbo] 55: num_leaves=8142; min_data_in_leaf=873; lambda_l2=0.134; learning_rate=0.0874; num_iterations=4878; early_stopping_rounds=470; feature_fraction=0.0585 : y = 0.933 : 177.1 secs : infill_ei
#
# Sat Nov 22 07:27:52 PM 2025 AUC 0.935319081258569
#
# [mbo] 56: num_leaves=6213; min_data_in_leaf=8; lambda_l2=0.483; learning_rate=0.0615; num_iterations=2699; early_stopping_rounds=159; feature_fraction=0.124 : y = 0.935 : 112.6 secs : infill_ei
#
# Sat Nov 22 07:35:22 PM 2025 AUC 0.93499059502647
#
# [mbo] 57: num_leaves=5484; min_data_in_leaf=516; lambda_l2=1.66; learning_rate=0.0158; num_iterations=4840; early_stopping_rounds=463; feature_fraction=0.406 : y = 0.935 : 448.3 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Sat Nov 22 07:38:59 PM 2025 AUC 0.937000769711355
#
# [mbo] 58: num_leaves=6540; min_data_in_leaf=266; lambda_l2=2.19; learning_rate=0.0282; num_iterations=3108; early_stopping_rounds=436; feature_fraction=0.148 : y = 0.937 : 217.0 secs : infill_ei
#
# Sat Nov 22 07:42:29 PM 2025 AUC 0.933483718960735
#
# [mbo] 59: num_leaves=5333; min_data_in_leaf=305; lambda_l2=1.23; learning_rate=0.00764; num_iterations=947; early_stopping_rounds=437; feature_fraction=0.516 : y = 0.933 : 208.2 secs : infill_ei
#
# Sat Nov 22 07:44:33 PM 2025 AUC 0.92916071935465
#
# [mbo] 60: num_leaves=1772; min_data_in_leaf=406; lambda_l2=0.0802; learning_rate=0.0944; num_iterations=1629; early_stopping_rounds=470; feature_fraction=0.132 : y = 0.929 : 123.8 secs : infill_ei
#
# Sat Nov 22 07:48:15 PM 2025 AUC 0.934322549992652
#
# [mbo] 61: num_leaves=7553; min_data_in_leaf=135; lambda_l2=2.41; learning_rate=0.0216; num_iterations=2818; early_stopping_rounds=322; feature_fraction=0.154 : y = 0.934 : 220.8 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Sat Nov 22 07:50:21 PM 2025 AUC 0.931985902270145
#
# [mbo] 62: num_leaves=6194; min_data_in_leaf=623; lambda_l2=0.4; learning_rate=0.0119; num_iterations=2749; early_stopping_rounds=199; feature_fraction=0.11 : y = 0.932 : 125.0 secs : infill_ei
#
# Sat Nov 22 07:52:51 PM 2025 AUC 0.936152879304294
#
# [mbo] 63: num_leaves=1282; min_data_in_leaf=16; lambda_l2=0.141; learning_rate=0.0406; num_iterations=1263; early_stopping_rounds=330; feature_fraction=0.145 : y = 0.936 : 148.5 secs : infill_ei
#
# Sat Nov 22 07:56:03 PM 2025 AUC 0.930434735925925
#
# [mbo] 64: num_leaves=7202; min_data_in_leaf=439; lambda_l2=44.2; learning_rate=0.0723; num_iterations=4468; early_stopping_rounds=427; feature_fraction=0.125 : y = 0.93 : 191.5 secs : infill_ei
#
# Sat Nov 22 07:59:37 PM 2025 AUC 0.935218421534739
#
# [mbo] 65: num_leaves=5512; min_data_in_leaf=2; lambda_l2=4.22; learning_rate=0.0383; num_iterations=1367; early_stopping_rounds=271; feature_fraction=0.303 : y = 0.935 : 213.0 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Sat Nov 22 08:02:22 PM 2025 AUC 0.936137780345719
#
# [mbo] 66: num_leaves=5887; min_data_in_leaf=2; lambda_l2=2.61; learning_rate=0.0308; num_iterations=3156; early_stopping_rounds=356; feature_fraction=0.266 : y = 0.936 : 163.9 secs : infill_ei
#
# Sat Nov 22 08:05:51 PM 2025 AUC 0.934616476386235
#
# [mbo] 67: num_leaves=7111; min_data_in_leaf=17; lambda_l2=4.98; learning_rate=0.0448; num_iterations=2812; early_stopping_rounds=464; feature_fraction=0.416 : y = 0.935 : 208.3 secs : infill_ei
#
# Sat Nov 22 08:08:51 PM 2025 AUC 0.93433328702986
#
# [mbo] 68: num_leaves=8182; min_data_in_leaf=12; lambda_l2=6.07; learning_rate=0.0828; num_iterations=1863; early_stopping_rounds=472; feature_fraction=0.0521 : y = 0.934 : 178.9 secs : infill_ei
#
# Sat Nov 22 08:10:41 PM 2025 AUC 0.933130403330092
#
# [mbo] 69: num_leaves=1077; min_data_in_leaf=119; lambda_l2=0.107; learning_rate=0.0976; num_iterations=2698; early_stopping_rounds=153; feature_fraction=0.172 : y = 0.933 : 109.6 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Sat Nov 22 08:12:17 PM 2025 AUC 0.909634075061285
#
# [mbo] 70: num_leaves=4; min_data_in_leaf=17; lambda_l2=0.285; learning_rate=0.0149; num_iterations=4828; early_stopping_rounds=155; feature_fraction=0.169 : y = 0.91 : 95.0 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf lambda_l2 learning_rate num_iterations
#         <int>            <int>     <num>         <num>          <int>
# 1:        994               73  1.318956    0.09428464           2554
#    early_stopping_rounds feature_fraction
#                    <int>            <num>
# 1:                   317        0.1062743

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5785200
#
# $envios
# [1] 1625

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_290219434
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Sat Nov 22 08:20:25 PM 2025"
# Inicio: Sat Nov 22 01:21:02 PM 2025
# Fin:    Sat Nov 22 08:20:25 PM 2025
# Duración (hh:mm:ss): 06:59:23
