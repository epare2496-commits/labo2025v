# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_16H_111_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 18 12:42:47 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660356 35.3 1454485    77.7 1454485  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 100009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63111
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),   # filas
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 18 01:00:49 AM 2025 AUC 0.921968917619411
#
# Tue Nov 18 01:04:27 AM 2025 AUC 0.925609444297929
#
# Tue Nov 18 01:09:06 AM 2025 AUC 0.923032890900294
#
# Tue Nov 18 01:11:06 AM 2025 AUC 0.921206252445192
#
# Tue Nov 18 01:13:27 AM 2025 AUC 0.92574063747132
#
# Tue Nov 18 01:15:13 AM 2025 AUC 0.921234437167865
#
# Tue Nov 18 01:15:56 AM 2025 AUC 0.913876882420719
#
# Tue Nov 18 01:18:30 AM 2025 AUC 0.925572535732524
#
# Tue Nov 18 01:20:19 AM 2025 AUC 0.917644240351262
#
# Tue Nov 18 01:23:10 AM 2025 AUC 0.92794307222872
#
# Tue Nov 18 01:24:38 AM 2025 AUC 0.920107048260969
#
# Tue Nov 18 01:28:01 AM 2025 AUC 0.923202670301154
#
# Tue Nov 18 01:30:07 AM 2025 AUC 0.921953818660836
#
# Tue Nov 18 01:30:58 AM 2025 AUC 0.914595257316452
#
# Tue Nov 18 01:32:38 AM 2025 AUC 0.916955392307852
#
# Tue Nov 18 01:35:44 AM 2025 AUC 0.923324133034575
#
# Tue Nov 18 01:41:27 AM 2025 AUC 0.918503538860357
#
# Tue Nov 18 01:47:06 AM 2025 AUC 0.9281843200335
#
# Tue Nov 18 01:50:30 AM 2025 AUC 0.920952254408728
#
# Tue Nov 18 01:52:49 AM 2025 AUC 0.918488439901783
#
# Tue Nov 18 01:54:26 AM 2025 AUC 0.916148436855149
#
# Tue Nov 18 01:55:04 AM 2025 AUC 0.920026856014318
#
# Tue Nov 18 01:56:28 AM 2025 AUC 0.914142288559217
#
# Tue Nov 18 01:57:54 AM 2025 AUC 0.919799365038462
#
# Tue Nov 18 01:58:21 AM 2025 AUC 0.913508467831501
#
# Tue Nov 18 01:58:43 AM 2025 AUC 0.912741776268329
#
# Tue Nov 18 02:01:17 AM 2025 AUC 0.928900681734756
#
# Tue Nov 18 02:04:57 AM 2025 AUC 0.926039932383508
#
# Tue Nov 18 02:10:12 AM 2025 AUC 0.920363730556735
#
# Tue Nov 18 02:11:44 AM 2025 AUC 0.915238808484138
#
# Tue Nov 18 02:15:27 AM 2025 AUC 0.922317871328688
#
# Tue Nov 18 02:16:35 AM 2025 AUC 0.922263850610233
#
# Tue Nov 18 02:18:27 AM 2025 AUC 0.927293817010017
#
# Tue Nov 18 02:22:10 AM 2025 AUC 0.920806633341587
#
# Tue Nov 18 02:22:59 AM 2025 AUC 0.90946731545214
#
# Tue Nov 18 02:24:25 AM 2025 AUC 0.920624439241455
#
# Tue Nov 18 02:25:46 AM 2025 AUC 0.921090493762788
#
# Tue Nov 18 02:27:55 AM 2025 AUC 0.924626334328522
#
# Tue Nov 18 02:28:50 AM 2025 AUC 0.903547517093699
#
# Tue Nov 18 02:30:26 AM 2025 AUC 0.926906612605684
#
# Tue Nov 18 02:31:51 AM 2025 AUC 0.924335427726654
#
# Tue Nov 18 02:33:20 AM 2025 AUC 0.879220578337088
#
# Tue Nov 18 02:34:02 AM 2025 AUC 0.919353106929482
#
# Tue Nov 18 02:35:04 AM 2025 AUC 0.918173710498608
#
# Tue Nov 18 02:38:26 AM 2025 AUC 0.927650487964788
#
# Tue Nov 18 02:41:57 AM 2025 AUC 0.919412496166542
#
# Tue Nov 18 02:42:42 AM 2025 AUC 0.918667949742613
#
# Tue Nov 18 02:43:10 AM 2025 AUC 0.917148323445193
#
# Tue Nov 18 02:44:55 AM 2025 AUC 0.915220354201436
#
# Tue Nov 18 02:45:22 AM 2025 AUC 0.923600947275108
#
# Tue Nov 18 02:47:25 AM 2025 AUC 0.925751710040942
#
# Tue Nov 18 02:50:27 AM 2025 AUC 0.910816491283875
#
# Tue Nov 18 02:55:28 AM 2025 AUC 0.913660128482071
#
# Tue Nov 18 02:55:46 AM 2025 AUC 0.912487442699452
#
# Tue Nov 18 02:58:00 AM 2025 AUC 0.920966011237652
#
# Tue Nov 18 02:58:22 AM 2025 AUC 0.903010665233272
#
# Tue Nov 18 02:58:46 AM 2025 AUC 0.90793560998786
#
# Tue Nov 18 03:00:23 AM 2025 AUC 0.920863002786932
#
# Tue Nov 18 03:01:23 AM 2025 AUC 0.914674107433452
#
# Tue Nov 18 03:02:28 AM 2025 AUC 0.919067233313805
#
# Tue Nov 18 03:06:37 AM 2025 AUC 0.923524110352584
#
# Tue Nov 18 03:08:57 AM 2025 AUC 0.925252773343158
#
# Tue Nov 18 03:15:56 AM 2025 AUC 0.918963218265848
#
# Tue Nov 18 03:16:39 AM 2025 AUC 0.917902935841505
#
# [mbo] 0: num_leaves=50; max_depth=13; min_child_weight=4.88; min_data_in_leaf=3507; min_gain_to_split=0.0486; lambda_l1=0.183; lambda_l2=0.269; scale_pos_weight=3.28; learning_rate=0.0666; num_iterations=2780; early_stopping_rounds=297; feature_fraction=0.548; bagging_fraction=0.736; bagging_freq=2; max_delta_step=5.12; path_smooth=6.86 : y = 0.922 : 156.6 secs : initdesign
#
# [mbo] 0: num_leaves=30; max_depth=19; min_child_weight=5.06; min_data_in_leaf=4203; min_gain_to_split=0.0361; lambda_l1=0.329; lambda_l2=0.322; scale_pos_weight=2.53; learning_rate=0.0372; num_iterations=1453; early_stopping_rounds=429; feature_fraction=0.599; bagging_fraction=0.747; bagging_freq=1; max_delta_step=6.48; path_smooth=3.4 : y = 0.926 : 218.3 secs : initdesign
#
# [mbo] 0: num_leaves=54; max_depth=13; min_child_weight=6.87; min_data_in_leaf=3859; min_gain_to_split=0.0851; lambda_l1=0.391; lambda_l2=0.259; scale_pos_weight=2.23; learning_rate=0.0711; num_iterations=2504; early_stopping_rounds=257; feature_fraction=0.53; bagging_fraction=0.668; bagging_freq=4; max_delta_step=4.18; path_smooth=4.49 : y = 0.923 : 278.4 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=12; min_child_weight=4.39; min_data_in_leaf=4997; min_gain_to_split=0.0538; lambda_l1=0.367; lambda_l2=0.421; scale_pos_weight=1.94; learning_rate=0.0504; num_iterations=2437; early_stopping_rounds=291; feature_fraction=0.659; bagging_fraction=0.705; bagging_freq=3; max_delta_step=0.954; path_smooth=6.88 : y = 0.921 : 120.5 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=12; min_child_weight=8.38; min_data_in_leaf=184; min_gain_to_split=0.0511; lambda_l1=0.291; lambda_l2=0.118; scale_pos_weight=4.48; learning_rate=0.0512; num_iterations=3725; early_stopping_rounds=262; feature_fraction=0.58; bagging_fraction=0.698; bagging_freq=1; max_delta_step=6.32; path_smooth=6.32 : y = 0.926 : 141.0 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=15; min_child_weight=3.81; min_data_in_leaf=7057; min_gain_to_split=0.068; lambda_l1=0.0668; lambda_l2=0.209; scale_pos_weight=3.41; learning_rate=0.0682; num_iterations=1084; early_stopping_rounds=224; feature_fraction=0.572; bagging_fraction=0.635; bagging_freq=2; max_delta_step=4.75; path_smooth=6.43 : y = 0.921 : 105.7 secs : initdesign
#
# [mbo] 0: num_leaves=14; max_depth=16; min_child_weight=7.24; min_data_in_leaf=4438; min_gain_to_split=0.0597; lambda_l1=0.364; lambda_l2=0.283; scale_pos_weight=4.26; learning_rate=0.0594; num_iterations=2301; early_stopping_rounds=96; feature_fraction=0.468; bagging_fraction=0.69; bagging_freq=5; max_delta_step=6.62; path_smooth=1.72 : y = 0.914 : 42.8 secs : initdesign
#
# [mbo] 0: num_leaves=29; max_depth=10; min_child_weight=2.37; min_data_in_leaf=2030; min_gain_to_split=0.0632; lambda_l1=0.171; lambda_l2=0.411; scale_pos_weight=2.29; learning_rate=0.0781; num_iterations=2898; early_stopping_rounds=352; feature_fraction=0.399; bagging_fraction=0.638; bagging_freq=2; max_delta_step=8.78; path_smooth=8.07 : y = 0.926 : 153.8 secs : initdesign
#
# [mbo] 0: num_leaves=13; max_depth=4; min_child_weight=5.47; min_data_in_leaf=6673; min_gain_to_split=0.00257; lambda_l1=0.477; lambda_l2=0.127; scale_pos_weight=3.75; learning_rate=0.0307; num_iterations=3917; early_stopping_rounds=187; feature_fraction=0.355; bagging_fraction=0.775; bagging_freq=4; max_delta_step=4.4; path_smooth=8.69 : y = 0.918 : 109.3 secs : initdesign
#
# [mbo] 0: num_leaves=39; max_depth=21; min_child_weight=3.59; min_data_in_leaf=6104; min_gain_to_split=0.0279; lambda_l1=0.311; lambda_l2=0.179; scale_pos_weight=4.03; learning_rate=0.0444; num_iterations=3653; early_stopping_rounds=395; feature_fraction=0.677; bagging_fraction=0.835; bagging_freq=2; max_delta_step=5.62; path_smooth=4.91 : y = 0.928 : 171.1 secs : initdesign
#
# [mbo] 0: num_leaves=43; max_depth=23; min_child_weight=7.92; min_data_in_leaf=1694; min_gain_to_split=0.0225; lambda_l1=0.381; lambda_l2=0.184; scale_pos_weight=2.8; learning_rate=0.0652; num_iterations=4242; early_stopping_rounds=289; feature_fraction=0.71; bagging_fraction=0.6; bagging_freq=2; max_delta_step=1.33; path_smooth=4.04 : y = 0.92 : 87.9 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=26; min_child_weight=4.69; min_data_in_leaf=4879; min_gain_to_split=0.0123; lambda_l1=0.446; lambda_l2=0.5; scale_pos_weight=1.42; learning_rate=0.0742; num_iterations=1288; early_stopping_rounds=449; feature_fraction=0.535; bagging_fraction=0.581; bagging_freq=1; max_delta_step=5.67; path_smooth=6.17 : y = 0.923 : 203.0 secs : initdesign
#
# [mbo] 0: num_leaves=22; max_depth=21; min_child_weight=7.16; min_data_in_leaf=6231; min_gain_to_split=0.041; lambda_l1=0.143; lambda_l2=0.245; scale_pos_weight=2.59; learning_rate=0.069; num_iterations=836; early_stopping_rounds=340; feature_fraction=0.448; bagging_fraction=0.798; bagging_freq=3; max_delta_step=2.67; path_smooth=0.0705 : y = 0.922 : 126.3 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=27; min_child_weight=2.8; min_data_in_leaf=2639; min_gain_to_split=0.018; lambda_l1=0.118; lambda_l2=0.475; scale_pos_weight=1.19; learning_rate=0.0539; num_iterations=413; early_stopping_rounds=181; feature_fraction=0.366; bagging_fraction=0.557; bagging_freq=4; max_delta_step=5.34; path_smooth=3.08 : y = 0.915 : 50.5 secs : initdesign
#
# [mbo] 0: num_leaves=20; max_depth=18; min_child_weight=4.6; min_data_in_leaf=6957; min_gain_to_split=0.0216; lambda_l1=0.0757; lambda_l2=0.255; scale_pos_weight=3.7; learning_rate=0.015; num_iterations=1577; early_stopping_rounds=205; feature_fraction=0.791; bagging_fraction=0.67; bagging_freq=3; max_delta_step=7.84; path_smooth=8.34 : y = 0.917 : 100.3 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=12; min_child_weight=1.84; min_data_in_leaf=4810; min_gain_to_split=0.0586; lambda_l1=0.212; lambda_l2=0.0328; scale_pos_weight=2.32; learning_rate=0.0201; num_iterations=1914; early_stopping_rounds=217; feature_fraction=0.459; bagging_fraction=0.878; bagging_freq=2; max_delta_step=7.5; path_smooth=4.72 : y = 0.923 : 186.1 secs : initdesign
#
# [mbo] 0: num_leaves=5; max_depth=24; min_child_weight=1.49; min_data_in_leaf=686; min_gain_to_split=0.0772; lambda_l1=0.27; lambda_l2=0.219; scale_pos_weight=4.22; learning_rate=0.0195; num_iterations=3957; early_stopping_rounds=249; feature_fraction=0.478; bagging_fraction=0.532; bagging_freq=3; max_delta_step=8.71; path_smooth=2.95 : y = 0.919 : 342.9 secs : initdesign
#
# [mbo] 0: num_leaves=44; max_depth=17; min_child_weight=8.72; min_data_in_leaf=2520; min_gain_to_split=0.0654; lambda_l1=0.0904; lambda_l2=0.293; scale_pos_weight=3.56; learning_rate=0.056; num_iterations=2671; early_stopping_rounds=453; feature_fraction=0.492; bagging_fraction=0.847; bagging_freq=3; max_delta_step=0.373; path_smooth=7.96 : y = 0.928 : 338.7 secs : initdesign
#
# [mbo] 0: num_leaves=48; max_depth=23; min_child_weight=3.68; min_data_in_leaf=1534; min_gain_to_split=0.0467; lambda_l1=0.259; lambda_l2=0.0738; scale_pos_weight=1.88; learning_rate=0.091; num_iterations=3176; early_stopping_rounds=368; feature_fraction=0.414; bagging_fraction=0.719; bagging_freq=4; max_delta_step=9.96; path_smooth=2.75 : y = 0.921 : 204.2 secs : initdesign
#
# [mbo] 0: num_leaves=24; max_depth=4; min_child_weight=8.03; min_data_in_leaf=5399; min_gain_to_split=0.0662; lambda_l1=0.439; lambda_l2=0.0922; scale_pos_weight=1.56; learning_rate=0.0232; num_iterations=1135; early_stopping_rounds=408; feature_fraction=0.584; bagging_fraction=0.505; bagging_freq=3; max_delta_step=1.17; path_smooth=2.58 : y = 0.918 : 139.3 secs : initdesign
#
# [mbo] 0: num_leaves=32; max_depth=11; min_child_weight=2.02; min_data_in_leaf=5698; min_gain_to_split=0.0323; lambda_l1=0.152; lambda_l2=0.378; scale_pos_weight=4.43; learning_rate=0.0487; num_iterations=773; early_stopping_rounds=162; feature_fraction=0.507; bagging_fraction=0.515; bagging_freq=1; max_delta_step=1.44; path_smooth=5.35 : y = 0.916 : 96.9 secs : initdesign
#
# [mbo] 0: num_leaves=34; max_depth=24; min_child_weight=5.2; min_data_in_leaf=3676; min_gain_to_split=0.0803; lambda_l1=0.225; lambda_l2=0.00422; scale_pos_weight=3.08; learning_rate=0.0761; num_iterations=3337; early_stopping_rounds=72; feature_fraction=0.772; bagging_fraction=0.683; bagging_freq=1; max_delta_step=2.06; path_smooth=3.84 : y = 0.92 : 38.1 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=18; min_child_weight=4.12; min_data_in_leaf=1197; min_gain_to_split=0.0562; lambda_l1=0.489; lambda_l2=0.309; scale_pos_weight=4.56; learning_rate=0.0422; num_iterations=1537; early_stopping_rounds=114; feature_fraction=0.438; bagging_fraction=0.889; bagging_freq=1; max_delta_step=3.69; path_smooth=1.72 : y = 0.914 : 84.2 secs : initdesign
#
# [mbo] 0: num_leaves=40; max_depth=24; min_child_weight=1.03; min_data_in_leaf=5897; min_gain_to_split=0.0926; lambda_l1=0.0553; lambda_l2=0.349; scale_pos_weight=4.96; learning_rate=0.0278; num_iterations=929; early_stopping_rounds=311; feature_fraction=0.625; bagging_fraction=0.649; bagging_freq=3; max_delta_step=8.5; path_smooth=0.7 : y = 0.92 : 85.8 secs : initdesign
#
# [mbo] 0: num_leaves=41; max_depth=15; min_child_weight=6.37; min_data_in_leaf=4073; min_gain_to_split=0.0839; lambda_l1=0.419; lambda_l2=0.459; scale_pos_weight=3.15; learning_rate=0.0982; num_iterations=3817; early_stopping_rounds=65; feature_fraction=0.513; bagging_fraction=0.6; bagging_freq=2; max_delta_step=3.39; path_smooth=2 : y = 0.914 : 26.5 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=25; min_child_weight=6.52; min_data_in_leaf=3824; min_gain_to_split=0.0338; lambda_l1=0.287; lambda_l2=0.464; scale_pos_weight=2.74; learning_rate=0.0338; num_iterations=171; early_stopping_rounds=169; feature_fraction=0.639; bagging_fraction=0.823; bagging_freq=2; max_delta_step=1.64; path_smooth=5.73 : y = 0.913 : 22.1 secs : initdesign
#
# [mbo] 0: num_leaves=35; max_depth=8; min_child_weight=3.11; min_data_in_leaf=1148; min_gain_to_split=0.00957; lambda_l1=0.316; lambda_l2=0.278; scale_pos_weight=1.81; learning_rate=0.0377; num_iterations=2194; early_stopping_rounds=387; feature_fraction=0.592; bagging_fraction=0.554; bagging_freq=3; max_delta_step=7.75; path_smooth=7.39 : y = 0.929 : 153.8 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=28; min_child_weight=3.41; min_data_in_leaf=5145; min_gain_to_split=0.03; lambda_l1=0.498; lambda_l2=0.0859; scale_pos_weight=4.87; learning_rate=0.0352; num_iterations=2578; early_stopping_rounds=281; feature_fraction=0.331; bagging_fraction=0.728; bagging_freq=3; max_delta_step=7.32; path_smooth=9.98 : y = 0.926 : 220.2 secs : initdesign
#
# [mbo] 0: num_leaves=8; max_depth=6; min_child_weight=6.94; min_data_in_leaf=7301; min_gain_to_split=0.0861; lambda_l1=0.206; lambda_l2=0.365; scale_pos_weight=4.9; learning_rate=0.0266; num_iterations=2952; early_stopping_rounds=194; feature_fraction=0.454; bagging_fraction=0.766; bagging_freq=3; max_delta_step=5.96; path_smooth=5.2 : y = 0.92 : 315.2 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=17; min_child_weight=5.51; min_data_in_leaf=8075; min_gain_to_split=0.0892; lambda_l1=0.0399; lambda_l2=0.0581; scale_pos_weight=1.74; learning_rate=0.047; num_iterations=3112; early_stopping_rounds=389; feature_fraction=0.609; bagging_fraction=0.867; bagging_freq=3; max_delta_step=8.22; path_smooth=5.07 : y = 0.915 : 91.7 secs : initdesign
#
# [mbo] 0: num_leaves=9; max_depth=26; min_child_weight=9.18; min_data_in_leaf=5375; min_gain_to_split=0.0158; lambda_l1=0.141; lambda_l2=0.00931; scale_pos_weight=3.85; learning_rate=0.0225; num_iterations=3060; early_stopping_rounds=329; feature_fraction=0.631; bagging_fraction=0.858; bagging_freq=1; max_delta_step=2.2; path_smooth=8.51 : y = 0.922 : 223.3 secs : initdesign
#
# [mbo] 0: num_leaves=63; max_depth=9; min_child_weight=8.14; min_data_in_leaf=7878; min_gain_to_split=0.00881; lambda_l1=0.129; lambda_l2=0.489; scale_pos_weight=1.09; learning_rate=0.0793; num_iterations=3614; early_stopping_rounds=464; feature_fraction=0.744; bagging_fraction=0.61; bagging_freq=4; max_delta_step=1.99; path_smooth=7.2 : y = 0.922 : 68.2 secs : initdesign
#
# [mbo] 0: num_leaves=57; max_depth=20; min_child_weight=0.547; min_data_in_leaf=281; min_gain_to_split=0.0433; lambda_l1=0.303; lambda_l2=0.169; scale_pos_weight=1.49; learning_rate=0.0156; num_iterations=4932; early_stopping_rounds=60; feature_fraction=0.377; bagging_fraction=0.627; bagging_freq=2; max_delta_step=5.91; path_smooth=6.05 : y = 0.927 : 112.1 secs : initdesign
#
# [mbo] 0: num_leaves=62; max_depth=3; min_child_weight=2.18; min_data_in_leaf=1853; min_gain_to_split=0.0358; lambda_l1=0.0382; lambda_l2=0.232; scale_pos_weight=4.74; learning_rate=0.0961; num_iterations=3435; early_stopping_rounds=491; feature_fraction=0.552; bagging_fraction=0.738; bagging_freq=4; max_delta_step=5; path_smooth=8.93 : y = 0.921 : 222.5 secs : initdesign
#
# [mbo] 0: num_leaves=2; max_depth=27; min_child_weight=6.67; min_data_in_leaf=1311; min_gain_to_split=0.0825; lambda_l1=0.278; lambda_l2=0.371; scale_pos_weight=1.76; learning_rate=0.0417; num_iterations=1228; early_stopping_rounds=441; feature_fraction=0.674; bagging_fraction=0.812; bagging_freq=5; max_delta_step=2.41; path_smooth=1.49 : y = 0.909 : 48.8 secs : initdesign
#
# [mbo] 0: num_leaves=33; max_depth=17; min_child_weight=6.18; min_data_in_leaf=3016; min_gain_to_split=0.0965; lambda_l1=0.356; lambda_l2=0.107; scale_pos_weight=3.32; learning_rate=0.0462; num_iterations=4074; early_stopping_rounds=380; feature_fraction=0.78; bagging_fraction=0.522; bagging_freq=1; max_delta_step=7.99; path_smooth=7.57 : y = 0.921 : 86.6 secs : initdesign
#
# [mbo] 0: num_leaves=18; max_depth=9; min_child_weight=1.62; min_data_in_leaf=5836; min_gain_to_split=0.0296; lambda_l1=0.476; lambda_l2=0.33; scale_pos_weight=3.59; learning_rate=0.0872; num_iterations=946; early_stopping_rounds=358; feature_fraction=0.317; bagging_fraction=0.818; bagging_freq=2; max_delta_step=4.64; path_smooth=5.9 : y = 0.921 : 81.0 secs : initdesign
#
# [mbo] 0: num_leaves=36; max_depth=29; min_child_weight=4.05; min_data_in_leaf=2883; min_gain_to_split=0.00489; lambda_l1=0.258; lambda_l2=0.398; scale_pos_weight=4.69; learning_rate=0.0584; num_iterations=2326; early_stopping_rounds=322; feature_fraction=0.646; bagging_fraction=0.872; bagging_freq=5; max_delta_step=9.09; path_smooth=0.257 : y = 0.925 : 129.2 secs : initdesign
#
# [mbo] 0: num_leaves=4; max_depth=5; min_child_weight=3.19; min_data_in_leaf=2179; min_gain_to_split=0.0736; lambda_l1=0.241; lambda_l2=0.202; scale_pos_weight=1.06; learning_rate=0.00959; num_iterations=531; early_stopping_rounds=227; feature_fraction=0.303; bagging_fraction=0.621; bagging_freq=4; max_delta_step=4.22; path_smooth=9.7 : y = 0.904 : 54.3 secs : initdesign
#
# [mbo] 0: num_leaves=50; max_depth=19; min_child_weight=9.75; min_data_in_leaf=5611; min_gain_to_split=0.071; lambda_l1=0.0265; lambda_l2=0.241; scale_pos_weight=3.19; learning_rate=0.0926; num_iterations=4758; early_stopping_rounds=106; feature_fraction=0.519; bagging_fraction=0.802; bagging_freq=4; max_delta_step=7.03; path_smooth=7.68 : y = 0.927 : 96.1 secs : initdesign
#
# [mbo] 0: num_leaves=56; max_depth=5; min_child_weight=7.68; min_data_in_leaf=519; min_gain_to_split=0.0248; lambda_l1=0.159; lambda_l2=0.403; scale_pos_weight=1.66; learning_rate=0.03; num_iterations=2754; early_stopping_rounds=153; feature_fraction=0.658; bagging_fraction=0.753; bagging_freq=5; max_delta_step=9.56; path_smooth=1.06 : y = 0.924 : 85.6 secs : initdesign
#
# [mbo] 0: num_leaves=52; max_depth=14; min_child_weight=0.89; min_data_in_leaf=4334; min_gain_to_split=0.0254; lambda_l1=0.392; lambda_l2=0.162; scale_pos_weight=3; learning_rate=0.055; num_iterations=1817; early_stopping_rounds=140; feature_fraction=0.747; bagging_fraction=0.675; bagging_freq=5; max_delta_step=0.0063; path_smooth=3.46 : y = 0.879 : 89.0 secs : initdesign
#
# [mbo] 0: num_leaves=15; max_depth=15; min_child_weight=8.56; min_data_in_leaf=3443; min_gain_to_split=0.0476; lambda_l1=0.247; lambda_l2=0.384; scale_pos_weight=2.64; learning_rate=0.0319; num_iterations=4852; early_stopping_rounds=84; feature_fraction=0.703; bagging_fraction=0.53; bagging_freq=4; max_delta_step=3.78; path_smooth=8.84 : y = 0.919 : 41.8 secs : initdesign
#
# [mbo] 0: num_leaves=26; max_depth=14; min_child_weight=7.58; min_data_in_leaf=6327; min_gain_to_split=0.0732; lambda_l1=0.338; lambda_l2=0.0943; scale_pos_weight=2.38; learning_rate=0.099; num_iterations=4440; early_stopping_rounds=476; feature_fraction=0.727; bagging_fraction=0.585; bagging_freq=5; max_delta_step=6.18; path_smooth=0.93 : y = 0.918 : 61.5 secs : initdesign
#
# [mbo] 0: num_leaves=13; max_depth=28; min_child_weight=1.16; min_data_in_leaf=883; min_gain_to_split=0.0919; lambda_l1=0.194; lambda_l2=0.0662; scale_pos_weight=4.37; learning_rate=0.0894; num_iterations=2079; early_stopping_rounds=423; feature_fraction=0.405; bagging_fraction=0.826; bagging_freq=2; max_delta_step=2.93; path_smooth=2.46 : y = 0.928 : 201.7 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=16; min_child_weight=8.92; min_data_in_leaf=4520; min_gain_to_split=0.0146; lambda_l1=0.202; lambda_l2=0.0311; scale_pos_weight=3.94; learning_rate=0.0125; num_iterations=1718; early_stopping_rounds=436; feature_fraction=0.337; bagging_fraction=0.655; bagging_freq=5; max_delta_step=0.714; path_smooth=8.16 : y = 0.919 : 211.8 secs : initdesign
#
# [mbo] 0: num_leaves=48; max_depth=11; min_child_weight=8.76; min_data_in_leaf=7176; min_gain_to_split=0.0622; lambda_l1=0.406; lambda_l2=0.0228; scale_pos_weight=1.32; learning_rate=0.0823; num_iterations=277; early_stopping_rounds=85; feature_fraction=0.483; bagging_fraction=0.84; bagging_freq=1; max_delta_step=6.76; path_smooth=1.11 : y = 0.919 : 45.1 secs : initdesign
#
# [mbo] 0: num_leaves=37; max_depth=23; min_child_weight=2.65; min_data_in_leaf=8043; min_gain_to_split=0.039; lambda_l1=0.326; lambda_l2=0.216; scale_pos_weight=1.2; learning_rate=0.0628; num_iterations=1340; early_stopping_rounds=123; feature_fraction=0.758; bagging_fraction=0.51; bagging_freq=1; max_delta_step=7.39; path_smooth=6.66 : y = 0.917 : 27.8 secs : initdesign
#
# [mbo] 0: num_leaves=27; max_depth=30; min_child_weight=9.9; min_data_in_leaf=7679; min_gain_to_split=0.0067; lambda_l1=0.436; lambda_l2=0.45; scale_pos_weight=4.11; learning_rate=0.0855; num_iterations=4141; early_stopping_rounds=496; feature_fraction=0.388; bagging_fraction=0.662; bagging_freq=5; max_delta_step=2.58; path_smooth=4.37 : y = 0.915 : 105.1 secs : initdesign
#
# [mbo] 0: num_leaves=59; max_depth=7; min_child_weight=0.0179; min_data_in_leaf=2059; min_gain_to_split=0.0951; lambda_l1=0.229; lambda_l2=0.433; scale_pos_weight=3.02; learning_rate=0.0917; num_iterations=200; early_stopping_rounds=244; feature_fraction=0.35; bagging_fraction=0.713; bagging_freq=5; max_delta_step=3.21; path_smooth=3.13 : y = 0.924 : 26.9 secs : initdesign
#
# [mbo] 0: num_leaves=31; max_depth=22; min_child_weight=0.735; min_data_in_leaf=441; min_gain_to_split=0.0791; lambda_l1=0.104; lambda_l2=0.484; scale_pos_weight=3.91; learning_rate=0.0952; num_iterations=4213; early_stopping_rounds=334; feature_fraction=0.765; bagging_fraction=0.546; bagging_freq=3; max_delta_step=0.484; path_smooth=5.57 : y = 0.926 : 123.0 secs : initdesign
#
# [mbo] 0: num_leaves=62; max_depth=6; min_child_weight=5.82; min_data_in_leaf=7431; min_gain_to_split=0.0755; lambda_l1=0.0496; lambda_l2=0.19; scale_pos_weight=4.13; learning_rate=0.011; num_iterations=2163; early_stopping_rounds=167; feature_fraction=0.615; bagging_fraction=0.706; bagging_freq=3; max_delta_step=0.2; path_smooth=9.55 : y = 0.911 : 181.8 secs : initdesign
#
# [mbo] 0: num_leaves=28; max_depth=3; min_child_weight=5.7; min_data_in_leaf=3118; min_gain_to_split=0.0692; lambda_l1=0.0074; lambda_l2=0.154; scale_pos_weight=4.78; learning_rate=0.00815; num_iterations=4632; early_stopping_rounds=469; feature_fraction=0.558; bagging_fraction=0.619; bagging_freq=4; max_delta_step=9.27; path_smooth=3.69 : y = 0.914 : 301.3 secs : initdesign
#
# [mbo] 0: num_leaves=16; max_depth=7; min_child_weight=6.02; min_data_in_leaf=918; min_gain_to_split=0.0517; lambda_l1=0.424; lambda_l2=0.0417; scale_pos_weight=1.27; learning_rate=0.0841; num_iterations=4587; early_stopping_rounds=53; feature_fraction=0.342; bagging_fraction=0.568; bagging_freq=4; max_delta_step=9.76; path_smooth=4.66 : y = 0.912 : 18.0 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=30; min_child_weight=7.38; min_data_in_leaf=7767; min_gain_to_split=0.0572; lambda_l1=0.0967; lambda_l2=0.137; scale_pos_weight=2.45; learning_rate=0.0183; num_iterations=3271; early_stopping_rounds=143; feature_fraction=0.794; bagging_fraction=0.761; bagging_freq=5; max_delta_step=6.89; path_smooth=0.4 : y = 0.921 : 133.7 secs : initdesign
#
# [mbo] 0: num_leaves=7; max_depth=29; min_child_weight=0.378; min_data_in_leaf=1569; min_gain_to_split=0.0202; lambda_l1=0.349; lambda_l2=0.316; scale_pos_weight=3.48; learning_rate=0.00607; num_iterations=348; early_stopping_rounds=202; feature_fraction=0.686; bagging_fraction=0.782; bagging_freq=4; max_delta_step=3.55; path_smooth=9.33 : y = 0.903 : 21.8 secs : initdesign
#
# [mbo] 0: num_leaves=2; max_depth=8; min_child_weight=2.94; min_data_in_leaf=6404; min_gain_to_split=0.0443; lambda_l1=0.00881; lambda_l2=0.427; scale_pos_weight=2.07; learning_rate=0.0722; num_iterations=562; early_stopping_rounds=107; feature_fraction=0.694; bagging_fraction=0.856; bagging_freq=4; max_delta_step=8.93; path_smooth=2.27 : y = 0.908 : 24.2 secs : initdesign
#
# [mbo] 0: num_leaves=24; max_depth=10; min_child_weight=9.63; min_data_in_leaf=96; min_gain_to_split=0.0041; lambda_l1=0.109; lambda_l2=0.442; scale_pos_weight=2.15; learning_rate=0.0643; num_iterations=4482; early_stopping_rounds=234; feature_fraction=0.496; bagging_fraction=0.897; bagging_freq=1; max_delta_step=1.75; path_smooth=4.12 : y = 0.921 : 97.3 secs : initdesign
#
# [mbo] 0: num_leaves=58; max_depth=20; min_child_weight=2.33; min_data_in_leaf=6816; min_gain_to_split=0.0131; lambda_l1=0.0232; lambda_l2=0.341; scale_pos_weight=2.83; learning_rate=0.0817; num_iterations=3477; early_stopping_rounds=310; feature_fraction=0.315; bagging_fraction=0.573; bagging_freq=2; max_delta_step=5.28; path_smooth=1.39 : y = 0.915 : 59.8 secs : initdesign
#
# [mbo] 0: num_leaves=21; max_depth=26; min_child_weight=9.43; min_data_in_leaf=2796; min_gain_to_split=0.097; lambda_l1=0.469; lambda_l2=0.142; scale_pos_weight=2.93; learning_rate=0.0405; num_iterations=2005; early_stopping_rounds=129; feature_fraction=0.43; bagging_fraction=0.792; bagging_freq=1; max_delta_step=3.09; path_smooth=9.15 : y = 0.919 : 65.6 secs : initdesign
#
# [mbo] 0: num_leaves=60; max_depth=29; min_child_weight=4.32; min_data_in_leaf=2399; min_gain_to_split=0.089; lambda_l1=0.461; lambda_l2=0.354; scale_pos_weight=3.65; learning_rate=0.0243; num_iterations=1672; early_stopping_rounds=479; feature_fraction=0.424; bagging_fraction=0.542; bagging_freq=5; max_delta_step=8.35; path_smooth=2.04 : y = 0.924 : 248.7 secs : initdesign
#
# [mbo] 0: num_leaves=37; max_depth=7; min_child_weight=0.258; min_data_in_leaf=6571; min_gain_to_split=0.0986; lambda_l1=0.414; lambda_l2=0.3; scale_pos_weight=1.6; learning_rate=0.0608; num_iterations=4358; early_stopping_rounds=416; feature_fraction=0.717; bagging_fraction=0.886; bagging_freq=5; max_delta_step=0.8; path_smooth=7.1 : y = 0.925 : 139.5 secs : initdesign
#
# [mbo] 0: num_leaves=12; max_depth=22; min_child_weight=1.39; min_data_in_leaf=4650; min_gain_to_split=0.000953; lambda_l1=0.0794; lambda_l2=0.0471; scale_pos_weight=2.06; learning_rate=0.00702; num_iterations=4815; early_stopping_rounds=275; feature_fraction=0.384; bagging_fraction=0.777; bagging_freq=3; max_delta_step=9.48; path_smooth=9.39 : y = 0.919 : 419.5 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=4; min_child_weight=9.31; min_data_in_leaf=3243; min_gain_to_split=0.0392; lambda_l1=0.176; lambda_l2=0.111; scale_pos_weight=4.62; learning_rate=0.0775; num_iterations=695; early_stopping_rounds=365; feature_fraction=0.733; bagging_fraction=0.59; bagging_freq=1; max_delta_step=4.02; path_smooth=0.499 : y = 0.918 : 43.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Nov 18 03:20:00 AM 2025 AUC 0.924231077146283
#
# [mbo] 1: num_leaves=47; max_depth=15; min_child_weight=3.97; min_data_in_leaf=4387; min_gain_to_split=0.0263; lambda_l1=0.3; lambda_l2=0.302; scale_pos_weight=3.78; learning_rate=0.041; num_iterations=3674; early_stopping_rounds=414; feature_fraction=0.611; bagging_fraction=0.774; bagging_freq=2; max_delta_step=7.44; path_smooth=7.96 : y = 0.924 : 197.4 secs : infill_ei
#
# Tue Nov 18 03:23:12 AM 2025 AUC 0.925809421615937
#
# [mbo] 2: num_leaves=36; max_depth=17; min_child_weight=6.65; min_data_in_leaf=2885; min_gain_to_split=0.0912; lambda_l1=0.0988; lambda_l2=0.313; scale_pos_weight=1.91; learning_rate=0.0479; num_iterations=4021; early_stopping_rounds=454; feature_fraction=0.438; bagging_fraction=0.791; bagging_freq=3; max_delta_step=1.58; path_smooth=8.99 : y = 0.926 : 189.6 secs : infill_ei
#
# Tue Nov 18 03:25:56 AM 2025 AUC 0.931361476449987
#
# [mbo] 3: num_leaves=37; max_depth=19; min_child_weight=0.73; min_data_in_leaf=2469; min_gain_to_split=0.073; lambda_l1=0.204; lambda_l2=0.246; scale_pos_weight=4.17; learning_rate=0.079; num_iterations=3388; early_stopping_rounds=409; feature_fraction=0.462; bagging_fraction=0.774; bagging_freq=2; max_delta_step=1.29; path_smooth=9.01 : y = 0.931 : 162.3 secs : infill_ei
#
# Tue Nov 18 03:27:53 AM 2025 AUC 0.926238567571866
#
# [mbo] 4: num_leaves=35; max_depth=27; min_child_weight=3.63; min_data_in_leaf=1698; min_gain_to_split=0.0908; lambda_l1=0.159; lambda_l2=0.324; scale_pos_weight=3.94; learning_rate=0.077; num_iterations=2568; early_stopping_rounds=404; feature_fraction=0.724; bagging_fraction=0.817; bagging_freq=2; max_delta_step=2.13; path_smooth=7.72 : y = 0.926 : 114.4 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Tue Nov 18 03:31:57 AM 2025 AUC 0.927506209027298
#
# [mbo] 5: num_leaves=30; max_depth=15; min_child_weight=0.415; min_data_in_leaf=1925; min_gain_to_split=0.0626; lambda_l1=0.321; lambda_l2=0.155; scale_pos_weight=4.87; learning_rate=0.0525; num_iterations=3100; early_stopping_rounds=415; feature_fraction=0.438; bagging_fraction=0.735; bagging_freq=2; max_delta_step=2.61; path_smooth=5.48 : y = 0.928 : 243.2 secs : infill_ei
#
# Tue Nov 18 03:34:04 AM 2025 AUC 0.92612146675981
#
# [mbo] 6: num_leaves=38; max_depth=15; min_child_weight=1.22; min_data_in_leaf=4340; min_gain_to_split=0.0713; lambda_l1=0.235; lambda_l2=0.278; scale_pos_weight=4.32; learning_rate=0.0596; num_iterations=3282; early_stopping_rounds=406; feature_fraction=0.351; bagging_fraction=0.872; bagging_freq=3; max_delta_step=0.816; path_smooth=5.24 : y = 0.926 : 124.6 secs : infill_ei
#
# Tue Nov 18 03:36:23 AM 2025 AUC 0.926766360057148
#
# [mbo] 7: num_leaves=31; max_depth=23; min_child_weight=3.53; min_data_in_leaf=995; min_gain_to_split=0.0591; lambda_l1=0.0705; lambda_l2=0.126; scale_pos_weight=4.08; learning_rate=0.0819; num_iterations=2727; early_stopping_rounds=424; feature_fraction=0.334; bagging_fraction=0.778; bagging_freq=2; max_delta_step=0.737; path_smooth=6.65 : y = 0.927 : 137.1 secs : infill_ei
#
# Tue Nov 18 03:39:59 AM 2025 AUC 0.927288448491413
#
# [mbo] 8: num_leaves=36; max_depth=19; min_child_weight=1.66; min_data_in_leaf=1718; min_gain_to_split=0.016; lambda_l1=0.264; lambda_l2=0.406; scale_pos_weight=2.05; learning_rate=0.0678; num_iterations=2334; early_stopping_rounds=455; feature_fraction=0.468; bagging_fraction=0.782; bagging_freq=3; max_delta_step=6.18; path_smooth=8.07 : y = 0.927 : 214.3 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Tue Nov 18 03:43:08 AM 2025 AUC 0.92914494933125
#
# [mbo] 9: num_leaves=38; max_depth=17; min_child_weight=7.46; min_data_in_leaf=480; min_gain_to_split=0.0256; lambda_l1=0.31; lambda_l2=0.327; scale_pos_weight=3.58; learning_rate=0.0447; num_iterations=2918; early_stopping_rounds=346; feature_fraction=0.528; bagging_fraction=0.702; bagging_freq=4; max_delta_step=6.74; path_smooth=8.34 : y = 0.929 : 186.4 secs : infill_ei
#
# Tue Nov 18 03:46:41 AM 2025 AUC 0.927793424772626
#
# [mbo] 10: num_leaves=38; max_depth=20; min_child_weight=1.13; min_data_in_leaf=2089; min_gain_to_split=0.063; lambda_l1=0.148; lambda_l2=0.0938; scale_pos_weight=2.08; learning_rate=0.0442; num_iterations=4140; early_stopping_rounds=445; feature_fraction=0.559; bagging_fraction=0.882; bagging_freq=2; max_delta_step=4.81; path_smooth=7.78 : y = 0.928 : 211.0 secs : infill_ei
#
# Tue Nov 18 03:51:01 AM 2025 AUC 0.931375904343736
#
# [mbo] 11: num_leaves=51; max_depth=22; min_child_weight=3.49; min_data_in_leaf=66; min_gain_to_split=0.023; lambda_l1=0.458; lambda_l2=0.172; scale_pos_weight=1.82; learning_rate=0.0366; num_iterations=4651; early_stopping_rounds=360; feature_fraction=0.497; bagging_fraction=0.71; bagging_freq=2; max_delta_step=6.99; path_smooth=3.14 : y = 0.931 : 258.3 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Tue Nov 18 03:55:29 AM 2025 AUC 0.930908172160339
#
# [mbo] 12: num_leaves=45; max_depth=25; min_child_weight=2.85; min_data_in_leaf=270; min_gain_to_split=0.0404; lambda_l1=0.401; lambda_l2=0.164; scale_pos_weight=3.28; learning_rate=0.0163; num_iterations=4306; early_stopping_rounds=244; feature_fraction=0.498; bagging_fraction=0.856; bagging_freq=2; max_delta_step=6.83; path_smooth=4.77 : y = 0.931 : 265.9 secs : infill_ei
#
# Tue Nov 18 03:59:27 AM 2025 AUC 0.927547815046481
#
# [mbo] 13: num_leaves=37; max_depth=21; min_child_weight=4.38; min_data_in_leaf=986; min_gain_to_split=0.0536; lambda_l1=0.361; lambda_l2=0.245; scale_pos_weight=2.27; learning_rate=0.0357; num_iterations=4416; early_stopping_rounds=328; feature_fraction=0.493; bagging_fraction=0.791; bagging_freq=3; max_delta_step=6.65; path_smooth=4.6 : y = 0.928 : 235.1 secs : infill_ei
#
# Tue Nov 18 04:01:27 AM 2025 AUC 0.926724418505552
#
# [mbo] 14: num_leaves=51; max_depth=18; min_child_weight=0.823; min_data_in_leaf=288; min_gain_to_split=0.0257; lambda_l1=0.146; lambda_l2=0.211; scale_pos_weight=3.35; learning_rate=0.0461; num_iterations=3429; early_stopping_rounds=368; feature_fraction=0.624; bagging_fraction=0.725; bagging_freq=2; max_delta_step=6.65; path_smooth=5.82 : y = 0.927 : 117.8 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Tue Nov 18 04:04:30 AM 2025 AUC 0.9328572799461
#
# [mbo] 15: num_leaves=46; max_depth=12; min_child_weight=2.98; min_data_in_leaf=2; min_gain_to_split=0.0364; lambda_l1=0.393; lambda_l2=0.171; scale_pos_weight=1.85; learning_rate=0.0419; num_iterations=4504; early_stopping_rounds=327; feature_fraction=0.417; bagging_fraction=0.827; bagging_freq=1; max_delta_step=6.16; path_smooth=6.69 : y = 0.933 : 181.3 secs : infill_ei
#
# Tue Nov 18 04:07:57 AM 2025 AUC 0.926975061217889
#
# [mbo] 16: num_leaves=40; max_depth=22; min_child_weight=3.33; min_data_in_leaf=1948; min_gain_to_split=0.0179; lambda_l1=0.451; lambda_l2=0.0536; scale_pos_weight=2.86; learning_rate=0.0409; num_iterations=4699; early_stopping_rounds=374; feature_fraction=0.393; bagging_fraction=0.84; bagging_freq=1; max_delta_step=4.93; path_smooth=9.57 : y = 0.927 : 204.4 secs : infill_ei
#
# Tue Nov 18 04:10:54 AM 2025 AUC 0.931975836297762
#
# [mbo] 17: num_leaves=51; max_depth=17; min_child_weight=2.52; min_data_in_leaf=25; min_gain_to_split=0.0609; lambda_l1=0.229; lambda_l2=0.272; scale_pos_weight=2.26; learning_rate=0.0503; num_iterations=4645; early_stopping_rounds=300; feature_fraction=0.533; bagging_fraction=0.829; bagging_freq=1; max_delta_step=6.45; path_smooth=8.34 : y = 0.932 : 175.0 secs : infill_ei
#
# Tue Nov 18 04:15:17 AM 2025 AUC 0.928537971196556
#
# [mbo] 18: num_leaves=50; max_depth=18; min_child_weight=0.973; min_data_in_leaf=137; min_gain_to_split=0.0677; lambda_l1=0.454; lambda_l2=0.133; scale_pos_weight=1.53; learning_rate=0.055; num_iterations=3895; early_stopping_rounds=354; feature_fraction=0.548; bagging_fraction=0.876; bagging_freq=1; max_delta_step=6.5; path_smooth=5.27 : y = 0.929 : 261.4 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Tue Nov 18 04:17:50 AM 2025 AUC 0.925675544183244
#
# [mbo] 19: num_leaves=46; max_depth=25; min_child_weight=3.11; min_data_in_leaf=5936; min_gain_to_split=0.0825; lambda_l1=0.318; lambda_l2=0.156; scale_pos_weight=4.47; learning_rate=0.0914; num_iterations=4201; early_stopping_rounds=400; feature_fraction=0.563; bagging_fraction=0.86; bagging_freq=1; max_delta_step=2.85; path_smooth=9.21 : y = 0.926 : 150.6 secs : infill_ei
#
# Tue Nov 18 04:21:03 AM 2025 AUC 0.929643886029034
#
# [mbo] 20: num_leaves=42; max_depth=23; min_child_weight=2.49; min_data_in_leaf=84; min_gain_to_split=0.0417; lambda_l1=0.309; lambda_l2=0.414; scale_pos_weight=3.55; learning_rate=0.0244; num_iterations=4538; early_stopping_rounds=308; feature_fraction=0.337; bagging_fraction=0.572; bagging_freq=1; max_delta_step=7.18; path_smooth=5.22 : y = 0.93 : 191.5 secs : infill_ei
#
# Tue Nov 18 04:23:18 AM 2025 AUC 0.928265183344976
#
# [mbo] 21: num_leaves=47; max_depth=16; min_child_weight=8.12; min_data_in_leaf=156; min_gain_to_split=0.0211; lambda_l1=0.359; lambda_l2=0.281; scale_pos_weight=1.63; learning_rate=0.0318; num_iterations=4809; early_stopping_rounds=264; feature_fraction=0.408; bagging_fraction=0.863; bagging_freq=1; max_delta_step=7.22; path_smooth=8.04 : y = 0.928 : 132.1 secs : infill_ei
#
# Tue Nov 18 04:26:42 AM 2025 AUC 0.926364392226653
#
# [mbo] 22: num_leaves=25; max_depth=16; min_child_weight=0.207; min_data_in_leaf=1680; min_gain_to_split=0.0873; lambda_l1=0.277; lambda_l2=0.159; scale_pos_weight=3.81; learning_rate=0.0846; num_iterations=4280; early_stopping_rounds=458; feature_fraction=0.435; bagging_fraction=0.85; bagging_freq=2; max_delta_step=1.1; path_smooth=9.07 : y = 0.926 : 201.7 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Tue Nov 18 04:30:12 AM 2025 AUC 0.93089978385002
#
# [mbo] 23: num_leaves=40; max_depth=10; min_child_weight=0.367; min_data_in_leaf=1741; min_gain_to_split=0.0542; lambda_l1=0.276; lambda_l2=0.463; scale_pos_weight=1.74; learning_rate=0.0314; num_iterations=4123; early_stopping_rounds=399; feature_fraction=0.679; bagging_fraction=0.74; bagging_freq=1; max_delta_step=1.37; path_smooth=8.33 : y = 0.931 : 207.4 secs : infill_ei
#
# Tue Nov 18 04:33:59 AM 2025 AUC 0.928313500012415
#
# [mbo] 24: num_leaves=42; max_depth=15; min_child_weight=0.118; min_data_in_leaf=23; min_gain_to_split=0.0611; lambda_l1=0.0918; lambda_l2=0.211; scale_pos_weight=1.5; learning_rate=0.059; num_iterations=4993; early_stopping_rounds=250; feature_fraction=0.458; bagging_fraction=0.744; bagging_freq=1; max_delta_step=6.3; path_smooth=7.82 : y = 0.928 : 225.8 secs : infill_ei
#
# Tue Nov 18 04:37:26 AM 2025 AUC 0.930106585226239
#
# [mbo] 25: num_leaves=40; max_depth=12; min_child_weight=2.24; min_data_in_leaf=62; min_gain_to_split=0.0401; lambda_l1=0.349; lambda_l2=0.417; scale_pos_weight=1.78; learning_rate=0.0282; num_iterations=4360; early_stopping_rounds=392; feature_fraction=0.656; bagging_fraction=0.81; bagging_freq=1; max_delta_step=6.18; path_smooth=6.88 : y = 0.93 : 203.5 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Tue Nov 18 04:39:41 AM 2025 AUC 0.933383730301731
#
# [mbo] 26: num_leaves=44; max_depth=18; min_child_weight=3.45; min_data_in_leaf=69; min_gain_to_split=0.0556; lambda_l1=0.37; lambda_l2=0.209; scale_pos_weight=4.09; learning_rate=0.0743; num_iterations=4582; early_stopping_rounds=351; feature_fraction=0.483; bagging_fraction=0.741; bagging_freq=2; max_delta_step=4.96; path_smooth=8.53 : y = 0.933 : 132.4 secs : infill_ei
#
# Tue Nov 18 04:45:26 AM 2025 AUC 0.932397265008197
#
# [mbo] 27: num_leaves=50; max_depth=27; min_child_weight=3.14; min_data_in_leaf=3; min_gain_to_split=0.0547; lambda_l1=0.379; lambda_l2=0.387; scale_pos_weight=2.33; learning_rate=0.012; num_iterations=4619; early_stopping_rounds=337; feature_fraction=0.409; bagging_fraction=0.704; bagging_freq=2; max_delta_step=4.64; path_smooth=8.52 : y = 0.932 : 341.8 secs : infill_ei
#
# Tue Nov 18 04:48:43 AM 2025 AUC 0.926825078229382
#
# [mbo] 28: num_leaves=50; max_depth=25; min_child_weight=4.08; min_data_in_leaf=29; min_gain_to_split=0.0292; lambda_l1=0.415; lambda_l2=0.305; scale_pos_weight=2.52; learning_rate=0.0516; num_iterations=2511; early_stopping_rounds=414; feature_fraction=0.304; bagging_fraction=0.876; bagging_freq=2; max_delta_step=7.25; path_smooth=5.69 : y = 0.927 : 195.2 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Tue Nov 18 04:51:06 AM 2025 AUC 0.928843641224586
#
# [mbo] 29: num_leaves=49; max_depth=15; min_child_weight=0.637; min_data_in_leaf=43; min_gain_to_split=0.0575; lambda_l1=0.304; lambda_l2=0.32; scale_pos_weight=3.68; learning_rate=0.0461; num_iterations=4711; early_stopping_rounds=343; feature_fraction=0.431; bagging_fraction=0.834; bagging_freq=1; max_delta_step=3.35; path_smooth=7.25 : y = 0.929 : 140.9 secs : infill_ei
#
# Tue Nov 18 04:53:34 AM 2025 AUC 0.924418304232607
#
# [mbo] 30: num_leaves=51; max_depth=22; min_child_weight=3.94; min_data_in_leaf=43; min_gain_to_split=0.0766; lambda_l1=0.462; lambda_l2=0.351; scale_pos_weight=2.68; learning_rate=0.0646; num_iterations=4707; early_stopping_rounds=299; feature_fraction=0.469; bagging_fraction=0.628; bagging_freq=2; max_delta_step=5; path_smooth=8.89 : y = 0.924 : 145.9 secs : infill_ei
#
# Tue Nov 18 05:00:01 AM 2025 AUC 0.930623976206726
#
# [mbo] 31: num_leaves=49; max_depth=20; min_child_weight=3.98; min_data_in_leaf=762; min_gain_to_split=0.0453; lambda_l1=0.336; lambda_l2=0.187; scale_pos_weight=2.08; learning_rate=0.0106; num_iterations=4739; early_stopping_rounds=356; feature_fraction=0.699; bagging_fraction=0.778; bagging_freq=2; max_delta_step=5.78; path_smooth=7.8 : y = 0.931 : 384.3 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Tue Nov 18 05:04:25 AM 2025 AUC 0.930345819836542
#
# [mbo] 32: num_leaves=38; max_depth=27; min_child_weight=1.91; min_data_in_leaf=20; min_gain_to_split=0.0447; lambda_l1=0.21; lambda_l2=0.142; scale_pos_weight=1.6; learning_rate=0.0274; num_iterations=4455; early_stopping_rounds=341; feature_fraction=0.426; bagging_fraction=0.748; bagging_freq=1; max_delta_step=5.99; path_smooth=8.4 : y = 0.93 : 261.0 secs : infill_ei
#
# Tue Nov 18 05:06:44 AM 2025 AUC 0.928555418882019
#
# [mbo] 33: num_leaves=38; max_depth=12; min_child_weight=5.56; min_data_in_leaf=2403; min_gain_to_split=0.0561; lambda_l1=0.311; lambda_l2=0.397; scale_pos_weight=1.7; learning_rate=0.0807; num_iterations=3487; early_stopping_rounds=451; feature_fraction=0.551; bagging_fraction=0.79; bagging_freq=1; max_delta_step=1.23; path_smooth=9.62 : y = 0.929 : 137.2 secs : infill_ei
#
# Tue Nov 18 05:11:41 AM 2025 AUC 0.929058046436344
#
# [mbo] 34: num_leaves=46; max_depth=24; min_child_weight=9.08; min_data_in_leaf=44; min_gain_to_split=0.052; lambda_l1=0.251; lambda_l2=0.166; scale_pos_weight=4.57; learning_rate=0.0471; num_iterations=4933; early_stopping_rounds=439; feature_fraction=0.414; bagging_fraction=0.781; bagging_freq=3; max_delta_step=5.34; path_smooth=9.77 : y = 0.929 : 294.8 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Tue Nov 18 05:16:21 AM 2025 AUC 0.926469413871849
#
# [mbo] 35: num_leaves=42; max_depth=26; min_child_weight=1.21; min_data_in_leaf=2992; min_gain_to_split=0.0567; lambda_l1=0.315; lambda_l2=0.388; scale_pos_weight=2.48; learning_rate=0.0547; num_iterations=4535; early_stopping_rounds=416; feature_fraction=0.544; bagging_fraction=0.546; bagging_freq=2; max_delta_step=1.83; path_smooth=8.44 : y = 0.926 : 276.8 secs : infill_ei
#
# Tue Nov 18 05:18:12 AM 2025 AUC 0.918026411769403
#
# [mbo] 36: num_leaves=44; max_depth=26; min_child_weight=1.71; min_data_in_leaf=30; min_gain_to_split=0.0501; lambda_l1=0.424; lambda_l2=0.314; scale_pos_weight=2.36; learning_rate=0.0751; num_iterations=4717; early_stopping_rounds=325; feature_fraction=0.458; bagging_fraction=0.787; bagging_freq=2; max_delta_step=6.15; path_smooth=9.54 : y = 0.918 : 108.9 secs : infill_ei
#
# Tue Nov 18 05:24:33 AM 2025 AUC 0.93369778864008
#
# [mbo] 37: num_leaves=48; max_depth=15; min_child_weight=4.17; min_data_in_leaf=23; min_gain_to_split=0.0555; lambda_l1=0.387; lambda_l2=0.203; scale_pos_weight=3.85; learning_rate=0.0187; num_iterations=4310; early_stopping_rounds=391; feature_fraction=0.389; bagging_fraction=0.719; bagging_freq=1; max_delta_step=5.06; path_smooth=7.27 : y = 0.934 : 379.4 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Tue Nov 18 05:28:34 AM 2025 AUC 0.932277479936839
#
# [mbo] 38: num_leaves=52; max_depth=17; min_child_weight=5.87; min_data_in_leaf=38; min_gain_to_split=0.0574; lambda_l1=0.116; lambda_l2=0.109; scale_pos_weight=2.19; learning_rate=0.0343; num_iterations=3924; early_stopping_rounds=351; feature_fraction=0.433; bagging_fraction=0.701; bagging_freq=1; max_delta_step=5.04; path_smooth=7.52 : y = 0.932 : 237.8 secs : infill_ei
#
# Tue Nov 18 05:36:19 AM 2025 AUC 0.934643318979257
#
# [mbo] 39: num_leaves=54; max_depth=16; min_child_weight=3.29; min_data_in_leaf=42; min_gain_to_split=0.0787; lambda_l1=0.314; lambda_l2=0.0616; scale_pos_weight=2.17; learning_rate=0.0126; num_iterations=4381; early_stopping_rounds=334; feature_fraction=0.476; bagging_fraction=0.66; bagging_freq=2; max_delta_step=6.17; path_smooth=6.35 : y = 0.935 : 463.2 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Tue Nov 18 05:39:59 AM 2025 AUC 0.932098976693248
#
# [mbo] 40: num_leaves=54; max_depth=21; min_child_weight=2.62; min_data_in_leaf=424; min_gain_to_split=0.0562; lambda_l1=0.35; lambda_l2=0.0736; scale_pos_weight=2.22; learning_rate=0.011; num_iterations=4680; early_stopping_rounds=342; feature_fraction=0.37; bagging_fraction=0.706; bagging_freq=1; max_delta_step=5.6; path_smooth=1.44 : y = 0.932 : 217.7 secs : infill_ei
#
# Tue Nov 18 05:45:27 AM 2025 AUC 0.932119779702839
#
# [mbo] 41: num_leaves=49; max_depth=8; min_child_weight=1.82; min_data_in_leaf=89; min_gain_to_split=0.0641; lambda_l1=0.242; lambda_l2=0.355; scale_pos_weight=1.64; learning_rate=0.0205; num_iterations=4313; early_stopping_rounds=367; feature_fraction=0.496; bagging_fraction=0.659; bagging_freq=1; max_delta_step=2.08; path_smooth=8.01 : y = 0.932 : 325.4 secs : infill_ei
#
# Tue Nov 18 05:49:20 AM 2025 AUC 0.932179504472312
#
# [mbo] 42: num_leaves=43; max_depth=22; min_child_weight=5.18; min_data_in_leaf=20; min_gain_to_split=0.0421; lambda_l1=0.288; lambda_l2=0.0483; scale_pos_weight=4.15; learning_rate=0.0353; num_iterations=3532; early_stopping_rounds=369; feature_fraction=0.471; bagging_fraction=0.844; bagging_freq=2; max_delta_step=5.54; path_smooth=7.77 : y = 0.932 : 229.9 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Tue Nov 18 05:51:55 AM 2025 AUC 0.925726209577571
#
# [mbo] 43: num_leaves=41; max_depth=15; min_child_weight=3.9; min_data_in_leaf=155; min_gain_to_split=0.0742; lambda_l1=0.284; lambda_l2=0.177; scale_pos_weight=3.74; learning_rate=0.046; num_iterations=4782; early_stopping_rounds=355; feature_fraction=0.537; bagging_fraction=0.714; bagging_freq=2; max_delta_step=3.15; path_smooth=6.96 : y = 0.926 : 151.4 secs : infill_ei
#
# Tue Nov 18 05:56:24 AM 2025 AUC 0.930787716024156
#
# [mbo] 44: num_leaves=55; max_depth=13; min_child_weight=1.88; min_data_in_leaf=738; min_gain_to_split=0.0685; lambda_l1=0.308; lambda_l2=0.327; scale_pos_weight=1.99; learning_rate=0.029; num_iterations=3184; early_stopping_rounds=418; feature_fraction=0.379; bagging_fraction=0.639; bagging_freq=1; max_delta_step=6.17; path_smooth=6.24 : y = 0.931 : 265.8 secs : infill_ei
#
# Tue Nov 18 05:59:10 AM 2025 AUC 0.931216190915259
#
# [mbo] 45: num_leaves=53; max_depth=18; min_child_weight=3.58; min_data_in_leaf=178; min_gain_to_split=0.0192; lambda_l1=0.213; lambda_l2=0.0335; scale_pos_weight=3.39; learning_rate=0.0379; num_iterations=4536; early_stopping_rounds=371; feature_fraction=0.387; bagging_fraction=0.661; bagging_freq=2; max_delta_step=5.08; path_smooth=6.42 : y = 0.931 : 163.3 secs : infill_ei
#
# Tue Nov 18 06:09:10 AM 2025 AUC 0.930904816836211
#
# [mbo] 46: num_leaves=63; max_depth=18; min_child_weight=4.06; min_data_in_leaf=1099; min_gain_to_split=0.092; lambda_l1=0.35; lambda_l2=0.221; scale_pos_weight=1.83; learning_rate=0.013; num_iterations=4416; early_stopping_rounds=352; feature_fraction=0.516; bagging_fraction=0.601; bagging_freq=1; max_delta_step=5.19; path_smooth=9.13 : y = 0.931 : 595.9 secs : infill_ei
#
# ...
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Tue Nov 18 08:09:04 AM 2025 AUC 0.933096850088815
#
# [mbo] 66: num_leaves=56; max_depth=17; min_child_weight=2.95; min_data_in_leaf=86; min_gain_to_split=0.0456; lambda_l1=0.37; lambda_l2=0.0169; scale_pos_weight=2.47; learning_rate=0.0134; num_iterations=3008; early_stopping_rounds=461; feature_fraction=0.44; bagging_fraction=0.814; bagging_freq=2; max_delta_step=4.74; path_smooth=6.91 : y = 0.933 : 423.0 secs : infill_ei
#
# Tue Nov 18 08:18:02 AM 2025 AUC 0.932774403440147
#
# [mbo] 67: num_leaves=60; max_depth=22; min_child_weight=2.16; min_data_in_leaf=2; min_gain_to_split=0.0465; lambda_l1=0.116; lambda_l2=0.244; scale_pos_weight=2.49; learning_rate=0.00866; num_iterations=4480; early_stopping_rounds=471; feature_fraction=0.581; bagging_fraction=0.721; bagging_freq=1; max_delta_step=6.43; path_smooth=6.04 : y = 0.933 : 533.6 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Tue Nov 18 08:23:06 AM 2025 AUC 0.929343584519608
#
# [mbo] 68: num_leaves=56; max_depth=21; min_child_weight=3.81; min_data_in_leaf=195; min_gain_to_split=0.054; lambda_l1=0.287; lambda_l2=0.121; scale_pos_weight=1.49; learning_rate=0.0128; num_iterations=4851; early_stopping_rounds=429; feature_fraction=0.465; bagging_fraction=0.694; bagging_freq=3; max_delta_step=5.87; path_smooth=5.68 : y = 0.929 : 299.9 secs : infill_ei
#
# Tue Nov 18 08:29:58 AM 2025 AUC 0.929200312179357
#
# [mbo] 69: num_leaves=45; max_depth=15; min_child_weight=6.74; min_data_in_leaf=519; min_gain_to_split=0.0837; lambda_l1=0.372; lambda_l2=0.18; scale_pos_weight=3.39; learning_rate=0.0216; num_iterations=2561; early_stopping_rounds=461; feature_fraction=0.472; bagging_fraction=0.714; bagging_freq=1; max_delta_step=4.85; path_smooth=8.97 : y = 0.929 : 407.7 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Tue Nov 18 08:34:13 AM 2025 AUC 0.932633479826785
#
# [mbo] 70: num_leaves=57; max_depth=29; min_child_weight=7.95; min_data_in_leaf=39; min_gain_to_split=0.0505; lambda_l1=0.113; lambda_l2=0.138; scale_pos_weight=3.02; learning_rate=0.019; num_iterations=4578; early_stopping_rounds=305; feature_fraction=0.459; bagging_fraction=0.765; bagging_freq=1; max_delta_step=7.29; path_smooth=6.73 : y = 0.933 : 251.6 secs : infill_ei
#
# Tue Nov 18 08:46:16 AM 2025 AUC 0.931845314189196
#
# [mbo] 71: num_leaves=53; max_depth=19; min_child_weight=0.465; min_data_in_leaf=15; min_gain_to_split=0.0254; lambda_l1=0.22; lambda_l2=0.346; scale_pos_weight=2.6; learning_rate=0.00583; num_iterations=4356; early_stopping_rounds=371; feature_fraction=0.413; bagging_fraction=0.805; bagging_freq=1; max_delta_step=5.15; path_smooth=4.12 : y = 0.932 : 718.8 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Tue Nov 18 08:53:15 AM 2025 AUC 0.930772281533168
#
# [mbo] 72: num_leaves=62; max_depth=18; min_child_weight=8.44; min_data_in_leaf=33; min_gain_to_split=0.0818; lambda_l1=0.172; lambda_l2=0.3; scale_pos_weight=2.67; learning_rate=0.0073; num_iterations=4042; early_stopping_rounds=218; feature_fraction=0.567; bagging_fraction=0.726; bagging_freq=2; max_delta_step=8.03; path_smooth=7.27 : y = 0.931 : 416.1 secs : infill_ei
#
# Tue Nov 18 08:57:27 AM 2025 AUC 0.933111613514977
#
# [mbo] 73: num_leaves=60; max_depth=20; min_child_weight=1.82; min_data_in_leaf=117; min_gain_to_split=0.0882; lambda_l1=0.126; lambda_l2=0.227; scale_pos_weight=2.63; learning_rate=0.0233; num_iterations=4145; early_stopping_rounds=280; feature_fraction=0.461; bagging_fraction=0.84; bagging_freq=1; max_delta_step=7.45; path_smooth=6.05 : y = 0.933 : 247.3 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Tue Nov 18 09:06:01 AM 2025 AUC 0.933277702059297
#
# [mbo] 74: num_leaves=59; max_depth=20; min_child_weight=5.03; min_data_in_leaf=2; min_gain_to_split=0.0625; lambda_l1=0.46; lambda_l2=0.216; scale_pos_weight=2.91; learning_rate=0.0132; num_iterations=4634; early_stopping_rounds=457; feature_fraction=0.456; bagging_fraction=0.657; bagging_freq=3; max_delta_step=5.98; path_smooth=1.64 : y = 0.933 : 510.8 secs : infill_ei
#
# Tue Nov 18 09:10:18 AM 2025 AUC 0.931707745899962
#
# [mbo] 75: num_leaves=55; max_depth=15; min_child_weight=4.51; min_data_in_leaf=122; min_gain_to_split=0.00559; lambda_l1=0.364; lambda_l2=0.1; scale_pos_weight=1.77; learning_rate=0.0352; num_iterations=2474; early_stopping_rounds=433; feature_fraction=0.456; bagging_fraction=0.753; bagging_freq=2; max_delta_step=8.96; path_smooth=1.47 : y = 0.932 : 253.1 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Tue Nov 18 09:16:15 AM 2025 AUC 0.930658536045241
#
# [mbo] 76: num_leaves=43; max_depth=22; min_child_weight=2.54; min_data_in_leaf=175; min_gain_to_split=0.0223; lambda_l1=0.265; lambda_l2=0.122; scale_pos_weight=1.61; learning_rate=0.0253; num_iterations=2795; early_stopping_rounds=487; feature_fraction=0.436; bagging_fraction=0.599; bagging_freq=1; max_delta_step=4.98; path_smooth=4.35 : y = 0.931 : 351.3 secs : infill_ei
#
# Tue Nov 18 09:20:08 AM 2025 AUC 0.93510098519027
#
# [mbo] 77: num_leaves=58; max_depth=20; min_child_weight=1.72; min_data_in_leaf=13; min_gain_to_split=0.0683; lambda_l1=0.234; lambda_l2=0.27; scale_pos_weight=3.91; learning_rate=0.0169; num_iterations=3947; early_stopping_rounds=370; feature_fraction=0.391; bagging_fraction=0.758; bagging_freq=3; max_delta_step=7.42; path_smooth=9.08 : y = 0.935 : 228.3 secs : infill_ei
#
# Tue Nov 18 09:22:22 AM 2025 AUC 0.928970136944199
#
# [mbo] 78: num_leaves=37; max_depth=23; min_child_weight=4.61; min_data_in_leaf=2105; min_gain_to_split=0.0597; lambda_l1=0.155; lambda_l2=0.475; scale_pos_weight=4.43; learning_rate=0.0767; num_iterations=4189; early_stopping_rounds=357; feature_fraction=0.474; bagging_fraction=0.725; bagging_freq=1; max_delta_step=4.57; path_smooth=9.44 : y = 0.929 : 131.0 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Tue Nov 18 09:26:31 AM 2025 AUC 0.933717249520021
#
# [mbo] 79: num_leaves=63; max_depth=12; min_child_weight=4.13; min_data_in_leaf=4; min_gain_to_split=0.0597; lambda_l1=0.429; lambda_l2=0.192; scale_pos_weight=3; learning_rate=0.0164; num_iterations=4663; early_stopping_rounds=369; feature_fraction=0.403; bagging_fraction=0.583; bagging_freq=4; max_delta_step=7.51; path_smooth=5.7 : y = 0.934 : 244.4 secs : infill_ei
#
# Tue Nov 18 09:29:39 AM 2025 AUC 0.934605068284201
#
# [mbo] 80: num_leaves=56; max_depth=18; min_child_weight=2.62; min_data_in_leaf=133; min_gain_to_split=0.0461; lambda_l1=0.441; lambda_l2=0.142; scale_pos_weight=4.72; learning_rate=0.0441; num_iterations=4468; early_stopping_rounds=371; feature_fraction=0.489; bagging_fraction=0.858; bagging_freq=4; max_delta_step=7.48; path_smooth=9.59 : y = 0.935 : 184.2 secs : infill_ei
#
# Tue Nov 18 09:33:25 AM 2025 AUC 0.932983775665713
#
# [mbo] 81: num_leaves=61; max_depth=21; min_child_weight=9.34; min_data_in_leaf=646; min_gain_to_split=0.0684; lambda_l1=0.159; lambda_l2=0.237; scale_pos_weight=3.86; learning_rate=0.0341; num_iterations=2384; early_stopping_rounds=488; feature_fraction=0.394; bagging_fraction=0.819; bagging_freq=3; max_delta_step=8.17; path_smooth=6.24 : y = 0.933 : 221.9 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Tue Nov 18 09:36:52 AM 2025 AUC 0.932012073798341
#
# [mbo] 82: num_leaves=63; max_depth=18; min_child_weight=8.25; min_data_in_leaf=52; min_gain_to_split=0.0838; lambda_l1=0.106; lambda_l2=0.0921; scale_pos_weight=2.44; learning_rate=0.0354; num_iterations=1777; early_stopping_rounds=441; feature_fraction=0.453; bagging_fraction=0.886; bagging_freq=3; max_delta_step=7.54; path_smooth=5.32 : y = 0.932 : 201.5 secs : infill_ei
#
# Tue Nov 18 09:41:48 AM 2025 AUC 0.931144051446514
#
# [mbo] 83: num_leaves=61; max_depth=21; min_child_weight=1.25; min_data_in_leaf=27; min_gain_to_split=0.0651; lambda_l1=0.447; lambda_l2=0.247; scale_pos_weight=3.94; learning_rate=0.0145; num_iterations=4336; early_stopping_rounds=441; feature_fraction=0.414; bagging_fraction=0.756; bagging_freq=3; max_delta_step=7.42; path_smooth=8.75 : y = 0.931 : 292.7 secs : infill_ei
#
# Tue Nov 18 09:49:12 AM 2025 AUC 0.934758742129248
#
# [mbo] 84: num_leaves=62; max_depth=23; min_child_weight=7.4; min_data_in_leaf=23; min_gain_to_split=0.0604; lambda_l1=0.381; lambda_l2=0.195; scale_pos_weight=3.46; learning_rate=0.0101; num_iterations=4258; early_stopping_rounds=400; feature_fraction=0.33; bagging_fraction=0.849; bagging_freq=2; max_delta_step=7.83; path_smooth=3.22 : y = 0.935 : 439.8 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Tue Nov 18 09:54:56 AM 2025 AUC 0.935759299784118
#
# [mbo] 85: num_leaves=59; max_depth=26; min_child_weight=6.58; min_data_in_leaf=422; min_gain_to_split=0.041; lambda_l1=0.292; lambda_l2=0.119; scale_pos_weight=3.57; learning_rate=0.0158; num_iterations=4196; early_stopping_rounds=354; feature_fraction=0.392; bagging_fraction=0.738; bagging_freq=4; max_delta_step=7.16; path_smooth=4.76 : y = 0.936 : 339.1 secs : infill_ei
#
# Tue Nov 18 09:56:59 AM 2025 AUC 0.930371991364738
#
# [mbo] 86: num_leaves=56; max_depth=18; min_child_weight=5.35; min_data_in_leaf=226; min_gain_to_split=0.0322; lambda_l1=0.369; lambda_l2=0.183; scale_pos_weight=4.53; learning_rate=0.0619; num_iterations=4504; early_stopping_rounds=256; feature_fraction=0.344; bagging_fraction=0.832; bagging_freq=4; max_delta_step=7.83; path_smooth=8.83 : y = 0.93 : 118.3 secs : infill_ei
#
# Tue Nov 18 10:00:08 AM 2025 AUC 0.928608768535649
#
# [mbo] 87: num_leaves=58; max_depth=28; min_child_weight=8.24; min_data_in_leaf=2681; min_gain_to_split=0.0635; lambda_l1=0.209; lambda_l2=0.0796; scale_pos_weight=4.01; learning_rate=0.0723; num_iterations=3739; early_stopping_rounds=474; feature_fraction=0.441; bagging_fraction=0.886; bagging_freq=2; max_delta_step=6.24; path_smooth=5.46 : y = 0.929 : 184.3 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Tue Nov 18 10:05:56 AM 2025 AUC 0.933280386318599
#
# [mbo] 88: num_leaves=59; max_depth=19; min_child_weight=5.19; min_data_in_leaf=13; min_gain_to_split=0.0554; lambda_l1=0.242; lambda_l2=0.0335; scale_pos_weight=3.41; learning_rate=0.0156; num_iterations=2704; early_stopping_rounds=334; feature_fraction=0.377; bagging_fraction=0.834; bagging_freq=4; max_delta_step=8.06; path_smooth=3.8 : y = 0.933 : 343.6 secs : infill_ei
#
# Tue Nov 18 10:08:51 AM 2025 AUC 0.928508779876645
#
# [mbo] 89: num_leaves=61; max_depth=25; min_child_weight=5.16; min_data_in_leaf=39; min_gain_to_split=0.0404; lambda_l1=0.306; lambda_l2=0.18; scale_pos_weight=2.82; learning_rate=0.0084; num_iterations=977; early_stopping_rounds=418; feature_fraction=0.407; bagging_fraction=0.678; bagging_freq=3; max_delta_step=9.62; path_smooth=2.59 : y = 0.929 : 166.9 secs : infill_ei
#
# Tue Nov 18 10:14:18 AM 2025 AUC 0.931866117198788
#
# [mbo] 90: num_leaves=61; max_depth=19; min_child_weight=7.33; min_data_in_leaf=51; min_gain_to_split=0.0647; lambda_l1=0.201; lambda_l2=0.189; scale_pos_weight=3.2; learning_rate=0.0204; num_iterations=3861; early_stopping_rounds=393; feature_fraction=0.404; bagging_fraction=0.666; bagging_freq=3; max_delta_step=9.43; path_smooth=7.23 : y = 0.932 : 321.9 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Tue Nov 18 10:20:01 AM 2025 AUC 0.932231176463878
#
# [mbo] 91: num_leaves=59; max_depth=23; min_child_weight=5.53; min_data_in_leaf=34; min_gain_to_split=0.0757; lambda_l1=0.0892; lambda_l2=0.311; scale_pos_weight=4.2; learning_rate=0.0181; num_iterations=4093; early_stopping_rounds=348; feature_fraction=0.429; bagging_fraction=0.779; bagging_freq=4; max_delta_step=7.56; path_smooth=2.79 : y = 0.932 : 338.4 secs : infill_ei
#
# Tue Nov 18 10:24:49 AM 2025 AUC 0.931688620552434
#
# [mbo] 92: num_leaves=55; max_depth=12; min_child_weight=2.14; min_data_in_leaf=1404; min_gain_to_split=0.0464; lambda_l1=0.404; lambda_l2=0.193; scale_pos_weight=1.58; learning_rate=0.0398; num_iterations=3666; early_stopping_rounds=447; feature_fraction=0.449; bagging_fraction=0.889; bagging_freq=1; max_delta_step=1.06; path_smooth=4.41 : y = 0.932 : 284.1 secs : infill_ei
#
# Saved the current state after iteration 93 in the file HT.RDATA.
#
# Tue Nov 18 10:28:35 AM 2025 AUC 0.931592658282383
#
# [mbo] 93: num_leaves=58; max_depth=22; min_child_weight=3.91; min_data_in_leaf=271; min_gain_to_split=0.057; lambda_l1=0.211; lambda_l2=0.263; scale_pos_weight=3.93; learning_rate=0.0355; num_iterations=3484; early_stopping_rounds=365; feature_fraction=0.424; bagging_fraction=0.865; bagging_freq=2; max_delta_step=7.02; path_smooth=7.62 : y = 0.932 : 221.9 secs : infill_ei
#
# Tue Nov 18 10:35:48 AM 2025 AUC 0.931058826213671
#
# [mbo] 94: num_leaves=53; max_depth=20; min_child_weight=8.16; min_data_in_leaf=116; min_gain_to_split=0.0617; lambda_l1=0.259; lambda_l2=0.0382; scale_pos_weight=1.99; learning_rate=0.0136; num_iterations=2452; early_stopping_rounds=406; feature_fraction=0.446; bagging_fraction=0.712; bagging_freq=3; max_delta_step=7.33; path_smooth=8.03 : y = 0.931 : 428.8 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Tue Nov 18 10:40:43 AM 2025 AUC 0.931625204926421
#
# [mbo] 95: num_leaves=60; max_depth=17; min_child_weight=4.21; min_data_in_leaf=31; min_gain_to_split=0.0224; lambda_l1=0.363; lambda_l2=0.421; scale_pos_weight=3.54; learning_rate=0.0125; num_iterations=4638; early_stopping_rounds=375; feature_fraction=0.313; bagging_fraction=0.836; bagging_freq=4; max_delta_step=7.51; path_smooth=5.14 : y = 0.932 : 285.5 secs : infill_ei
#
# Tue Nov 18 10:43:05 AM 2025 AUC 0.932711994411372
#
# [mbo] 96: num_leaves=48; max_depth=18; min_child_weight=0.878; min_data_in_leaf=113; min_gain_to_split=0.031; lambda_l1=0.293; lambda_l2=0.0558; scale_pos_weight=4.95; learning_rate=0.0767; num_iterations=4420; early_stopping_rounds=386; feature_fraction=0.527; bagging_fraction=0.867; bagging_freq=1; max_delta_step=6.01; path_smooth=8.33 : y = 0.933 : 138.5 secs : infill_ei
#
# Tue Nov 18 10:47:08 AM 2025 AUC 0.931870143587741
#
# [mbo] 97: num_leaves=52; max_depth=29; min_child_weight=9.96; min_data_in_leaf=1213; min_gain_to_split=0.0744; lambda_l1=0.118; lambda_l2=0.0481; scale_pos_weight=3.58; learning_rate=0.0329; num_iterations=1694; early_stopping_rounds=473; feature_fraction=0.305; bagging_fraction=0.815; bagging_freq=1; max_delta_step=6.28; path_smooth=1.46 : y = 0.932 : 238.7 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.
#
# Tue Nov 18 10:51:22 AM 2025 AUC 0.930247508839601
#
# [mbo] 98: num_leaves=62; max_depth=27; min_child_weight=9.89; min_data_in_leaf=316; min_gain_to_split=0.0489; lambda_l1=0.147; lambda_l2=0.0497; scale_pos_weight=3.38; learning_rate=0.0302; num_iterations=2731; early_stopping_rounds=499; feature_fraction=0.473; bagging_fraction=0.826; bagging_freq=4; max_delta_step=8.06; path_smooth=1.44 : y = 0.93 : 250.0 secs : infill_ei
#
# Tue Nov 18 10:57:02 AM 2025 AUC 0.930211942403848
#
# [mbo] 99: num_leaves=59; max_depth=24; min_child_weight=5.92; min_data_in_leaf=1217; min_gain_to_split=0.0198; lambda_l1=0.212; lambda_l2=0.276; scale_pos_weight=2.69; learning_rate=0.0277; num_iterations=2228; early_stopping_rounds=487; feature_fraction=0.341; bagging_fraction=0.851; bagging_freq=1; max_delta_step=8.48; path_smooth=6.23 : y = 0.93 : 335.7 secs : infill_ei
#
# Tue Nov 18 10:59:18 AM 2025 AUC 0.933540423938493
#
# [mbo] 100: num_leaves=46; max_depth=18; min_child_weight=2.03; min_data_in_leaf=210; min_gain_to_split=0.057; lambda_l1=0.244; lambda_l2=0.13; scale_pos_weight=4.65; learning_rate=0.0762; num_iterations=4098; early_stopping_rounds=372; feature_fraction=0.495; bagging_fraction=0.636; bagging_freq=3; max_delta_step=7.02; path_smooth=8.72 : y = 0.934 : 131.3 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:         57        19         3.192424               15        0.06567139
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.3104654 0.2484952         2.632279   0.007931443           4332
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   367        0.4577231        0.8272273            3
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       6.993878    7.760825

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6429600
#
# $envios
# [1] 1489

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_40348644
#                   2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 11:13:11 AM 2025"
# Inicio: Tue Nov 18 12:43:52 AM 2025
# Fin:    Tue Nov 18 11:13:11 AM 2025
# Duración (hh:mm:ss): 10:29:19
