# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_12H_124_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 17 09:45:06 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454477    77.7 1438383  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 499999 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63113
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),   # filas
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 17 10:04:11 PM 2025 AUC 0.928136674430887
#
# Mon Nov 17 10:07:22 PM 2025 AUC 0.923064430947094
#
# Mon Nov 17 10:09:37 PM 2025 AUC 0.921731360671172
#
# Mon Nov 17 10:13:21 PM 2025 AUC 0.9305759950717
#
# Mon Nov 17 10:14:59 PM 2025 AUC 0.919388673365236
#
# Mon Nov 17 10:19:06 PM 2025 AUC 0.930912869614118
#
# Mon Nov 17 10:24:00 PM 2025 AUC 0.920590886000178
#
# Mon Nov 17 10:26:32 PM 2025 AUC 0.920410034029697
#
# Mon Nov 17 10:27:42 PM 2025 AUC 0.918465623697715
#
# Mon Nov 17 10:34:25 PM 2025 AUC 0.922759096451476
#
# Mon Nov 17 10:37:17 PM 2025 AUC 0.920699934034328
#
# Mon Nov 17 10:38:53 PM 2025 AUC 0.920695907645374
#
# Mon Nov 17 10:42:04 PM 2025 AUC 0.920154022798756
#
# Mon Nov 17 10:44:49 PM 2025 AUC 0.926588192345969
#
# Mon Nov 17 10:48:44 PM 2025 AUC 0.917834151696888
#
# Mon Nov 17 10:49:17 PM 2025 AUC 0.91233074906269
#
# Mon Nov 17 10:50:02 PM 2025 AUC 0.91506198290261
#
# Mon Nov 17 10:52:29 PM 2025 AUC 0.926205349863002
#
# Mon Nov 17 10:55:04 PM 2025 AUC 0.920784488202345
#
# Mon Nov 17 10:59:42 PM 2025 AUC 0.929059724098408
#
# Mon Nov 17 11:01:57 PM 2025 AUC 0.917479493936594
#
# Mon Nov 17 11:06:25 PM 2025 AUC 0.921548159973802
#
# Mon Nov 17 11:08:38 PM 2025 AUC 0.922185671558058
#
# Mon Nov 17 11:12:08 PM 2025 AUC 0.919275934474546
#
# Mon Nov 17 11:14:31 PM 2025 AUC 0.923324133034575
#
# Mon Nov 17 11:17:07 PM 2025 AUC 0.918733378563103
#
# Mon Nov 17 11:19:45 PM 2025 AUC 0.92549435668035
#
# Mon Nov 17 11:27:10 PM 2025 AUC 0.919535301029615
#
# Mon Nov 17 11:28:28 PM 2025 AUC 0.924764909214995
#
# Mon Nov 17 11:29:52 PM 2025 AUC 0.917312398795036
#
# Mon Nov 17 11:31:02 PM 2025 AUC 0.924821949725165
#
# Mon Nov 17 11:37:20 PM 2025 AUC 0.921403881036312
#
# Mon Nov 17 11:41:08 PM 2025 AUC 0.918094860381608
#
# Mon Nov 17 11:44:38 PM 2025 AUC 0.916716828762375
#
# Mon Nov 17 11:45:48 PM 2025 AUC 0.914933809520934
#
# Mon Nov 17 11:46:37 PM 2025 AUC 0.915404897028458
#
# Mon Nov 17 11:48:33 PM 2025 AUC 0.919291368965533
#
# Mon Nov 17 11:50:40 PM 2025 AUC 0.918756194767171
#
# Mon Nov 17 11:52:04 PM 2025 AUC 0.925830560157942
#
# Mon Nov 17 11:52:34 PM 2025 AUC 0.915965907222604
#
# Mon Nov 17 11:57:10 PM 2025 AUC 0.922349746907901
#
# Mon Nov 17 11:58:05 PM 2025 AUC 0.870128153249732
#
# Tue Nov 18 12:00:48 AM 2025 AUC 0.928131305912282
#
# Tue Nov 18 12:01:05 AM 2025 AUC 0.913301108800411
#
# Tue Nov 18 12:04:50 AM 2025 AUC 0.92032178900514
#
# Tue Nov 18 12:05:18 AM 2025 AUC 0.918262626587991
#
# Tue Nov 18 12:07:28 AM 2025 AUC 0.914842880237074
#
# Tue Nov 18 12:11:06 AM 2025 AUC 0.924328046013573
#
# Tue Nov 18 12:13:10 AM 2025 AUC 0.915554208952139
#
# Tue Nov 18 12:14:12 AM 2025 AUC 0.91704967691584
#
# Tue Nov 18 12:15:14 AM 2025 AUC 0.919415180425844
#
# Tue Nov 18 12:18:28 AM 2025 AUC 0.922039714958505
#
# Tue Nov 18 12:25:28 AM 2025 AUC 0.925920482844563
#
# Tue Nov 18 12:27:43 AM 2025 AUC 0.92033755902854
#
# Tue Nov 18 12:28:39 AM 2025 AUC 0.917538212108828
#
# Tue Nov 18 12:29:47 AM 2025 AUC 0.917415742778168
#
# Tue Nov 18 12:38:02 AM 2025 AUC 0.930584047849606
#
# Tue Nov 18 12:39:16 AM 2025 AUC 0.922680581866889
#
# Tue Nov 18 12:40:52 AM 2025 AUC 0.927981993988601
#
# Tue Nov 18 12:45:20 AM 2025 AUC 0.918366977168361
#
# Tue Nov 18 12:49:18 AM 2025 AUC 0.922341694129995
#
# Tue Nov 18 12:51:27 AM 2025 AUC 0.915649164624952
#
# Tue Nov 18 12:54:01 AM 2025 AUC 0.91728018768341
#
# Tue Nov 18 12:55:13 AM 2025 AUC 0.920377822918072
#
# [mbo] 0: num_leaves=47; max_depth=6; min_child_weight=5.16; min_data_in_leaf=2527; min_gain_to_split=0.0335; lambda_l1=0.255; lambda_l2=0.181; scale_pos_weight=4.15; learning_rate=0.0446; num_iterations=3607; early_stopping_rounds=416; feature_fraction=0.527; bagging_fraction=0.67; bagging_freq=3; max_delta_step=8.89; path_smooth=6.39 : y = 0.928 : 462.0 secs : initdesign
#
# [mbo] 0: num_leaves=29; max_depth=12; min_child_weight=3.52; min_data_in_leaf=3934; min_gain_to_split=0.0221; lambda_l1=0.154; lambda_l2=0.222; scale_pos_weight=2.64; learning_rate=0.0888; num_iterations=3212; early_stopping_rounds=277; feature_fraction=0.577; bagging_fraction=0.765; bagging_freq=3; max_delta_step=6.51; path_smooth=2.91 : y = 0.923 : 190.7 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=19; min_child_weight=4.62; min_data_in_leaf=2224; min_gain_to_split=0.0674; lambda_l1=0.391; lambda_l2=0.254; scale_pos_weight=2.85; learning_rate=0.0225; num_iterations=3375; early_stopping_rounds=134; feature_fraction=0.417; bagging_fraction=0.634; bagging_freq=2; max_delta_step=5.99; path_smooth=5.59 : y = 0.922 : 135.5 secs : initdesign
#
# [mbo] 0: num_leaves=34; max_depth=15; min_child_weight=7.91; min_data_in_leaf=1048; min_gain_to_split=0.0216; lambda_l1=0.214; lambda_l2=0.264; scale_pos_weight=3.89; learning_rate=0.0589; num_iterations=1282; early_stopping_rounds=376; feature_fraction=0.504; bagging_fraction=0.641; bagging_freq=3; max_delta_step=5.28; path_smooth=6.73 : y = 0.931 : 223.5 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=15; min_child_weight=3.37; min_data_in_leaf=4380; min_gain_to_split=0.056; lambda_l1=0.00899; lambda_l2=0.139; scale_pos_weight=3.02; learning_rate=0.0526; num_iterations=2387; early_stopping_rounds=268; feature_fraction=0.478; bagging_fraction=0.623; bagging_freq=4; max_delta_step=5.63; path_smooth=7.73 : y = 0.919 : 98.6 secs : initdesign
#
# [mbo] 0: num_leaves=37; max_depth=20; min_child_weight=3.9; min_data_in_leaf=802; min_gain_to_split=0.0469; lambda_l1=0.231; lambda_l2=0.176; scale_pos_weight=3.55; learning_rate=0.034; num_iterations=2874; early_stopping_rounds=323; feature_fraction=0.567; bagging_fraction=0.804; bagging_freq=1; max_delta_step=4.54; path_smooth=7.04 : y = 0.931 : 246.4 secs : initdesign
#
# [mbo] 0: num_leaves=5; max_depth=13; min_child_weight=7.2; min_data_in_leaf=6436; min_gain_to_split=0.0398; lambda_l1=0.449; lambda_l2=0.36; scale_pos_weight=1.06; learning_rate=0.0509; num_iterations=2499; early_stopping_rounds=368; feature_fraction=0.489; bagging_fraction=0.66; bagging_freq=4; max_delta_step=1.47; path_smooth=1.79 : y = 0.921 : 294.8 secs : initdesign
#
# [mbo] 0: num_leaves=38; max_depth=21; min_child_weight=2.07; min_data_in_leaf=5883; min_gain_to_split=0.0372; lambda_l1=0.272; lambda_l2=0.212; scale_pos_weight=3.08; learning_rate=0.0581; num_iterations=3634; early_stopping_rounds=192; feature_fraction=0.355; bagging_fraction=0.614; bagging_freq=5; max_delta_step=1.86; path_smooth=6.16 : y = 0.92 : 151.1 secs : initdesign
#
# [mbo] 0: num_leaves=14; max_depth=13; min_child_weight=6.11; min_data_in_leaf=6970; min_gain_to_split=0.0442; lambda_l1=0.351; lambda_l2=0.2; scale_pos_weight=3.67; learning_rate=0.068; num_iterations=3279; early_stopping_rounds=174; feature_fraction=0.639; bagging_fraction=0.789; bagging_freq=4; max_delta_step=8.06; path_smooth=7.88 : y = 0.918 : 70.9 secs : initdesign
#
# [mbo] 0: num_leaves=16; max_depth=18; min_child_weight=1.29; min_data_in_leaf=3422; min_gain_to_split=0.0667; lambda_l1=0.385; lambda_l2=0.288; scale_pos_weight=2.6; learning_rate=0.0144; num_iterations=2659; early_stopping_rounds=455; feature_fraction=0.586; bagging_fraction=0.627; bagging_freq=3; max_delta_step=3.84; path_smooth=7.3 : y = 0.923 : 402.7 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=18; min_child_weight=9.58; min_data_in_leaf=7060; min_gain_to_split=0.0522; lambda_l1=0.146; lambda_l2=0.231; scale_pos_weight=3.43; learning_rate=0.0633; num_iterations=3809; early_stopping_rounds=337; feature_fraction=0.522; bagging_fraction=0.608; bagging_freq=4; max_delta_step=4.52; path_smooth=4.07 : y = 0.921 : 172.2 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=13; min_child_weight=6.42; min_data_in_leaf=2330; min_gain_to_split=0.0651; lambda_l1=0.208; lambda_l2=0.393; scale_pos_weight=1.43; learning_rate=0.0714; num_iterations=1992; early_stopping_rounds=158; feature_fraction=0.7; bagging_fraction=0.799; bagging_freq=1; max_delta_step=3.22; path_smooth=4.32 : y = 0.921 : 95.2 secs : initdesign
#
# [mbo] 0: num_leaves=38; max_depth=26; min_child_weight=3.13; min_data_in_leaf=7348; min_gain_to_split=0.00971; lambda_l1=0.0755; lambda_l2=0.463; scale_pos_weight=3.19; learning_rate=0.0186; num_iterations=1489; early_stopping_rounds=188; feature_fraction=0.336; bagging_fraction=0.555; bagging_freq=4; max_delta_step=2.34; path_smooth=1.12 : y = 0.92 : 191.6 secs : initdesign
#
# [mbo] 0: num_leaves=43; max_depth=19; min_child_weight=8.66; min_data_in_leaf=1345; min_gain_to_split=0.0425; lambda_l1=0.416; lambda_l2=0.242; scale_pos_weight=2.01; learning_rate=0.0433; num_iterations=1185; early_stopping_rounds=343; feature_fraction=0.666; bagging_fraction=0.666; bagging_freq=4; max_delta_step=5.52; path_smooth=9.77 : y = 0.927 : 164.5 secs : initdesign
#
# [mbo] 0: num_leaves=58; max_depth=9; min_child_weight=8.16; min_data_in_leaf=4662; min_gain_to_split=0.0618; lambda_l1=0.0599; lambda_l2=0.0909; scale_pos_weight=4.06; learning_rate=0.00655; num_iterations=1451; early_stopping_rounds=401; feature_fraction=0.596; bagging_fraction=0.841; bagging_freq=2; max_delta_step=5.42; path_smooth=3.63 : y = 0.918 : 235.1 secs : initdesign
#
# [mbo] 0: num_leaves=12; max_depth=24; min_child_weight=6.71; min_data_in_leaf=5963; min_gain_to_split=0.0933; lambda_l1=0.332; lambda_l2=0.43; scale_pos_weight=1.72; learning_rate=0.0618; num_iterations=207; early_stopping_rounds=117; feature_fraction=0.461; bagging_fraction=0.699; bagging_freq=2; max_delta_step=4.34; path_smooth=2.42 : y = 0.912 : 33.2 secs : initdesign
#
# [mbo] 0: num_leaves=28; max_depth=10; min_child_weight=7.08; min_data_in_leaf=3136; min_gain_to_split=0.0605; lambda_l1=0.0324; lambda_l2=0.406; scale_pos_weight=2.39; learning_rate=0.0553; num_iterations=424; early_stopping_rounds=74; feature_fraction=0.749; bagging_fraction=0.676; bagging_freq=5; max_delta_step=2.06; path_smooth=8.26 : y = 0.915 : 44.6 secs : initdesign
#
# [mbo] 0: num_leaves=21; max_depth=28; min_child_weight=9.06; min_data_in_leaf=109; min_gain_to_split=0.0378; lambda_l1=0.406; lambda_l2=0.0141; scale_pos_weight=3.24; learning_rate=0.0418; num_iterations=3869; early_stopping_rounds=385; feature_fraction=0.656; bagging_fraction=0.58; bagging_freq=5; max_delta_step=3.72; path_smooth=3.08 : y = 0.926 : 147.4 secs : initdesign
#
# [mbo] 0: num_leaves=41; max_depth=4; min_child_weight=5.36; min_data_in_leaf=2106; min_gain_to_split=0.0289; lambda_l1=0.316; lambda_l2=0.189; scale_pos_weight=4.01; learning_rate=0.0939; num_iterations=2574; early_stopping_rounds=392; feature_fraction=0.614; bagging_fraction=0.807; bagging_freq=3; max_delta_step=6.27; path_smooth=3.55 : y = 0.921 : 155.3 secs : initdesign
#
# [mbo] 0: num_leaves=57; max_depth=13; min_child_weight=2.41; min_data_in_leaf=1576; min_gain_to_split=0.0626; lambda_l1=0.286; lambda_l2=0.143; scale_pos_weight=2.52; learning_rate=0.0325; num_iterations=2311; early_stopping_rounds=154; feature_fraction=0.372; bagging_fraction=0.711; bagging_freq=3; max_delta_step=7.63; path_smooth=9.87 : y = 0.929 : 277.7 secs : initdesign
#
# [mbo] 0: num_leaves=4; max_depth=15; min_child_weight=0.315; min_data_in_leaf=6785; min_gain_to_split=0.0465; lambda_l1=0.135; lambda_l2=0.386; scale_pos_weight=2.2; learning_rate=0.0905; num_iterations=2058; early_stopping_rounds=207; feature_fraction=0.558; bagging_fraction=0.558; bagging_freq=3; max_delta_step=1.27; path_smooth=6.01 : y = 0.917 : 134.6 secs : initdesign
#
# [mbo] 0: num_leaves=18; max_depth=16; min_child_weight=2.33; min_data_in_leaf=5630; min_gain_to_split=0.0721; lambda_l1=0.48; lambda_l2=0.000666; scale_pos_weight=1.54; learning_rate=0.0237; num_iterations=3487; early_stopping_rounds=229; feature_fraction=0.426; bagging_fraction=0.891; bagging_freq=3; max_delta_step=3.41; path_smooth=1.3 : y = 0.922 : 268.7 secs : initdesign
#
# [mbo] 0: num_leaves=17; max_depth=28; min_child_weight=3.72; min_data_in_leaf=3634; min_gain_to_split=0.0128; lambda_l1=0.461; lambda_l2=0.498; scale_pos_weight=3.61; learning_rate=0.0753; num_iterations=928; early_stopping_rounds=270; feature_fraction=0.34; bagging_fraction=0.814; bagging_freq=3; max_delta_step=0.232; path_smooth=7.49 : y = 0.922 : 132.6 secs : initdesign
#
# [mbo] 0: num_leaves=56; max_depth=17; min_child_weight=3.08; min_data_in_leaf=5332; min_gain_to_split=0.0699; lambda_l1=0.00586; lambda_l2=0.0301; scale_pos_weight=1.37; learning_rate=0.0691; num_iterations=4249; early_stopping_rounds=256; feature_fraction=0.714; bagging_fraction=0.885; bagging_freq=5; max_delta_step=7.07; path_smooth=0.538 : y = 0.919 : 210.1 secs : initdesign
#
# [mbo] 0: num_leaves=40; max_depth=20; min_child_weight=6.3; min_data_in_leaf=750; min_gain_to_split=0.0259; lambda_l1=0.167; lambda_l2=0.31; scale_pos_weight=2.89; learning_rate=0.0999; num_iterations=4801; early_stopping_rounds=217; feature_fraction=0.326; bagging_fraction=0.528; bagging_freq=1; max_delta_step=5.15; path_smooth=9.31 : y = 0.923 : 142.8 secs : initdesign
#
# [mbo] 0: num_leaves=32; max_depth=3; min_child_weight=9.2; min_data_in_leaf=5054; min_gain_to_split=0.0846; lambda_l1=0.28; lambda_l2=0.295; scale_pos_weight=4.71; learning_rate=0.0469; num_iterations=3077; early_stopping_rounds=480; feature_fraction=0.385; bagging_fraction=0.759; bagging_freq=5; max_delta_step=6.63; path_smooth=3.39 : y = 0.919 : 155.7 secs : initdesign
#
# [mbo] 0: num_leaves=62; max_depth=25; min_child_weight=8.49; min_data_in_leaf=3319; min_gain_to_split=0.0763; lambda_l1=0.191; lambda_l2=0.0641; scale_pos_weight=3.99; learning_rate=0.0739; num_iterations=1059; early_stopping_rounds=305; feature_fraction=0.314; bagging_fraction=0.755; bagging_freq=4; max_delta_step=1.6; path_smooth=8.06 : y = 0.925 : 158.9 secs : initdesign
#
# [mbo] 0: num_leaves=13; max_depth=7; min_child_weight=1.53; min_data_in_leaf=5672; min_gain_to_split=0.0957; lambda_l1=0.161; lambda_l2=0.242; scale_pos_weight=2.49; learning_rate=0.0107; num_iterations=4514; early_stopping_rounds=282; feature_fraction=0.397; bagging_fraction=0.705; bagging_freq=2; max_delta_step=0.921; path_smooth=9 : y = 0.92 : 444.5 secs : initdesign
#
# [mbo] 0: num_leaves=36; max_depth=29; min_child_weight=2.94; min_data_in_leaf=4854; min_gain_to_split=0.081; lambda_l1=0.125; lambda_l2=0.12; scale_pos_weight=4.6; learning_rate=0.0608; num_iterations=525; early_stopping_rounds=177; feature_fraction=0.645; bagging_fraction=0.895; bagging_freq=5; max_delta_step=3.45; path_smooth=0.0768 : y = 0.925 : 78.6 secs : initdesign
#
# [mbo] 0: num_leaves=22; max_depth=4; min_child_weight=5.49; min_data_in_leaf=4332; min_gain_to_split=0.0885; lambda_l1=0.443; lambda_l2=0.371; scale_pos_weight=2.13; learning_rate=0.0374; num_iterations=3007; early_stopping_rounds=123; feature_fraction=0.692; bagging_fraction=0.571; bagging_freq=4; max_delta_step=8.15; path_smooth=5.31 : y = 0.917 : 84.0 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=17; min_child_weight=5.21; min_data_in_leaf=511; min_gain_to_split=0.0177; lambda_l1=0.29; lambda_l2=0.408; scale_pos_weight=4.25; learning_rate=0.0166; num_iterations=2209; early_stopping_rounds=61; feature_fraction=0.744; bagging_fraction=0.722; bagging_freq=3; max_delta_step=6.95; path_smooth=6.95 : y = 0.925 : 69.6 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=24; min_child_weight=0.646; min_data_in_leaf=2978; min_gain_to_split=0.0782; lambda_l1=0.423; lambda_l2=0.166; scale_pos_weight=3.47; learning_rate=0.00641; num_iterations=4594; early_stopping_rounds=237; feature_fraction=0.756; bagging_fraction=0.545; bagging_freq=5; max_delta_step=2.86; path_smooth=7.64 : y = 0.921 : 377.6 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=11; min_child_weight=5.79; min_data_in_leaf=7858; min_gain_to_split=0.0172; lambda_l1=0.304; lambda_l2=0.381; scale_pos_weight=3.28; learning_rate=0.0092; num_iterations=1642; early_stopping_rounds=346; feature_fraction=0.302; bagging_fraction=0.862; bagging_freq=2; max_delta_step=8.52; path_smooth=3.15 : y = 0.918 : 228.3 secs : initdesign
#
# [mbo] 0: num_leaves=51; max_depth=14; min_child_weight=4.81; min_data_in_leaf=6172; min_gain_to_split=0.0513; lambda_l1=0.0158; lambda_l2=0.268; scale_pos_weight=1.2; learning_rate=0.083; num_iterations=4737; early_stopping_rounds=299; feature_fraction=0.425; bagging_fraction=0.686; bagging_freq=1; max_delta_step=2.73; path_smooth=0.451 : y = 0.917 : 210.5 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=16; min_child_weight=8.02; min_data_in_leaf=1789; min_gain_to_split=0.0547; lambda_l1=0.344; lambda_l2=0.442; scale_pos_weight=4.43; learning_rate=0.0382; num_iterations=833; early_stopping_rounds=429; feature_fraction=0.688; bagging_fraction=0.868; bagging_freq=3; max_delta_step=4.75; path_smooth=8.74 : y = 0.915 : 69.9 secs : initdesign
#
# [mbo] 0: num_leaves=7; max_depth=22; min_child_weight=7.58; min_data_in_leaf=8186; min_gain_to_split=0.0269; lambda_l1=0.467; lambda_l2=0.427; scale_pos_weight=3.35; learning_rate=0.0205; num_iterations=4401; early_stopping_rounds=140; feature_fraction=0.669; bagging_fraction=0.567; bagging_freq=1; max_delta_step=6.2; path_smooth=3.95 : y = 0.915 : 48.6 secs : initdesign
#
# [mbo] 0: num_leaves=30; max_depth=10; min_child_weight=9.22; min_data_in_leaf=2920; min_gain_to_split=0.0122; lambda_l1=0.183; lambda_l2=0.072; scale_pos_weight=1.8; learning_rate=0.0182; num_iterations=589; early_stopping_rounds=144; feature_fraction=0.56; bagging_fraction=0.855; bagging_freq=5; max_delta_step=3.04; path_smooth=2.53 : y = 0.919 : 116.0 secs : initdesign
#
# [mbo] 0: num_leaves=20; max_depth=20; min_child_weight=7.46; min_data_in_leaf=7799; min_gain_to_split=0.0309; lambda_l1=0.226; lambda_l2=0.0314; scale_pos_weight=2.98; learning_rate=0.0248; num_iterations=1717; early_stopping_rounds=289; feature_fraction=0.682; bagging_fraction=0.504; bagging_freq=4; max_delta_step=6.86; path_smooth=9.22 : y = 0.919 : 127.2 secs : initdesign
#
# [mbo] 0: num_leaves=34; max_depth=7; min_child_weight=0.127; min_data_in_leaf=173; min_gain_to_split=0.0987; lambda_l1=0.485; lambda_l2=0.155; scale_pos_weight=3.82; learning_rate=0.0516; num_iterations=2717; early_stopping_rounds=219; feature_fraction=0.464; bagging_fraction=0.831; bagging_freq=3; max_delta_step=9.04; path_smooth=0.882 : y = 0.926 : 84.3 secs : initdesign
#
# [mbo] 0: num_leaves=8; max_depth=11; min_child_weight=1.91; min_data_in_leaf=7286; min_gain_to_split=0.0566; lambda_l1=0.198; lambda_l2=0.0832; scale_pos_weight=1.97; learning_rate=0.0925; num_iterations=4626; early_stopping_rounds=103; feature_fraction=0.762; bagging_fraction=0.514; bagging_freq=2; max_delta_step=8.66; path_smooth=1.71 : y = 0.916 : 29.5 secs : initdesign
#
# [mbo] 0: num_leaves=15; max_depth=4; min_child_weight=5.95; min_data_in_leaf=1245; min_gain_to_split=0.0771; lambda_l1=0.236; lambda_l2=0.45; scale_pos_weight=1.86; learning_rate=0.097; num_iterations=4099; early_stopping_rounds=490; feature_fraction=0.496; bagging_fraction=0.688; bagging_freq=2; max_delta_step=9.81; path_smooth=5.68 : y = 0.922 : 276.0 secs : initdesign
#
# [mbo] 0: num_leaves=49; max_depth=29; min_child_weight=2.56; min_data_in_leaf=3798; min_gain_to_split=0.0892; lambda_l1=0.321; lambda_l2=0.42; scale_pos_weight=2.36; learning_rate=0.0278; num_iterations=644; early_stopping_rounds=433; feature_fraction=0.734; bagging_fraction=0.748; bagging_freq=1; max_delta_step=0.00611; path_smooth=0.7 : y = 0.87 : 55.5 secs : initdesign
#
# [mbo] 0: num_leaves=9; max_depth=22; min_child_weight=3.96; min_data_in_leaf=2034; min_gain_to_split=0.00822; lambda_l1=0.0245; lambda_l2=0.331; scale_pos_weight=2.78; learning_rate=0.0844; num_iterations=2103; early_stopping_rounds=317; feature_fraction=0.35; bagging_fraction=0.87; bagging_freq=4; max_delta_step=9.63; path_smooth=4.43 : y = 0.928 : 162.1 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=11; min_child_weight=6.97; min_data_in_leaf=2570; min_gain_to_split=0.0422; lambda_l1=0.0844; lambda_l2=0.348; scale_pos_weight=4.67; learning_rate=0.0855; num_iterations=136; early_stopping_rounds=242; feature_fraction=0.713; bagging_fraction=0.646; bagging_freq=2; max_delta_step=0.463; path_smooth=1.05 : y = 0.913 : 17.7 secs : initdesign
#
# [mbo] 0: num_leaves=26; max_depth=23; min_child_weight=9.97; min_data_in_leaf=3479; min_gain_to_split=0.0346; lambda_l1=0.262; lambda_l2=0.491; scale_pos_weight=1.44; learning_rate=0.0775; num_iterations=3703; early_stopping_rounds=458; feature_fraction=0.784; bagging_fraction=0.782; bagging_freq=5; max_delta_step=3.92; path_smooth=3.78 : y = 0.92 : 225.0 secs : initdesign
#
# [mbo] 0: num_leaves=33; max_depth=8; min_child_weight=4.19; min_data_in_leaf=4898; min_gain_to_split=0.00693; lambda_l1=0.436; lambda_l2=0.459; scale_pos_weight=3.75; learning_rate=0.0871; num_iterations=758; early_stopping_rounds=52; feature_fraction=0.318; bagging_fraction=0.718; bagging_freq=5; max_delta_step=5.94; path_smooth=5.03 : y = 0.918 : 27.9 secs : initdesign
#
# [mbo] 0: num_leaves=2; max_depth=28; min_child_weight=4.97; min_data_in_leaf=2779; min_gain_to_split=0.0826; lambda_l1=0.178; lambda_l2=0.305; scale_pos_weight=2.27; learning_rate=0.0667; num_iterations=4021; early_stopping_rounds=360; feature_fraction=0.792; bagging_fraction=0.587; bagging_freq=1; max_delta_step=0.593; path_smooth=8.52 : y = 0.915 : 130.0 secs : initdesign
#
# [mbo] 0: num_leaves=22; max_depth=23; min_child_weight=1.83; min_data_in_leaf=6068; min_gain_to_split=0.0981; lambda_l1=0.0503; lambda_l2=0.163; scale_pos_weight=4.88; learning_rate=0.0817; num_iterations=4166; early_stopping_rounds=415; feature_fraction=0.515; bagging_fraction=0.725; bagging_freq=5; max_delta_step=8.43; path_smooth=5.79 : y = 0.924 : 217.4 secs : initdesign
#
# [mbo] 0: num_leaves=63; max_depth=3; min_child_weight=2.73; min_data_in_leaf=5471; min_gain_to_split=0.00578; lambda_l1=0.115; lambda_l2=0.0177; scale_pos_weight=4.34; learning_rate=0.0494; num_iterations=3417; early_stopping_rounds=199; feature_fraction=0.448; bagging_fraction=0.519; bagging_freq=1; max_delta_step=7.76; path_smooth=9.6 : y = 0.916 : 124.6 secs : initdesign
#
# [mbo] 0: num_leaves=28; max_depth=9; min_child_weight=0.933; min_data_in_leaf=4130; min_gain_to_split=0.0142; lambda_l1=0.0687; lambda_l2=0.0541; scale_pos_weight=1.66; learning_rate=0.0955; num_iterations=321; early_stopping_rounds=405; feature_fraction=0.545; bagging_fraction=0.771; bagging_freq=1; max_delta_step=4.18; path_smooth=6.72 : y = 0.917 : 61.9 secs : initdesign
#
# [mbo] 0: num_leaves=14; max_depth=30; min_child_weight=9.75; min_data_in_leaf=5241; min_gain_to_split=0.0915; lambda_l1=0.101; lambda_l2=0.32; scale_pos_weight=3.81; learning_rate=0.04; num_iterations=1002; early_stopping_rounds=85; feature_fraction=0.725; bagging_fraction=0.775; bagging_freq=1; max_delta_step=9.13; path_smooth=5.41 : y = 0.919 : 62.2 secs : initdesign
#
# [mbo] 0: num_leaves=23; max_depth=26; min_child_weight=8.88; min_data_in_leaf=1919; min_gain_to_split=0.0869; lambda_l1=0.375; lambda_l2=0.128; scale_pos_weight=1.26; learning_rate=0.0567; num_iterations=1346; early_stopping_rounds=451; feature_fraction=0.542; bagging_fraction=0.597; bagging_freq=2; max_delta_step=7.97; path_smooth=0.266 : y = 0.922 : 193.9 secs : initdesign
#
# [mbo] 0: num_leaves=44; max_depth=18; min_child_weight=9.44; min_data_in_leaf=6841; min_gain_to_split=0.000129; lambda_l1=0.38; lambda_l2=0.114; scale_pos_weight=4.27; learning_rate=0.0299; num_iterations=4850; early_stopping_rounds=466; feature_fraction=0.623; bagging_fraction=0.845; bagging_freq=3; max_delta_step=2.29; path_smooth=1.46 : y = 0.926 : 420.2 secs : initdesign
#
# [mbo] 0: num_leaves=49; max_depth=8; min_child_weight=7.69; min_data_in_leaf=6335; min_gain_to_split=0.0324; lambda_l1=0.472; lambda_l2=0.358; scale_pos_weight=1.61; learning_rate=0.0352; num_iterations=2812; early_stopping_rounds=247; feature_fraction=0.37; bagging_fraction=0.655; bagging_freq=2; max_delta_step=0.94; path_smooth=8.3 : y = 0.92 : 134.6 secs : initdesign
#
# [mbo] 0: num_leaves=31; max_depth=26; min_child_weight=0.481; min_data_in_leaf=4549; min_gain_to_split=0.0238; lambda_l1=0.244; lambda_l2=0.205; scale_pos_weight=4.49; learning_rate=0.0457; num_iterations=373; early_stopping_rounds=495; feature_fraction=0.39; bagging_fraction=0.602; bagging_freq=5; max_delta_step=1.22; path_smooth=4.7 : y = 0.918 : 55.6 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=21; min_child_weight=1.16; min_data_in_leaf=7978; min_gain_to_split=0.00245; lambda_l1=0.0438; lambda_l2=0.0993; scale_pos_weight=4.76; learning_rate=0.0727; num_iterations=1870; early_stopping_rounds=164; feature_fraction=0.789; bagging_fraction=0.834; bagging_freq=2; max_delta_step=9.91; path_smooth=2.15 : y = 0.917 : 68.0 secs : initdesign
#
# [mbo] 0: num_leaves=51; max_depth=5; min_child_weight=4.5; min_data_in_leaf=1017; min_gain_to_split=0.0839; lambda_l1=0.406; lambda_l2=0.473; scale_pos_weight=4.52; learning_rate=0.0129; num_iterations=4334; early_stopping_rounds=441; feature_fraction=0.606; bagging_fraction=0.537; bagging_freq=1; max_delta_step=7.26; path_smooth=6.56 : y = 0.931 : 495.4 secs : initdesign
#
# [mbo] 0: num_leaves=59; max_depth=6; min_child_weight=1.07; min_data_in_leaf=1496; min_gain_to_split=0.0952; lambda_l1=0.125; lambda_l2=0.274; scale_pos_weight=2.07; learning_rate=0.0957; num_iterations=3101; early_stopping_rounds=329; feature_fraction=0.774; bagging_fraction=0.743; bagging_freq=4; max_delta_step=2.53; path_smooth=8.83 : y = 0.923 : 73.7 secs : initdesign
#
# [mbo] 0: num_leaves=60; max_depth=25; min_child_weight=0.227; min_data_in_leaf=285; min_gain_to_split=0.0709; lambda_l1=0.358; lambda_l2=0.0401; scale_pos_weight=4.99; learning_rate=0.065; num_iterations=4996; early_stopping_rounds=69; feature_fraction=0.435; bagging_fraction=0.592; bagging_freq=1; max_delta_step=1.97; path_smooth=2.23 : y = 0.928 : 96.1 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=30; min_child_weight=4.24; min_data_in_leaf=7561; min_gain_to_split=0.0497; lambda_l1=0.493; lambda_l2=0.102; scale_pos_weight=1.91; learning_rate=0.0117; num_iterations=2470; early_stopping_rounds=83; feature_fraction=0.599; bagging_fraction=0.878; bagging_freq=5; max_delta_step=7.38; path_smooth=4.69 : y = 0.918 : 268.2 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=27; min_child_weight=8.42; min_data_in_leaf=4022; min_gain_to_split=0.00394; lambda_l1=0.31; lambda_l2=0.323; scale_pos_weight=2.69; learning_rate=0.0778; num_iterations=1620; early_stopping_rounds=475; feature_fraction=0.63; bagging_fraction=0.825; bagging_freq=1; max_delta_step=9.25; path_smooth=9.45 : y = 0.922 : 238.1 secs : initdesign
#
# [mbo] 0: num_leaves=11; max_depth=9; min_child_weight=1.71; min_data_in_leaf=7463; min_gain_to_split=0.0189; lambda_l1=0.36; lambda_l2=0.343; scale_pos_weight=1.18; learning_rate=0.0316; num_iterations=1112; early_stopping_rounds=353; feature_fraction=0.454; bagging_fraction=0.508; bagging_freq=4; max_delta_step=9.46; path_smooth=1.98 : y = 0.916 : 128.7 secs : initdesign
#
# [mbo] 0: num_leaves=3; max_depth=6; min_child_weight=5.65; min_data_in_leaf=6625; min_gain_to_split=0.0739; lambda_l1=0.104; lambda_l2=0.0559; scale_pos_weight=4.82; learning_rate=0.0798; num_iterations=1809; early_stopping_rounds=110; feature_fraction=0.406; bagging_fraction=0.735; bagging_freq=2; max_delta_step=0.662; path_smooth=4.94 : y = 0.917 : 153.9 secs : initdesign
#
# [mbo] 0: num_leaves=61; max_depth=27; min_child_weight=6.84; min_data_in_leaf=604; min_gain_to_split=0.0586; lambda_l1=0.0917; lambda_l2=0.477; scale_pos_weight=1.08; learning_rate=0.0262; num_iterations=3972; early_stopping_rounds=94; feature_fraction=0.484; bagging_fraction=0.541; bagging_freq=4; max_delta_step=4.89; path_smooth=2.77 : y = 0.92 : 72.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Nov 18 12:58:13 AM 2025 AUC 0.925347729015971
#
# [mbo] 1: num_leaves=56; max_depth=7; min_child_weight=5.32; min_data_in_leaf=933; min_gain_to_split=0.0317; lambda_l1=0.409; lambda_l2=0.193; scale_pos_weight=4.1; learning_rate=0.0503; num_iterations=2982; early_stopping_rounds=280; feature_fraction=0.531; bagging_fraction=0.754; bagging_freq=2; max_delta_step=6.91; path_smooth=6.55 : y = 0.925 : 177.4 secs : infill_ei
#
# Tue Nov 18 01:00:41 AM 2025 AUC 0.923450964286601
#
# [mbo] 2: num_leaves=34; max_depth=21; min_child_weight=7.32; min_data_in_leaf=333; min_gain_to_split=0.0496; lambda_l1=0.223; lambda_l2=0.128; scale_pos_weight=4.05; learning_rate=0.0774; num_iterations=1989; early_stopping_rounds=407; feature_fraction=0.498; bagging_fraction=0.699; bagging_freq=3; max_delta_step=7.37; path_smooth=6.57 : y = 0.923 : 146.6 secs : infill_ei
#
# Tue Nov 18 01:02:21 AM 2025 AUC 0.918668620807439
#
# [mbo] 3: num_leaves=29; max_depth=25; min_child_weight=8.05; min_data_in_leaf=1139; min_gain_to_split=0.0102; lambda_l1=0.205; lambda_l2=0.299; scale_pos_weight=3.6; learning_rate=0.0668; num_iterations=1326; early_stopping_rounds=149; feature_fraction=0.486; bagging_fraction=0.61; bagging_freq=4; max_delta_step=4.65; path_smooth=9.07 : y = 0.919 : 99.1 secs : infill_ei
#
# Tue Nov 18 01:08:18 AM 2025 AUC 0.933848107161
#
# [mbo] 4: num_leaves=43; max_depth=18; min_child_weight=1.56; min_data_in_leaf=191; min_gain_to_split=0.0365; lambda_l1=0.255; lambda_l2=0.182; scale_pos_weight=4.01; learning_rate=0.0349; num_iterations=3516; early_stopping_rounds=406; feature_fraction=0.413; bagging_fraction=0.815; bagging_freq=2; max_delta_step=9.68; path_smooth=6.46 : y = 0.934 : 355.3 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Tue Nov 18 01:12:16 AM 2025 AUC 0.929951569251541
#
# [mbo] 5: num_leaves=44; max_depth=15; min_child_weight=0.415; min_data_in_leaf=656; min_gain_to_split=0.0292; lambda_l1=0.133; lambda_l2=0.247; scale_pos_weight=3.06; learning_rate=0.0194; num_iterations=3407; early_stopping_rounds=402; feature_fraction=0.477; bagging_fraction=0.715; bagging_freq=3; max_delta_step=9.14; path_smooth=7.42 : y = 0.93 : 236.3 secs : infill_ei
#
# Tue Nov 18 01:15:22 AM 2025 AUC 0.930555863126934
#
# [mbo] 6: num_leaves=23; max_depth=18; min_child_weight=4; min_data_in_leaf=628; min_gain_to_split=0.0137; lambda_l1=0.459; lambda_l2=0.125; scale_pos_weight=3.75; learning_rate=0.0458; num_iterations=3089; early_stopping_rounds=357; feature_fraction=0.369; bagging_fraction=0.624; bagging_freq=3; max_delta_step=4.09; path_smooth=9.02 : y = 0.931 : 184.9 secs : infill_ei
#
# Tue Nov 18 01:18:49 AM 2025 AUC 0.929206687295199
#
# [mbo] 7: num_leaves=32; max_depth=21; min_child_weight=1.79; min_data_in_leaf=870; min_gain_to_split=0.0213; lambda_l1=0.389; lambda_l2=0.166; scale_pos_weight=3.98; learning_rate=0.0578; num_iterations=3911; early_stopping_rounds=409; feature_fraction=0.486; bagging_fraction=0.784; bagging_freq=2; max_delta_step=4.9; path_smooth=7.16 : y = 0.929 : 205.7 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Tue Nov 18 01:24:31 AM 2025 AUC 0.928750027681424
#
# [mbo] 8: num_leaves=36; max_depth=16; min_child_weight=4.74; min_data_in_leaf=477; min_gain_to_split=0.0238; lambda_l1=0.398; lambda_l2=0.176; scale_pos_weight=3.26; learning_rate=0.0324; num_iterations=3649; early_stopping_rounds=476; feature_fraction=0.355; bagging_fraction=0.722; bagging_freq=4; max_delta_step=4.28; path_smooth=3.44 : y = 0.929 : 340.5 secs : infill_ei
#
# Tue Nov 18 01:27:09 AM 2025 AUC 0.93235633005384
#
# [mbo] 9: num_leaves=55; max_depth=15; min_child_weight=2.83; min_data_in_leaf=138; min_gain_to_split=0.0605; lambda_l1=0.131; lambda_l2=0.189; scale_pos_weight=4.73; learning_rate=0.0345; num_iterations=3192; early_stopping_rounds=396; feature_fraction=0.302; bagging_fraction=0.773; bagging_freq=2; max_delta_step=9.86; path_smooth=7.09 : y = 0.932 : 156.8 secs : infill_ei
#
# Tue Nov 18 01:34:04 AM 2025 AUC 0.928477575362258
#
# [mbo] 10: num_leaves=24; max_depth=16; min_child_weight=8.94; min_data_in_leaf=448; min_gain_to_split=0.00886; lambda_l1=0.339; lambda_l2=0.22; scale_pos_weight=2.25; learning_rate=0.03; num_iterations=3071; early_stopping_rounds=405; feature_fraction=0.534; bagging_fraction=0.735; bagging_freq=2; max_delta_step=6.33; path_smooth=9.96 : y = 0.928 : 414.1 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Tue Nov 18 01:38:45 AM 2025 AUC 0.933088461778496
#
# [mbo] 11: num_leaves=53; max_depth=18; min_child_weight=2.69; min_data_in_leaf=71; min_gain_to_split=0.0272; lambda_l1=0.354; lambda_l2=0.175; scale_pos_weight=3.72; learning_rate=0.0259; num_iterations=2736; early_stopping_rounds=331; feature_fraction=0.34; bagging_fraction=0.899; bagging_freq=2; max_delta_step=7.66; path_smooth=7.81 : y = 0.933 : 279.3 secs : infill_ei
#
# Tue Nov 18 01:45:06 AM 2025 AUC 0.932564360149755
#
# [mbo] 12: num_leaves=51; max_depth=18; min_child_weight=5.27; min_data_in_leaf=271; min_gain_to_split=0.0145; lambda_l1=0.244; lambda_l2=0.134; scale_pos_weight=4.08; learning_rate=0.0256; num_iterations=2619; early_stopping_rounds=346; feature_fraction=0.357; bagging_fraction=0.773; bagging_freq=1; max_delta_step=2.77; path_smooth=5.26 : y = 0.933 : 378.0 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Tue Nov 18 01:49:28 AM 2025 AUC 0.927516946064507
#
# [mbo] 13: num_leaves=45; max_depth=20; min_child_weight=4.06; min_data_in_leaf=115; min_gain_to_split=0.0307; lambda_l1=0.283; lambda_l2=0.169; scale_pos_weight=1.88; learning_rate=0.0289; num_iterations=1761; early_stopping_rounds=444; feature_fraction=0.32; bagging_fraction=0.611; bagging_freq=1; max_delta_step=7.54; path_smooth=7.63 : y = 0.928 : 260.9 secs : infill_ei
#
# Tue Nov 18 01:54:43 AM 2025 AUC 0.933664235398804
#
# [mbo] 14: num_leaves=55; max_depth=18; min_child_weight=7.2; min_data_in_leaf=384; min_gain_to_split=0.0472; lambda_l1=0.075; lambda_l2=0.138; scale_pos_weight=4.03; learning_rate=0.0266; num_iterations=3375; early_stopping_rounds=336; feature_fraction=0.339; bagging_fraction=0.865; bagging_freq=1; max_delta_step=7.16; path_smooth=8.96 : y = 0.934 : 313.3 secs : infill_ei
#
# Tue Nov 18 01:58:58 AM 2025 AUC 0.931652718584268
#
# [mbo] 15: num_leaves=48; max_depth=21; min_child_weight=8.38; min_data_in_leaf=158; min_gain_to_split=0.0206; lambda_l1=0.28; lambda_l2=0.132; scale_pos_weight=2.92; learning_rate=0.0314; num_iterations=3921; early_stopping_rounds=368; feature_fraction=0.377; bagging_fraction=0.853; bagging_freq=2; max_delta_step=3.39; path_smooth=8.34 : y = 0.932 : 252.0 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Tue Nov 18 02:04:00 AM 2025 AUC 0.930999101444199
#
# [mbo] 16: num_leaves=55; max_depth=17; min_child_weight=2.69; min_data_in_leaf=263; min_gain_to_split=0.041; lambda_l1=0.309; lambda_l2=0.135; scale_pos_weight=4.21; learning_rate=0.0208; num_iterations=3544; early_stopping_rounds=396; feature_fraction=0.362; bagging_fraction=0.834; bagging_freq=1; max_delta_step=6.58; path_smooth=9.16 : y = 0.931 : 300.7 secs : infill_ei
#
# Tue Nov 18 02:11:31 AM 2025 AUC 0.928654400943786
#
# [mbo] 17: num_leaves=22; max_depth=20; min_child_weight=3.58; min_data_in_leaf=425; min_gain_to_split=0.0211; lambda_l1=0.213; lambda_l2=0.158; scale_pos_weight=3.91; learning_rate=0.014; num_iterations=3386; early_stopping_rounds=342; feature_fraction=0.306; bagging_fraction=0.873; bagging_freq=2; max_delta_step=8.54; path_smooth=6.77 : y = 0.929 : 449.3 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Tue Nov 18 02:14:59 AM 2025 AUC 0.924806850766591
#
# [mbo] 18: num_leaves=53; max_depth=17; min_child_weight=6.29; min_data_in_leaf=860; min_gain_to_split=0.0341; lambda_l1=0.336; lambda_l2=0.182; scale_pos_weight=4.24; learning_rate=0.0551; num_iterations=3566; early_stopping_rounds=326; feature_fraction=0.43; bagging_fraction=0.727; bagging_freq=2; max_delta_step=9.78; path_smooth=8.98 : y = 0.925 : 207.0 secs : infill_ei
#
# Tue Nov 18 02:20:17 AM 2025 AUC 0.933179391062356
#
# [mbo] 19: num_leaves=51; max_depth=19; min_child_weight=1.87; min_data_in_leaf=955; min_gain_to_split=0.03; lambda_l1=0.339; lambda_l2=0.118; scale_pos_weight=4.12; learning_rate=0.0361; num_iterations=2499; early_stopping_rounds=356; feature_fraction=0.44; bagging_fraction=0.872; bagging_freq=4; max_delta_step=3.86; path_smooth=7.28 : y = 0.933 : 315.9 secs : infill_ei
#
# Tue Nov 18 02:24:34 AM 2025 AUC 0.930586396576496
#
# [mbo] 20: num_leaves=52; max_depth=18; min_child_weight=5.92; min_data_in_leaf=68; min_gain_to_split=0.0402; lambda_l1=0.0735; lambda_l2=0.143; scale_pos_weight=4.25; learning_rate=0.0318; num_iterations=2886; early_stopping_rounds=328; feature_fraction=0.338; bagging_fraction=0.859; bagging_freq=3; max_delta_step=7.64; path_smooth=7.08 : y = 0.931 : 255.6 secs : infill_ei
#
# Saved the current state after iteration 21 in the file HT.RDATA.
#
# Tue Nov 18 02:31:19 AM 2025 AUC 0.931886920208379
#
# [mbo] 21: num_leaves=34; max_depth=15; min_child_weight=0.0374; min_data_in_leaf=585; min_gain_to_split=0.0116; lambda_l1=0.0943; lambda_l2=0.221; scale_pos_weight=3.5; learning_rate=0.0398; num_iterations=2313; early_stopping_rounds=467; feature_fraction=0.515; bagging_fraction=0.897; bagging_freq=2; max_delta_step=8.26; path_smooth=6.87 : y = 0.932 : 402.2 secs : infill_ei
#
# Tue Nov 18 02:35:06 AM 2025 AUC 0.929636168783541
#
# [mbo] 22: num_leaves=45; max_depth=20; min_child_weight=3.81; min_data_in_leaf=360; min_gain_to_split=0.0265; lambda_l1=0.417; lambda_l2=0.0835; scale_pos_weight=3.89; learning_rate=0.0422; num_iterations=2312; early_stopping_rounds=296; feature_fraction=0.368; bagging_fraction=0.878; bagging_freq=3; max_delta_step=2.5; path_smooth=7.02 : y = 0.93 : 225.9 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Tue Nov 18 02:39:12 AM 2025 AUC 0.929088915418318
#
# [mbo] 23: num_leaves=38; max_depth=17; min_child_weight=8.2; min_data_in_leaf=768; min_gain_to_split=0.0204; lambda_l1=0.0972; lambda_l2=0.13; scale_pos_weight=4.98; learning_rate=0.033; num_iterations=4134; early_stopping_rounds=491; feature_fraction=0.412; bagging_fraction=0.848; bagging_freq=1; max_delta_step=7.38; path_smooth=6.47 : y = 0.929 : 241.7 secs : infill_ei
#
# Tue Nov 18 02:43:59 AM 2025 AUC 0.92811520035647
#
# [mbo] 24: num_leaves=43; max_depth=13; min_child_weight=0.537; min_data_in_leaf=273; min_gain_to_split=0.0283; lambda_l1=0.403; lambda_l2=0.287; scale_pos_weight=4.2; learning_rate=0.0343; num_iterations=3792; early_stopping_rounds=397; feature_fraction=0.446; bagging_fraction=0.702; bagging_freq=2; max_delta_step=4.87; path_smooth=5.91 : y = 0.928 : 285.5 secs : infill_ei
#
# Tue Nov 18 02:52:35 AM 2025 AUC 0.933697453107668
#
# [mbo] 25: num_leaves=48; max_depth=18; min_child_weight=1.06; min_data_in_leaf=395; min_gain_to_split=0.0788; lambda_l1=0.164; lambda_l2=0.186; scale_pos_weight=4.07; learning_rate=0.0278; num_iterations=3525; early_stopping_rounds=455; feature_fraction=0.376; bagging_fraction=0.86; bagging_freq=1; max_delta_step=9.19; path_smooth=5.38 : y = 0.934 : 514.3 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Tue Nov 18 02:56:34 AM 2025 AUC 0.931679225644876
#
# [mbo] 26: num_leaves=63; max_depth=17; min_child_weight=0.903; min_data_in_leaf=1110; min_gain_to_split=0.0331; lambda_l1=0.0942; lambda_l2=0.179; scale_pos_weight=2.92; learning_rate=0.034; num_iterations=3512; early_stopping_rounds=374; feature_fraction=0.431; bagging_fraction=0.864; bagging_freq=1; max_delta_step=7.96; path_smooth=4.89 : y = 0.932 : 237.4 secs : infill_ei
#
# Tue Nov 18 03:00:25 AM 2025 AUC 0.929583490194736
#
# [mbo] 27: num_leaves=52; max_depth=20; min_child_weight=0.388; min_data_in_leaf=1499; min_gain_to_split=0.0937; lambda_l1=0.288; lambda_l2=0.191; scale_pos_weight=4.7; learning_rate=0.031; num_iterations=1664; early_stopping_rounds=388; feature_fraction=0.383; bagging_fraction=0.829; bagging_freq=2; max_delta_step=9.1; path_smooth=7.58 : y = 0.93 : 229.4 secs : infill_ei
#
# Tue Nov 18 03:03:14 AM 2025 AUC 0.930901125979671
#
# [mbo] 28: num_leaves=53; max_depth=16; min_child_weight=5.81; min_data_in_leaf=1167; min_gain_to_split=0.00548; lambda_l1=0.069; lambda_l2=0.214; scale_pos_weight=4.24; learning_rate=0.0448; num_iterations=1743; early_stopping_rounds=341; feature_fraction=0.424; bagging_fraction=0.803; bagging_freq=4; max_delta_step=3.78; path_smooth=9.64 : y = 0.931 : 166.9 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Tue Nov 18 03:07:35 AM 2025 AUC 0.927367634140826
#
# [mbo] 29: num_leaves=44; max_depth=18; min_child_weight=5.6; min_data_in_leaf=454; min_gain_to_split=0.0427; lambda_l1=0.116; lambda_l2=0.264; scale_pos_weight=3.56; learning_rate=0.0301; num_iterations=3127; early_stopping_rounds=391; feature_fraction=0.536; bagging_fraction=0.821; bagging_freq=1; max_delta_step=8.51; path_smooth=8.65 : y = 0.927 : 259.3 secs : infill_ei
#
# Tue Nov 18 03:11:18 AM 2025 AUC 0.926450624056735
#
# [mbo] 30: num_leaves=18; max_depth=13; min_child_weight=6.68; min_data_in_leaf=672; min_gain_to_split=0.0207; lambda_l1=0.439; lambda_l2=0.216; scale_pos_weight=4.23; learning_rate=0.0425; num_iterations=1642; early_stopping_rounds=373; feature_fraction=0.332; bagging_fraction=0.823; bagging_freq=3; max_delta_step=4.11; path_smooth=6.95 : y = 0.926 : 221.3 secs : infill_ei
#
# Tue Nov 18 03:14:42 AM 2025 AUC 0.929741525961149
#
# [mbo] 31: num_leaves=63; max_depth=21; min_child_weight=5.84; min_data_in_leaf=986; min_gain_to_split=0.00788; lambda_l1=0.207; lambda_l2=0.323; scale_pos_weight=2.08; learning_rate=0.0312; num_iterations=3410; early_stopping_rounds=332; feature_fraction=0.362; bagging_fraction=0.839; bagging_freq=1; max_delta_step=4.91; path_smooth=7.56 : y = 0.93 : 202.2 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Tue Nov 18 03:20:33 AM 2025 AUC 0.934342681937418
#
# [mbo] 32: num_leaves=60; max_depth=18; min_child_weight=2.09; min_data_in_leaf=440; min_gain_to_split=0.0544; lambda_l1=0.124; lambda_l2=0.142; scale_pos_weight=3.67; learning_rate=0.036; num_iterations=2173; early_stopping_rounds=379; feature_fraction=0.46; bagging_fraction=0.864; bagging_freq=2; max_delta_step=0.384; path_smooth=8.98 : y = 0.934 : 349.0 secs : infill_ei
#
# Tue Nov 18 03:26:44 AM 2025 AUC 0.930444466365895
#
# [mbo] 33: num_leaves=55; max_depth=18; min_child_weight=3.89; min_data_in_leaf=400; min_gain_to_split=0.00232; lambda_l1=0.255; lambda_l2=0.129; scale_pos_weight=2.32; learning_rate=0.0246; num_iterations=2687; early_stopping_rounds=320; feature_fraction=0.476; bagging_fraction=0.784; bagging_freq=2; max_delta_step=1.22; path_smooth=9.57 : y = 0.93 : 369.6 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Tue Nov 18 03:31:38 AM 2025 AUC 0.928903701526471
#
# [mbo] 34: num_leaves=46; max_depth=24; min_child_weight=0.613; min_data_in_leaf=866; min_gain_to_split=0.0271; lambda_l1=0.147; lambda_l2=0.156; scale_pos_weight=2.58; learning_rate=0.0396; num_iterations=3076; early_stopping_rounds=443; feature_fraction=0.382; bagging_fraction=0.659; bagging_freq=3; max_delta_step=3.1; path_smooth=7.78 : y = 0.929 : 292.1 secs : infill_ei
#
# Tue Nov 18 03:38:26 AM 2025 AUC 0.931975500765349
#
# [mbo] 35: num_leaves=59; max_depth=17; min_child_weight=0.993; min_data_in_leaf=119; min_gain_to_split=0.0783; lambda_l1=0.199; lambda_l2=0.156; scale_pos_weight=4.39; learning_rate=0.0154; num_iterations=3049; early_stopping_rounds=385; feature_fraction=0.395; bagging_fraction=0.894; bagging_freq=1; max_delta_step=8.98; path_smooth=6.14 : y = 0.932 : 405.7 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Tue Nov 18 03:43:37 AM 2025 AUC 0.932149642087575
#
# [mbo] 36: num_leaves=55; max_depth=18; min_child_weight=2.4; min_data_in_leaf=874; min_gain_to_split=0.0136; lambda_l1=0.209; lambda_l2=0.172; scale_pos_weight=3.97; learning_rate=0.0292; num_iterations=3528; early_stopping_rounds=365; feature_fraction=0.307; bagging_fraction=0.893; bagging_freq=3; max_delta_step=1.7; path_smooth=7.18 : y = 0.932 : 309.6 secs : infill_ei
#
# Tue Nov 18 03:47:51 AM 2025 AUC 0.928106140981325
#
# [mbo] 37: num_leaves=61; max_depth=18; min_child_weight=6.9; min_data_in_leaf=1210; min_gain_to_split=0.0833; lambda_l1=0.28; lambda_l2=0.148; scale_pos_weight=3.45; learning_rate=0.0346; num_iterations=2432; early_stopping_rounds=448; feature_fraction=0.415; bagging_fraction=0.881; bagging_freq=1; max_delta_step=2.72; path_smooth=7.7 : y = 0.928 : 251.7 secs : infill_ei
#
# Tue Nov 18 03:50:55 AM 2025 AUC 0.924937372875157
#
# [mbo] 38: num_leaves=24; max_depth=14; min_child_weight=0.389; min_data_in_leaf=122; min_gain_to_split=0.0465; lambda_l1=0.256; lambda_l2=0.172; scale_pos_weight=2.93; learning_rate=0.042; num_iterations=2963; early_stopping_rounds=476; feature_fraction=0.616; bagging_fraction=0.633; bagging_freq=4; max_delta_step=3.71; path_smooth=8.64 : y = 0.925 : 181.5 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Tue Nov 18 03:56:11 AM 2025 AUC 0.931470860016548
#
# [mbo] 39: num_leaves=45; max_depth=23; min_child_weight=0.0915; min_data_in_leaf=583; min_gain_to_split=0.0478; lambda_l1=0.26; lambda_l2=0.14; scale_pos_weight=4.75; learning_rate=0.0427; num_iterations=2583; early_stopping_rounds=362; feature_fraction=0.528; bagging_fraction=0.896; bagging_freq=3; max_delta_step=3.73; path_smooth=5.43 : y = 0.931 : 313.8 secs : infill_ei
#
# Tue Nov 18 03:58:15 AM 2025 AUC 0.931760424488766
#
# [mbo] 40: num_leaves=54; max_depth=17; min_child_weight=8.26; min_data_in_leaf=658; min_gain_to_split=0.0265; lambda_l1=0.161; lambda_l2=0.139; scale_pos_weight=3.38; learning_rate=0.0254; num_iterations=742; early_stopping_rounds=348; feature_fraction=0.313; bagging_fraction=0.89; bagging_freq=2; max_delta_step=4.84; path_smooth=9.93 : y = 0.932 : 120.6 secs : infill_ei
#
# Tue Nov 18 04:01:46 AM 2025 AUC 0.929805948184401
#
# [mbo] 41: num_leaves=47; max_depth=18; min_child_weight=1.27; min_data_in_leaf=999; min_gain_to_split=0.00322; lambda_l1=0.208; lambda_l2=0.217; scale_pos_weight=4.84; learning_rate=0.0541; num_iterations=1765; early_stopping_rounds=422; feature_fraction=0.593; bagging_fraction=0.824; bagging_freq=2; max_delta_step=7.45; path_smooth=5.53 : y = 0.93 : 208.5 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Tue Nov 18 04:07:06 AM 2025 AUC 0.931432944853906
#
# [mbo] 42: num_leaves=60; max_depth=15; min_child_weight=8.93; min_data_in_leaf=364; min_gain_to_split=0.000774; lambda_l1=0.0696; lambda_l2=0.324; scale_pos_weight=2.46; learning_rate=0.0363; num_iterations=2263; early_stopping_rounds=336; feature_fraction=0.347; bagging_fraction=0.88; bagging_freq=3; max_delta_step=5.66; path_smooth=7.83 : y = 0.931 : 318.6 secs : infill_ei
#
# Tue Nov 18 04:09:30 AM 2025 AUC 0.926610001952799
#
# [mbo] 43: num_leaves=61; max_depth=19; min_child_weight=2.34; min_data_in_leaf=147; min_gain_to_split=0.0493; lambda_l1=0.13; lambda_l2=0.126; scale_pos_weight=3.88; learning_rate=0.033; num_iterations=3444; early_stopping_rounds=198; feature_fraction=0.576; bagging_fraction=0.716; bagging_freq=1; max_delta_step=2.43; path_smooth=9.44 : y = 0.927 : 142.0 secs : infill_ei
#
# Tue Nov 18 04:12:47 AM 2025 AUC 0.930209929209372
#
# [mbo] 44: num_leaves=47; max_depth=14; min_child_weight=0.927; min_data_in_leaf=124; min_gain_to_split=0.0467; lambda_l1=0.0654; lambda_l2=0.177; scale_pos_weight=3.77; learning_rate=0.0244; num_iterations=2871; early_stopping_rounds=157; feature_fraction=0.346; bagging_fraction=0.855; bagging_freq=1; max_delta_step=9.63; path_smooth=7.29 : y = 0.93 : 194.7 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Tue Nov 18 04:17:06 AM 2025 AUC 0.930204225158355
#
# [mbo] 45: num_leaves=34; max_depth=18; min_child_weight=5.32; min_data_in_leaf=517; min_gain_to_split=5.39e-05; lambda_l1=0.386; lambda_l2=0.335; scale_pos_weight=1.11; learning_rate=0.0754; num_iterations=3611; early_stopping_rounds=370; feature_fraction=0.396; bagging_fraction=0.844; bagging_freq=5; max_delta_step=7.38; path_smooth=6.19 : y = 0.93 : 255.8 secs : infill_ei
#
# Tue Nov 18 04:24:12 AM 2025 AUC 0.928409797814879
#
# ...
#
# Tue Nov 18 05:40:04 AM 2025 AUC 0.926625436443786
#
# [mbo] 66: num_leaves=35; max_depth=12; min_child_weight=1.95; min_data_in_leaf=1318; min_gain_to_split=0.00624; lambda_l1=0.0338; lambda_l2=0.239; scale_pos_weight=4.08; learning_rate=0.0393; num_iterations=2866; early_stopping_rounds=423; feature_fraction=0.44; bagging_fraction=0.728; bagging_freq=2; max_delta_step=2.94; path_smooth=6.87 : y = 0.927 : 233.9 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Tue Nov 18 05:48:38 AM 2025 AUC 0.929907950037882
#
# [mbo] 67: num_leaves=47; max_depth=15; min_child_weight=0.751; min_data_in_leaf=519; min_gain_to_split=0.0189; lambda_l1=0.193; lambda_l2=0.203; scale_pos_weight=4.29; learning_rate=0.0263; num_iterations=4034; early_stopping_rounds=485; feature_fraction=0.488; bagging_fraction=0.872; bagging_freq=4; max_delta_step=8.41; path_smooth=9.42 : y = 0.93 : 510.6 secs : infill_ei
#
# Tue Nov 18 05:52:49 AM 2025 AUC 0.93039413650398
#
# [mbo] 68: num_leaves=35; max_depth=17; min_child_weight=2.27; min_data_in_leaf=41; min_gain_to_split=0.0214; lambda_l1=0.277; lambda_l2=0.359; scale_pos_weight=3.08; learning_rate=0.0309; num_iterations=3696; early_stopping_rounds=352; feature_fraction=0.32; bagging_fraction=0.85; bagging_freq=3; max_delta_step=8.81; path_smooth=7.8 : y = 0.93 : 249.0 secs : infill_ei
#
# Saved the current state after iteration 69 in the file HT.RDATA.
#
# Tue Nov 18 05:56:30 AM 2025 AUC 0.929249635444033
#
# [mbo] 69: num_leaves=60; max_depth=20; min_child_weight=7.09; min_data_in_leaf=617; min_gain_to_split=0.0751; lambda_l1=0.311; lambda_l2=0.116; scale_pos_weight=3.77; learning_rate=0.0373; num_iterations=2029; early_stopping_rounds=346; feature_fraction=0.396; bagging_fraction=0.573; bagging_freq=5; max_delta_step=0.562; path_smooth=9.37 : y = 0.929 : 217.9 secs : infill_ei
#
# Tue Nov 18 06:00:24 AM 2025 AUC 0.932088239656039
#
# [mbo] 70: num_leaves=44; max_depth=23; min_child_weight=3.09; min_data_in_leaf=168; min_gain_to_split=0.0653; lambda_l1=0.0965; lambda_l2=0.167; scale_pos_weight=3.65; learning_rate=0.0288; num_iterations=3004; early_stopping_rounds=364; feature_fraction=0.379; bagging_fraction=0.858; bagging_freq=1; max_delta_step=9.65; path_smooth=6.93 : y = 0.932 : 231.7 secs : infill_ei
#
# Tue Nov 18 06:05:51 AM 2025 AUC 0.935336528944033
#
# [mbo] 71: num_leaves=56; max_depth=21; min_child_weight=1.4; min_data_in_leaf=420; min_gain_to_split=0.0969; lambda_l1=0.207; lambda_l2=0.135; scale_pos_weight=3.85; learning_rate=0.0315; num_iterations=3010; early_stopping_rounds=355; feature_fraction=0.358; bagging_fraction=0.873; bagging_freq=4; max_delta_step=3.46; path_smooth=8.61 : y = 0.935 : 324.5 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Tue Nov 18 06:09:03 AM 2025 AUC 0.927464267475702
#
# [mbo] 72: num_leaves=54; max_depth=21; min_child_weight=9.21; min_data_in_leaf=24; min_gain_to_split=0.0176; lambda_l1=0.429; lambda_l2=0.115; scale_pos_weight=4.87; learning_rate=0.0281; num_iterations=4627; early_stopping_rounds=189; feature_fraction=0.42; bagging_fraction=0.684; bagging_freq=4; max_delta_step=0.989; path_smooth=1.16 : y = 0.927 : 187.8 secs : infill_ei
#
# Tue Nov 18 06:10:37 AM 2025 AUC 0.921806855464045
#
# [mbo] 73: num_leaves=13; max_depth=15; min_child_weight=9.52; min_data_in_leaf=120; min_gain_to_split=6.55e-05; lambda_l1=0.203; lambda_l2=0.332; scale_pos_weight=2.85; learning_rate=0.0769; num_iterations=2509; early_stopping_rounds=407; feature_fraction=0.619; bagging_fraction=0.69; bagging_freq=3; max_delta_step=7.54; path_smooth=5.52 : y = 0.922 : 90.3 secs : infill_ei
#
# Tue Nov 18 06:13:07 AM 2025 AUC 0.927506880092124
#
# [mbo] 74: num_leaves=29; max_depth=24; min_child_weight=5.84; min_data_in_leaf=252; min_gain_to_split=0.0939; lambda_l1=0.279; lambda_l2=0.123; scale_pos_weight=4.22; learning_rate=0.028; num_iterations=977; early_stopping_rounds=282; feature_fraction=0.354; bagging_fraction=0.899; bagging_freq=4; max_delta_step=0.762; path_smooth=9.04 : y = 0.928 : 146.7 secs : infill_ei
#
# Tue Nov 18 06:18:48 AM 2025 AUC 0.933741743386153
#
# [mbo] 75: num_leaves=61; max_depth=17; min_child_weight=3.94; min_data_in_leaf=17; min_gain_to_split=0.0646; lambda_l1=0.0409; lambda_l2=0.174; scale_pos_weight=3.27; learning_rate=0.0197; num_iterations=3136; early_stopping_rounds=347; feature_fraction=0.397; bagging_fraction=0.894; bagging_freq=2; max_delta_step=6.08; path_smooth=8.61 : y = 0.934 : 339.1 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Tue Nov 18 06:22:23 AM 2025 AUC 0.933500831113786
#
# [mbo] 76: num_leaves=58; max_depth=24; min_child_weight=2.16; min_data_in_leaf=396; min_gain_to_split=0.0625; lambda_l1=0.241; lambda_l2=0.142; scale_pos_weight=4.35; learning_rate=0.0344; num_iterations=1268; early_stopping_rounds=391; feature_fraction=0.382; bagging_fraction=0.858; bagging_freq=5; max_delta_step=5.31; path_smooth=8.62 : y = 0.934 : 210.7 secs : infill_ei
#
# Tue Nov 18 06:25:32 AM 2025 AUC 0.932384179244099
#
# [mbo] 77: num_leaves=58; max_depth=20; min_child_weight=1.99; min_data_in_leaf=123; min_gain_to_split=0.0911; lambda_l1=0.471; lambda_l2=0.0506; scale_pos_weight=3.55; learning_rate=0.039; num_iterations=4324; early_stopping_rounds=260; feature_fraction=0.351; bagging_fraction=0.607; bagging_freq=5; max_delta_step=3.41; path_smooth=3.14 : y = 0.932 : 185.9 secs : infill_ei
#
# Tue Nov 18 06:28:59 AM 2025 AUC 0.931442675293876
#
# [mbo] 78: num_leaves=63; max_depth=21; min_child_weight=1.08; min_data_in_leaf=195; min_gain_to_split=0.0904; lambda_l1=0.171; lambda_l2=0.137; scale_pos_weight=2.97; learning_rate=0.0277; num_iterations=2019; early_stopping_rounds=322; feature_fraction=0.372; bagging_fraction=0.887; bagging_freq=5; max_delta_step=4.31; path_smooth=8.19 : y = 0.931 : 204.3 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Tue Nov 18 06:30:57 AM 2025 AUC 0.931256790337203
#
# [mbo] 79: num_leaves=63; max_depth=20; min_child_weight=1.91; min_data_in_leaf=186; min_gain_to_split=0.0193; lambda_l1=0.384; lambda_l2=0.145; scale_pos_weight=2.79; learning_rate=0.0412; num_iterations=2458; early_stopping_rounds=112; feature_fraction=0.341; bagging_fraction=0.882; bagging_freq=4; max_delta_step=3.53; path_smooth=8.45 : y = 0.931 : 115.7 secs : infill_ei
#
# Tue Nov 18 06:34:23 AM 2025 AUC 0.932293921025065
#
# [mbo] 80: num_leaves=56; max_depth=18; min_child_weight=7.54; min_data_in_leaf=454; min_gain_to_split=0.099; lambda_l1=0.0879; lambda_l2=0.157; scale_pos_weight=3.76; learning_rate=0.0259; num_iterations=4169; early_stopping_rounds=281; feature_fraction=0.374; bagging_fraction=0.87; bagging_freq=1; max_delta_step=7.39; path_smooth=5.71 : y = 0.932 : 203.2 secs : infill_ei
#
# Tue Nov 18 06:37:49 AM 2025 AUC 0.928362152212266
#
# [mbo] 81: num_leaves=54; max_depth=12; min_child_weight=5.87; min_data_in_leaf=323; min_gain_to_split=0.0194; lambda_l1=0.355; lambda_l2=0.234; scale_pos_weight=3.84; learning_rate=0.0185; num_iterations=2861; early_stopping_rounds=377; feature_fraction=0.338; bagging_fraction=0.554; bagging_freq=3; max_delta_step=3.58; path_smooth=6.24 : y = 0.928 : 203.7 secs : infill_ei
#
# Tue Nov 18 06:41:29 AM 2025 AUC 0.930048202586418
#
# [mbo] 82: num_leaves=49; max_depth=18; min_child_weight=0.15; min_data_in_leaf=83; min_gain_to_split=0.0752; lambda_l1=0.226; lambda_l2=0.156; scale_pos_weight=1.65; learning_rate=0.0351; num_iterations=4145; early_stopping_rounds=410; feature_fraction=0.424; bagging_fraction=0.867; bagging_freq=2; max_delta_step=9.7; path_smooth=7.81 : y = 0.93 : 217.4 secs : infill_ei
#
# Saved the current state after iteration 83 in the file HT.RDATA.
#
# Tue Nov 18 06:43:48 AM 2025 AUC 0.931343357699697
#
# [mbo] 83: num_leaves=58; max_depth=19; min_child_weight=2.26; min_data_in_leaf=501; min_gain_to_split=0.0348; lambda_l1=0.413; lambda_l2=0.124; scale_pos_weight=3.67; learning_rate=0.0321; num_iterations=2232; early_stopping_rounds=291; feature_fraction=0.327; bagging_fraction=0.524; bagging_freq=2; max_delta_step=9.09; path_smooth=3.45 : y = 0.931 : 133.0 secs : infill_ei
#
# Tue Nov 18 06:48:29 AM 2025 AUC 0.925917798585261
#
# [mbo] 84: num_leaves=33; max_depth=15; min_child_weight=3.37; min_data_in_leaf=1031; min_gain_to_split=0.073; lambda_l1=0.294; lambda_l2=0.0688; scale_pos_weight=4.3; learning_rate=0.0267; num_iterations=1689; early_stopping_rounds=486; feature_fraction=0.582; bagging_fraction=0.536; bagging_freq=4; max_delta_step=7.14; path_smooth=3.69 : y = 0.926 : 276.7 secs : infill_ei
#
# Tue Nov 18 06:51:00 AM 2025 AUC 0.925064204127183
#
# [mbo] 85: num_leaves=38; max_depth=21; min_child_weight=1.77; min_data_in_leaf=691; min_gain_to_split=0.00173; lambda_l1=0.217; lambda_l2=0.378; scale_pos_weight=4.82; learning_rate=0.0943; num_iterations=3951; early_stopping_rounds=370; feature_fraction=0.345; bagging_fraction=0.892; bagging_freq=5; max_delta_step=8.61; path_smooth=7.24 : y = 0.925 : 148.4 secs : infill_ei
#
# Tue Nov 18 06:55:22 AM 2025 AUC 0.932296269751954
#
# [mbo] 86: num_leaves=63; max_depth=21; min_child_weight=7.64; min_data_in_leaf=549; min_gain_to_split=0.0657; lambda_l1=0.219; lambda_l2=0.0455; scale_pos_weight=4.4; learning_rate=0.0409; num_iterations=3592; early_stopping_rounds=366; feature_fraction=0.421; bagging_fraction=0.848; bagging_freq=5; max_delta_step=6.19; path_smooth=2.71 : y = 0.932 : 259.0 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Tue Nov 18 06:59:20 AM 2025 AUC 0.932819364783457
#
# [mbo] 87: num_leaves=55; max_depth=21; min_child_weight=4.91; min_data_in_leaf=39; min_gain_to_split=0.0904; lambda_l1=0.403; lambda_l2=0.111; scale_pos_weight=4.35; learning_rate=0.0328; num_iterations=3711; early_stopping_rounds=116; feature_fraction=0.335; bagging_fraction=0.873; bagging_freq=4; max_delta_step=0.55; path_smooth=9.15 : y = 0.933 : 234.8 secs : infill_ei
#
# Tue Nov 18 07:01:40 AM 2025 AUC 0.923211394143886
#
# [mbo] 88: num_leaves=53; max_depth=23; min_child_weight=5; min_data_in_leaf=738; min_gain_to_split=0.0783; lambda_l1=0.413; lambda_l2=0.0567; scale_pos_weight=4.43; learning_rate=0.0571; num_iterations=2972; early_stopping_rounds=286; feature_fraction=0.392; bagging_fraction=0.771; bagging_freq=5; max_delta_step=6.05; path_smooth=1.98 : y = 0.923 : 137.0 secs : infill_ei
#
# Tue Nov 18 07:04:46 AM 2025 AUC 0.925984234002989
#
# [mbo] 89: num_leaves=58; max_depth=15; min_child_weight=3.17; min_data_in_leaf=19; min_gain_to_split=0.0639; lambda_l1=0.253; lambda_l2=0.0782; scale_pos_weight=3.25; learning_rate=0.0285; num_iterations=3657; early_stopping_rounds=364; feature_fraction=0.432; bagging_fraction=0.846; bagging_freq=3; max_delta_step=8.63; path_smooth=2.66 : y = 0.926 : 181.6 secs : infill_ei
#
# Tue Nov 18 07:08:33 AM 2025 AUC 0.933328702986037
#
# [mbo] 90: num_leaves=60; max_depth=22; min_child_weight=8.16; min_data_in_leaf=521; min_gain_to_split=0.0592; lambda_l1=0.178; lambda_l2=0.0277; scale_pos_weight=4.52; learning_rate=0.0222; num_iterations=4117; early_stopping_rounds=285; feature_fraction=0.46; bagging_fraction=0.869; bagging_freq=4; max_delta_step=2.79; path_smooth=9.22 : y = 0.933 : 224.5 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Tue Nov 18 07:12:52 AM 2025 AUC 0.930020353396158
#
# [mbo] 91: num_leaves=63; max_depth=26; min_child_weight=2.81; min_data_in_leaf=408; min_gain_to_split=0.0848; lambda_l1=0.265; lambda_l2=0.0407; scale_pos_weight=4.43; learning_rate=0.0359; num_iterations=4809; early_stopping_rounds=399; feature_fraction=0.35; bagging_fraction=0.825; bagging_freq=5; max_delta_step=2.8; path_smooth=8.16 : y = 0.93 : 254.5 secs : infill_ei
#
# Tue Nov 18 07:16:07 AM 2025 AUC 0.929618385565664
#
# [mbo] 92: num_leaves=60; max_depth=18; min_child_weight=6.88; min_data_in_leaf=252; min_gain_to_split=0.0969; lambda_l1=0.265; lambda_l2=0.133; scale_pos_weight=1.01; learning_rate=0.0349; num_iterations=4594; early_stopping_rounds=195; feature_fraction=0.305; bagging_fraction=0.893; bagging_freq=3; max_delta_step=4.87; path_smooth=8.12 : y = 0.93 : 191.8 secs : infill_ei
#
# Tue Nov 18 07:19:05 AM 2025 AUC 0.931047418111637
#
# [mbo] 93: num_leaves=63; max_depth=21; min_child_weight=8.89; min_data_in_leaf=529; min_gain_to_split=0.0353; lambda_l1=0.22; lambda_l2=0.0162; scale_pos_weight=3.94; learning_rate=0.0303; num_iterations=3847; early_stopping_rounds=367; feature_fraction=0.344; bagging_fraction=0.725; bagging_freq=4; max_delta_step=1.07; path_smooth=3.72 : y = 0.931 : 173.8 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Tue Nov 18 07:23:43 AM 2025 AUC 0.9283735603143
#
# [mbo] 94: num_leaves=62; max_depth=25; min_child_weight=9.19; min_data_in_leaf=1293; min_gain_to_split=0.0608; lambda_l1=0.0393; lambda_l2=0.0605; scale_pos_weight=4.44; learning_rate=0.0396; num_iterations=3550; early_stopping_rounds=310; feature_fraction=0.505; bagging_fraction=0.857; bagging_freq=5; max_delta_step=2.64; path_smooth=6.26 : y = 0.928 : 274.4 secs : infill_ei
#
# Tue Nov 18 07:25:25 AM 2025 AUC 0.931415832700855
#
# [mbo] 95: num_leaves=61; max_depth=21; min_child_weight=7.25; min_data_in_leaf=327; min_gain_to_split=0.0737; lambda_l1=0.412; lambda_l2=0.0191; scale_pos_weight=3.91; learning_rate=0.0337; num_iterations=3193; early_stopping_rounds=142; feature_fraction=0.332; bagging_fraction=0.639; bagging_freq=3; max_delta_step=2.75; path_smooth=8.69 : y = 0.931 : 97.3 secs : infill_ei
#
# Tue Nov 18 07:30:46 AM 2025 AUC 0.93174398340054
#
# [mbo] 96: num_leaves=61; max_depth=21; min_child_weight=3.98; min_data_in_leaf=597; min_gain_to_split=0.0764; lambda_l1=0.0782; lambda_l2=0.142; scale_pos_weight=4.5; learning_rate=0.0278; num_iterations=4104; early_stopping_rounds=394; feature_fraction=0.323; bagging_fraction=0.812; bagging_freq=2; max_delta_step=0.659; path_smooth=7.66 : y = 0.932 : 315.6 secs : infill_ei
#
# Saved the current state after iteration 97 in the file HT.RDATA.
#
# Tue Nov 18 07:35:11 AM 2025 AUC 0.930283075275355
#
# [mbo] 97: num_leaves=63; max_depth=21; min_child_weight=6.91; min_data_in_leaf=48; min_gain_to_split=0.0879; lambda_l1=0.233; lambda_l2=0.00935; scale_pos_weight=2.43; learning_rate=0.0262; num_iterations=4867; early_stopping_rounds=269; feature_fraction=0.374; bagging_fraction=0.782; bagging_freq=2; max_delta_step=4.61; path_smooth=7.53 : y = 0.93 : 259.7 secs : infill_ei
#
# Tue Nov 18 07:42:50 AM 2025 AUC 0.934597015506295
#
# [mbo] 98: num_leaves=60; max_depth=20; min_child_weight=8.3; min_data_in_leaf=1301; min_gain_to_split=0.0967; lambda_l1=0.306; lambda_l2=0.0362; scale_pos_weight=4.88; learning_rate=0.02; num_iterations=4924; early_stopping_rounds=467; feature_fraction=0.356; bagging_fraction=0.714; bagging_freq=5; max_delta_step=7.84; path_smooth=8.37 : y = 0.935 : 453.0 secs : infill_ei
#
# Saved the current state after iteration 99 in the file HT.RDATA.
#
# Tue Nov 18 07:48:34 AM 2025 AUC 0.930148191245422
#
# [mbo] 99: num_leaves=59; max_depth=21; min_child_weight=7.15; min_data_in_leaf=1346; min_gain_to_split=0.0869; lambda_l1=0.275; lambda_l2=0.0192; scale_pos_weight=4.47; learning_rate=0.0193; num_iterations=4046; early_stopping_rounds=357; feature_fraction=0.347; bagging_fraction=0.572; bagging_freq=3; max_delta_step=8.02; path_smooth=9.08 : y = 0.93 : 340.2 secs : infill_ei
#
# Tue Nov 18 07:53:12 AM 2025 AUC 0.931743312335715
#
# [mbo] 100: num_leaves=61; max_depth=19; min_child_weight=7.97; min_data_in_leaf=28; min_gain_to_split=0.0288; lambda_l1=0.225; lambda_l2=0.113; scale_pos_weight=4.64; learning_rate=0.0106; num_iterations=3774; early_stopping_rounds=180; feature_fraction=0.334; bagging_fraction=0.838; bagging_freq=3; max_delta_step=3.46; path_smooth=8.05 : y = 0.932 : 274.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:         56        21         1.403845              420         0.0968881
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.2072733 0.1353775         3.845439    0.03154453           3010
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   355        0.3582829        0.8728474            4
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       3.455244     8.61086

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6122700
#
# $envios
# [1] 1387

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1777363148
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 08:01:48 AM 2025"
# Inicio: Mon Nov 17 09:45:06 PM 2025
# Fin:    Tue Nov 18 08:01:48 AM 2025
# Duración (hh:mm:ss): 10:16:42
