# %% [markdown]
# <a href="https://colab.research.google.com/github/epare2496-commits/labo2025v/blob/main/610_WorkFlow_12H_124_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 18 11:11:03 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454485    77.7 1438379  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63124
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  # makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9)   # filas
  # makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  # makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  # makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 18 11:25:32 AM 2025 AUC 0.930471308958917
#
# Tue Nov 18 11:29:52 AM 2025 AUC 0.928618163443207
#
# Tue Nov 18 11:33:21 AM 2025 AUC 0.925254115472809
#
# Tue Nov 18 11:36:17 AM 2025 AUC 0.925904712821163
#
# Tue Nov 18 11:39:44 AM 2025 AUC 0.928452074898887
#
# Tue Nov 18 11:43:01 AM 2025 AUC 0.928392685661828
#
# Tue Nov 18 11:43:47 AM 2025 AUC 0.918998113636775
#
# Tue Nov 18 11:44:31 AM 2025 AUC 0.914796576764112
#
# Tue Nov 18 11:47:31 AM 2025 AUC 0.92757801296363
#
# Tue Nov 18 11:50:12 AM 2025 AUC 0.924961866741289
#
# Tue Nov 18 11:54:30 AM 2025 AUC 0.922810097378217
#
# Tue Nov 18 11:57:44 AM 2025 AUC 0.926774077302641
#
# Tue Nov 18 11:58:07 AM 2025 AUC 0.915726001547476
#
# Tue Nov 18 12:02:58 PM 2025 AUC 0.925715808072776
#
# Tue Nov 18 12:06:06 PM 2025 AUC 0.925276596144464
#
# Tue Nov 18 12:06:24 PM 2025 AUC 0.912290485173158
#
# Tue Nov 18 12:08:57 PM 2025 AUC 0.920891187509605
#
# Tue Nov 18 12:09:49 PM 2025 AUC 0.923942854803717
#
# Tue Nov 18 12:12:21 PM 2025 AUC 0.925167212577902
#
# Tue Nov 18 12:14:54 PM 2025 AUC 0.922158828965037
#
# Tue Nov 18 12:17:16 PM 2025 AUC 0.922598711958174
#
# Tue Nov 18 12:19:18 PM 2025 AUC 0.91916487324592
#
# Tue Nov 18 12:25:13 PM 2025 AUC 0.927833353129746
#
# Tue Nov 18 12:26:49 PM 2025 AUC 0.923452977481078
#
# Tue Nov 18 12:28:02 PM 2025 AUC 0.921969924216649
#
# Tue Nov 18 12:29:47 PM 2025 AUC 0.913026978819181
#
# Tue Nov 18 12:33:16 PM 2025 AUC 0.927326028121643
#
# Tue Nov 18 12:36:07 PM 2025 AUC 0.930228383492074
#
# Tue Nov 18 12:38:51 PM 2025 AUC 0.926685161213258
#
# Tue Nov 18 12:40:03 PM 2025 AUC 0.922541000383178
#
# Tue Nov 18 12:47:29 PM 2025 AUC 0.925914443261133
#
# Tue Nov 18 12:48:27 PM 2025 AUC 0.916373914636528
#
# Tue Nov 18 12:54:59 PM 2025 AUC 0.92755855208369
#
# Tue Nov 18 12:56:18 PM 2025 AUC 0.913205482062773
#
# Tue Nov 18 01:01:17 PM 2025 AUC 0.930473993218219
#
# Tue Nov 18 01:02:03 PM 2025 AUC 0.924360257125199
#
# Tue Nov 18 01:04:34 PM 2025 AUC 0.923136905948251
#
# Tue Nov 18 01:13:36 PM 2025 AUC 0.924725651922701
#
# Tue Nov 18 01:16:51 PM 2025 AUC 0.921506889487031
#
# Tue Nov 18 01:20:19 PM 2025 AUC 0.919128300212929
#
# Tue Nov 18 01:21:35 PM 2025 AUC 0.921971937411126
#
# Tue Nov 18 01:23:09 PM 2025 AUC 0.927984007183078
#
# Tue Nov 18 01:24:23 PM 2025 AUC 0.914517078264277
#
# Tue Nov 18 01:25:53 PM 2025 AUC 0.920412382756587
#
# Tue Nov 18 01:28:13 PM 2025 AUC 0.919710113416666
#
# Tue Nov 18 01:33:44 PM 2025 AUC 0.930856500168773
#
# Tue Nov 18 01:35:29 PM 2025 AUC 0.922319884523165
#
# Tue Nov 18 01:37:24 PM 2025 AUC 0.925735268952716
#
# [mbo] 0: num_leaves=40; min_child_weight=8.33; min_data_in_leaf=2174; min_gain_to_split=0.0346; lambda_l1=0.132; lambda_l2=0.295; scale_pos_weight=3.91; learning_rate=0.0561; num_iterations=800; early_stopping_rounds=293; feature_fraction=0.531; bagging_fraction=0.559 : y = 0.93 : 143.2 secs : initdesign
#
# [mbo] 0: num_leaves=35; min_child_weight=3.54; min_data_in_leaf=1721; min_gain_to_split=0.0137; lambda_l1=0.255; lambda_l2=0.305; scale_pos_weight=3.1; learning_rate=0.0246; num_iterations=2320; early_stopping_rounds=178; feature_fraction=0.596; bagging_fraction=0.743 : y = 0.929 : 260.5 secs : initdesign
#
# [mbo] 0: num_leaves=31; min_child_weight=4.51; min_data_in_leaf=4035; min_gain_to_split=0.0454; lambda_l1=0.308; lambda_l2=0.335; scale_pos_weight=2.59; learning_rate=0.0668; num_iterations=2166; early_stopping_rounds=431; feature_fraction=0.415; bagging_fraction=0.787 : y = 0.925 : 208.7 secs : initdesign
#
# [mbo] 0: num_leaves=28; min_child_weight=7.35; min_data_in_leaf=1931; min_gain_to_split=0.0661; lambda_l1=0.18; lambda_l2=0.275; scale_pos_weight=2.85; learning_rate=0.0479; num_iterations=3498; early_stopping_rounds=317; feature_fraction=0.502; bagging_fraction=0.834 : y = 0.926 : 176.0 secs : initdesign
#
# [mbo] 0: num_leaves=23; min_child_weight=2.76; min_data_in_leaf=6859; min_gain_to_split=0.0292; lambda_l1=0.137; lambda_l2=0.318; scale_pos_weight=2.58; learning_rate=0.0457; num_iterations=2007; early_stopping_rounds=412; feature_fraction=0.729; bagging_fraction=0.66 : y = 0.928 : 207.0 secs : initdesign
#
# [mbo] 0: num_leaves=41; min_child_weight=8.83; min_data_in_leaf=5620; min_gain_to_split=0.0384; lambda_l1=0.193; lambda_l2=0.2; scale_pos_weight=4.39; learning_rate=0.0859; num_iterations=2067; early_stopping_rounds=335; feature_fraction=0.369; bagging_fraction=0.695 : y = 0.928 : 197.2 secs : initdesign
#
# [mbo] 0: num_leaves=44; min_child_weight=3.25; min_data_in_leaf=4738; min_gain_to_split=0.0193; lambda_l1=0.17; lambda_l2=0.392; scale_pos_weight=3.7; learning_rate=0.0506; num_iterations=318; early_stopping_rounds=221; feature_fraction=0.606; bagging_fraction=0.729 : y = 0.919 : 46.3 secs : initdesign
#
# [mbo] 0: num_leaves=12; min_child_weight=9.07; min_data_in_leaf=5355; min_gain_to_split=0.0482; lambda_l1=0.0943; lambda_l2=0.0787; scale_pos_weight=2.74; learning_rate=0.0578; num_iterations=281; early_stopping_rounds=204; feature_fraction=0.556; bagging_fraction=0.547 : y = 0.915 : 43.4 secs : initdesign
#
# [mbo] 0: num_leaves=42; min_child_weight=5.01; min_data_in_leaf=1286; min_gain_to_split=0.0512; lambda_l1=0.24; lambda_l2=0.433; scale_pos_weight=3.2; learning_rate=0.0409; num_iterations=3305; early_stopping_rounds=375; feature_fraction=0.613; bagging_fraction=0.717 : y = 0.928 : 179.9 secs : initdesign
#
# [mbo] 0: num_leaves=58; min_child_weight=7.05; min_data_in_leaf=6053; min_gain_to_split=0.0567; lambda_l1=0.148; lambda_l2=0.117; scale_pos_weight=1.73; learning_rate=0.0737; num_iterations=1899; early_stopping_rounds=273; feature_fraction=0.67; bagging_fraction=0.589 : y = 0.925 : 161.5 secs : initdesign
#
# [mbo] 0: num_leaves=30; min_child_weight=7.74; min_data_in_leaf=7425; min_gain_to_split=0.0104; lambda_l1=0.353; lambda_l2=0.254; scale_pos_weight=3.58; learning_rate=0.0795; num_iterations=4567; early_stopping_rounds=381; feature_fraction=0.495; bagging_fraction=0.536 : y = 0.923 : 257.5 secs : initdesign
#
# [mbo] 0: num_leaves=55; min_child_weight=8.7; min_data_in_leaf=5020; min_gain_to_split=0.0842; lambda_l1=0.215; lambda_l2=0.403; scale_pos_weight=3.29; learning_rate=0.063; num_iterations=1389; early_stopping_rounds=477; feature_fraction=0.399; bagging_fraction=0.615 : y = 0.927 : 194.5 secs : initdesign
#
# [mbo] 0: num_leaves=27; min_child_weight=2.04; min_data_in_leaf=6332; min_gain_to_split=0.0629; lambda_l1=0.206; lambda_l2=0.448; scale_pos_weight=2.42; learning_rate=0.0943; num_iterations=2834; early_stopping_rounds=61; feature_fraction=0.678; bagging_fraction=0.771 : y = 0.916 : 22.6 secs : initdesign
#
# [mbo] 0: num_leaves=25; min_child_weight=7.2; min_data_in_leaf=7120; min_gain_to_split=0.067; lambda_l1=0.124; lambda_l2=0.00766; scale_pos_weight=1.34; learning_rate=0.034; num_iterations=2669; early_stopping_rounds=166; feature_fraction=0.51; bagging_fraction=0.833 : y = 0.926 : 291.4 secs : initdesign
#
# [mbo] 0: num_leaves=21; min_child_weight=6.18; min_data_in_leaf=5154; min_gain_to_split=0.0368; lambda_l1=0.285; lambda_l2=0.363; scale_pos_weight=4.14; learning_rate=0.02; num_iterations=1486; early_stopping_rounds=466; feature_fraction=0.337; bagging_fraction=0.801 : y = 0.925 : 187.3 secs : initdesign
#
# [mbo] 0: num_leaves=11; min_child_weight=5.85; min_data_in_leaf=2847; min_gain_to_split=0.00397; lambda_l1=0.392; lambda_l2=0.479; scale_pos_weight=2; learning_rate=0.0394; num_iterations=200; early_stopping_rounds=245; feature_fraction=0.758; bagging_fraction=0.627 : y = 0.912 : 18.1 secs : initdesign
#
# [mbo] 0: num_leaves=15; min_child_weight=2.1; min_data_in_leaf=2703; min_gain_to_split=0.0282; lambda_l1=0.106; lambda_l2=0.414; scale_pos_weight=3.35; learning_rate=0.0623; num_iterations=2478; early_stopping_rounds=279; feature_fraction=0.454; bagging_fraction=0.776 : y = 0.921 : 153.4 secs : initdesign
#
# [mbo] 0: num_leaves=54; min_child_weight=9.22; min_data_in_leaf=6302; min_gain_to_split=0.0588; lambda_l1=0.47; lambda_l2=0.217; scale_pos_weight=3.42; learning_rate=0.0778; num_iterations=465; early_stopping_rounds=236; feature_fraction=0.695; bagging_fraction=0.572 : y = 0.924 : 51.4 secs : initdesign
#
# [mbo] 0: num_leaves=61; min_child_weight=7.51; min_data_in_leaf=4265; min_gain_to_split=0.069; lambda_l1=0.439; lambda_l2=0.128; scale_pos_weight=1.52; learning_rate=0.0174; num_iterations=2385; early_stopping_rounds=58; feature_fraction=0.426; bagging_fraction=0.735 : y = 0.925 : 152.1 secs : initdesign
#
# [mbo] 0: num_leaves=56; min_child_weight=2.54; min_data_in_leaf=3560; min_gain_to_split=0.0559; lambda_l1=0.00334; lambda_l2=0.438; scale_pos_weight=1.89; learning_rate=0.0113; num_iterations=1251; early_stopping_rounds=362; feature_fraction=0.648; bagging_fraction=0.681 : y = 0.922 : 153.2 secs : initdesign
#
# [mbo] 0: num_leaves=24; min_child_weight=5.56; min_data_in_leaf=1168; min_gain_to_split=0.0766; lambda_l1=0.0234; lambda_l2=0.155; scale_pos_weight=1.98; learning_rate=0.0716; num_iterations=4003; early_stopping_rounds=393; feature_fraction=0.543; bagging_fraction=0.558 : y = 0.923 : 142.5 secs : initdesign
#
# [mbo] 0: num_leaves=19; min_child_weight=6.67; min_data_in_leaf=7664; min_gain_to_split=0.0774; lambda_l1=0.327; lambda_l2=0.379; scale_pos_weight=2.1; learning_rate=0.0538; num_iterations=3387; early_stopping_rounds=211; feature_fraction=0.48; bagging_fraction=0.599 : y = 0.919 : 121.4 secs : initdesign
#
# [mbo] 0: num_leaves=34; min_child_weight=6.62; min_data_in_leaf=2506; min_gain_to_split=0.0406; lambda_l1=0.0859; lambda_l2=0.17; scale_pos_weight=3.04; learning_rate=0.0155; num_iterations=4431; early_stopping_rounds=142; feature_fraction=0.382; bagging_fraction=0.892 : y = 0.928 : 355.5 secs : initdesign
#
# [mbo] 0: num_leaves=47; min_child_weight=1.37; min_data_in_leaf=4492; min_gain_to_split=0.061; lambda_l1=0.0534; lambda_l2=0.234; scale_pos_weight=4.77; learning_rate=0.0972; num_iterations=3653; early_stopping_rounds=101; feature_fraction=0.625; bagging_fraction=0.608 : y = 0.923 : 96.3 secs : initdesign
#
# [mbo] 0: num_leaves=17; min_child_weight=3.94; min_data_in_leaf=3640; min_gain_to_split=0.0925; lambda_l1=0.235; lambda_l2=0.0533; scale_pos_weight=2.94; learning_rate=0.0839; num_iterations=852; early_stopping_rounds=149; feature_fraction=0.7; bagging_fraction=0.65 : y = 0.922 : 72.4 secs : initdesign
#
# [mbo] 0: num_leaves=3; min_child_weight=9.53; min_data_in_leaf=613; min_gain_to_split=0.012; lambda_l1=0.271; lambda_l2=0.158; scale_pos_weight=4.61; learning_rate=0.0324; num_iterations=3088; early_stopping_rounds=295; feature_fraction=0.66; bagging_fraction=0.817 : y = 0.913 : 104.8 secs : initdesign
#
# [mbo] 0: num_leaves=45; min_child_weight=4.01; min_data_in_leaf=5813; min_gain_to_split=0.0215; lambda_l1=0.362; lambda_l2=0.27; scale_pos_weight=1.65; learning_rate=0.0433; num_iterations=3216; early_stopping_rounds=306; feature_fraction=0.759; bagging_fraction=0.687 : y = 0.927 : 208.9 secs : initdesign
#
# [mbo] 0: num_leaves=61; min_child_weight=5.78; min_data_in_leaf=3338; min_gain_to_split=0.0533; lambda_l1=0.0519; lambda_l2=0.023; scale_pos_weight=3.97; learning_rate=0.0651; num_iterations=1691; early_stopping_rounds=400; feature_fraction=0.302; bagging_fraction=0.821 : y = 0.93 : 171.5 secs : initdesign
#
# [mbo] 0: num_leaves=38; min_child_weight=3.64; min_data_in_leaf=4290; min_gain_to_split=0.025; lambda_l1=0.373; lambda_l2=0.426; scale_pos_weight=4.89; learning_rate=0.0498; num_iterations=2601; early_stopping_rounds=73; feature_fraction=0.407; bagging_fraction=0.526 : y = 0.927 : 164.2 secs : initdesign
#
# [mbo] 0: num_leaves=49; min_child_weight=0.636; min_data_in_leaf=6551; min_gain_to_split=0.0874; lambda_l1=0.228; lambda_l2=0.0868; scale_pos_weight=1.28; learning_rate=0.0748; num_iterations=918; early_stopping_rounds=79; feature_fraction=0.459; bagging_fraction=0.889 : y = 0.923 : 71.2 secs : initdesign
#
# [mbo] 0: num_leaves=21; min_child_weight=0.0748; min_data_in_leaf=3208; min_gain_to_split=0.0331; lambda_l1=0.406; lambda_l2=0.473; scale_pos_weight=4.93; learning_rate=0.0266; num_iterations=4378; early_stopping_rounds=423; feature_fraction=0.362; bagging_fraction=0.842 : y = 0.926 : 446.6 secs : initdesign
#
# [mbo] 0: num_leaves=3; min_child_weight=6.39; min_data_in_leaf=893; min_gain_to_split=0.0167; lambda_l1=0.339; lambda_l2=0.465; scale_pos_weight=2.31; learning_rate=0.0884; num_iterations=3942; early_stopping_rounds=357; feature_fraction=0.721; bagging_fraction=0.579 : y = 0.916 : 58.3 secs : initdesign
#
# [mbo] 0: num_leaves=59; min_child_weight=10; min_data_in_leaf=3862; min_gain_to_split=0.0424; lambda_l1=0.317; lambda_l2=0.0684; scale_pos_weight=2.19; learning_rate=0.0294; num_iterations=2897; early_stopping_rounds=438; feature_fraction=0.438; bagging_fraction=0.515 : y = 0.928 : 391.9 secs : initdesign
#
# [mbo] 0: num_leaves=6; min_child_weight=0.884; min_data_in_leaf=8145; min_gain_to_split=0.0148; lambda_l1=0.0146; lambda_l2=0.0495; scale_pos_weight=1.12; learning_rate=0.0923; num_iterations=1566; early_stopping_rounds=184; feature_fraction=0.47; bagging_fraction=0.634 : y = 0.913 : 79.2 secs : initdesign
#
# [mbo] 0: num_leaves=46; min_child_weight=0.443; min_data_in_leaf=2368; min_gain_to_split=0.089; lambda_l1=0.495; lambda_l2=0.221; scale_pos_weight=1.78; learning_rate=0.0222; num_iterations=3721; early_stopping_rounds=127; feature_fraction=0.574; bagging_fraction=0.52 : y = 0.93 : 299.0 secs : initdesign
#
# [mbo] 0: num_leaves=31; min_child_weight=3.12; min_data_in_leaf=192; min_gain_to_split=0.0713; lambda_l1=0.383; lambda_l2=0.495; scale_pos_weight=4.24; learning_rate=0.0381; num_iterations=1110; early_stopping_rounds=155; feature_fraction=0.747; bagging_fraction=0.86 : y = 0.924 : 45.4 secs : initdesign
#
# [mbo] 0: num_leaves=14; min_child_weight=8.32; min_data_in_leaf=804; min_gain_to_split=0.0975; lambda_l1=0.0679; lambda_l2=0.105; scale_pos_weight=4.3; learning_rate=0.01; num_iterations=3000; early_stopping_rounds=197; feature_fraction=0.784; bagging_fraction=0.618 : y = 0.923 : 150.8 secs : initdesign
#
# [mbo] 0: num_leaves=11; min_child_weight=4.18; min_data_in_leaf=7248; min_gain_to_split=0.0743; lambda_l1=0.0331; lambda_l2=0.18; scale_pos_weight=4.48; learning_rate=0.0366; num_iterations=4846; early_stopping_rounds=457; feature_fraction=0.384; bagging_fraction=0.707 : y = 0.925 : 542.7 secs : initdesign
#
# [mbo] 0: num_leaves=7; min_child_weight=4.66; min_data_in_leaf=5763; min_gain_to_split=0.0943; lambda_l1=0.486; lambda_l2=0.344; scale_pos_weight=1.2; learning_rate=0.0702; num_iterations=1766; early_stopping_rounds=452; feature_fraction=0.344; bagging_fraction=0.798 : y = 0.922 : 194.6 secs : initdesign
#
# [mbo] 0: num_leaves=17; min_child_weight=1.66; min_data_in_leaf=2930; min_gain_to_split=0.0266; lambda_l1=0.448; lambda_l2=0.1; scale_pos_weight=3.82; learning_rate=0.00727; num_iterations=4778; early_stopping_rounds=115; feature_fraction=0.799; bagging_fraction=0.858 : y = 0.919 : 208.0 secs : initdesign
#
# [mbo] 0: num_leaves=63; min_child_weight=1.74; min_data_in_leaf=6819; min_gain_to_split=0.0817; lambda_l1=0.398; lambda_l2=0.283; scale_pos_weight=4.07; learning_rate=0.0992; num_iterations=4126; early_stopping_rounds=348; feature_fraction=0.323; bagging_fraction=0.867 : y = 0.922 : 76.3 secs : initdesign
#
# [mbo] 0: num_leaves=53; min_child_weight=2.41; min_data_in_leaf=1500; min_gain_to_split=0.00473; lambda_l1=0.164; lambda_l2=0.136; scale_pos_weight=1.42; learning_rate=0.0809; num_iterations=4936; early_stopping_rounds=96; feature_fraction=0.565; bagging_fraction=0.761 : y = 0.928 : 93.3 secs : initdesign
#
# [mbo] 0: num_leaves=9; min_child_weight=0.227; min_data_in_leaf=396; min_gain_to_split=0.00767; lambda_l1=0.431; lambda_l2=0.326; scale_pos_weight=2.78; learning_rate=0.0133; num_iterations=1135; early_stopping_rounds=482; feature_fraction=0.638; bagging_fraction=0.652 : y = 0.915 : 74.1 secs : initdesign
#
# [mbo] 0: num_leaves=51; min_child_weight=5.24; min_data_in_leaf=7956; min_gain_to_split=0.1; lambda_l1=0.423; lambda_l2=0.0348; scale_pos_weight=4.67; learning_rate=0.028; num_iterations=580; early_stopping_rounds=255; feature_fraction=0.586; bagging_fraction=0.756 : y = 0.92 : 90.0 secs : initdesign
#
# [mbo] 0: num_leaves=5; min_child_weight=8.06; min_data_in_leaf=1538; min_gain_to_split=0.0793; lambda_l1=0.463; lambda_l2=0.24; scale_pos_weight=4.5; learning_rate=0.0867; num_iterations=4633; early_stopping_rounds=112; feature_fraction=0.311; bagging_fraction=0.669 : y = 0.92 : 140.3 secs : initdesign
#
# [mbo] 0: num_leaves=38; min_child_weight=4.94; min_data_in_leaf=54; min_gain_to_split=0.091; lambda_l1=0.301; lambda_l2=0.191; scale_pos_weight=1.05; learning_rate=0.00679; num_iterations=3795; early_stopping_rounds=499; feature_fraction=0.771; bagging_fraction=0.878 : y = 0.931 : 330.8 secs : initdesign
#
# [mbo] 0: num_leaves=51; min_child_weight=1.13; min_data_in_leaf=7811; min_gain_to_split=0.000739; lambda_l1=0.277; lambda_l2=0.019; scale_pos_weight=3.63; learning_rate=0.0914; num_iterations=4282; early_stopping_rounds=330; feature_fraction=0.714; bagging_fraction=0.505 : y = 0.922 : 105.3 secs : initdesign
#
# [mbo] 0: num_leaves=36; min_child_weight=9.72; min_data_in_leaf=4942; min_gain_to_split=0.0472; lambda_l1=0.0751; lambda_l2=0.374; scale_pos_weight=2.4; learning_rate=0.0594; num_iterations=697; early_stopping_rounds=264; feature_fraction=0.529; bagging_fraction=0.713 : y = 0.926 : 115.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Nov 18 01:40:48 PM 2025 AUC 0.929847554203584
#
# [mbo] 1: num_leaves=39; min_child_weight=8.58; min_data_in_leaf=1194; min_gain_to_split=0.0437; lambda_l1=0.218; lambda_l2=0.226; scale_pos_weight=3.77; learning_rate=0.0393; num_iterations=2400; early_stopping_rounds=340; feature_fraction=0.458; bagging_fraction=0.527 : y = 0.93 : 201.6 secs : infill_ei
#
# Tue Nov 18 01:42:38 PM 2025 AUC 0.928476904297432
#
# [mbo] 2: num_leaves=44; min_child_weight=9.22; min_data_in_leaf=1619; min_gain_to_split=0.0431; lambda_l1=0.0455; lambda_l2=0.198; scale_pos_weight=4.6; learning_rate=0.0725; num_iterations=1294; early_stopping_rounds=354; feature_fraction=0.34; bagging_fraction=0.547 : y = 0.928 : 108.5 secs : infill_ei
#
# Tue Nov 18 01:46:38 PM 2025 AUC 0.929250977573685
#
# [mbo] 3: num_leaves=40; min_child_weight=8.15; min_data_in_leaf=2356; min_gain_to_split=0.0554; lambda_l1=0.31; lambda_l2=0.0622; scale_pos_weight=2.29; learning_rate=0.0375; num_iterations=2596; early_stopping_rounds=247; feature_fraction=0.512; bagging_fraction=0.573 : y = 0.929 : 239.9 secs : infill_ei
#
# Tue Nov 18 01:53:12 PM 2025 AUC 0.929402973756668
#
# [mbo] 4: num_leaves=40; min_child_weight=1.64; min_data_in_leaf=1743; min_gain_to_split=0.0863; lambda_l1=0.397; lambda_l2=0.186; scale_pos_weight=1.39; learning_rate=0.0115; num_iterations=3690; early_stopping_rounds=308; feature_fraction=0.731; bagging_fraction=0.746 : y = 0.929 : 392.5 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Tue Nov 18 01:56:57 PM 2025 AUC 0.926005372544993
#
# [mbo] 5: num_leaves=38; min_child_weight=7.83; min_data_in_leaf=2142; min_gain_to_split=0.0305; lambda_l1=0.119; lambda_l2=0.131; scale_pos_weight=3.75; learning_rate=0.0545; num_iterations=1456; early_stopping_rounds=390; feature_fraction=0.538; bagging_fraction=0.603 : y = 0.926 : 224.6 secs : infill_ei
#
# Tue Nov 18 01:59:29 PM 2025 AUC 0.929347610908561
#
# [mbo] 6: num_leaves=42; min_child_weight=7.8; min_data_in_leaf=799; min_gain_to_split=0.0754; lambda_l1=0.266; lambda_l2=0.278; scale_pos_weight=1.56; learning_rate=0.03; num_iterations=2913; early_stopping_rounds=295; feature_fraction=0.652; bagging_fraction=0.569 : y = 0.929 : 151.1 secs : infill_ei
#
# Tue Nov 18 02:01:31 PM 2025 AUC 0.932483161305865
#
# [mbo] 7: num_leaves=41; min_child_weight=7.78; min_data_in_leaf=697; min_gain_to_split=0.0649; lambda_l1=0.409; lambda_l2=0.24; scale_pos_weight=3.03; learning_rate=0.0212; num_iterations=3372; early_stopping_rounds=154; feature_fraction=0.41; bagging_fraction=0.714 : y = 0.932 : 120.5 secs : infill_ei
#
# Tue Nov 18 02:05:51 PM 2025 AUC 0.926791860520518
#
# [mbo] 8: num_leaves=40; min_child_weight=8.2; min_data_in_leaf=1530; min_gain_to_split=0.0522; lambda_l1=0.21; lambda_l2=0.255; scale_pos_weight=3.67; learning_rate=0.0253; num_iterations=3576; early_stopping_rounds=133; feature_fraction=0.413; bagging_fraction=0.535 : y = 0.927 : 259.2 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Tue Nov 18 02:09:06 PM 2025 AUC 0.928921484744348
#
# [mbo] 9: num_leaves=41; min_child_weight=7.54; min_data_in_leaf=744; min_gain_to_split=0.0443; lambda_l1=0.473; lambda_l2=0.255; scale_pos_weight=2.7; learning_rate=0.0482; num_iterations=2461; early_stopping_rounds=261; feature_fraction=0.473; bagging_fraction=0.732 : y = 0.929 : 194.6 secs : infill_ei
#
# Tue Nov 18 02:11:54 PM 2025 AUC 0.927998435076827
#
# [mbo] 10: num_leaves=45; min_child_weight=5.82; min_data_in_leaf=240; min_gain_to_split=0.081; lambda_l1=0.478; lambda_l2=0.196; scale_pos_weight=1.55; learning_rate=0.0204; num_iterations=3464; early_stopping_rounds=178; feature_fraction=0.307; bagging_fraction=0.7 : y = 0.928 : 165.7 secs : infill_ei
#
# Tue Nov 18 02:18:11 PM 2025 AUC 0.929998208256916
#
# [mbo] 11: num_leaves=39; min_child_weight=7.64; min_data_in_leaf=1773; min_gain_to_split=0.0214; lambda_l1=0.477; lambda_l2=0.1; scale_pos_weight=2.44; learning_rate=0.019; num_iterations=3246; early_stopping_rounds=147; feature_fraction=0.571; bagging_fraction=0.755 : y = 0.93 : 376.4 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Tue Nov 18 02:23:36 PM 2025 AUC 0.927847109958669
#
# [mbo] 12: num_leaves=39; min_child_weight=9.45; min_data_in_leaf=3442; min_gain_to_split=0.0683; lambda_l1=0.43; lambda_l2=0.198; scale_pos_weight=3.92; learning_rate=0.0145; num_iterations=3481; early_stopping_rounds=228; feature_fraction=0.384; bagging_fraction=0.717 : y = 0.928 : 323.6 secs : infill_ei
#
# Tue Nov 18 02:29:01 PM 2025 AUC 0.93075181405599
#
# [mbo] 13: num_leaves=41; min_child_weight=6.18; min_data_in_leaf=428; min_gain_to_split=0.0935; lambda_l1=0.281; lambda_l2=0.0868; scale_pos_weight=3.73; learning_rate=0.011; num_iterations=3157; early_stopping_rounds=126; feature_fraction=0.454; bagging_fraction=0.833 : y = 0.931 : 324.3 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Tue Nov 18 02:36:52 PM 2025 AUC 0.934924830673568
#
# [mbo] 14: num_leaves=45; min_child_weight=2.43; min_data_in_leaf=441; min_gain_to_split=0.061; lambda_l1=0.308; lambda_l2=0.209; scale_pos_weight=2.88; learning_rate=0.0121; num_iterations=3219; early_stopping_rounds=90; feature_fraction=0.549; bagging_fraction=0.732 : y = 0.935 : 469.3 secs : infill_ei
#
# Tue Nov 18 02:37:49 PM 2025 AUC 0.924410586987114
#
# [mbo] 15: num_leaves=44; min_child_weight=3.55; min_data_in_leaf=585; min_gain_to_split=0.0572; lambda_l1=0.397; lambda_l2=0.249; scale_pos_weight=1.9; learning_rate=0.0258; num_iterations=4584; early_stopping_rounds=87; feature_fraction=0.451; bagging_fraction=0.76 : y = 0.924 : 56.1 secs : infill_ei
#
# Tue Nov 18 02:43:30 PM 2025 AUC 0.92979621774443
#
# [mbo] 16: num_leaves=45; min_child_weight=3.24; min_data_in_leaf=244; min_gain_to_split=0.0847; lambda_l1=0.279; lambda_l2=0.178; scale_pos_weight=2.91; learning_rate=0.0101; num_iterations=2671; early_stopping_rounds=233; feature_fraction=0.5; bagging_fraction=0.87 : y = 0.93 : 339.1 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Tue Nov 18 02:46:39 PM 2025 AUC 0.926893526841586
#
# [mbo] 17: num_leaves=49; min_child_weight=7.2; min_data_in_leaf=1133; min_gain_to_split=0.0369; lambda_l1=0.291; lambda_l2=0.19; scale_pos_weight=3.31; learning_rate=0.0145; num_iterations=3110; early_stopping_rounds=96; feature_fraction=0.544; bagging_fraction=0.737 : y = 0.927 : 188.3 secs : infill_ei
#
# Tue Nov 18 02:47:52 PM 2025 AUC 0.924036132814466
#
# [mbo] 18: num_leaves=44; min_child_weight=3.3; min_data_in_leaf=50; min_gain_to_split=0.0634; lambda_l1=0.193; lambda_l2=0.0673; scale_pos_weight=3.06; learning_rate=0.00777; num_iterations=687; early_stopping_rounds=179; feature_fraction=0.65; bagging_fraction=0.809 : y = 0.924 : 71.4 secs : infill_ei
#
# Tue Nov 18 02:54:28 PM 2025 AUC 0.929344255584434
#
# [mbo] 19: num_leaves=45; min_child_weight=5.38; min_data_in_leaf=631; min_gain_to_split=0.0826; lambda_l1=0.17; lambda_l2=0.463; scale_pos_weight=2.81; learning_rate=0.0056; num_iterations=3347; early_stopping_rounds=93; feature_fraction=0.441; bagging_fraction=0.646 : y = 0.929 : 393.8 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Tue Nov 18 03:01:09 PM 2025 AUC 0.930521638820832
#
# [mbo] 20: num_leaves=41; min_child_weight=5.6; min_data_in_leaf=43; min_gain_to_split=0.0511; lambda_l1=0.431; lambda_l2=0.21; scale_pos_weight=3.22; learning_rate=0.0117; num_iterations=2878; early_stopping_rounds=302; feature_fraction=0.473; bagging_fraction=0.699 : y = 0.931 : 399.5 secs : infill_ei
#
# Tue Nov 18 03:04:25 PM 2025 AUC 0.926809643738395
#
# [mbo] 21: num_leaves=42; min_child_weight=2.26; min_data_in_leaf=14; min_gain_to_split=0.0649; lambda_l1=0.17; lambda_l2=0.219; scale_pos_weight=2.76; learning_rate=0.0149; num_iterations=3194; early_stopping_rounds=157; feature_fraction=0.523; bagging_fraction=0.848 : y = 0.927 : 194.7 secs : infill_ei
#
# Tue Nov 18 03:07:46 PM 2025 AUC 0.922870828744928
#
# [mbo] 22: num_leaves=45; min_child_weight=4.54; min_data_in_leaf=2285; min_gain_to_split=0.0689; lambda_l1=0.346; lambda_l2=0.0812; scale_pos_weight=3.23; learning_rate=0.00548; num_iterations=2852; early_stopping_rounds=76; feature_fraction=0.656; bagging_fraction=0.594 : y = 0.923 : 199.9 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Tue Nov 18 03:14:00 PM 2025 AUC 0.928265518877389
#
# [mbo] 23: num_leaves=43; min_child_weight=0.234; min_data_in_leaf=272; min_gain_to_split=0.0831; lambda_l1=0.219; lambda_l2=0.128; scale_pos_weight=3.39; learning_rate=0.00528; num_iterations=3086; early_stopping_rounds=118; feature_fraction=0.523; bagging_fraction=0.729 : y = 0.928 : 373.2 secs : infill_ei
#
# Tue Nov 18 03:16:46 PM 2025 AUC 0.931287994851591
#
# [mbo] 24: num_leaves=45; min_child_weight=2.23; min_data_in_leaf=98; min_gain_to_split=0.0573; lambda_l1=0.356; lambda_l2=0.332; scale_pos_weight=3.5; learning_rate=0.0388; num_iterations=3346; early_stopping_rounds=190; feature_fraction=0.522; bagging_fraction=0.798 : y = 0.931 : 164.1 secs : infill_ei
#
# Tue Nov 18 03:22:42 PM 2025 AUC 0.929519739036311
#
# [mbo] 25: num_leaves=46; min_child_weight=1.75; min_data_in_leaf=630; min_gain_to_split=0.0537; lambda_l1=0.306; lambda_l2=0.209; scale_pos_weight=2.77; learning_rate=0.00669; num_iterations=3735; early_stopping_rounds=169; feature_fraction=0.446; bagging_fraction=0.649 : y = 0.93 : 354.8 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Tue Nov 18 03:27:20 PM 2025 AUC 0.930242140320997
#
# [mbo] 26: num_leaves=46; min_child_weight=2.32; min_data_in_leaf=531; min_gain_to_split=0.0758; lambda_l1=0.105; lambda_l2=0.328; scale_pos_weight=2.33; learning_rate=0.00795; num_iterations=3045; early_stopping_rounds=111; feature_fraction=0.478; bagging_fraction=0.743 : y = 0.93 : 276.6 secs : infill_ei
#
# Tue Nov 18 03:32:07 PM 2025 AUC 0.930700813129249
#
# [mbo] 27: num_leaves=41; min_child_weight=5.72; min_data_in_leaf=217; min_gain_to_split=0.0831; lambda_l1=0.394; lambda_l2=0.437; scale_pos_weight=4.12; learning_rate=0.00783; num_iterations=2121; early_stopping_rounds=218; feature_fraction=0.39; bagging_fraction=0.837 : y = 0.931 : 285.8 secs : infill_ei
#
# Tue Nov 18 03:37:53 PM 2025 AUC 0.928440666796853
#
# [mbo] 28: num_leaves=37; min_child_weight=2.94; min_data_in_leaf=3183; min_gain_to_split=0.0651; lambda_l1=0.386; lambda_l2=0.0245; scale_pos_weight=3.28; learning_rate=0.0174; num_iterations=3316; early_stopping_rounds=399; feature_fraction=0.677; bagging_fraction=0.69 : y = 0.928 : 344.3 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Tue Nov 18 03:42:36 PM 2025 AUC 0.928872161479671
#
# [mbo] 29: num_leaves=45; min_child_weight=2.61; min_data_in_leaf=571; min_gain_to_split=0.0646; lambda_l1=0.388; lambda_l2=0.173; scale_pos_weight=2.6; learning_rate=0.011; num_iterations=3250; early_stopping_rounds=162; feature_fraction=0.509; bagging_fraction=0.821 : y = 0.929 : 282.1 secs : infill_ei
#
# Tue Nov 18 03:54:39 PM 2025 AUC 0.932596235728968
#
# [mbo] 30: num_leaves=45; min_child_weight=2.87; min_data_in_leaf=1871; min_gain_to_split=0.0701; lambda_l1=0.488; lambda_l2=0.253; scale_pos_weight=2.82; learning_rate=0.00947; num_iterations=4197; early_stopping_rounds=275; feature_fraction=0.54; bagging_fraction=0.737 : y = 0.933 : 721.4 secs : infill_ei
#
# Saved the current state after iteration 31 in the file HT.RDATA.
#
# Tue Nov 18 03:57:17 PM 2025 AUC 0.929240240536476
#
# [mbo] 31: num_leaves=45; min_child_weight=7.72; min_data_in_leaf=422; min_gain_to_split=0.0764; lambda_l1=0.285; lambda_l2=0.341; scale_pos_weight=2.51; learning_rate=0.0415; num_iterations=1742; early_stopping_rounds=220; feature_fraction=0.55; bagging_fraction=0.672 : y = 0.929 : 156.6 secs : infill_ei
#
# Tue Nov 18 03:58:32 PM 2025 AUC 0.924625327731284
#
# [mbo] 32: num_leaves=47; min_child_weight=2.1; min_data_in_leaf=1276; min_gain_to_split=0.0372; lambda_l1=0.394; lambda_l2=0.338; scale_pos_weight=2.64; learning_rate=0.038; num_iterations=2855; early_stopping_rounds=96; feature_fraction=0.547; bagging_fraction=0.656 : y = 0.925 : 72.6 secs : infill_ei
#
# Tue Nov 18 04:09:59 PM 2025 AUC 0.926528803108909
#
# [mbo] 33: num_leaves=42; min_child_weight=2.51; min_data_in_leaf=3654; min_gain_to_split=0.0537; lambda_l1=0.323; lambda_l2=0.189; scale_pos_weight=2.77; learning_rate=0.00513; num_iterations=4324; early_stopping_rounds=139; feature_fraction=0.449; bagging_fraction=0.729 : y = 0.927 : 685.8 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Tue Nov 18 04:11:53 PM 2025 AUC 0.932591202742776
#
# [mbo] 34: num_leaves=41; min_child_weight=8.23; min_data_in_leaf=122; min_gain_to_split=0.0173; lambda_l1=0.321; lambda_l2=0.136; scale_pos_weight=2.75; learning_rate=0.0272; num_iterations=3412; early_stopping_rounds=127; feature_fraction=0.711; bagging_fraction=0.531 : y = 0.933 : 112.1 secs : infill_ei
#
# Tue Nov 18 04:14:35 PM 2025 AUC 0.931236658392437
#
# [mbo] 35: num_leaves=46; min_child_weight=4.84; min_data_in_leaf=49; min_gain_to_split=0.0628; lambda_l1=0.119; lambda_l2=0.232; scale_pos_weight=3.58; learning_rate=0.0389; num_iterations=3376; early_stopping_rounds=351; feature_fraction=0.335; bagging_fraction=0.732 : y = 0.931 : 161.1 secs : infill_ei
#
# Tue Nov 18 04:17:48 PM 2025 AUC 0.929660998182085
#
# [mbo] 36: num_leaves=44; min_child_weight=5.73; min_data_in_leaf=193; min_gain_to_split=0.0897; lambda_l1=0.363; lambda_l2=0.392; scale_pos_weight=3.12; learning_rate=0.026; num_iterations=3376; early_stopping_rounds=329; feature_fraction=0.617; bagging_fraction=0.785 : y = 0.93 : 191.2 secs : infill_ei
#
# Tue Nov 18 04:19:57 PM 2025 AUC 0.930362260924768
#
# [mbo] 37: num_leaves=47; min_child_weight=1.65; min_data_in_leaf=89; min_gain_to_split=0.0679; lambda_l1=0.263; lambda_l2=0.432; scale_pos_weight=3.16; learning_rate=0.0154; num_iterations=4028; early_stopping_rounds=63; feature_fraction=0.31; bagging_fraction=0.789 : y = 0.93 : 126.7 secs : infill_ei
#
# Tue Nov 18 04:22:28 PM 2025 AUC 0.929164410211191
#
# [mbo] 38: num_leaves=40; min_child_weight=8.33; min_data_in_leaf=62; min_gain_to_split=0.061; lambda_l1=0.323; lambda_l2=0.278; scale_pos_weight=2.81; learning_rate=0.0526; num_iterations=3134; early_stopping_rounds=159; feature_fraction=0.543; bagging_fraction=0.846 : y = 0.929 : 150.0 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Tue Nov 18 04:30:11 PM 2025 AUC 0.930235429672742
#
# [mbo] 39: num_leaves=46; min_child_weight=7.77; min_data_in_leaf=147; min_gain_to_split=0.061; lambda_l1=0.35; lambda_l2=0.312; scale_pos_weight=2.68; learning_rate=0.00597; num_iterations=3249; early_stopping_rounds=249; feature_fraction=0.485; bagging_fraction=0.715 : y = 0.93 : 461.2 secs : infill_ei
#
# Tue Nov 18 04:35:20 PM 2025 AUC 0.929252990768161
#
# [mbo] 40: num_leaves=45; min_child_weight=2.82; min_data_in_leaf=1571; min_gain_to_split=0.0536; lambda_l1=0.113; lambda_l2=0.129; scale_pos_weight=3.07; learning_rate=0.016; num_iterations=3716; early_stopping_rounds=176; feature_fraction=0.488; bagging_fraction=0.73 : y = 0.929 : 307.7 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Tue Nov 18 04:38:05 PM 2025 AUC 0.925904041756338
#
# [mbo] 41: num_leaves=47; min_child_weight=2.12; min_data_in_leaf=1233; min_gain_to_split=0.061; lambda_l1=0.498; lambda_l2=0.207; scale_pos_weight=3.1; learning_rate=0.0496; num_iterations=2642; early_stopping_rounds=440; feature_fraction=0.445; bagging_fraction=0.717 : y = 0.926 : 164.1 secs : infill_ei
#
# Tue Nov 18 04:40:03 PM 2025 AUC 0.930707523777504
#
# [mbo] 42: num_leaves=38; min_child_weight=7.46; min_data_in_leaf=153; min_gain_to_split=0.00751; lambda_l1=0.321; lambda_l2=0.278; scale_pos_weight=2.6; learning_rate=0.0173; num_iterations=3263; early_stopping_rounds=205; feature_fraction=0.752; bagging_fraction=0.65 : y = 0.931 : 115.3 secs : infill_ei
#
# Tue Nov 18 04:42:08 PM 2025 AUC 0.933081415597828
#
# [mbo] 43: num_leaves=45; min_child_weight=4.92; min_data_in_leaf=72; min_gain_to_split=0.0128; lambda_l1=0.282; lambda_l2=0.261; scale_pos_weight=1.27; learning_rate=0.0516; num_iterations=3279; early_stopping_rounds=141; feature_fraction=0.397; bagging_fraction=0.743 : y = 0.933 : 124.3 secs : infill_ei
#
# Tue Nov 18 04:44:46 PM 2025 AUC 0.925659103095018
#
# [mbo] 44: num_leaves=44; min_child_weight=7.15; min_data_in_leaf=221; min_gain_to_split=0.0451; lambda_l1=0.402; lambda_l2=0.409; scale_pos_weight=3.91; learning_rate=0.0533; num_iterations=4780; early_stopping_rounds=286; feature_fraction=0.395; bagging_fraction=0.721 : y = 0.926 : 156.2 secs : infill_ei
#
# Tue Nov 18 04:45:30 PM 2025 AUC 0.923885478761134
#
# [mbo] 45: num_leaves=41; min_child_weight=4.9; min_data_in_leaf=45; min_gain_to_split=0.00912; lambda_l1=0.315; lambda_l2=0.154; scale_pos_weight=1.31; learning_rate=0.0555; num_iterations=3569; early_stopping_rounds=162; feature_fraction=0.669; bagging_fraction=0.65 : y = 0.924 : 42.1 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Tue Nov 18 04:46:34 PM 2025 AUC 0.927575328704328
#
# [mbo] 46: num_leaves=44; min_child_weight=6.93; min_data_in_leaf=85; min_gain_to_split=0.0135; lambda_l1=0.117; lambda_l2=0.282; scale_pos_weight=2.64; learning_rate=0.0862; num_iterations=3047; early_stopping_rounds=93; feature_fraction=0.416; bagging_fraction=0.751 : y = 0.928 : 62.7 secs : infill_ei
#
# Tue Nov 18 04:50:57 PM 2025 AUC 0.929207022827612
#
# [mbo] 47: num_leaves=45; min_child_weight=3.66; min_data_in_leaf=228; min_gain_to_split=0.0942; lambda_l1=0.286; lambda_l2=0.182; scale_pos_weight=3.78; learning_rate=0.013; num_iterations=3210; early_stopping_rounds=136; feature_fraction=0.408; bagging_fraction=0.738 : y = 0.929 : 261.7 secs : infill_ei
#
# Tue Nov 18 04:56:10 PM 2025 AUC 0.931368858163067
#
# [mbo] 48: num_leaves=39; min_child_weight=8.68; min_data_in_leaf=259; min_gain_to_split=0.0192; lambda_l1=0.376; lambda_l2=0.312; scale_pos_weight=2.81; learning_rate=0.012; num_iterations=2700; early_stopping_rounds=230; feature_fraction=0.396; bagging_fraction=0.538 : y = 0.931 : 311.5 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Tue Nov 18 04:58:32 PM 2025 AUC 0.928244380335385
#
# [mbo] 49: num_leaves=45; min_child_weight=8.74; min_data_in_leaf=82; min_gain_to_split=0.00553; lambda_l1=0.317; lambda_l2=0.381; scale_pos_weight=1.56; learning_rate=0.0473; num_iterations=2638; early_stopping_rounds=328; feature_fraction=0.325; bagging_fraction=0.776 : y = 0.928 : 140.6 secs : infill_ei
#
# Tue Nov 18 05:00:35 PM 2025 AUC 0.926946876495216
#
# [mbo] 50: num_leaves=46; min_child_weight=9.05; min_data_in_leaf=534; min_gain_to_split=0.042; lambda_l1=0.307; lambda_l2=0.222; scale_pos_weight=1.07; learning_rate=0.0384; num_iterations=3184; early_stopping_rounds=125; feature_fraction=0.606; bagging_fraction=0.789 : y = 0.927 : 120.8 secs : infill_ei
#
# Tue Nov 18 05:01:55 PM 2025 AUC 0.927658540742694
#
# [mbo] 51: num_leaves=45; min_child_weight=6.89; min_data_in_leaf=67; min_gain_to_split=0.0745; lambda_l1=0.348; lambda_l2=0.254; scale_pos_weight=2.97; learning_rate=0.054; num_iterations=3662; early_stopping_rounds=64; feature_fraction=0.451; bagging_fraction=0.736 : y = 0.928 : 79.1 secs : infill_ei
#
# Tue Nov 18 05:04:09 PM 2025 AUC 0.928991275486203
#
# [mbo] 52: num_leaves=45; min_child_weight=5.68; min_data_in_leaf=165; min_gain_to_split=0.0219; lambda_l1=0.235; lambda_l2=0.306; scale_pos_weight=1.46; learning_rate=0.0444; num_iterations=2914; early_stopping_rounds=90; feature_fraction=0.377; bagging_fraction=0.506 : y = 0.929 : 131.8 secs : infill_ei
#
# Tue Nov 18 05:06:03 PM 2025 AUC 0.926494578802807
#
# [mbo] 53: num_leaves=41; min_child_weight=7.98; min_data_in_leaf=1402; min_gain_to_split=0.025; lambda_l1=0.297; lambda_l2=0.158; scale_pos_weight=3.03; learning_rate=0.0367; num_iterations=1036; early_stopping_rounds=233; feature_fraction=0.681; bagging_fraction=0.511 : y = 0.926 : 112.6 secs : infill_ei
#
# Tue Nov 18 05:15:13 PM 2025 AUC 0.931196058970493
#
# [mbo] 54: num_leaves=42; min_child_weight=2.32; min_data_in_leaf=2269; min_gain_to_split=0.0645; lambda_l1=0.489; lambda_l2=0.292; scale_pos_weight=3.95; learning_rate=0.0132; num_iterations=4094; early_stopping_rounds=381; feature_fraction=0.46; bagging_fraction=0.735 : y = 0.931 : 548.3 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Tue Nov 18 05:19:01 PM 2025 AUC 0.932277479936839
#
# [mbo] 55: num_leaves=43; min_child_weight=6.58; min_data_in_leaf=64; min_gain_to_split=0.0414; lambda_l1=0.128; lambda_l2=0.227; scale_pos_weight=2.39; learning_rate=0.0221; num_iterations=3375; early_stopping_rounds=294; feature_fraction=0.391; bagging_fraction=0.521 : y = 0.932 : 227.2 secs : infill_ei
#
# Tue Nov 18 05:21:52 PM 2025 AUC 0.928539984391032
#
# [mbo] 56: num_leaves=42; min_child_weight=0.759; min_data_in_leaf=68; min_gain_to_split=0.0835; lambda_l1=0.309; lambda_l2=0.389; scale_pos_weight=3.28; learning_rate=0.0193; num_iterations=3276; early_stopping_rounds=101; feature_fraction=0.551; bagging_fraction=0.716 : y = 0.929 : 169.7 secs : infill_ei
#
# Tue Nov 18 05:26:41 PM 2025 AUC 0.930198185574925
#
# [mbo] 57: num_leaves=45; min_child_weight=3.78; min_data_in_leaf=581; min_gain_to_split=0.0352; lambda_l1=0.274; lambda_l2=0.297; scale_pos_weight=1.53; learning_rate=0.00637; num_iterations=2989; early_stopping_rounds=202; feature_fraction=0.642; bagging_fraction=0.746 : y = 0.93 : 286.5 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Tue Nov 18 05:32:12 PM 2025 AUC 0.930036458951971
#
# [mbo] 58: num_leaves=42; min_child_weight=8.95; min_data_in_leaf=537; min_gain_to_split=0.0181; lambda_l1=0.165; lambda_l2=0.188; scale_pos_weight=2.27; learning_rate=0.0166; num_iterations=4793; early_stopping_rounds=291; feature_fraction=0.549; bagging_fraction=0.545 : y = 0.93 : 329.4 secs : infill_ei
#
# Tue Nov 18 05:35:26 PM 2025 AUC 0.930523652015308
#
# [mbo] 59: num_leaves=42; min_child_weight=7.05; min_data_in_leaf=502; min_gain_to_split=0.0229; lambda_l1=0.247; lambda_l2=0.414; scale_pos_weight=2.94; learning_rate=0.019; num_iterations=3321; early_stopping_rounds=270; feature_fraction=0.703; bagging_fraction=0.543 : y = 0.931 : 192.0 secs : infill_ei
#
# Tue Nov 18 05:40:23 PM 2025 AUC 0.92939357884911
#
# [mbo] 60: num_leaves=45; min_child_weight=5.81; min_data_in_leaf=1125; min_gain_to_split=0.0127; lambda_l1=0.408; lambda_l2=0.397; scale_pos_weight=1.59; learning_rate=0.0135; num_iterations=3276; early_stopping_rounds=188; feature_fraction=0.323; bagging_fraction=0.735 : y = 0.929 : 295.1 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Tue Nov 18 05:47:22 PM 2025 AUC 0.931707074835136
#
# [mbo] 61: num_leaves=45; min_child_weight=5.19; min_data_in_leaf=723; min_gain_to_split=0.0118; lambda_l1=0.216; lambda_l2=0.0985; scale_pos_weight=3.72; learning_rate=0.011; num_iterations=2975; early_stopping_rounds=280; feature_fraction=0.403; bagging_fraction=0.852 : y = 0.932 : 418.0 secs : infill_ei
#
# Tue Nov 18 05:52:02 PM 2025 AUC 0.930162283606759
#
# [mbo] 62: num_leaves=40; min_child_weight=7.52; min_data_in_leaf=26; min_gain_to_split=0.0316; lambda_l1=0.227; lambda_l2=0.317; scale_pos_weight=3.73; learning_rate=0.00932; num_iterations=2618; early_stopping_rounds=210; feature_fraction=0.369; bagging_fraction=0.685 : y = 0.93 : 276.5 secs : infill_ei
#
# Saved the current state after iteration 63 in the file HT.RDATA.
#
# Tue Nov 18 05:56:23 PM 2025 AUC 0.931285310592288
#
# [mbo] 63: num_leaves=41; min_child_weight=5.58; min_data_in_leaf=582; min_gain_to_split=0.0534; lambda_l1=0.208; lambda_l2=0.168; scale_pos_weight=2.42; learning_rate=0.021; num_iterations=2636; early_stopping_rounds=451; feature_fraction=0.447; bagging_fraction=0.871 : y = 0.931 : 258.8 secs : infill_ei
#
# Tue Nov 18 06:00:55 PM 2025 AUC 0.935574085892271
#
# [mbo] 64: num_leaves=45; min_child_weight=1.67; min_data_in_leaf=197; min_gain_to_split=0.00982; lambda_l1=0.411; lambda_l2=0.231; scale_pos_weight=2.4; learning_rate=0.0208; num_iterations=3331; early_stopping_rounds=160; feature_fraction=0.422; bagging_fraction=0.742 : y = 0.936 : 270.5 secs : infill_ei
#
# Tue Nov 18 06:09:48 PM 2025 AUC 0.931830886295447
#
# [mbo] 65: num_leaves=45; min_child_weight=2.2; min_data_in_leaf=2242; min_gain_to_split=0.029; lambda_l1=0.495; lambda_l2=0.285; scale_pos_weight=3.76; learning_rate=0.0157; num_iterations=3446; early_stopping_rounds=282; feature_fraction=0.425; bagging_fraction=0.771 : y = 0.932 : 531.7 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Tue Nov 18 06:11:19 PM 2025 AUC 0.92877989006616
#
# [mbo] 66: num_leaves=41; min_child_weight=8.5; min_data_in_leaf=25; min_gain_to_split=0.000792; lambda_l1=0.434; lambda_l2=0.172; scale_pos_weight=2.74; learning_rate=0.0704; num_iterations=3225; early_stopping_rounds=152; feature_fraction=0.548; bagging_fraction=0.621 : y = 0.929 : 88.8 secs : infill_ei
#
# Tue Nov 18 06:15:56 PM 2025 AUC 0.927123702076744
#
# [mbo] 67: num_leaves=44; min_child_weight=4.67; min_data_in_leaf=826; min_gain_to_split=0.0142; lambda_l1=0.307; lambda_l2=0.275; scale_pos_weight=2.22; learning_rate=0.0316; num_iterations=3140; early_stopping_rounds=202; feature_fraction=0.416; bagging_fraction=0.769 : y = 0.927 : 274.3 secs : infill_ei
#
# Tue Nov 18 06:20:33 PM 2025 AUC 0.926564369544662
#
# [mbo] 68: num_leaves=40; min_child_weight=6.73; min_data_in_leaf=1267; min_gain_to_split=0.0677; lambda_l1=0.451; lambda_l2=0.112; scale_pos_weight=3.62; learning_rate=0.0272; num_iterations=3322; early_stopping_rounds=403; feature_fraction=0.488; bagging_fraction=0.867 : y = 0.927 : 274.7 secs : infill_ei
#
# Saved the current state after iteration 69 in the file HT.RDATA.
#
# Tue Nov 18 06:24:10 PM 2025 AUC 0.930407557800491
#
# [mbo] 69: num_leaves=40; min_child_weight=9.97; min_data_in_leaf=430; min_gain_to_split=0.0395; lambda_l1=0.286; lambda_l2=0.145; scale_pos_weight=3.57; learning_rate=0.00646; num_iterations=3989; early_stopping_rounds=76; feature_fraction=0.781; bagging_fraction=0.541 : y = 0.93 : 215.4 secs : infill_ei
#
# Tue Nov 18 06:27:36 PM 2025 AUC 0.932262716510678
#
# [mbo] 70: num_leaves=46; min_child_weight=2.86; min_data_in_leaf=238; min_gain_to_split=0.0159; lambda_l1=0.17; lambda_l2=0.386; scale_pos_weight=3.26; learning_rate=0.0242; num_iterations=3798; early_stopping_rounds=360; feature_fraction=0.7; bagging_fraction=0.821 : y = 0.932 : 205.1 secs : infill_ei
#
# Tue Nov 18 06:30:04 PM 2025 AUC 0.925481941981077
#
# [mbo] 71: num_leaves=45; min_child_weight=0.846; min_data_in_leaf=2694; min_gain_to_split=0.00862; lambda_l1=0.105; lambda_l2=0.0515; scale_pos_weight=1.83; learning_rate=0.0268; num_iterations=3358; early_stopping_rounds=82; feature_fraction=0.395; bagging_fraction=0.814 : y = 0.925 : 144.6 secs : infill_ei
#
# Tue Nov 18 06:36:18 PM 2025 AUC 0.932528793714002
#
# [mbo] 72: num_leaves=47; min_child_weight=1.71; min_data_in_leaf=117; min_gain_to_split=0.0206; lambda_l1=0.359; lambda_l2=0.149; scale_pos_weight=3.28; learning_rate=0.0122; num_iterations=3498; early_stopping_rounds=300; feature_fraction=0.465; bagging_fraction=0.773 : y = 0.933 : 372.6 secs : infill_ei
#
# Saved the current state after iteration 73 in the file HT.RDATA.
#
# Tue Nov 18 06:38:45 PM 2025 AUC 0.931360469852748
#
# [mbo] 73: num_leaves=47; min_child_weight=5.28; min_data_in_leaf=21; min_gain_to_split=0.0335; lambda_l1=0.183; lambda_l2=0.188; scale_pos_weight=1.58; learning_rate=0.0675; num_iterations=3442; early_stopping_rounds=404; feature_fraction=0.52; bagging_fraction=0.801 : y = 0.931 : 143.2 secs : infill_ei
#
# Tue Nov 18 06:39:28 PM 2025 AUC 0.928239347349193
#
# [mbo] 74: num_leaves=46; min_child_weight=1.76; min_data_in_leaf=472; min_gain_to_split=0.0213; lambda_l1=0.412; lambda_l2=0.165; scale_pos_weight=2.09; learning_rate=0.0808; num_iterations=3368; early_stopping_rounds=73; feature_fraction=0.34; bagging_fraction=0.726 : y = 0.928 : 41.9 secs : infill_ei
#
# Tue Nov 18 06:42:13 PM 2025 AUC 0.929869028278001
#
# [mbo] 75: num_leaves=46; min_child_weight=1.39; min_data_in_leaf=266; min_gain_to_split=0.0109; lambda_l1=0.455; lambda_l2=0.181; scale_pos_weight=2.82; learning_rate=0.0216; num_iterations=3418; early_stopping_rounds=207; feature_fraction=0.69; bagging_fraction=0.733 : y = 0.93 : 162.2 secs : infill_ei
#
# Tue Nov 18 06:44:10 PM 2025 AUC 0.930312266595265
#
# [mbo] 76: num_leaves=48; min_child_weight=5.48; min_data_in_leaf=107; min_gain_to_split=0.017; lambda_l1=0.109; lambda_l2=0.4; scale_pos_weight=1.15; learning_rate=0.0564; num_iterations=2432; early_stopping_rounds=145; feature_fraction=0.384; bagging_fraction=0.841 : y = 0.93 : 113.6 secs : infill_ei
#
# Tue Nov 18 06:50:31 PM 2025 AUC 0.932511010496125
#
# [mbo] 77: num_leaves=46; min_child_weight=2.44; min_data_in_leaf=393; min_gain_to_split=0.0543; lambda_l1=0.3; lambda_l2=0.416; scale_pos_weight=3.49; learning_rate=0.013; num_iterations=3245; early_stopping_rounds=332; feature_fraction=0.342; bagging_fraction=0.823 : y = 0.933 : 379.1 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Tue Nov 18 06:53:30 PM 2025 AUC 0.928780896663399
#
# [mbo] 78: num_leaves=43; min_child_weight=5.92; min_data_in_leaf=436; min_gain_to_split=0.0656; lambda_l1=0.241; lambda_l2=0.337; scale_pos_weight=4.34; learning_rate=0.0177; num_iterations=2931; early_stopping_rounds=61; feature_fraction=0.556; bagging_fraction=0.678 : y = 0.929 : 177.6 secs : infill_ei
#
# Tue Nov 18 06:57:51 PM 2025 AUC 0.930410242059793
#
# [mbo] 79: num_leaves=45; min_child_weight=5.48; min_data_in_leaf=4; min_gain_to_split=0.0112; lambda_l1=0.115; lambda_l2=0.252; scale_pos_weight=1.73; learning_rate=0.0304; num_iterations=2114; early_stopping_rounds=389; feature_fraction=0.325; bagging_fraction=0.736 : y = 0.93 : 258.6 secs : infill_ei
#
# Tue Nov 18 07:00:21 PM 2025 AUC 0.930226370297597
#
# [mbo] 80: num_leaves=41; min_child_weight=8.76; min_data_in_leaf=4; min_gain_to_split=0.00608; lambda_l1=0.408; lambda_l2=0.134; scale_pos_weight=3.08; learning_rate=0.0152; num_iterations=3224; early_stopping_rounds=267; feature_fraction=0.738; bagging_fraction=0.572 : y = 0.93 : 148.0 secs : infill_ei
#
# Tue Nov 18 07:05:23 PM 2025 AUC 0.93064511474873
#
# [mbo] 81: num_leaves=47; min_child_weight=4.9; min_data_in_leaf=5; min_gain_to_split=0.0267; lambda_l1=0.258; lambda_l2=0.357; scale_pos_weight=1.06; learning_rate=0.0155; num_iterations=3286; early_stopping_rounds=483; feature_fraction=0.506; bagging_fraction=0.862 : y = 0.931 : 299.9 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Tue Nov 18 07:09:55 PM 2025 AUC 0.930792749010347
#
# [mbo] 82: num_leaves=40; min_child_weight=7.02; min_data_in_leaf=162; min_gain_to_split=0.0461; lambda_l1=0.498; lambda_l2=0.38; scale_pos_weight=4.69; learning_rate=0.0123; num_iterations=4007; early_stopping_rounds=115; feature_fraction=0.493; bagging_fraction=0.709 : y = 0.931 : 269.8 secs : infill_ei
#
# Tue Nov 18 07:14:40 PM 2025 AUC 0.931541321823229
#
# [mbo] 83: num_leaves=45; min_child_weight=0.976; min_data_in_leaf=451; min_gain_to_split=0.0224; lambda_l1=0.353; lambda_l2=0.361; scale_pos_weight=3.3; learning_rate=0.0142; num_iterations=3317; early_stopping_rounds=304; feature_fraction=0.326; bagging_fraction=0.736 : y = 0.932 : 283.6 secs : infill_ei
#
# Tue Nov 18 07:17:51 PM 2025 AUC 0.933695439913191
#
# [mbo] 84: num_leaves=45; min_child_weight=5.49; min_data_in_leaf=43; min_gain_to_split=0.093; lambda_l1=0.0578; lambda_l2=0.224; scale_pos_weight=4.83; learning_rate=0.0123; num_iterations=2901; early_stopping_rounds=363; feature_fraction=0.713; bagging_fraction=0.854 : y = 0.934 : 188.9 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Tue Nov 18 07:23:16 PM 2025 AUC 0.931234645197961
#
# [mbo] 85: num_leaves=45; min_child_weight=5.58; min_data_in_leaf=4; min_gain_to_split=0.049; lambda_l1=0.0999; lambda_l2=0.457; scale_pos_weight=2.65; learning_rate=0.00746; num_iterations=3268; early_stopping_rounds=332; feature_fraction=0.739; bagging_fraction=0.859 : y = 0.931 : 322.3 secs : infill_ei
#
# Tue Nov 18 07:29:22 PM 2025 AUC 0.93236002091038
#
# [mbo] 86: num_leaves=45; min_child_weight=2.31; min_data_in_leaf=130; min_gain_to_split=0.0266; lambda_l1=0.311; lambda_l2=0.11; scale_pos_weight=1.34; learning_rate=0.0101; num_iterations=3036; early_stopping_rounds=217; feature_fraction=0.421; bagging_fraction=0.732 : y = 0.932 : 363.9 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Tue Nov 18 07:38:15 PM 2025 AUC 0.929767361956932
#
# [mbo] 87: num_leaves=45; min_child_weight=3.51; min_data_in_leaf=1442; min_gain_to_split=0.0144; lambda_l1=0.185; lambda_l2=0.175; scale_pos_weight=3.94; learning_rate=0.0189; num_iterations=3729; early_stopping_rounds=394; feature_fraction=0.528; bagging_fraction=0.863 : y = 0.93 : 530.8 secs : infill_ei
#
# Tue Nov 18 07:43:05 PM 2025 AUC 0.926153006806611
#
# [mbo] 88: num_leaves=47; min_child_weight=5.51; min_data_in_leaf=5034; min_gain_to_split=0.0901; lambda_l1=0.0505; lambda_l2=0.46; scale_pos_weight=2.5; learning_rate=0.0137; num_iterations=2897; early_stopping_rounds=392; feature_fraction=0.358; bagging_fraction=0.849 : y = 0.926 : 287.9 secs : infill_ei
#
# Saved the current state after iteration 89 in the file HT.RDATA.
#
# Tue Nov 18 07:45:15 PM 2025 AUC 0.928735264255262
#
# [mbo] 89: num_leaves=46; min_child_weight=5.11; min_data_in_leaf=273; min_gain_to_split=0.000806; lambda_l1=0.211; lambda_l2=0.264; scale_pos_weight=1.05; learning_rate=0.048; num_iterations=3988; early_stopping_rounds=240; feature_fraction=0.699; bagging_fraction=0.735 : y = 0.929 : 127.4 secs : infill_ei
#
# Tue Nov 18 07:49:43 PM 2025 AUC 0.928315513206891
#
# [mbo] 90: num_leaves=49; min_child_weight=2.05; min_data_in_leaf=889; min_gain_to_split=0.0248; lambda_l1=0.427; lambda_l2=0.365; scale_pos_weight=4.66; learning_rate=0.041; num_iterations=3047; early_stopping_rounds=486; feature_fraction=0.54; bagging_fraction=0.79 : y = 0.928 : 265.8 secs : infill_ei
#
# Tue Nov 18 07:52:50 PM 2025 AUC 0.929889831287592
#
# [mbo] 91: num_leaves=45; min_child_weight=7.56; min_data_in_leaf=59; min_gain_to_split=0.0238; lambda_l1=0.389; lambda_l2=0.305; scale_pos_weight=2.1; learning_rate=0.0232; num_iterations=2397; early_stopping_rounds=371; feature_fraction=0.386; bagging_fraction=0.551 : y = 0.93 : 183.8 secs : infill_ei
#
# Tue Nov 18 08:02:26 PM 2025 AUC 0.933907160865647
#
# [mbo] 92: num_leaves=45; min_child_weight=1.91; min_data_in_leaf=594; min_gain_to_split=0.0591; lambda_l1=0.364; lambda_l2=0.469; scale_pos_weight=4.46; learning_rate=0.011; num_iterations=4366; early_stopping_rounds=327; feature_fraction=0.511; bagging_fraction=0.76 : y = 0.934 : 574.0 secs : infill_ei
#
# Saved the current state after iteration 93 in the file HT.RDATA.
#
# Tue Nov 18 08:03:58 PM 2025 AUC 0.933738052529612
#
# [mbo] 93: num_leaves=45; min_child_weight=4.11; min_data_in_leaf=442; min_gain_to_split=0.0946; lambda_l1=0.205; lambda_l2=0.293; scale_pos_weight=4.42; learning_rate=0.0578; num_iterations=4023; early_stopping_rounds=429; feature_fraction=0.751; bagging_fraction=0.783 : y = 0.934 : 89.7 secs : infill_ei
#
# Tue Nov 18 08:07:52 PM 2025 AUC 0.931452070201434
#
# [mbo] 94: num_leaves=45; min_child_weight=2.28; min_data_in_leaf=155; min_gain_to_split=0.053; lambda_l1=0.384; lambda_l2=0.186; scale_pos_weight=3.81; learning_rate=0.0208; num_iterations=3459; early_stopping_rounds=287; feature_fraction=0.371; bagging_fraction=0.742 : y = 0.931 : 230.8 secs : infill_ei
#
# Tue Nov 18 08:10:28 PM 2025 AUC 0.928221228598904
#
# [mbo] 95: num_leaves=47; min_child_weight=4.6; min_data_in_leaf=32; min_gain_to_split=0.0931; lambda_l1=0.141; lambda_l2=0.267; scale_pos_weight=4.28; learning_rate=0.0488; num_iterations=3508; early_stopping_rounds=377; feature_fraction=0.576; bagging_fraction=0.838 : y = 0.928 : 154.2 secs : infill_ei
#
# Tue Nov 18 08:12:50 PM 2025 AUC 0.930994068458007
#
# [mbo] 96: num_leaves=45; min_child_weight=1.53; min_data_in_leaf=10; min_gain_to_split=0.0714; lambda_l1=0.111; lambda_l2=0.309; scale_pos_weight=1.51; learning_rate=0.0367; num_iterations=4188; early_stopping_rounds=419; feature_fraction=0.632; bagging_fraction=0.772 : y = 0.931 : 139.2 secs : infill_ei
#
# Saved the current state after iteration 97 in the file HT.RDATA.
#
# Tue Nov 18 08:21:52 PM 2025 AUC 0.927592440857379
#
# [mbo] 97: num_leaves=45; min_child_weight=3.84; min_data_in_leaf=3079; min_gain_to_split=0.0994; lambda_l1=0.399; lambda_l2=0.382; scale_pos_weight=3.28; learning_rate=0.00751; num_iterations=4452; early_stopping_rounds=415; feature_fraction=0.761; bagging_fraction=0.855 : y = 0.928 : 539.2 secs : infill_ei
#
# Tue Nov 18 08:29:46 PM 2025 AUC 0.933479357039369
#
# [mbo] 98: num_leaves=45; min_child_weight=6.1; min_data_in_leaf=401; min_gain_to_split=0.0407; lambda_l1=0.213; lambda_l2=0.0597; scale_pos_weight=3.5; learning_rate=0.0104; num_iterations=4081; early_stopping_rounds=431; feature_fraction=0.612; bagging_fraction=0.603 : y = 0.933 : 471.0 secs : infill_ei
#
# Saved the current state after iteration 99 in the file HT.RDATA.
#
# Tue Nov 18 08:34:16 PM 2025 AUC 0.931040707463382
#
# [mbo] 99: num_leaves=45; min_child_weight=6.55; min_data_in_leaf=105; min_gain_to_split=0.0297; lambda_l1=0.332; lambda_l2=0.405; scale_pos_weight=3.91; learning_rate=0.0195; num_iterations=3180; early_stopping_rounds=433; feature_fraction=0.398; bagging_fraction=0.825 : y = 0.931 : 266.3 secs : infill_ei
#
# Tue Nov 18 08:40:33 PM 2025 AUC 0.93224963074658
#
# [mbo] 100: num_leaves=45; min_child_weight=1.95; min_data_in_leaf=456; min_gain_to_split=0.0782; lambda_l1=0.0276; lambda_l2=0.0704; scale_pos_weight=4.01; learning_rate=0.0119; num_iterations=4068; early_stopping_rounds=419; feature_fraction=0.674; bagging_fraction=0.72 : y = 0.932 : 374.2 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf min_gain_to_split lambda_l1
#         <int>            <num>            <int>             <num>     <num>
# 1:         45         1.674223              197       0.009816399 0.4110179
#    lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>            <num>         <num>          <int>
# 1: 0.2312644         2.395107    0.02076664           3331
#    early_stopping_rounds feature_fraction bagging_fraction
#                    <int>            <num>            <num>
# 1:                   160        0.4224026        0.7416637

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5696400
#
# $envios
# [1] 1680

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1565114757
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 08:49:26 PM 2025"
# Inicio: Tue Nov 18 11:11:03 AM 2025
# Fin:    Tue Nov 18 08:49:26 PM 2025
# Duración (hh:mm:ss): 09:38:22
